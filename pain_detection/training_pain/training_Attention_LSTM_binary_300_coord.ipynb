# %% [markdown]
# ### Attention-LSTM model - binary training - 300 coordinates

# %% [markdown]
# #### Environment preparation

# %%
from google.colab import drive
drive.mount('/content/drive')

COLAB_ROOT = '/content/drive/MyDrive/PainRecognitionProject/'
print(f"Dane będą wczytywane z: {COLAB_ROOT}")
# Out:
# Mounted at /content/drive
# Dane będą wczytywane z: /content/drive/MyDrive/PainRecognitionProject/

# %%
import os

# %cd /content

# !rm -rf automatic-pain-recognition

print(f"Obecne położenie: {os.getcwd()}")
# Out:
# /content
# Obecne położenie: /content

# %%
USERNAME = 'alicka33'
REPO_NAME = 'automatic-pain-recognition'

REPO_URL = f"https://github.com/{USERNAME}/{REPO_NAME}.git"

print("Rozpoczynam klonowanie...")

# !git clone {REPO_URL}

# %cd $REPO_NAME
# Out:
# Rozpoczynam klonowanie...
# Cloning into 'automatic-pain-recognition'...
# remote: Enumerating objects: 321, done.
# remote: Counting objects: 100% (44/44), done.
# remote: Compressing objects: 100% (30/30), done.
# remote: Total 321 (delta 24), reused 34 (delta 14), pack-reused 277 (from 1)
# Receiving objects: 100% (321/321), 11.99 MiB | 17.25 MiB/s, done.
# Resolving deltas: 100% (148/148), done.
# /content/automatic-pain-recognition

# %%
# !pip install -r requirements.txt

# %%
import sys
import os

sys.path.append(os.getcwd())
print(f"Dodano do ścieżki Pythona: {os.getcwd()}")
# Out:
# Dodano do ścieżki Pythona: /content/automatic-pain-recognition

# %% [markdown]
# #### Attention-LSTM model - binary training

# %%
import os
import numpy as np
import pandas as pd
import shutil

import torch
import torch.nn as nn
from torch.utils.data import DataLoader
from torch.optim.lr_scheduler import ReduceLROnPlateau

from training_utils.preprocessed_dataset import PreprocessedDataset
from training_utils.train import Trainer
from training_utils.evaluate import Evaluator
from models.Attention_LSTM import AttentionSequenceModel

# %% [markdown]
# #### Hiperparameters

# %%
MAX_SEQUENCE_LENGTH = 46
NUM_FEATURES = 300
NUM_CLASSES = 2
HIDDEN_SIZE = 128
NUM_LAYERS = 2
NUM_EPOCHS = 200
BATCH_SIZE = 16
LEARNING_RATE = 0.00005
DROPOUT_PROB = 0.3
WEIGHT_DECAY = 0.005
SCHEDULER_FACTOR = 0.9

# %% [markdown]
# #### Data preparation

# %%
COLAB_ROOT = '/content/drive/MyDrive/PainRecognitionProject/'
PROCESSED_DATA_DIR = os.path.join(COLAB_ROOT, 'data/BioVid_HeatPain_processed_478_xyz_frontalized/')
MODEL_SAVE_DIR = os.path.join(COLAB_ROOT, 'models/')
LOCAL_PROCESSED_DATA_ROOT = '/content/temp_data/'

DEVICE = torch.device("cuda" if torch.cuda.is_available() else "cpu")

# %%
print("Kopiowanie danych z Google Drive do lokalnej pamięci Colab (RAM)...")
if os.path.exists(LOCAL_PROCESSED_DATA_ROOT):
    shutil.rmtree(LOCAL_PROCESSED_DATA_ROOT)
try:
    shutil.copytree(PROCESSED_DATA_DIR, LOCAL_PROCESSED_DATA_ROOT)
    print("Kopiowanie zakończone pomyślnie. Czas trwania: (sprawdź zegar)")
    CURRENT_DATA_DIR = LOCAL_PROCESSED_DATA_ROOT

except Exception as e:
    print(f"Błąd kopiowania danych (sprawdź, czy dane są zamontowane): {e}")
    print("Używam danych bezpośrednio z Drive (może się zawiesić).")
    CURRENT_DATA_DIR = PROCESSED_DATA_DIR

# %% [markdown]
# Dla 100 dystansów euklidesowych

# %%
best100 = np.load('/content/drive/MyDrive/PainRecognitionProject/data/top_100_important_landmarks_emotions.npy')

# %% [markdown]
# Dla 100 przesunięć (czyli 300 współrzędnych) -> 100 punktów każde po 3 współrzędne

# %%
best_100_landmarks = np.load('/content/drive/MyDrive/PainRecognitionProject/data/top_100_important_landmarks_emotions.npy')

feature_indices_x = best_100_landmarks * 3
feature_indices_y = best_100_landmarks * 3 + 1
feature_indices_z = best_100_landmarks * 3 + 2

# Interleave to get [X1, Y1, Z1, X2, Y2, Z2, ...]
best_300_features = np.stack([feature_indices_x, feature_indices_y, feature_indices_z], axis=1).flatten()

# %%
train_dataset = PreprocessedDataset(
    'train',
    processed_data_dir=CURRENT_DATA_DIR,
    indices=best_300_features,
    compute_euclidean=False,
    center_point_index=2,
    max_sequence_length=MAX_SEQUENCE_LENGTH,
    selected_labels=[0, 4],
    label_map={0: 0, 4: 1},
)

val_dataset = PreprocessedDataset(
    'val',
    processed_data_dir=CURRENT_DATA_DIR,
    indices=best_300_features,
    compute_euclidean=False,
    center_point_index=2,
    max_sequence_length=MAX_SEQUENCE_LENGTH,
    selected_labels=[0, 4],
    label_map={0: 0, 4: 1},
)

test_dataset = PreprocessedDataset(
    'test',
    processed_data_dir=CURRENT_DATA_DIR,
    indices=best_300_features,
    compute_euclidean=False,
    center_point_index=2,
    max_sequence_length=MAX_SEQUENCE_LENGTH,
    selected_labels=[0, 4],
    label_map={0: 0, 4: 1},
)

# %%
def preview_single(dataset, idx=0, timesteps_to_show=3, features_to_show=8):
    x, y = dataset[idx]
    print(f"\nSingle sample idx={idx} from split={dataset.dataset_name}")
    print(f"x shape: {tuple(x.shape)}, y: {y}")
    print(np.round(x[:timesteps_to_show, :features_to_show], 4))

preview_single(train_dataset, 0)
preview_single(val_dataset, 0)
preview_single(test_dataset, 0)
# Out:
# Single sample idx=0 from split=train
# x shape: (46, 300), y: 0
# tensor([[0.1507, 0.1288, 0.1142, 0.1074, 0.2043, 0.0947, 0.1404, 0.0928],
#         [0.1488, 0.1293, 0.1180, 0.1079, 0.2146, 0.1028, 0.1382, 0.0917],
#         [0.1507, 0.1252, 0.1187, 0.1093, 0.2105, 0.1028, 0.1401, 0.0886]])
#
# Single sample idx=0 from split=val
# x shape: (46, 300), y: 0
# tensor([[0.1483, 0.1156, 0.1151, 0.1027, 0.1887, 0.0901, 0.1374, 0.0823],
#         [0.1522, 0.1143, 0.1157, 0.1043, 0.1852, 0.0900, 0.1415, 0.0816],
#         [0.1524, 0.1143, 0.1155, 0.1045, 0.1854, 0.0897, 0.1416, 0.0817]])
#
# Single sample idx=0 from split=test
# x shape: (46, 300), y: 0
# tensor([[0.1401, 0.1400, 0.1036, 0.0984, 0.2080, 0.0833, 0.1307, 0.1012],
#         [0.1392, 0.1376, 0.1043, 0.0974, 0.2055, 0.0839, 0.1297, 0.0993],
#         [0.1393, 0.1381, 0.1052, 0.0976, 0.2081, 0.0852, 0.1300, 0.0995]])

# %%
train_loader = DataLoader(train_dataset, batch_size=BATCH_SIZE, shuffle=True, num_workers=0, pin_memory=True)
for X, y in train_loader:
    print(X.shape, y.shape)  # (B, T_max, num_features)
    break

val_loader = DataLoader(val_dataset, batch_size=BATCH_SIZE, shuffle=True, num_workers=0, pin_memory=True)
for X, y in val_loader:
    print(X.shape, y.shape)  # (B, T_max, num_features)
    break

test_loader = DataLoader(test_dataset, batch_size=BATCH_SIZE, shuffle=True, num_workers=0, pin_memory=True)
for X, y in test_loader:
    print(X.shape, y.shape)  # (B, T_max, num_features)
    break
# Out:
# torch.Size([16, 46, 300]) torch.Size([16])
# torch.Size([16, 46, 300]) torch.Size([16])
# torch.Size([16, 46, 300]) torch.Size([16])

# %% [markdown]
# #### Model preparation

# %%
model = AttentionSequenceModel(NUM_FEATURES, HIDDEN_SIZE, NUM_LAYERS, NUM_CLASSES, DROPOUT_PROB).to(DEVICE)

# %% [markdown]
# #### Training

# %%
criterion = nn.CrossEntropyLoss()
optimizer = torch.optim.AdamW(model.parameters(), lr=LEARNING_RATE, weight_decay=WEIGHT_DECAY)

scheduler = ReduceLROnPlateau(
    optimizer,
    mode='max',
    factor=SCHEDULER_FACTOR,
    patience=10,
    min_lr=1e-7
)

model_name = 'testing_new_code_attention_lstm_2_classes_300_coord.pt'
model_filepath = os.path.join(MODEL_SAVE_DIR, model_name)

# %%
trainer = Trainer(
    model=model,
    train_loader=train_loader,
    val_loader=val_loader,
    optimizer=optimizer,
    scheduler=scheduler,
    criterion=criterion,
    device=DEVICE,
    model_save_path=model_filepath,
    num_epochs=NUM_EPOCHS,
    monitor='val_acc',  # or 'val_loss'
    minimize_monitor=False,
    save_best_only=True
)

# %%
trainer.print_training_config()

# %%
final_model_path, best_model_path, history = trainer.fit()
print(f"Final model saved to: {final_model_path}")
if best_model_path:
    print(f"Best model saved to: {best_model_path}")
# Out:
# Starting training for 200 epochs on cuda
# Saved best model to /content/drive/MyDrive/PainRecognitionProject/models/best_testing_new_code_attention_lstm_2_classes_300_coord.pt (metric=0.4981)
# Epoch 1/200 | Time 6.34s | Train loss 0.7142 | Train acc 0.5180 | Val loss 0.6915 | Val acc 0.4981
# Saved best model to /content/drive/MyDrive/PainRecognitionProject/models/best_testing_new_code_attention_lstm_2_classes_300_coord.pt (metric=0.5000)
# Epoch 2/200 | Time 3.05s | Train loss 0.7138 | Train acc 0.5127 | Val loss 0.6973 | Val acc 0.5000
# Saved best model to /content/drive/MyDrive/PainRecognitionProject/models/best_testing_new_code_attention_lstm_2_classes_300_coord.pt (metric=0.5115)
# Epoch 3/200 | Time 2.43s | Train loss 0.7033 | Train acc 0.5197 | Val loss 0.6893 | Val acc 0.5115
# Saved best model to /content/drive/MyDrive/PainRecognitionProject/models/best_testing_new_code_attention_lstm_2_classes_300_coord.pt (metric=0.5692)
# Epoch 4/200 | Time 2.39s | Train loss 0.7034 | Train acc 0.5209 | Val loss 0.6872 | Val acc 0.5692
# Epoch 5/200 | Time 2.36s | Train loss 0.7005 | Train acc 0.5115 | Val loss 0.6865 | Val acc 0.5615
# Epoch 6/200 | Time 2.62s | Train loss 0.6969 | Train acc 0.5201 | Val loss 0.6899 | Val acc 0.5365
# Epoch 7/200 | Time 2.81s | Train loss 0.6902 | Train acc 0.5303 | Val loss 0.6939 | Val acc 0.5019
# Saved best model to /content/drive/MyDrive/PainRecognitionProject/models/best_testing_new_code_attention_lstm_2_classes_300_coord.pt (metric=0.5788)
# Epoch 8/200 | Time 2.41s | Train loss 0.6866 | Train acc 0.5488 | Val loss 0.6788 | Val acc 0.5788
# Epoch 9/200 | Time 2.37s | Train loss 0.6823 | Train acc 0.5475 | Val loss 0.6736 | Val acc 0.5615
# Saved best model to /content/drive/MyDrive/PainRecognitionProject/models/best_testing_new_code_attention_lstm_2_classes_300_coord.pt (metric=0.5808)
# Epoch 10/200 | Time 2.36s | Train loss 0.6740 | Train acc 0.5664 | Val loss 0.6818 | Val acc 0.5808
# Saved best model to /content/drive/MyDrive/PainRecognitionProject/models/best_testing_new_code_attention_lstm_2_classes_300_coord.pt (metric=0.5885)
# Epoch 11/200 | Time 2.48s | Train loss 0.6784 | Train acc 0.5738 | Val loss 0.6733 | Val acc 0.5885
# Epoch 12/200 | Time 3.10s | Train loss 0.6739 | Train acc 0.5754 | Val loss 0.6894 | Val acc 0.5654
# Epoch 13/200 | Time 2.45s | Train loss 0.6649 | Train acc 0.5730 | Val loss 0.7222 | Val acc 0.5385
# Saved best model to /content/drive/MyDrive/PainRecognitionProject/models/best_testing_new_code_attention_lstm_2_classes_300_coord.pt (metric=0.6000)
# Epoch 14/200 | Time 2.39s | Train loss 0.6665 | Train acc 0.5898 | Val loss 0.6637 | Val acc 0.6000
# Epoch 15/200 | Time 2.41s | Train loss 0.6603 | Train acc 0.5906 | Val loss 0.6582 | Val acc 0.5865
# Epoch 16/200 | Time 2.44s | Train loss 0.6553 | Train acc 0.5996 | Val loss 0.6555 | Val acc 0.5942
# Epoch 17/200 | Time 3.09s | Train loss 0.6576 | Train acc 0.6070 | Val loss 0.6756 | Val acc 0.5904
# Saved best model to /content/drive/MyDrive/PainRecognitionProject/models/best_testing_new_code_attention_lstm_2_class
# Epoch 185/200 | Time 2.95s | Train loss 0.5142 | Train acc 0.7193 | Val loss 0.5425 | Val acc 0.7538
# Epoch 186/200 | Time 2.46s | Train loss 0.5178 | Train acc 0.7225 | Val loss 0.5509 | Val acc 0.7288
# Epoch 187/200 | Time 2.40s | Train loss 0.5177 | Train acc 0.7135 | Val loss 0.5435 | Val acc 0.7481
# Epoch 188/200 | Time 2.41s | Train loss 0.5162 | Train acc 0.7135 | Val loss 0.5685 | Val acc 0.7423
# Epoch 189/200 | Time 2.38s | Train loss 0.5162 | Train acc 0.7230 | Val loss 0.5500 | Val acc 0.7327
# Epoch 190/200 | Time 2.82s | Train loss 0.5191 | Train acc 0.7238 | Val loss 0.5756 | Val acc 0.7154
# Epoch 191/200 | Time 2.65s | Train loss 0.5233 | Train acc 0.7152 | Val loss 0.5417 | Val acc 0.7500
# Epoch 192/200 | Time 2.39s | Train loss 0.5213 | Train acc 0.7160 | Val loss 0.5731 | Val acc 0.7308
# Epoch 193/200 | Time 2.39s | Train loss 0.5130 | Train acc 0.7160 | Val loss 0.6025 | Val acc 0.7192
# Epoch 194/200 | Time 2.36s | Train loss 0.5205 | Train acc 0.7225 | Val loss 0.5580 | Val acc 0.7212
# Epoch 195/200 | Time 2.67s | Train loss 0.5094 | Train acc 0.7221 | Val loss 0.5932 | Val acc 0.7288
# Epoch 196/200 | Time 2.83s | Train loss 0.5159 | Train acc 0.7217 | Val loss 0.5509 | Val acc 0.7385
# Epoch 197/200 | Time 2.38s | Train loss 0.5126 | Train acc 0.7123 | Val loss 0.5615 | Val acc 0.7365
# Epoch 198/200 | Time 2.40s | Train loss 0.5180 | Train acc 0.7127 | Val loss 0.5625 | Val acc 0.7288
# Epoch 199/200 | Time 2.37s | Train loss 0.5106 | Train acc 0.7205 | Val loss 0.5499 | Val acc 0.7365
# Epoch 200/200 | Time 2.55s | Train loss 0.5166 | Train acc 0.7189 | Val loss 0.5577 | Val acc 0.7154
# Training finished. Best epoch: 161. Best monitored metric: 0.7596
# Final model saved to: /content/drive/MyDrive/PainRecognitionProject/models/testing_new_code_attention_lstm_2_classes_300_coord.pt
# Best model saved to: /content/drive/MyDrive/PainRecognitionProject/models/best_testing_new_code_attention_lstm_2_classes_300_coord.pt

# %%
trainer.plot_history()

# %% [markdown]
# #### Evaluate

# %%
model.load_state_dict(torch.load(best_model_path, map_location=DEVICE), strict=False)
# Out:
# <All keys matched successfully>

# %%
evaluator = Evaluator(model, test_loader, device=DEVICE, model_name=model_name, num_classes=NUM_CLASSES)

# %%
loss, acc, labels, preds = evaluator.evaluate_epoch()
# Out:
# ==================================================
# WYNIKI OCENY DLA MODELU: testing_new_code_attention_lstm_2_classes_300_coord.pt
# ==================================================
# Test Loss: 0.5100
# Test Accuracy: 0.7481
#
# --- Szczegółowy Raport Klasyfikacji ---
#               precision    recall  f1-score   support
#
#      Klasa 0       0.69      0.88      0.78       260
#      Klasa 1       0.84      0.61      0.71       260
#
#     accuracy                           0.75       520
#    macro avg       0.77      0.75      0.74       520
# weighted avg       0.77      0.75      0.74       520
#
# ==================================================
# Confusion matrix:
#  [[230  30]
#  [101 159]]
