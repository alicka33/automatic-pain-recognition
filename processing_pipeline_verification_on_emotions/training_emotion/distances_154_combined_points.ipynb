# %% [markdown]
# ### Distances 154 combined points - 6 class training

# %% [markdown]
# #### Environment preparation

# %%
# Montowanie Google Drive
from google.colab import drive
drive.mount('/content/drive')

COLAB_ROOT = '/content/drive/MyDrive/PainRecognitionProject/'
print(f"Dane będą wczytywane z: {COLAB_ROOT}")
# Out:
# Mounted at /content/drive
# Dane będą wczytywane z: /content/drive/MyDrive/PainRecognitionProject/

# %%
import os

# Przejście do katalogu głównego
# %cd /content

# Klonowanie repo
# !rm -rf automatic-pain-recognition

print(f"Obecne położenie: {os.getcwd()}")
# Out:
# /content
# Obecne położenie: /content

# %%
# Upewnij się, że nazwa użytkownika i repozytorium są poprawne
USERNAME = 'alicka33'
REPO_NAME = 'automatic-pain-recognition'

# Tworzenie poprawnego adresu URL (format: https://<TOKEN>@github.com/...)
REPO_URL = f"https://github.com/{USERNAME}/{REPO_NAME}.git"

print("Rozpoczynam klonowanie...")

# Klonowanie
# !git clone {REPO_URL}

# Wejście do katalogu
# %cd $REPO_NAME
# Out:
# Rozpoczynam klonowanie...
# Cloning into 'automatic-pain-recognition'...
# remote: Enumerating objects: 241, done.
# remote: Counting objects: 100% (241/241), done.
# remote: Compressing objects: 100% (189/189), done.
# remote: Total 241 (delta 108), reused 179 (delta 48), pack-reused 0 (from 0)
# Receiving objects: 100% (241/241), 10.86 MiB | 16.67 MiB/s, done.
# Resolving deltas: 100% (108/108), done.
# /content/automatic-pain-recognition

# %%
# Instalacja wymaganych bibliotek
# !pip install -r requirements.txt
# Out:
# Requirement already satisfied: torch>=1.10.0 in /usr/local/lib/python3.12/dist-packages (from -r requirements.txt (line 2)) (2.9.0+cu126)
# Requirement already satisfied: torchvision>=0.11.0 in /usr/local/lib/python3.12/dist-packages (from -r requirements.txt (line 3)) (0.24.0+cu126)
# Requirement already satisfied: torchaudio>=0.10.0 in /usr/local/lib/python3.12/dist-packages (from -r requirements.txt (line 4)) (2.9.0+cu126)
# Requirement already satisfied: pandas>=1.3.0 in /usr/local/lib/python3.12/dist-packages (from -r requirements.txt (line 7)) (2.2.2)
# Requirement already satisfied: numpy>=1.21.0 in /usr/local/lib/python3.12/dist-packages (from -r requirements.txt (line 8)) (2.0.2)
# Requirement already satisfied: opencv-python>=4.5.5 in /usr/local/lib/python3.12/dist-packages (from -r requirements.txt (line 11)) (4.12.0.88)
# Requirement already satisfied: dlib>=19.24.2 in /usr/local/lib/python3.12/dist-packages (from -r requirements.txt (line 12)) (19.24.6)
# Requirement already satisfied: imutils>=0.5.4 in /usr/local/lib/python3.12/dist-packages (from -r requirements.txt (line 13)) (0.5.4)
# Collecting mediapipe>=0.10.15 (from -r requirements.txt (line 14))
#   Downloading mediapipe-0.10.31-py3-none-manylinux_2_28_x86_64.whl.metadata (9.7 kB)
# Requirement already satisfied: scikit-learn>=1.0.0 in /usr/local/lib/python3.12/dist-packages (from -r requirements.txt (line 17)) (1.6.1)
# Requirement already satisfied: tqdm>=4.62.3 in /usr/local/lib/python3.12/dist-packages (from -r requirements.txt (line 20)) (4.67.1)
# Requirement already satisfied: matplotlib>=3.5.0 in /usr/local/lib/python3.12/dist-packages (from -r requirements.txt (line 23)) (3.10.0)
# Requirement already satisfied: shap>=0.44.0 in /usr/local/lib/python3.12/dist-packages (from -r requirements.txt (line 26)) (0.50.0)
# Requirement already satisfied: filelock in /usr/local/lib/python3.12/dist-packages (from torch>=1.10.0->-r requirements.txt (line 2)) (3.20.0)
# Requirement already satisfied: typing-extensions>=4.10.0 in /usr/local/lib/python3.12/dist-packages (from torch>=1.10.0->-r requirements.txt (line 2)) (4.15.0)
# Requirement already satisfied: setuptools in /usr/local/lib/python3.12/dist-packages (from torch>=1.10.0->-r requirements.txt (line 2)) (75.2.0)
# Requirement already satisfied: sympy>=1.13.3 in /usr/local/lib/python3.12/dist-packages (from torch>=1.10.0->-r requirements.txt (line 2)) (1.14.0)
# Requirement already satisfied: networkx>=2.5.1 in /usr/local/lib/python3.12/dist-packages (from torch>=1.10.0->-r requirements.txt (line 2)) (3.6.1)
# Requirement already satisfied: jinja2 in /usr/local/lib/python3.12/dist-packages (from torch>=1.10.0->-r requirements.txt (line 2)) (3.1.6)
# Requirement already satisfied: fsspec>=0.8.5 in /usr/local/lib/python3.12/dist-packages (from torch>=1.10.0->-r requirements.txt (line 2)) (2025.3.0)
# Requirement already satisfied: nvidia-cuda-nvrtc-cu12==12.6.77 in /usr/local/lib/python3.12/dist-packages (from torch>=1.10.0->-r requirements.txt (line 2)) (12.6.77)
# Requirement already satisfied: nvidia-cuda-runtime-cu12==12.6.77 in /usr/local/lib/python3.12/dist-packages (from torch>=1.10.0->-r requirements.txt (line 2)) (12.6.77)
# Requirement already satisfied: nvidia-cuda-cupti-cu12==12.6.80 in /usr/local/lib/python3.12/dist-packages (from torch>=1.10.0->-r requirements.txt (line 2)) (12.6.80)
# Requirement already satisfied: nvidia-cudnn-cu12==9.10.2.21 in /usr/local/lib/python3.12/dist-packages (from torch>=1.10.0->-r requirements.txt (line 2)) (9.10.2.21)
# Requirement already satisfied: nvidia-cublas-cu12==12.6.4.1 in /usr/local/lib/python3.12/dist-packages (from torch>=1.10.0->-r requirements.txt (line 2)) (12.6.4.1)
# Requirement already satisfied: nvidia-cufft-cu12==11.3.0.4 in /usr/local/lib/python3.12/dist-packages (from torch>=1.10.0->-r requirements.txt (line 2)) (11.3.0.4)
# Requirement already satisfied: nvidia-curand-cu12==10.3.7.77 in /usr/local/lib/python3.12/dist-packages (from torch>=1.10.0->-r requirements.txt (line 2)) (10.3.7.77)
# Requirement already satisfied: nvidia-cusolver-cu12==11.7.1.2 in /usr/local/lib/python3.12/dist-packages (from torch>=1.10.0->-r requirements.txt (line 2)) (11.7.1.2)
# Requirement already satisfied: nvidia-cusparse-cu12==12.5.4.2 in /usr/local/lib/python3.12/dist-packages (from torch>=1.10.0->-r requirements.txt (line 2)) (12.5.4.2)
# Requirement already satisfied: nvidia-cusparselt-cu12==0.7.1 in /usr/local/lib/python3.12/dist-packages (from torch>=1.10.0->-r requirements.txt (line 2)) (0.7.1)
# Requirement already satisfied: nvidia-nccl-cu12==2.27.5 in /usr/local/lib/python3.12/dist-packages (from torch>=1.10.0->-r requirements.txt (line 2)) (2.27.5)
# Requirement already satisfied: nvidia-nvshmem-cu12==3.3.20 in /usr/local/lib/python3.12/dist-packages (from torch>=1.10.0->-r requirements.txt (line 2)) (3.3.20)
# Requirement already satisfied: nvidia-nvtx-cu12==12.6.77 in /usr/local/lib/python3.12/dist-packages (from torch>=1.10.0->-r requirements.txt (line 2)) (12.6.77)
# Requirement already satisfied: nvidia-nvjitlink-cu12==12.6.85 in /usr/local/lib/python3.12/dist-packages (from torch>=1.10.0->-r requirements.txt (line 2)) (12.6.85)
# Requirement already satisfied: nvidia-cufile-cu12==1.11.1.6 in /usr/local/lib/python3.12/dist-packages (from torch>=1.10.0->-r requirements.txt (line 2)) (1.11.1.6)
# Requirement already satisfied: triton==3.5.0 in /usr/local/lib/python3.12/dist-packages (from torch>=1.10.0->-r requirements.txt (line 2)) (3.5.0)
# Requirement already satisfied: pillow!=8.3.*,>=5.3.0 in /usr/local/lib/python3.12/dist-packages (from torchvision>=0.11.0->-r requirements.txt (line 3)) (11.3.0)
# Requirement already satisfied: python-dateutil>=2.8.2 in /usr/local/lib/python3.12/dist-packages (from pandas>=1.3.0->-r requirements.txt (line 7)) (2.9.0.post0)
# Requirement already satisfied: pytz>=2020.1 in /usr/local/lib/python3.12/dist-packages (from pandas>=1.3.0->-r requirements.txt (line 7)) (2025.2)
# Requirement already satisfied: tzdata>=2022.7 in /usr/local/lib/python3.12/dist-packages (from pandas>=1.3.0->-r requirements.txt (line 7)) (2025.3)
# Collecting absl-py~=2.3 (from mediapipe>=0.10.15->-r requirements.txt (line 14))
#   Downloading absl_py-2.3.1-py3-none-any.whl.metadata (3.3 kB)
# Collecting sounddevice~=0.5 (from mediapipe>=0.10.15->-r requirements.txt (line 14))
#   Downloading sounddevice-0.5.3-py3-none-any.whl.metadata (1.6 kB)
# Requirement already satisfied: flatbuffers~=25.9 in /usr/local/lib/python3.12/dist-packages (from mediapipe>=0.10.15->-r requirements.txt (line 14)) (25.9.23)
# Requirement already satisfied: scipy>=1.6.0 in /usr/local/lib/python3.12/dist-packages (from scikit-learn>=1.0.0->-r requirements.txt (line 17)) (1.16.3)
# Requirement already satisfied: joblib>=1.2.0 in /usr/local/lib/python3.12/dist-packages (from scikit-learn>=1.0.0->-r requirements.txt (line 17)) (1.5.3)
# Requirement already satisfied: threadpoolctl>=3.1.0 in /usr/local/lib/python3.12/dist-packages (from scikit-learn>=1.0.0->-r requirements.txt (line 17)) (3.6.0)
# Requirement already satisfied: contourpy>=1.0.1 in /usr/local/lib/python3.12/dist-packages (from matplotlib>=3.5.0->-r requirements.txt (line 23)) (1.3.3)
# Requirement already satisfied: cycler>=0.10 in /usr/local/lib/python3.12/dist-packages (from matplotlib>=3.5.0->-r requirements.txt (line 23)) (0.12.1)
# Requirement already satisfied: fonttools>=4.22.0 in /usr/local/lib/python3.12/dist-packages (from matplotlib>=3.5.0->-r requirements.txt (line 23)) (4.61.1)
# Requirement already satisfied: kiwisolver>=1.3.1 in /usr/local/lib/python3.12/dist-packages (from matplotlib>=3.5.0->-r requirements.txt (line 23)) (1.4.9)
# Requirement already satisfied: packaging>=20.0 in /usr/local/lib/python3.12/dist-packages (from matplotlib>=3.5.0->-r requirements.txt (line 23)) (25.0)
# Requirement already satisfied: pyparsing>=2.3.1 in /usr/local/lib/python3.12/dist-packages (from matplotlib>=3.5.0->-r requirements.txt (line 23)) (3.2.5)
# Requirement already satisfied: slicer==0.0.8 in /usr/local/lib/python3.12/dist-packages (from shap>=0.44.0->-r requirements.txt (line 26)) (0.0.8)
# Requirement already satisfied: numba>=0.54 in /usr/local/lib/python3.12/dist-packages (from shap>=0.44.0->-r requirements.txt (line 26)) (0.60.0)
# Requirement already satisfied: cloudpickle in /usr/local/lib/python3.12/dist-packages (from shap>=0.44.0->-r requirements.txt (line 26)) (3.1.2)
# Requirement already satisfied: llvmlite<0.44,>=0.43.0dev0 in /usr/local/lib/python3.12/dist-packages (from numba>=0.54->shap>=0.44.0->-r requirements.txt (line 26)) (0.43.0)
# Requirement already satisfied: six>=1.5 in /usr/local/lib/python3.12/dist-packages (from python-dateutil>=2.8.2->pandas>=1.3.0->-r requirements.txt (line 7)) (1.17.0)
# Requirement already satisfied: CFFI>=1.0 in /usr/local/lib/python3.12/dist-packages (from sounddevice~=0.5->mediapipe>=0.10.15->-r requirements.txt (line 14)) (2.0.0)
# Requirement already satisfied: mpmath<1.4,>=1.1.0 in /usr/local/lib/python3.12/dist-packages (from sympy>=1.13.3->torch>=1.10.0->-r requirements.txt (line 2)) (1.3.0)
# Requirement already satisfied: MarkupSafe>=2.0 in /usr/local/lib/python3.12/dist-packages (from jinja2->torch>=1.10.0->-r requirements.txt (line 2)) (3.0.3)
# Requirement already satisfied: pycparser in /usr/local/lib/python3.12/dist-packages (from CFFI>=1.0->sounddevice~=0.5->mediapipe>=0.10.15->-r requirements.txt (line 14)) (2.23)
# Downloading mediapipe-0.10.31-py3-none-manylinux_2_28_x86_64.whl (10.3 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 10.3/10.3 MB 72.9 MB/s eta 0:00:00
# Downloading absl_py-2.3.1-py3-none-any.whl (135 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 135.8/135.8 kB 13.2 MB/s eta 0:00:00
# Downloading sounddevice-0.5.3-py3-none-any.whl (32 kB)
# Installing collected packages: absl-py, sounddevice, mediapipe
#   Attempting uninstall: absl-py
#     Found existing installation: absl-py 1.4.0
#     Uninstalling absl-py-1.4.0:
#       Successfully uninstalled absl-py-1.4.0
# Successfully installed absl-py-2.3.1 mediapipe-0.10.31 sounddevice-0.5.3

# %%
import sys
import os

# Dodaj katalog główny projektu do ścieżki systemowej
sys.path.append(os.getcwd())
print(f"Dodano do ścieżki Pythona: {os.getcwd()}")
# Out:
# Dodano do ścieżki Pythona: /content/automatic-pain-recognition

# %% [markdown]
# #### Distances 154 combined points - 6 class training

# %%
import os
import numpy as np
import pandas as pd
import shutil

import torch
import torch.nn as nn
from torch.utils.data import DataLoader
from torch.optim.lr_scheduler import ReduceLROnPlateau

from training_utils.preprocessed_dataset import PreprocessedDataset
from training_utils.train import Trainer
from training_utils.evaluate import Evaluator
from models.Bi_LSTM import SequenceModel

# %% [markdown]
# #### Hiperparameters

# %%
MAX_SEQUENCE_LENGTH = 37
NUM_FEATURES = 154
NUM_CLASSES = 6
HIDDEN_SIZE = 128
NUM_LAYERS = 2
NUM_EPOCHS = 200
BATCH_SIZE = 16
LEARNING_RATE = 0.00005
DROPOUT_PROB = 0.4
WEIGHT_DECAY = 0.005
SCHEDULER_FACTOR = 0.8

# %% [markdown]
# #### Data preparation

# %%
COLAB_ROOT = '/content/drive/MyDrive/PainRecognitionProject/'
PROCESSED_DATA_DIR = os.path.join(COLAB_ROOT, 'data/RAVDESS_processed_478_xyz_frontalized/')
MODEL_SAVE_DIR = os.path.join(COLAB_ROOT, 'models/')
LOCAL_PROCESSED_DATA_ROOT = '/content/temp_data/'

DEVICE = torch.device("cuda" if torch.cuda.is_available() else "cpu")

# %%
print("Kopiowanie danych z Google Drive do lokalnej pamięci Colab (RAM)...")
if os.path.exists(LOCAL_PROCESSED_DATA_ROOT):
    shutil.rmtree(LOCAL_PROCESSED_DATA_ROOT)
try:
    shutil.copytree(PROCESSED_DATA_DIR, LOCAL_PROCESSED_DATA_ROOT)
    print("✅ Kopiowanie zakończone pomyślnie. Czas trwania: (sprawdź zegar)")
    CURRENT_DATA_DIR = LOCAL_PROCESSED_DATA_ROOT

except Exception as e:
    print(f"❌ Błąd kopiowania danych (sprawdź, czy dane są zamontowane): {e}")
    print("Używam danych bezpośrednio z Drive (może się zawiesić).")
    CURRENT_DATA_DIR = PROCESSED_DATA_DIR
# Out:
# Kopiowanie danych z Google Drive do lokalnej pamięci Colab (RAM)...
# ✅ Kopiowanie zakończone pomyślnie. Czas trwania: (sprawdź zegar)

# %%
best_154_landmarks = np.load('/content/drive/MyDrive/PainRecognitionProject/data/combined_selected_points_emotions.npy')

# %%
train_dataset = PreprocessedDataset(
    'train',
    processed_data_dir=CURRENT_DATA_DIR,
    indices=best_154_landmarks,
    compute_euclidean=True,
    center_point_index=2,
    max_sequence_length=MAX_SEQUENCE_LENGTH,
    selected_labels=[2, 3, 4, 5, 6, 8],
    label_map={2: 0, 3: 1, 4: 2, 5: 3, 6: 4, 8: 5},
)

val_dataset = PreprocessedDataset(
    'val',
    processed_data_dir=CURRENT_DATA_DIR,
    indices=best_154_landmarks,
    compute_euclidean=True,
    center_point_index=2,
    max_sequence_length=MAX_SEQUENCE_LENGTH,
    selected_labels=[2, 3, 4, 5, 6, 8],
    label_map={2: 0, 3: 1, 4: 2, 5: 3, 6: 4, 8: 5},
)

test_dataset = PreprocessedDataset(
    'test',
    processed_data_dir=CURRENT_DATA_DIR,
    indices=best_154_landmarks,
    compute_euclidean=True,
    center_point_index=2,
    max_sequence_length=MAX_SEQUENCE_LENGTH,
    selected_labels=[2, 3, 4, 5, 6, 8],
    label_map={2: 0, 3: 1, 4: 2, 5: 3, 6: 4, 8: 5},
)

# %%
def preview_single(dataset, idx=0, timesteps_to_show=3, features_to_show=8):
    x, y = dataset[idx]
    print(f"\nSingle sample idx={idx} from split={dataset.dataset_name}")
    print(f"x shape: {tuple(x.shape)}, y: {y}")
    print(np.round(x[:timesteps_to_show, :features_to_show], 4))

preview_single(train_dataset, 0)
preview_single(val_dataset, 0)
preview_single(test_dataset, 0)
# Out:
# Single sample idx=0 from split=train
# x shape: (37, 154), y: 0
# tensor([[0.0000, 0.1144, 0.1634, 0.3016, 0.3973, 0.4532, 0.1317, 0.1736],
#         [0.0000, 0.1166, 0.1651, 0.2994, 0.3941, 0.4516, 0.1305, 0.1725],
#         [0.0000, 0.1176, 0.1661, 0.2988, 0.3955, 0.4537, 0.1278, 0.1702]])
#
# Single sample idx=0 from split=val
# x shape: (37, 154), y: 0
# tensor([[0.0000, 0.1165, 0.1638, 0.2942, 0.3949, 0.4512, 0.1199, 0.1994],
#         [0.0000, 0.1154, 0.1632, 0.2941, 0.4017, 0.4612, 0.1226, 0.1965],
#         [0.0000, 0.1144, 0.1620, 0.2925, 0.3961, 0.4548, 0.1134, 0.1923]])
#
# Single sample idx=0 from split=test
# x shape: (37, 154), y: 0
# tensor([[0.0000, 0.1116, 0.1613, 0.3001, 0.4110, 0.4719, 0.1351, 0.2000],
#         [0.0000, 0.1127, 0.1621, 0.2991, 0.4090, 0.4696, 0.1349, 0.1977],
#         [0.0000, 0.1128, 0.1618, 0.2977, 0.4069, 0.4673, 0.1374, 0.2016]])

# %%
train_loader = DataLoader(train_dataset, batch_size=BATCH_SIZE, shuffle=True, num_workers=0, pin_memory=True)
for X, y in train_loader:
    print(X.shape, y.shape)  # (B, T_max, num_features)
    break

val_loader = DataLoader(val_dataset, batch_size=BATCH_SIZE, shuffle=True, num_workers=0, pin_memory=True)
for X, y in val_loader:
    print(X.shape, y.shape)  # (B, T_max, num_features)
    break

test_loader = DataLoader(test_dataset, batch_size=BATCH_SIZE, shuffle=True, num_workers=0, pin_memory=True)
for X, y in test_loader:
    print(X.shape, y.shape)  # (B, T_max, num_features)
    break
# Out:
# torch.Size([16, 37, 154]) torch.Size([16])
# torch.Size([16, 37, 154]) torch.Size([16])
# torch.Size([16, 37, 154]) torch.Size([16])

# %% [markdown]
# #### Model preparation

# %%
model = SequenceModel(NUM_FEATURES, HIDDEN_SIZE, NUM_LAYERS, NUM_CLASSES, DROPOUT_PROB).to(DEVICE)

# %% [markdown]
# #### Training

# %%
criterion = nn.CrossEntropyLoss()
optimizer = torch.optim.AdamW(model.parameters(), lr=LEARNING_RATE, weight_decay=WEIGHT_DECAY)

scheduler = ReduceLROnPlateau(
    optimizer,
    mode='max',
    factor=SCHEDULER_FACTOR,
    patience=10,
    min_lr=1e-7
)

model_name = 'testing_new_code_emotions_154_distances_6_classes.pt'
model_filepath = os.path.join(MODEL_SAVE_DIR, model_name)

# %%
trainer = Trainer(
    model=model,
    train_loader=train_loader,
    val_loader=val_loader,
    optimizer=optimizer,
    scheduler=scheduler,
    criterion=criterion,
    device=DEVICE,
    model_save_path=model_filepath,
    num_epochs=NUM_EPOCHS,
    monitor='val_acc',  # or 'val_loss'
    minimize_monitor=False,
    save_best_only=True
)

# %%
trainer.print_training_config()
# Out:
# ==================================================
# 🚀 TRAINING CONFIGURATION
# ==================================================
#
# --- Model Architecture ---
#   Model Type            : SequenceModel
#   Input Features        : 154
#   Hidden Size           : 128
#   Num Layers            : 2
#   Bidirectional         : True
#   Dropout (LSTM)        : 0.4
#   Num Parameters        : 687622
#
# --- Optimizer & Regularization ---
#   Optimizer             : AdamW
#   Learning Rate (LR)    : 5e-05
#   Weight Decay (L2)     : 0.005
#
# --- Training Flow ---
#   Batch Size            : 16
#   Num Epochs            : 200
#   Device                : cuda
# ==================================================

# %%
final_model_path, best_model_path, history = trainer.fit()
print(f"Final model saved to: {final_model_path}")
if best_model_path:
    print(f"Best model saved to: {best_model_path}")
# Out:
# Starting training for 200 epochs on cuda
# Saved best model to /content/drive/MyDrive/PainRecognitionProject/models/best_testing_new_code_emotions_154_distances_6_classes.pt (metric=0.1645)
# Epoch 1/200 | Time 4.77s | Train loss 1.7944 | Train acc 0.1556 | Val loss 1.7921 | Val acc 0.1645
# Epoch 2/200 | Time 2.81s | Train loss 1.7910 | Train acc 0.1790 | Val loss 1.7910 | Val acc 0.1645
# Epoch 3/200 | Time 2.84s | Train loss 1.7893 | Train acc 0.1868 | Val loss 1.7901 | Val acc 0.1645
# Saved best model to /content/drive/MyDrive/PainRecognitionProject/models/best_testing_new_code_emotions_154_distances_6_classes.pt (metric=0.1828)
# Epoch 4/200 | Time 2.79s | Train loss 1.7908 | Train acc 0.1868 | Val loss 1.7884 | Val acc 0.1828
# Saved best model to /content/drive/MyDrive/PainRecognitionProject/models/best_testing_new_code_emotions_154_distances_6_classes.pt (metric=0.2141)
# Epoch 5/200 | Time 3.17s | Train loss 1.7861 | Train acc 0.1960 | Val loss 1.7845 | Val acc 0.2141
# Saved best model to /content/drive/MyDrive/PainRecognitionProject/models/best_testing_new_code_emotions_154_distances_6_classes.pt (metric=0.3107)
# Epoch 6/200 | Time 3.15s | Train loss 1.7785 | Train acc 0.2207 | Val loss 1.7615 | Val acc 0.3107
# Epoch 7/200 | Time 2.80s | Train loss 1.7278 | Train acc 0.2591 | Val loss 1.6865 | Val acc 0.2350
# Epoch 8/200 | Time 2.82s | Train loss 1.6691 | Train acc 0.2826 | Val loss 1.6687 | Val acc 0.2193
# Saved best model to /content/drive/MyDrive/PainRecognitionProject/models/best_testing_new_code_emotions_154_distances_6_classes.pt (metric=0.3133)
# Epoch 9/200 | Time 2.84s | Train loss 1.5834 | Train acc 0.3229 | Val loss 1.6331 | Val acc 0.3133
# Epoch 10/200 | Time 3.61s | Train loss 1.5520 | Train acc 0.3281 | Val loss 1.6894 | Val acc 0.2298
# Epoch 11/200 | Time 2.80s | Train loss 1.5340 | Train acc 0.3529 | Val loss 1.7926 | Val acc 0.2846
# Epoch 12/200 | Time 2.94s | Train loss 1.4887 | Train acc 0.3685 | Val loss 1.7093 | Val acc 0.2454
# Saved best model to /content/drive/MyDrive/PainRecognitionProject/models/best_testing_new_code_emotions_154_distances_6_classes.pt (metric=0.3890)
# Epoch 13/200 | Time 2.81s | Train loss 1.4971 | Train acc 0.3509 | Val loss 1.5975 | Val acc 0.3890
# Epoch 14/200 | Time 3.65s | Train loss 1.4578 | Train acc 0.3665 | Val loss 1.6400 | Val acc 0.3159
# Epoch 15/200 | Time 2.98s | Train loss 1.4394 | Train acc 0.3854 | Val loss 1.7289 | Val acc 0.2272
# Epoch 16/200 | Time 2.80s | Train loss 1.4749 | Train acc 0.3704 | Val loss 1.6616 | Val acc 0.3446
# Epoch 17/200 | Time 2.82s | Train loss 1.4369 | Train acc 0.3789 | Val loss 1.5639 | Val acc 0.3316
# Epoch 18/200 | Time 2.98s | Train loss 1.4111 | Train acc 0.4076 | Val loss 1.6153 | Val acc 0.3003
# Epoch 19/200 | Time 3.44s | Train loss 1.3963 | Train acc 0.4010 | Val loss 1.8338 | Val acc 0.2715
# Saved best model to /content/drive/MyDrive/PainRecognitionProject/models/best_testing_new_code_emotions_154_distances_6_classes.pt (metric=0.4204)
# Epoch 20/200 | Time 2.90s | Train loss 1.4212 | Train acc 0.4056 | Val loss 1.4372 | Val acc 0.4204
# Epoch 21/200 | Time 2.78s | Train loss 1.3777 | Train acc 0.4180 | Val loss 2.1005 | Val acc 0.2350
# Epoch 22/200 | Time 2.80s | Train loss 1.3570 | Train acc 0.4414 | Val loss 1.6015 | Val acc 0.3629
# Epoch 23/200 | Time 3.47s | Train loss 1.3453 | Train acc 0.4297 | Val loss 1.4443 | Val acc 0.3864
# Epoch 24/200 | Time 2.97s | Train loss 1.3279 | Train acc 0.4720 | Val loss 1.5044 | Val acc 0.3708
# Epoch 25/200 | Time 2.81s | Train loss 1.2956 | Train acc 0.4609 | Val loss 1.5577 | Val acc 0.3969
# Epoch 26/200 | Time 2.78s | Train loss 1.2939 | Train acc 0.4753 | Val loss 1.5610 | Val acc 0.3342
# Epoch 27/200 | Time 3.00s | Train loss 1.2665 | Train acc 0.4837 | Val loss 1.6018 | Val acc 0.3473
# Epoch 28/200 | Time 3.32s | Train loss 1.2670 | Train acc 0.4753 | Val loss 1.6735 | Val acc 0.3446
# Epoch 29/200 | Time 2.80s | Train loss 1.3033 | Train acc 0.4674 | Val loss 1.7928 | Val acc 0.3185
# Epoch 30/200 | Time 2.77s | Train loss 1.2260 | Train acc 0.5052 | Val loss 1.4126 | Val acc 0.4099
# Saved best model to /content/drive/MyDrive/PainRecognitionProject/models/best_testing_new_code_emotions_154_distances_6_classes.pt (metric=0.4230)
# Epoch 31/200 | Time 2.79s | Train loss 1.2138 | Train acc 0.5117 | Val loss 1.4896 | Val acc 0.4230
# Epoch 32/200 | Time 3.35s | Train loss 1.2112 | Train acc 0.5137 | Val loss 1.4703 | Val acc 0.4047
# Saved best model to /content/drive/MyDrive/PainRecognitionProject/models/best_testing_new_code_emotions_154_distances_6_classes.pt (metric=0.4334)
# Epoch 33/200 | Time 2.91s | Train loss 1.2077 | Train acc 0.5104 | Val loss 1.3427 | Val acc 0.4334
# Epoch 34/200 | Time 2.74s | Train loss 1.2101 | Train acc 0.5020 | Val loss 1.7973 | Val acc 0.3394
# Epoch 35/200 | Time 2.74s | Train loss 1.2283 | Train acc 0.4967 | Val loss 1.3574 | Val acc 0.4308
# Saved best model to /content/drive/MyDrive/PainRecognitionProject/models/best_testing_new_code_emotions_154_distances_6_classes.pt (metric=0.4595)
# Epoch 36/200 | Time 2.93s | Train loss 1.1652 | Train acc 0.5384 | Val loss 1.3802 | Val acc 0.4595
# Epoch 37/200 | Time 3.32s | Train loss 1.2111 | Train acc 0.5111 | Val loss 1.4311 | Val acc 0.4021
# Epoch 38/200 | Time 2.73s | Train loss 1.1524 | Train acc 0.5273 | Val loss 1.6520 | Val acc 0.3342
# Epoch 39/200 | Time 2.78s | Train loss 1.1262 | Train acc 0.5358 | Val loss 1.6419 | Val acc 0.3551
# Epoch 40/200 | Time 2.72s | Train loss 1.1196 | Train acc 0.5469 | Val loss 1.8171 | Val acc 0.3185
# Epoch 41/200 | Time 3.25s | Train loss 1.1214 | Train acc 0.5417 | Val loss 1.6501 | Val acc 0.3760
# Epoch 42/200 | Time 2.95s | Train loss 1.1202 | Train acc 0.5605 | Val loss 1.3960 | Val acc 0.4465
# Epoch 43/200 | Time 2.77s | Train loss 1.1041 | Train acc 0.5618 | Val loss 1.6671 | Val acc 0.4021
# Epoch 44/200 | Time 2.75s | Train loss 1.0604 | Train acc 0.5807 | Val loss 1.7586 | Val acc 0.3890
# Saved best model to /content/drive/MyDrive/PainRecognitionProject/models/best_testing_new_code_emotions_154_distances_6_classes.pt (metric=0.4726)
# Epoch 45/200 | Time 2.84s | Train loss 1.0685 | Train acc 0.5638 | Val loss 1.4216 | Val acc 0.4726
# Epoch 46/200 | Time 3.41s | Train loss 1.0582 | Train acc 0.5833 | Val loss 1.6691 | Val acc 0.3812
# Epoch 47/200 | Time 2.75s | Train loss 1.0946 | Train acc 0.5605 | Val loss 1.6246 | Val acc 0.4047
# Epoch 48/200 | Time 2.72s | Train loss 1.0927 | Train acc 0.5658 | Val loss 1.3802 | Val acc 0.4491
# Epoch 49/200 | Time 2.77s | Train loss 1.0334 | Train acc 0.5898 | Val loss 1.5218 | Val acc 0.4334
# Epoch 50/200 | Time 3.18s | Train loss 1.0211 | Train acc 0.5885 | Val loss 1.6326 | Val acc 0.4256
# Epoch 51/200 | Time 3.03s | Train loss 1.0223 | Train acc 0.5859 | Val loss 1.6256 | Val acc 0.4099
# Epoch 52/200 | Time 2.74s | Train loss 1.0427 | Train acc 0.5814 | Val loss 1.7514 | Val acc 0.4125
# Saved best model to /content/drive/MyDrive/PainRecognitionProject/models/best_testing_new_code_emotions_154_distances_6_classes.pt (metric=0.4883)
# Epoch 53/200 | Time 2.78s | Train loss 1.0185 | Train acc 0.5951 | Val loss 1.3669 | Val acc 0.4883
# Epoch 54/200 | Time 2.76s | Train loss 0.9982 | Train acc 0.5853 | Val loss 1.4049 | Val acc 0.4439
# Epoch 55/200 | Time 3.52s | Train loss 1.0293 | Train acc 0.5723 | Val loss 1.9449 | Val acc 0.3708
# Saved best model to /content/drive/MyDrive/PainRecognitionProject/models/best_testing_new_code_emotions_154_distances_6_classes.pt (metric=0.4961)
# Epoch 56/200 | Time 2.73s | Train loss 0.9875 | Train acc 0.6061 | Val loss 1.3227 | Val acc 0.4961
# Epoch 57/200 | Time 2.72s | Train loss 0.9879 | Train acc 0.5996 | Val loss 1.3438 | Val acc 0.4360
# Epoch 58/200 | Time 2.78s | Train loss 0.9841 | Train acc 0.6035 | Val loss 1.5170 | Val acc 0.4308
# Epoch 59/200 | Time 3.13s | Train loss 0.9278 | Train acc 0.6204 | Val loss 1.8816 | Val acc 0.4021
# Epoch 60/200 | Time 3.12s | Train loss 0.9291 | Train acc 0.6263 | Val loss 1.4235 | Val acc 0.4700
# Epoch 61/200 | Time 2.75s | Train loss 0.9476 | Train acc 0.6204 | Val loss 1.5203 | Val acc 0.4778
# Epoch 62/200 | Time 2.75s | Train loss 0.9911 | Train acc 0.6003 | Val loss 1.3477 | Val acc 0.4517
# Epoch 63/200 | Time 2.78s | Train loss 0.9299 | Train acc 0.6289 | Val loss 1.4051 | Val acc 0.4569
# Epoch 64/200 | Time 3.52s | Train loss 0.9883 | Train acc 0.5996 | Val loss 2.2226 | Val acc 0.3708
# Epoch 65/200 | Time 2.78s | Train loss 0.8848 | Train acc 0.6380 | Val loss 1.4029 | Val acc 0.4856
# Epoch 66/200 | Time 2.70s | Train loss 0.8852 | Train acc 0.6491 | Val loss 1.2262 | Val acc 0.4961
# Epoch 67/200 | Time 2.67s | Train loss 0.9061 | Train acc 0.6419 | Val loss 1.4535 | Val acc 0.4830
# Saved best model to /content/drive/MyDrive/PainRecognitionProject/models/best_testing_new_code_emotions_154_distances_6_classes.pt (metric=0.5379)
# Epoch 68/200 | Time 2.94s | Train loss 0.8763 | Train acc 0.6374 | Val loss 1.2832 | Val acc 0.5379
# Epoch 69/200 | Time 3.14s | Train loss 0.8734 | Train acc 0.6439 | Val loss 1.3405 | Val acc 0.4830
# Epoch 70/200 | Time 2.66s | Train loss 0.8797 | Train acc 0.6471 | Val loss 1.4229 | Val acc 0.4856
# Epoch 71/200 | Time 2.67s | Train loss 0.9497 | Train acc 0.6165 | Val loss 1.7341 | Val acc 0.4334
# Saved best model to /content/drive/MyDrive/PainRecognitionProject/models/best_testing_new_code_emotions_154_distances_6_classes.pt (metric=0.5483)
# Epoch 72/200 | Time 2.66s | Train loss 0.8603 | Train acc 0.6419 | Val loss 1.2604 | Val acc 0.5483
# Epoch 73/200 | Time 3.22s | Train loss 0.8297 | Train acc 0.6654 | Val loss 1.3610 | Val acc 0.5300
# Epoch 74/200 | Time 2.92s | Train loss 0.8824 | Train acc 0.6380 | Val loss 1.6932 | Val acc 0.4386
# Epoch 75/200 | Time 2.72s | Train loss 0.8271 | Train acc 0.6602 | Val loss 1.4759 | Val acc 0.4830
# Epoch 76/200 | Time 2.66s | Train loss 0.8090 | Train acc 0.6751 | Val loss 1.5145 | Val acc 0.4961
# Epoch 77/200 | Time 2.70s | Train loss 0.7916 | Train acc 0.6738 | Val loss 1.3789 | Val acc 0.5405
# Epoch 78/200 | Time 3.37s | Train loss 0.8225 | Train acc 0.6686 | Val loss 1.7694 | Val acc 0.4439
# Epoch 79/200 | Time 2.69s | Train loss 0.8213 | Train acc 0.6686 | Val loss 1.3501 | Val acc 0.5196
# Epoch 80/200 | Time 2.66s | Train loss 0.7807 | Train acc 0.6875 | Val loss 1.4845 | Val acc 0.5013
# Epoch 81/200 | Time 2.66s | Train loss 0.7779 | Train acc 0.6758 | Val loss 1.7218 | Val acc 0.4413
# Epoch 82/200 | Time 2.94s | Train loss 0.7847 | Train acc 0.6790 | Val loss 1.6700 | Val acc 0.4569
# Epoch 83/200 | Time 3.08s | Train loss 0.7416 | Train acc 0.6953 | Val loss 1.6088 | Val acc 0.4909
# Epoch 84/200 | Time 2.64s | Train loss 0.7974 | Train acc 0.6797 | Val loss 1.9312 | Val acc 0.4465
# Epoch 85/200 | Time 2.68s | Train loss 0.7722 | Train acc 0.6908 | Val loss 1.4987 | Val acc 0.4804
# Epoch 86/200 | Time 2.68s | Train loss 0.7570 | Train acc 0.6849 | Val loss 1.4654 | Val acc 0.4935
# Epoch 87/200 | Time 3.29s | Train loss 0.7860 | Train acc 0.6790 | Val loss 1.4252 | Val acc 0.5352
# Epoch 88/200 | Time 2.90s | Train loss 0.7452 | Train acc 0.6908 | Val loss 1.4825 | Val acc 0.5248
# Epoch 89/200 | Time 2.69s | Train loss 0.7098 | Train acc 0.7129 | Val loss 1.7061 | Val acc 0.4595
# Epoch 90/200 | Time 2.68s | Train loss 0.7381 | Train acc 0.6986 | Val loss 1.7437 | Val acc 0.4595
# Epoch 91/200 | Time 2.75s | Train loss 0.7273 | Train acc 0.7025 | Val loss 2.0696 | Val acc 0.4465
# Epoch 92/200 | Time 3.36s | Train loss 0.7377 | Train acc 0.7031 | Val loss 1.5218 | Val acc 0.4961
# Epoch 93/200 | Time 2.69s | Train loss 0.7140 | Train acc 0.7018 | Val loss 1.9838 | Val acc 0.4178
# Epoch 94/200 | Time 2.68s | Train loss 0.7372 | Train acc 0.6934 | Val loss 1.6168 | Val acc 0.4648
# Epoch 95/200 | Time 2.70s | Train loss 0.6886 | Train acc 0.7103 | Val loss 1.5304 | Val acc 0.4961
# Epoch 96/200 | Time 3.01s | Train loss 0.6922 | Train acc 0.7181 | Val loss 1.6587 | Val acc 0.4830
# Epoch 97/200 | Time 3.10s | Train loss 0.6917 | Train acc 0.7109 | Val loss 1.4138 | Val acc 0.5352
# Epoch 98/200 | Time 2.67s | Train loss 0.6678 | Train acc 0.7214 | Val loss 1.4636 | Val acc 0.4961
# Epoch 99/200 | Time 2.76s | Train loss 0.6908 | Train acc 0.7161 | Val loss 1.4285 | Val acc 0.5170
# Epoch 100/200 | Time 2.81s | Train loss 0.7057 | Train acc 0.7051 | Val loss 1.4535 | Val acc 0.5274
# Epoch 101/200 | Time 3.50s | Train loss 0.6758 | Train acc 0.7279 | Val loss 1.7654 | Val acc 0.4961
# Epoch 102/200 | Time 2.86s | Train loss 0.6926 | Train acc 0.7129 | Val loss 1.8190 | Val acc 0.4569
# Epoch 103/200 | Time 2.76s | Train loss 0.6652 | Train acc 0.7383 | Val loss 1.4738 | Val acc 0.5248
# Epoch 104/200 | Time 2.75s | Train loss 0.6687 | Train acc 0.7305 | Val loss 1.7639 | Val acc 0.4360
# Epoch 105/200 | Time 3.01s | Train loss 0.6868 | Train acc 0.7168 | Val loss 1.8459 | Val acc 0.4778
# Epoch 106/200 | Time 3.30s | Train loss 0.6338 | Train acc 0.7396 | Val loss 1.8899 | Val acc 0.4334
# Epoch 107/200 | Time 2.75s | Train loss 0.6801 | Train acc 0.7285 | Val loss 2.0527 | Val acc 0.4726
# Epoch 108/200 | Time 2.74s | Train loss 0.6261 | Train acc 0.7396 | Val loss 1.6644 | Val acc 0.4830
# Epoch 109/200 | Time 2.71s | Train loss 0.6229 | Train acc 0.7624 | Val loss 1.6694 | Val acc 0.4465
# Epoch 110/200 | Time 3.35s | Train loss 0.6347 | Train acc 0.7376 | Val loss 1.8120 | Val acc 0.4595
# Epoch 111/200 | Time 2.92s | Train loss 0.6246 | Train acc 0.7428 | Val loss 2.0287 | Val acc 0.4386
# Epoch 112/200 | Time 2.74s | Train loss 0.6365 | Train acc 0.7428 | Val loss 1.5381 | Val acc 0.5300
# Epoch 113/200 | Time 2.74s | Train loss 0.6199 | Train acc 0.7383 | Val loss 1.6822 | Val acc 0.4935
# Epoch 114/200 | Time 2.88s | Train loss 0.5967 | Train acc 0.7487 | Val loss 1.7061 | Val acc 0.4883
# Epoch 115/200 | Time 3.48s | Train loss 0.6022 | Train acc 0.7513 | Val loss 1.5734 | Val acc 0.4804
# Epoch 116/200 | Time 2.76s | Train loss 0.6010 | Train acc 0.7533 | Val loss 1.5541 | Val acc 0.5117
# Epoch 117/200 | Time 2.86s | Train loss 0.6022 | Train acc 0.7656 | Val loss 1.9093 | Val acc 0.4778
# Epoch 118/200 | Time 2.67s | Train loss 0.6083 | Train acc 0.7591 | Val loss 1.7353 | Val acc 0.4987
# Epoch 119/200 | Time 3.20s | Train loss 0.5784 | Train acc 0.7624 | Val loss 1.8706 | Val acc 0.4648
# Epoch 120/200 | Time 3.00s | Train loss 0.5902 | Train acc 0.7565 | Val loss 1.7064 | Val acc 0.4961
# Epoch 121/200 | Time 2.66s | Train loss 0.6100 | Train acc 0.7572 | Val loss 2.2516 | Val acc 0.4465
# Epoch 122/200 | Time 2.67s | Train loss 0.5829 | Train acc 0.7630 | Val loss 1.7668 | Val acc 0.4935
# Epoch 123/200 | Time 2.61s | Train loss 0.5940 | Train acc 0.7565 | Val loss 1.6624 | Val acc 0.5039
# Epoch 124/200 | Time 3.43s | Train loss 0.5740 | Train acc 0.7695 | Val loss 1.6857 | Val acc 0.4830
# Epoch 125/200 | Time 2.67s | Train loss 0.5798 | Train acc 0.7572 | Val loss 1.8143 | Val acc 0.4883
# Epoch 126/200 | Time 2.63s | Train loss 0.5705 | Train acc 0.7604 | Val loss 2.0404 | Val acc 0.4543
# Epoch 127/200 | Time 2.64s | Train loss 0.5873 | Train acc 0.7604 | Val loss 1.8099 | Val acc 0.4883
# Epoch 128/200 | Time 2.88s | Train loss 0.5694 | Train acc 0.7650 | Val loss 1.5572 | Val acc 0.5222
# Epoch 129/200 | Time 3.19s | Train loss 0.5544 | Train acc 0.7728 | Val loss 1.8118 | Val acc 0.4883
# Epoch 130/200 | Time 2.69s | Train loss 0.5469 | Train acc 0.7812 | Val loss 1.8712 | Val acc 0.4674
# Epoch 131/200 | Time 2.69s | Train loss 0.5573 | Train acc 0.7708 | Val loss 1.7478 | Val acc 0.4856
# Epoch 132/200 | Time 2.65s | Train loss 0.5481 | Train acc 0.7611 | Val loss 1.8492 | Val acc 0.4909
# Epoch 133/200 | Time 3.13s | Train loss 0.5580 | Train acc 0.7650 | Val loss 1.8921 | Val acc 0.4569
# Epoch 134/200 | Time 2.94s | Train loss 0.5442 | Train acc 0.7715 | Val loss 1.7247 | Val acc 0.5013
# Epoch 135/200 | Time 2.65s | Train loss 0.5482 | Train acc 0.7747 | Val loss 1.8925 | Val acc 0.4987
# Epoch 136/200 | Time 2.63s | Train loss 0.5626 | Train acc 0.7708 | Val loss 1.8871 | Val acc 0.4726
# Epoch 137/200 | Time 2.65s | Train loss 0.5270 | Train acc 0.7852 | Val loss 1.7513 | Val acc 0.4856
# Epoch 138/200 | Time 3.40s | Train loss 0.5379 | Train acc 0.7812 | Val loss 1.9583 | Val acc 0.4830
# Epoch 139/200 | Time 2.67s | Train loss 0.5369 | Train acc 0.7845 | Val loss 1.6672 | Val acc 0.5091
# Epoch 140/200 | Time 2.62s | Train loss 0.5327 | Train acc 0.7826 | Val loss 1.7639 | Val acc 0.5065
# Epoch 141/200 | Time 2.62s | Train loss 0.5290 | Train acc 0.7767 | Val loss 1.7632 | Val acc 0.5013
# Epoch 142/200 | Time 2.80s | Train loss 0.5361 | Train acc 0.7773 | Val loss 1.9058 | Val acc 0.4909
# Epoch 143/200 | Time 3.34s | Train loss 0.5331 | Train acc 0.7806 | Val loss 2.1221 | Val acc 0.4621
# Epoch 144/200 | Time 2.68s | Train loss 0.5137 | Train acc 0.7923 | Val loss 1.7926 | Val acc 0.4856
# Epoch 145/200 | Time 2.67s | Train loss 0.5211 | Train acc 0.7871 | Val loss 2.0590 | Val acc 0.4569
# Epoch 146/200 | Time 2.64s | Train loss 0.5331 | Train acc 0.7865 | Val loss 1.8021 | Val acc 0.4909
# Epoch 147/200 | Time 3.02s | Train loss 0.5443 | Train acc 0.7871 | Val loss 1.9577 | Val acc 0.5039
# Epoch 148/200 | Time 3.01s | Train loss 0.5369 | Train acc 0.7819 | Val loss 1.9450 | Val acc 0.4726
# Epoch 149/200 | Time 2.68s | Train loss 0.5251 | Train acc 0.7975 | Val loss 1.8980 | Val acc 0.4961
# Epoch 150/200 | Time 2.62s | Train loss 0.5265 | Train acc 0.7858 | Val loss 1.9139 | Val acc 0.4674
# Epoch 151/200 | Time 2.64s | Train loss 0.5213 | Train acc 0.7858 | Val loss 1.9275 | Val acc 0.4883
# Epoch 152/200 | Time 3.32s | Train loss 0.5051 | Train acc 0.8034 | Val loss 1.9320 | Val acc 0.4883
# Epoch 153/200 | Time 2.80s | Train loss 0.5019 | Train acc 0.8079 | Val loss 1.7931 | Val acc 0.5144
# Epoch 154/200 | Time 2.65s | Train loss 0.4981 | Train acc 0.7995 | Val loss 2.0797 | Val acc 0.4830
# Epoch 155/200 | Time 2.67s | Train loss 0.5122 | Train acc 0.7982 | Val loss 1.9114 | Val acc 0.4909
# Epoch 156/200 | Time 2.75s | Train loss 0.4948 | Train acc 0.7975 | Val loss 1.9255 | Val acc 0.4830
# Epoch 157/200 | Time 3.30s | Train loss 0.5103 | Train acc 0.7865 | Val loss 1.8832 | Val acc 0.5013
# Epoch 158/200 | Time 2.64s | Train loss 0.5008 | Train acc 0.7975 | Val loss 1.8039 | Val acc 0.4883
# Epoch 159/200 | Time 2.68s | Train loss 0.5117 | Train acc 0.7904 | Val loss 1.9712 | Val acc 0.4830
# Epoch 160/200 | Time 2.74s | Train loss 0.4817 | Train acc 0.8132 | Val loss 1.9301 | Val acc 0.4778
# Epoch 161/200 | Time 3.07s | Train loss 0.4995 | Train acc 0.7982 | Val loss 1.9180 | Val acc 0.4961
# Epoch 162/200 | Time 3.03s | Train loss 0.4956 | Train acc 0.8014 | Val loss 1.8784 | Val acc 0.4935
# Epoch 163/200 | Time 2.67s | Train loss 0.4992 | Train acc 0.7917 | Val loss 2.0176 | Val acc 0.4778
# Epoch 164/200 | Time 2.69s | Train loss 0.4894 | Train acc 0.7910 | Val loss 1.8524 | Val acc 0.4856
# Epoch 165/200 | Time 2.72s | Train loss 0.4874 | Train acc 0.8014 | Val loss 1.8413 | Val acc 0.4935
# Epoch 166/200 | Time 3.32s | Train loss 0.4772 | Train acc 0.8158 | Val loss 1.8815 | Val acc 0.4987
# Epoch 167/200 | Time 2.74s | Train loss 0.4943 | Train acc 0.7982 | Val loss 1.8571 | Val acc 0.4856
# Epoch 168/200 | Time 2.65s | Train loss 0.4813 | Train acc 0.8079 | Val loss 1.9907 | Val acc 0.4621
# Epoch 169/200 | Time 2.70s | Train loss 0.4798 | Train acc 0.8021 | Val loss 1.9384 | Val acc 0.4752
# Epoch 170/200 | Time 2.72s | Train loss 0.5056 | Train acc 0.7910 | Val loss 1.7433 | Val acc 0.5117
# Epoch 171/200 | Time 3.32s | Train loss 0.4891 | Train acc 0.8060 | Val loss 1.8271 | Val acc 0.4883
# Epoch 172/200 | Time 2.74s | Train loss 0.4769 | Train acc 0.8105 | Val loss 1.8821 | Val acc 0.4883
# Epoch 173/200 | Time 2.70s | Train loss 0.4753 | Train acc 0.8066 | Val loss 1.8699 | Val acc 0.5065
# Epoch 174/200 | Time 2.64s | Train loss 0.4825 | Train acc 0.8047 | Val loss 1.9269 | Val acc 0.4830
# Epoch 175/200 | Time 3.00s | Train loss 0.4843 | Train acc 0.8086 | Val loss 1.9827 | Val acc 0.4883
# Epoch 176/200 | Time 3.04s | Train loss 0.4809 | Train acc 0.8027 | Val loss 2.0268 | Val acc 0.4909
# Epoch 177/200 | Time 2.61s | Train loss 0.4757 | Train acc 0.7975 | Val loss 1.9969 | Val acc 0.4726
# Epoch 178/200 | Time 2.62s | Train loss 0.4764 | Train acc 0.8001 | Val loss 2.0418 | Val acc 0.4883
# Epoch 179/200 | Time 2.71s | Train loss 0.4741 | Train acc 0.8034 | Val loss 2.0189 | Val acc 0.4961
# Epoch 180/200 | Time 3.31s | Train loss 0.4739 | Train acc 0.8047 | Val loss 1.9322 | Val acc 0.4856
# Epoch 181/200 | Time 2.88s | Train loss 0.4727 | Train acc 0.8197 | Val loss 1.9404 | Val acc 0.4804
# Epoch 182/200 | Time 2.74s | Train loss 0.4843 | Train acc 0.8105 | Val loss 1.8796 | Val acc 0.4883
# Epoch 183/200 | Time 2.68s | Train loss 0.4678 | Train acc 0.8073 | Val loss 1.9752 | Val acc 0.4883
# Epoch 184/200 | Time 2.81s | Train loss 0.4827 | Train acc 0.7852 | Val loss 2.1244 | Val acc 0.4909
# Epoch 185/200 | Time 3.36s | Train loss 0.4692 | Train acc 0.8040 | Val loss 2.0870 | Val acc 0.4778
# Epoch 186/200 | Time 2.77s | Train loss 0.4687 | Train acc 0.8079 | Val loss 2.0165 | Val acc 0.4830
# Epoch 187/200 | Time 2.76s | Train loss 0.4696 | Train acc 0.8151 | Val loss 1.8971 | Val acc 0.5013
# Epoch 188/200 | Time 2.72s | Train loss 0.4690 | Train acc 0.8092 | Val loss 2.1584 | Val acc 0.4674
# Epoch 189/200 | Time 3.18s | Train loss 0.4577 | Train acc 0.8132 | Val loss 1.9484 | Val acc 0.5013
# Epoch 190/200 | Time 3.02s | Train loss 0.4555 | Train acc 0.8125 | Val loss 2.0798 | Val acc 0.4752
# Epoch 191/200 | Time 2.77s | Train loss 0.4622 | Train acc 0.8171 | Val loss 1.9322 | Val acc 0.4856
# Epoch 192/200 | Time 2.76s | Train loss 0.4695 | Train acc 0.8066 | Val loss 2.0304 | Val acc 0.4830
# Epoch 193/200 | Time 2.82s | Train loss 0.4569 | Train acc 0.8268 | Val loss 2.0680 | Val acc 0.4726
# Epoch 194/200 | Time 3.50s | Train loss 0.4548 | Train acc 0.8229 | Val loss 1.9760 | Val acc 0.4987
# Epoch 195/200 | Time 2.72s | Train loss 0.4577 | Train acc 0.8203 | Val loss 1.9338 | Val acc 0.5013
# Epoch 196/200 | Time 2.76s | Train loss 0.4733 | Train acc 0.8047 | Val loss 1.8871 | Val acc 0.4935
# Epoch 197/200 | Time 2.76s | Train loss 0.4641 | Train acc 0.8060 | Val loss 2.0214 | Val acc 0.4856
# Epoch 198/200 | Time 3.19s | Train loss 0.4540 | Train acc 0.8203 | Val loss 1.9913 | Val acc 0.4883
# Epoch 199/200 | Time 3.12s | Train loss 0.4499 | Train acc 0.8190 | Val loss 2.1444 | Val acc 0.4778
# Epoch 200/200 | Time 2.80s | Train loss 0.4589 | Train acc 0.8236 | Val loss 2.0599 | Val acc 0.4752
# Training finished. Best epoch: 71. Best monitored metric: 0.5483
# Final model saved to: /content/drive/MyDrive/PainRecognitionProject/models/testing_new_code_emotions_154_distances_6_classes.pt
# Best model saved to: /content/drive/MyDrive/PainRecognitionProject/models/best_testing_new_code_emotions_154_distances_6_classes.pt

# %%
trainer.plot_history()

# %% [markdown]
# #### Evaluate

# %%
model.load_state_dict(torch.load(best_model_path, map_location=DEVICE), strict=False)
# Out:
# <All keys matched successfully>

# %%
evaluator = Evaluator(model, test_loader, device=DEVICE, model_name=model_name, num_classes=NUM_CLASSES)

# %%
loss, acc, labels, preds = evaluator.evaluate_epoch()
# Out:
# ==================================================
# WYNIKI OCENY DLA MODELU: testing_new_code_emotions_154_distances_6_classes.pt
# ==================================================
# Test Loss: 1.4928
# Test Accuracy: 0.4844
#
# --- Szczegółowy Raport Klasyfikacji ---
#               precision    recall  f1-score   support
#
#      Klasa 0       0.60      0.50      0.55        64
#      Klasa 1       1.00      0.47      0.64        64
#      Klasa 2       0.36      0.81      0.50        64
#      Klasa 3       0.69      0.66      0.67        64
#      Klasa 4       0.33      0.38      0.35        64
#      Klasa 5       0.27      0.09      0.14        64
#
#     accuracy                           0.48       384
#    macro avg       0.54      0.48      0.47       384
# weighted avg       0.54      0.48      0.47       384
#
# ==================================================
# Confusion matrix:
#  [[32  0 28  2  0  2]
#  [ 8 30 14  0  4  8]
#  [ 0  0 52  8  4  0]
#  [ 0  0  8 42 12  2]
#  [12  0 20  4 24  4]
#  [ 1  0 24  5 28  6]]
