# %% [markdown]
# ### STA-LSTM model - multiclass training - 1434 coordinates

# %% [markdown]
# #### Environment preparation

# %%
from google.colab import drive
drive.mount('/content/drive')

COLAB_ROOT = '/content/drive/MyDrive/PainRecognitionProject/'
print(f"Dane będą wczytywane z: {COLAB_ROOT}")
# Out:
# Mounted at /content/drive
# Dane będą wczytywane z: /content/drive/MyDrive/PainRecognitionProject/

# %%
import os

# %cd /content

# !rm -rf automatic-pain-recognition

print(f"Obecne położenie: {os.getcwd()}")
# Out:
# /content
# Obecne położenie: /content

# %%
USERNAME = 'alicka33'
REPO_NAME = 'automatic-pain-recognition'

REPO_URL = f"https://github.com/{USERNAME}/{REPO_NAME}.git"

print("Rozpoczynam klonowanie...")

# !git clone {REPO_URL}

# %cd $REPO_NAME
# Out:
# Rozpoczynam klonowanie...
# Cloning into 'automatic-pain-recognition'...
# remote: Enumerating objects: 313, done.
# remote: Counting objects: 100% (36/36), done.
# remote: Compressing objects: 100% (22/22), done.
# remote: Total 313 (delta 23), reused 27 (delta 14), pack-reused 277 (from 1)
# Receiving objects: 100% (313/313), 11.57 MiB | 17.71 MiB/s, done.
# Resolving deltas: 100% (147/147), done.
# /content/automatic-pain-recognition

# %%
# !pip install -r requirements.txt

# %%
import sys
import os

sys.path.append(os.getcwd())
print(f"Dodano do ścieżki Pythona: {os.getcwd()}")
# Out:
# Dodano do ścieżki Pythona: /content/automatic-pain-recognition

# %% [markdown]
# #### STA-LSTM model - multiclass training

# %%
import os
import numpy as np
import pandas as pd
import shutil

import torch
import torch.nn as nn
from torch.utils.data import DataLoader
from torch.optim.lr_scheduler import ReduceLROnPlateau

from training_utils.preprocessed_dataset import PreprocessedDataset
from training_utils.train import Trainer
from training_utils.evaluate import Evaluator
from models.STA_LSTM import STA_LSTM

# %%
MAX_SEQUENCE_LENGTH = 46
NUM_FEATURES = 1434
NUM_CLASSES = 5
HIDDEN_SIZE = 128
NUM_LAYERS = 2
NUM_EPOCHS = 200
BATCH_SIZE = 16
LEARNING_RATE = 0.00005
DROPOUT_PROB = 0.3
WEIGHT_DECAY = 0.005
SCHEDULER_FACTOR = 0.9

# %% [markdown]
# #### Data preparation

# %%
COLAB_ROOT = '/content/drive/MyDrive/PainRecognitionProject/'
PROCESSED_DATA_DIR = os.path.join(COLAB_ROOT, 'data/BioVid_HeatPain_processed_478_xyz_frontalized/')
MODEL_SAVE_DIR = os.path.join(COLAB_ROOT, 'models/')
LOCAL_PROCESSED_DATA_ROOT = '/content/temp_data/'

DEVICE = torch.device("cuda" if torch.cuda.is_available() else "cpu")

# %%
print("Kopiowanie danych z Google Drive do lokalnej pamięci Colab (RAM)...")
if os.path.exists(LOCAL_PROCESSED_DATA_ROOT):
    shutil.rmtree(LOCAL_PROCESSED_DATA_ROOT)
try:
    shutil.copytree(PROCESSED_DATA_DIR, LOCAL_PROCESSED_DATA_ROOT)
    print("Kopiowanie zakończone pomyślnie. Czas trwania: (sprawdź zegar)")
    CURRENT_DATA_DIR = LOCAL_PROCESSED_DATA_ROOT

except Exception as e:
    print(f"Błąd kopiowania danych (sprawdź, czy dane są zamontowane): {e}")
    print("Używam danych bezpośrednio z Drive (może się zawiesić).")
    CURRENT_DATA_DIR = PROCESSED_DATA_DIR

# %%
train_dataset = PreprocessedDataset(
    'train',
    processed_data_dir=CURRENT_DATA_DIR,
    indices=None,
    compute_euclidean=False,
    center_point_index=2,
    max_sequence_length=MAX_SEQUENCE_LENGTH,
    selected_labels=None,
    label_map=None,
)

val_dataset = PreprocessedDataset(
    'val',
    processed_data_dir=CURRENT_DATA_DIR,
    indices=None,
    compute_euclidean=False,
    center_point_index=2,
    max_sequence_length=MAX_SEQUENCE_LENGTH,
    selected_labels=None,
    label_map=None,
)

test_dataset = PreprocessedDataset(
    'test',
    processed_data_dir=CURRENT_DATA_DIR,
    indices=None,
    compute_euclidean=False,
    center_point_index=2,
    max_sequence_length=MAX_SEQUENCE_LENGTH,
    selected_labels=None,
    label_map=None,
)

# %%
def preview_single(dataset, idx=0, timesteps_to_show=3, features_to_show=8):
    x, y = dataset[idx]
    print(f"\nSingle sample idx={idx} from split={dataset.dataset_name}")
    print(f"x shape: {tuple(x.shape)}, y: {y}")
    print(np.round(x[:timesteps_to_show, :features_to_show], 4))

preview_single(train_dataset, 0)
preview_single(val_dataset, 0)
preview_single(test_dataset, 0)
# Out:
# Single sample idx=0 from split=train
# x shape: (46, 1434), y: 0
# tensor([[ 0.0166,  0.1003,  0.0049,  0.0033, -0.0350, -0.0782,  0.0000,  0.0000],
#         [ 0.0074,  0.0975,  0.0028,  0.0024, -0.0366, -0.0783,  0.0000,  0.0000],
#         [ 0.0077,  0.0955,  0.0037,  0.0022, -0.0362, -0.0781,  0.0000,  0.0000]])
#
# Single sample idx=0 from split=val
# x shape: (46, 1434), y: 0
# tensor([[ 0.0002,  0.1079,  0.0064,  0.0040, -0.0341, -0.0773,  0.0000,  0.0000],
#         [-0.0022,  0.1043,  0.0072,  0.0032, -0.0341, -0.0777,  0.0000,  0.0000],
#         [-0.0005,  0.1048,  0.0073,  0.0031, -0.0340, -0.0774,  0.0000,  0.0000]])
#
# Single sample idx=0 from split=test
# x shape: (46, 1434), y: 0
# tensor([[ 0.0002,  0.0989,  0.0039,  0.0052, -0.0319, -0.0745,  0.0000,  0.0000],
#         [-0.0045,  0.0965,  0.0040,  0.0047, -0.0339, -0.0747,  0.0000,  0.0000],
#         [-0.0028,  0.0980,  0.0043,  0.0052, -0.0344, -0.0745,  0.0000,  0.0000]])

# %%
train_loader = DataLoader(train_dataset, batch_size=BATCH_SIZE, shuffle=True, num_workers=0, pin_memory=True)
for X, y in train_loader:
    print(X.shape, y.shape)  # (B, T_max, num_features)
    break

val_loader = DataLoader(val_dataset, batch_size=BATCH_SIZE, shuffle=True, num_workers=0, pin_memory=True)
for X, y in val_loader:
    print(X.shape, y.shape)  # (B, T_max, num_features)
    break

test_loader = DataLoader(test_dataset, batch_size=BATCH_SIZE, shuffle=True, num_workers=0, pin_memory=True)
for X, y in test_loader:
    print(X.shape, y.shape)  # (B, T_max, num_features)
    break
# Out:
# torch.Size([16, 46, 1434]) torch.Size([16])
# torch.Size([16, 46, 1434]) torch.Size([16])
# torch.Size([16, 46, 1434]) torch.Size([16])

# %% [markdown]
# #### Model preparation

# %%
model = STA_LSTM(NUM_FEATURES, HIDDEN_SIZE, NUM_LAYERS, NUM_CLASSES, DROPOUT_PROB).to(DEVICE)

# %% [markdown]
# #### Training

# %%
criterion = nn.CrossEntropyLoss()
optimizer = torch.optim.AdamW(model.parameters(), lr=LEARNING_RATE, weight_decay=WEIGHT_DECAY)

scheduler = ReduceLROnPlateau(
    optimizer,
    mode='max',
    factor=SCHEDULER_FACTOR,
    patience=10,
    min_lr=1e-7
)

model_name = 'testing_new_code_sta_lstm_5_classes_1434_coord.pt'
model_filepath = os.path.join(MODEL_SAVE_DIR, model_name)

# %%
trainer = Trainer(
    model=model,
    train_loader=train_loader,
    val_loader=val_loader,
    optimizer=optimizer,
    scheduler=scheduler,
    criterion=criterion,
    device=DEVICE,
    model_save_path=model_filepath,
    num_epochs=NUM_EPOCHS,
    monitor='val_acc',  # or 'val_loss'
    minimize_monitor=False,
    save_best_only=True
)

# %%
trainer.print_training_config()

# %%
final_model_path, best_model_path, history = trainer.fit()
print(f"Final model saved to: {final_model_path}")
if best_model_path:
    print(f"Best model saved to: {best_model_path}")
# Out:
# Starting training for 200 epochs on cuda
# Saved best model to /content/drive/MyDrive/PainRecognitionProject/models/best_testing_new_code_sta_lstm_5_classes_1434_coord.pt (metric=0.2000)
# Epoch 1/200 | Time 22.00s | Train loss 1.6642 | Train acc 0.2020 | Val loss 1.6345 | Val acc 0.2000
# Epoch 2/200 | Time 9.45s | Train loss 1.6485 | Train acc 0.1970 | Val loss 1.6110 | Val acc 0.2000
# Epoch 3/200 | Time 7.03s | Train loss 1.6374 | Train acc 0.2070 | Val loss 1.6256 | Val acc 0.2000
# Epoch 4/200 | Time 6.58s | Train loss 1.6315 | Train acc 0.2108 | Val loss 1.6115 | Val acc 0.2000
# Saved best model to /content/drive/MyDrive/PainRecognitionProject/models/best_testing_new_code_sta_lstm_5_classes_1434_coord.pt (metric=0.2008)
# Epoch 5/200 | Time 7.12s | Train loss 1.6272 | Train acc 0.2034 | Val loss 1.6096 | Val acc 0.2008
# Epoch 6/200 | Time 6.84s | Train loss 1.6274 | Train acc 0.1977 | Val loss 1.6136 | Val acc 0.2000
# Saved best model to /content/drive/MyDrive/PainRecognitionProject/models/best_testing_new_code_sta_lstm_5_classes_1434_coord.pt (metric=0.2146)
# Epoch 7/200 | Time 7.10s | Train loss 1.6277 | Train acc 0.2018 | Val loss 1.6094 | Val acc 0.2146
# Epoch 8/200 | Time 7.12s | Train loss 1.6249 | Train acc 0.2005 | Val loss 1.6139 | Val acc 0.2000
# Epoch 9/200 | Time 6.82s | Train loss 1.6206 | Train acc 0.2041 | Val loss 1.6082 | Val acc 0.2000
# Epoch 10/200 | Time 7.19s | Train loss 1.6212 | Train acc 0.1998 | Val loss 1.6120 | Val acc 0.2054
# Epoch 11/200 | Time 6.36s | Train loss 1.6215 | Train acc 0.2075 | Val loss 1.6124 | Val acc 0.1992
# Saved best model to /content/drive/MyDrive/PainRecognitionProject/models/best_testing_new_code_sta_lstm_5_classes_1434_coord.pt (metric=0.2162)
# Epoch 12/200 | Time 6.85s | Train loss 1.6166 | Train acc 0.2008 | Val loss 1.6122 | Val acc 0.2162
# Epoch 13/200 | Time 6.20s | Train loss 1.6164 | Train acc 0.2079 | Val loss 1.6153 | Val acc 0.2000
# Epoch 14/200 | Time 6.90s | Train loss 1.6154 | Train acc 0.2095 | Val loss 1.6198 | Val acc 0.1977
# Saved best model to /content/drive/MyDrive/PainRecognitionProject/models/best_testing_new_code_sta_lstm_5_classes_1434_coord.pt (metric=0.2292)
# Epoch 15/200 | Time 6.10s | Train loss 1.6172 | Train acc 0.2059 | Val loss 1.6080 | Val acc 0.2292
# Epoch 16/200 | Time 6.97s | Train loss 1.6140 | Train acc 0.2066 | Val loss 1.6048 | Val acc 0.2177
# Epoch 17/200 | Time 6.17s | Train loss 1.6110 | Train acc 0.2161 | Val loss 1.6068 | Val acc 0.2131
# Epoch 18/200 | Time 6.84s | Train loss 1.6063 | Train acc 0.2225 | Val loss 1.6303 | Val acc 0.2046
# Saved best model to /content/drive/MyDrive/PainRecognitionProject/models/best_testing_new_code_sta_lstm_5_classes_1434_coord.pt (metric=0.2400)
# Epoch 19/200 | Time 6.28s | Train loss 1.6043 | Train acc 0.2295 | Val loss 1.5940 | Val acc 0.2400
# Epoch 20/200 | Time 6.78s | Train loss 1.5996 | Train acc 0.2331 | Val loss 1.5987 | Val acc 0.2323
# Epoch 21/200 | Time 6.34s | Train loss 1.5951 | Train acc 0.2375 | Val loss 1.5927 | Val acc 0.2315
# Epoch 22/200 | Time 6.66s | Train loss 1.5946 | Train acc 0.2439 | Val loss 1.5955 | Val acc 0.2331
# Epoch 23/200 | Time 6.39s | Train loss 1.5907 | Train acc 0.2421 | Val loss 1.6066 | Val acc 0.2269
# Saved best model to /content/drive/MyDrive/PainRecognitionProject/models/best_testing_new_code_sta_lstm_5_classes_1434_coord.pt (metric=0.2492)
# Epoch 24/200 | Time 6.78s | Train loss 1.5901 | Train acc 0.2315 | Val loss 1.5822 | Val acc 0.2492
# Epoch 25/200 | Time 6.37s | Train loss 1.5825 | Train acc 0.2466 | Val loss 1.5858 | Val acc 0.2408
# Saved best model to /content/drive/MyDrive/PainRecognitionProject/models/best_testing_new_code_sta_lstm_5_classes_1434_coord.pt (metric=0.2538)
# Epoch 26/200 | Time 6.64s | Train loss 1.5817 | Train acc 0.2497 | Val loss 1.5693 | Val acc 0.2538
# Saved best model to /content/drive/MyDrive/PainRecognitionProject/models/best_testing_new_code_sta_lstm_5_classes_1434_coord.pt (metric=0.2769)
# Epoch 27/200 | Time 6.43s | Train loss 1.5812 | Train acc 0.2462 | Val loss 1.5756 | Val acc 0.2769
# Epoch 28/200 | Time 6.70s | Train loss 1.5776 | Train acc 0.2495 | Val loss 1.6256 | Val acc 0.2231
# Epoch 29/200 | Time 6.34s | Train loss 1.5719 | Train acc 0.2541 | Val loss 1.5846 | Val acc 0.2315
# Epoch 30/200 | Time 6.60s | Train loss 1.5760 | Train acc 0.2552 | Val loss 1.5642 | Val acc 0.2385
# Epoch 31/200 | Time 6.33s | Train loss 1.5712 | Train acc 0.2507 | Val loss 1.6123 | Val acc 0.2338
# Epoch 32/200 | Time 6.73s | Train loss 1.5713 | Train acc 0.2605 | Val loss 1.5879 | Val acc 0.2385
# Epoch 33/200 | Time 6.51s | Train loss 1.5658 | Train acc 0.2513 | Val loss 1.5545 | Val acc 0.2654
# Epoch 34/200 | Time 6.70s | Train loss 1.5667 | Train acc 0.2559 | Val loss 1.5602 | Val acc 0.2415
# Epoch 35/200 | Time 6.42s | Train loss 1.5629 | Train acc 0.2618 | Val loss 1.5743 | Val acc 0.2585
# Epoch 36/200 | Time 6.39s | Train loss 1.5622 | Train acc 0.2580 | Val loss 1.5494 | Val acc 0.2669
# Epoch 37/200 | Time 6.47s | Train loss 1.5596 | Train acc 0.2692 | Val loss 1.5457 | Val acc 0.2685
# Epoch 38/200 | Time 6.34s | Train loss 1.5633 | Train acc 0.2618 | Val loss 1.5801 | Val acc 0.2508
# Saved best model to /content/drive/MyDrive/PainRecognitionProject/models/best_testing_new_code_sta_lstm_5_classes_1434_coord.pt (metric=0.2815)
# Epoch 39/200 | Time 6.56s | Train loss 1.5612 | Train acc 0.2607 | Val loss 1.5419 | Val acc 0.2815
# Epoch 40/200 | Time 6.32s | Train loss 1.5531 | Train acc 0.2675 | Val loss 1.5422 | Val acc 0.2815
# Saved best model to /content/drive/MyDrive/PainRecognitionProject/models/best_testing_new_code_sta_lstm_5_classes_1434_coord.pt (metric=0.3000)
# Epoch 41/200 | Time 6.65s | Train loss 1.5565 | Train acc 0.2711 | Val loss 1.5375 | Val acc 0.3000
# Epoch 42/200 | Time 6.25s | Train loss 1.5542 | Train acc 0.2743 | Val loss 1.5436 | Val acc 0.2700
# Epoch 43/200 | Time 6.67s | Train loss 1.5582 | Train acc 0.2575 | Val loss 1.5484 | Val acc 0.2777
# Epoch 44/200 | Time 6.07s | Train loss 1.5552 | Train acc 0.2661 | Val loss 1.5389 | Val acc 0.2800
# Epoch 45/200 | Time 6.66s | Train loss 1.5515 | Train acc 0.2654 | Val loss 1.5406 | Val acc 0.2800
# Epoch 46/200 | Time 6.11s | Train loss 1.5489 | Train acc 0.2664 | Val loss 1.5447 | Val acc 0.2777
# Epoch 47/200 | Time 6.76s | Train loss 1.5495 | Train acc 0.2774 | Val loss 1.5669 | Val acc 0.2585
# Epoch 48/200 | Time 6.27s | Train loss 1.5499 | Train acc 0.2656 | Val loss 1.5693 | Val acc 0.2669
# Epoch 49/200 | Time 6.83s | Train loss 1.5522 | Train acc 0.2646 | Val loss 1.5557 | Val acc 0.2646
# Epoch 50/200 | Time 6.41s | Train loss 1.5463 | Train acc 0.2723 | Val loss 1.5489 | Val acc 0.2777
# Epoch 51/200 | Time 6.82s | Train loss 1.5459 | Train acc 0.2739 | Val loss 1.5723 | Val acc 0.2500
# Epoch 52/200 | Time 6.31s | Train loss 1.5490 | Train acc 0.2766 | Val loss 1.5370 | Val acc 0.2885
# Epoch 53/200 | Time 6.86s | Train loss 1.5431 | Train acc 0.2730 | Val loss 1.5323 | Val acc 0.2838
# Epoch 54/200 | Time 6.20s | Train loss 1.5443 | Train acc 0.2711 | Val loss 1.5326 | Val acc 0.2831
# Epoch 55/200 | Time 7.06s | Train loss 1.5423 | Train acc 0.2708 | Val loss 1.5450 | Val acc 0.2723
# Epoch 56/200 | Time 6.61s | Train loss 1.5419 | Train acc 0.2792 | Val loss 1.5462 | Val acc 0.2777
# Epoch 57/200 | Time 6.94s | Train loss 1.5424 | Train acc 0.2795 | Val loss 1.5809 | Val acc 0.2623
# Epoch 58/200 | Time 6.53s | Train loss 1.5402 | Train acc 0.2780 | Val loss 1.5390 | Val acc 0.2892
# Epoch 59/200 | Time 6.85s | Train loss 1.5389 | Train acc 0.2834 | Val loss 1.5343 | Val acc 0.2831
# Epoch 60/200 | Time 6.36s | Train loss 1.5462 | Train acc 0.2708 | Val loss 1.5403 | Val acc 0.2800
# Epoch 61/200 | Time 6.78s | Train loss 1.5419 | Train acc 0.2695 | Val loss 1.5297 | Val acc 0.2923
# Epoch 62/200 | Time 6.37s | Train loss 1.5379 | Train acc 0.2772 | Val loss 1.5349 | Val acc 0.2908
# Epoch 63/200 | Time 6.67s | Train loss 1.5379 | Train acc 0.2826 | Val loss 1.5534 | Val acc 0.2700
# Epoch 64/200 | Time 6.35s | Train loss 1.5405 | Train acc 0.2730 | Val loss 1.5379 | Val acc 0.2854
# Epoch 65/200 | Time 6.70s | Train loss 1.5342 | Train acc 0.2823 | Val loss 1.5488 | Val acc 0.2646
# Epoch 66/200 | Time 6.23s | Train loss 1.5378 | Train acc 0.2787 | Val loss 1.5366 | Val acc 0.2769
# Epoch 67/200 | Time 6.84s | Train loss 1.5372 | Train acc 0.2811 | Val loss 1.5539 | Val acc 0.2608
# Epoch 68/200 | Time 6.27s | Train loss 1.5317 | Train acc 0.2880 | Val loss 1.5371 | Val acc 0.2908
# Epoch 69/200 | Time 7.03s | Train loss 1.5323 | Train acc 0.2870 | Val loss 1.5350 | Val acc 0.2900
# Epoch 70/200 | Time 6.42s | Train loss 1.5339 | Train acc 0.2756 | Val loss 1.5412 | Val acc 0.2731
# Epoch 71/200 | Time 6.78s | Train loss 1.5363 | Train acc 0.2813 | Val loss 1.5312 | Val acc 0.2946
# Epoch 72/200 | Time 6.63s | Train loss 1.5325 | Train acc 0.2839 | Val loss 1.5269 | Val acc 0.2746
# Epoch 73/200 | Time 6.76s | Train loss 1.5313 | Train acc 0.2798 | Val loss 1.5358 | Val acc 0.2946
# Epoch 74/200 | Time 6.40s | Train loss 1.5319 | Train acc 0.2841 | Val loss 1.5310 | Val acc 0.2962
# Epoch 75/200 | Time 6.81s | Train loss 1.5277 | Train acc 0.2892 | Val loss 1.5445 | Val acc 0.2762
# Epoch 76/200 | Time 6.30s | Train loss 1.5279 | Train acc 0.2789 | Val loss 1.5289 | Val acc 0.2885
# Epoch 77/200 | Time 6.73s | Train loss 1.5242 | Train acc 0.2846 | Val loss 1.5357 | Val acc 0.2900
# Epoch 78/200 | Time 6.31s | Train loss 1.5253 | Train acc 0.2939 | Val loss 1.5416 | Val acc 0.2823
# Epoch 79/200 | Time 6.73s | Train loss 1.5250 | Train acc 0.2877 | Val loss 1.5531 | Val acc 0.2654
# Epoch 80/200 | Time 6.33s | Train loss 1.5273 | Train acc 0.2805 | Val loss 1.5291 | Val acc 0.2792
# Epoch 81/200 | Time 6.69s | Train loss 1.5301 | Train acc 0.2849 | Val loss 1.5340 | Val acc 0.2908
# Epoch 82/200 | Time 6.25s | Train loss 1.5250 | Train acc 0.2870 | Val loss 1.5354 | Val acc 0.2777
# Epoch 83/200 | Time 6.69s | Train loss 1.5228 | Train acc 0.2831 | Val loss 1.5367 | Val acc 0.2908
# Epoch 84/200 | Time 6.22s | Train loss 1.5240 | Train acc 0.2933 | Val loss 1.5322 | Val acc 0.2846
# Epoch 85/200 | Time 6.72s | Train loss 1.5251 | Train acc 0.2818 | Val loss 1.5516 | Val acc 0.2792
# Epoch 86/200 | Time 6.18s | Train loss 1.5251 | Train acc 0.2898 | Val loss 1.5290 | Val acc 0.2900
# Epoch 87/200 | Time 6.88s | Train loss 1.5204 | Train acc 0.2897 | Val loss 1.5195 | Val acc 0.2946
# Epoch 88/200 | Time 6.10s | Train loss 1.5206 | Train acc 0.2964 | Val loss 1.5246 | Val acc 0.2908
# Epoch 89/200 | Time 6.82s | Train loss 1.5200 | Train acc 0.2898 | Val loss 1.5358 | Val acc 0.2777
# Epoch 90/200 | Time 6.12s | Train loss 1.5196 | Train acc 0.2874 | Val loss 1.5235 | Val acc 0.2908
# Epoch 91/200 | Time 6.86s | Train loss 1.5197 | Train acc 0.2834 | Val loss 1.5332 | Val acc 0.2823
# Epoch 92/200 | Time 6.22s | Train loss 1.5226 | Train acc 0.2887 | Val loss 1.5215 | Val acc 0.3000
# Epoch 93/200 | Time 6.78s | Train loss 1.5179 | Train acc 0.2964 | Val loss 1.5194 | Val acc 0.2969
# Saved best model to /content/drive/MyDrive/PainRecognitionProject/models/best_testing_new_code_sta_lstm_5_classes_1434_coord.pt (metric=0.3008)
# Epoch 94/200 | Time 6.18s | Train loss 1.5196 | Train acc 0.2874 | Val loss 1.5231 | Val acc 0.3008
# Epoch 95/200 | Time 6.86s | Train loss 1.5172 | Train acc 0.2862 | Val loss 1.5369 | Val acc 0.2862
# Epoch 96/200 | Time 6.09s | Train loss 1.5169 | Train acc 0.2885 | Val loss 1.5298 | Val acc 0.2800
# Saved best model to /content/drive/MyDrive/PainRecognitionProject/models/best_testing_new_code_sta_lstm_5_classes_1434_coord.pt (metric=0.3023)
# Epoch 97/200 | Time 6.94s | Train loss 1.5171 | Train acc 0.2975 | Val loss 1.5222 | Val acc 0.3023
# Saved best model to /content/drive/MyDrive/PainRecognitionProject/models/best_testing_new_code_sta_lstm_5_classes_1434_coord.pt (metric=0.3069)
# Epoch 98/200 | Time 6.27s | Train loss 1.5133 | Train acc 0.2959 | Val loss 1.5268 | Val acc 0.3069
# Epoch 99/200 | Time 6.87s | Train loss 1.5182 | Train acc 0.2821 | Val loss 1.5312 | Val acc 0.2885
# Epoch 100/200 | Time 6.16s | Train loss 1.5162 | Train acc 0.2838 | Val loss 1.5287 | Val acc 0.2854
# Saved best model to /content/drive/MyDrive/PainRecognitionProject/models/best_testing_new_code_sta_lstm_5_classes_1434_coord.pt (metric=0.3092)
# Epoch 101/200 | Time 6.88s | Train loss 1.5132 | Train acc 0.2898 | Val loss 1.5226 | Val acc 0.3092
# Epoch 102/200 | Time 6.09s | Train loss 1.5177 | Train acc 0.2880 | Val loss 1.5278 | Val acc 0.2908
# Epoch 103/200 | Time 6.92s | Train loss 1.5109 | Train acc 0.2908 | Val loss 1.5298 | Val acc 0.2846
# Epoch 104/200 | Time 6.28s | Train loss 1.5111 | Train acc 0.2989 | Val loss 1.5344 | Val acc 0.2846
# Epoch 105/200 | Time 6.84s | Train loss 1.5125 | Train acc 0.2941 | Val loss 1.5292 | Val acc 0.2931
# Epoch 106/200 | Time 6.08s | Train loss 1.5111 | Train acc 0.3015 | Val loss 1.5264 | Val acc 0.2854
# Epoch 107/200 | Time 6.88s | Train loss 1.5149 | Train acc 0.2910 | Val loss 1.5224 | Val acc 0.2923
# Epoch 108/200 | Time 6.26s | Train loss 1.5133 | Train acc 0.2961 | Val loss 1.5224 | Val acc 0.2815
# Epoch 109/200 | Time 6.81s | Train loss 1.5126 | Train acc 0.2866 | Val loss 1.5204 | Val acc 0.2962
# Epoch 110/200 | Time 6.18s | Train loss 1.5115 | Train acc 0.2905 | Val loss 1.5175 | Val acc 0.3008
# Epoch 111/200 | Time 6.90s | Train loss 1.5110 | Train acc 0.2889 | Val loss 1.5171 | Val acc 0.2900
# Epoch 112/200 | Time 6.27s | Train loss 1.5137 | Train acc 0.2943 | Val loss 1.5262 | Val acc 0.3031
# Epoch 113/200 | Time 7.04s | Train loss 1.5089 | Train acc 0.2916 | Val loss 1.5244 | Val acc 0.2923
# Epoch 114/200 | Time 6.18s | Train loss 1.5105 | Train acc 0.2946 | Val loss 1.5330 | Val acc 0.2838
# Epoch 115/200 | Time 6.87s | Train loss 1.5115 | Train acc 0.2957 | Val loss 1.5257 | Val acc 0.2669
# Epoch 116/200 | Time 6.13s | Train loss 1.5099 | Train acc 0.3028 | Val loss 1.5422 | Val acc 0.2831
# Epoch 117/200 | Time 6.85s | Train loss 1.5095 | Train acc 0.2905 | Val loss 1.5164 | Val acc 0.2877
# Epoch 118/200 | Time 6.23s | Train loss 1.5079 | Train acc 0.2933 | Val loss 1.5208 | Val acc 0.2938
# Epoch 119/200 | Time 6.87s | Train loss 1.5093 | Train acc 0.2974 | Val loss 1.5298 | Val acc 0.2862
# Epoch 120/200 | Time 6.19s | Train loss 1.5044 | Train acc 0.2946 | Val loss 1.5244 | Val acc 0.2915
# Epoch 121/200 | Time 6.80s | Train loss 1.5043 | Train acc 0.2944 | Val loss 1.5511 | Val acc 0.2569
# Epoch 122/200 | Time 6.17s | Train loss 1.5047 | Train acc 0.2970 | Val loss 1.5408 | Val acc 0.2662
# Epoch 123/200 | Time 6.84s | Train loss 1.5049 | Train acc 0.2993 | Val loss 1.5382 | Val acc 0.2846
# Epoch 124/200 | Time 6.09s | Train loss 1.5028 | Train acc 0.2902 | Val loss 1.5292 | Val acc 0.2777
# Epoch 125/200 | Time 6.87s | Train loss 1.5033 | Train acc 0.2966 | Val loss 1.5227 | Val acc 0.2908
# Epoch 126/200 | Time 6.13s | Train loss 1.5043 | Train acc 0.2943 | Val loss 1.5323 | Val acc 0.2892
# Epoch 127/200 | Time 6.84s | Train loss 1.5050 | Train acc 0.3002 | Val loss 1.5213 | Val acc 0.2900
# Epoch 128/200 | Time 6.14s | Train loss 1.4986 | Train acc 0.3025 | Val loss 1.5234 | Val acc 0.2892
# Epoch 129/200 | Time 6.88s | Train loss 1.5010 | Train acc 0.3034 | Val loss 1.5155 | Val acc 0.2985
# Epoch 130/200 | Time 6.09s | Train loss 1.5023 | Train acc 0.2923 | Val loss 1.5203 | Val acc 0.3000
# Epoch 131/200 | Time 6.94s | Train loss 1.4981 | Train acc 0.3015 | Val loss 1.5276 | Val acc 0.2854
# Epoch 132/200 | Time 6.15s | Train loss 1.4989 | Train acc 0.3016 | Val loss 1.5203 | Val acc 0.2946
# Epoch 133/200 | Time 6.86s | Train loss 1.4973 | Train acc 0.3052 | Val loss 1.5320 | Val acc 0.2838
# Epoch 134/200 | Time 6.09s | Train loss 1.4962 | Train acc 0.3089 | Val loss 1.5309 | Val acc 0.2815
# Epoch 135/200 | Time 6.82s | Train loss 1.4968 | Train acc 0.3095 | Val loss 1.5374 | Val acc 0.2738
# Epoch 136/200 | Time 6.11s | Train loss 1.4959 | Train acc 0.3052 | Val loss 1.5401 | Val acc 0.2654
# Epoch 137/200 | Time 6.83s | Train loss 1.4957 | Train acc 0.2984 | Val loss 1.5344 | Val acc 0.2869
# Epoch 138/200 | Time 6.07s | Train loss 1.4961 | Train acc 0.3075 | Val loss 1.5309 | Val acc 0.2715
# Epoch 139/200 | Time 6.77s | Train loss 1.4945 | Train acc 0.3000 | Val loss 1.5166 | Val acc 0.2977
# Epoch 140/200 | Time 6.13s | Train loss 1.4936 | Train acc 0.3041 | Val loss 1.5195 | Val acc 0.2962
# Epoch 141/200 | Time 6.98s | Train loss 1.4973 | Train acc 0.3013 | Val loss 1.5373 | Val acc 0.2723
# Epoch 142/200 | Time 6.09s | Train loss 1.4937 | Train acc 0.3000 | Val loss 1.5337 | Val acc 0.2992
# Epoch 143/200 | Time 6.94s | Train loss 1.4952 | Train acc 0.3061 | Val loss 1.5202 | Val acc 0.2946
# Epoch 144/200 | Time 6.21s | Train loss 1.4921 | Train acc 0.3049 | Val loss 1.5203 | Val acc 0.2931
# Epoch 145/200 | Time 6.85s | Train loss 1.4916 | Train acc 0.3044 | Val loss 1.5270 | Val acc 0.2946
# Epoch 146/200 | Time 6.11s | Train loss 1.4885 | Train acc 0.3062 | Val loss 1.5284 | Val acc 0.2869
# Epoch 147/200 | Time 6.79s | Train loss 1.4921 | Train acc 0.3074 | Val loss 1.5393 | Val acc 0.2869
# Epoch 148/200 | Time 6.25s | Train loss 1.4904 | Train acc 0.2979 | Val loss 1.5287 | Val acc 0.2923
# Epoch 149/200 | Time 6.88s | Train loss 1.4918 | Train acc 0.3041 | Val loss 1.5314 | Val acc 0.2785
# Epoch 150/200 | Time 6.09s | Train loss 1.4920 | Train acc 0.3030 | Val loss 1.5301 | Val acc 0.2892
# Epoch 151/200 | Time 6.93s | Train loss 1.4877 | Train acc 0.3115 | Val loss 1.5296 | Val acc 0.2831
# Epoch 152/200 | Time 6.19s | Train loss 1.4899 | Train acc 0.2987 | Val loss 1.5376 | Val acc 0.2831
# Epoch 153/200 | Time 6.91s | Train loss 1.4896 | Train acc 0.3043 | Val loss 1.5171 | Val acc 0.3046
# Epoch 154/200 | Time 6.23s | Train loss 1.4878 | Train acc 0.3067 | Val loss 1.5220 | Val acc 0.2946
# Epoch 155/200 | Time 6.88s | Train loss 1.4900 | Train acc 0.3007 | Val loss 1.5313 | Val acc 0.2700
# Epoch 156/200 | Time 6.18s | Train loss 1.4856 | Train acc 0.3082 | Val loss 1.5483 | Val acc 0.2631
# Epoch 157/200 | Time 6.82s | Train loss 1.4864 | Train acc 0.3110 | Val loss 1.5419 | Val acc 0.2777
# Epoch 158/200 | Time 6.20s | Train loss 1.4875 | Train acc 0.3061 | Val loss 1.5240 | Val acc 0.2954
# Epoch 159/200 | Time 6.95s | Train loss 1.4855 | Train acc 0.3123 | Val loss 1.5327 | Val acc 0.2954
# Epoch 160/200 | Time 6.19s | Train loss 1.4869 | Train acc 0.2995 | Val loss 1.5246 | Val acc 0.2908
# Epoch 161/200 | Time 6.97s | Train loss 1.4852 | Train acc 0.3048 | Val loss 1.5299 | Val acc 0.2815
# Epoch 162/200 | Time 6.12s | Train loss 1.4817 | Train acc 0.3070 | Val loss 1.5424 | Val acc 0.2769
# Epoch 163/200 | Time 6.91s | Train loss 1.4816 | Train acc 0.3074 | Val loss 1.5402 | Val acc 0.2838
# Epoch 164/200 | Time 6.11s | Train loss 1.4821 | Train acc 0.3111 | Val loss 1.5223 | Val acc 0.2954
# Epoch 165/200 | Time 6.96s | Train loss 1.4824 | Train acc 0.3089 | Val loss 1.5217 | Val acc 0.2938
# Epoch 166/200 | Time 6.15s | Train loss 1.4843 | Train acc 0.3057 | Val loss 1.5452 | Val acc 0.2769
# Epoch 167/200 | Time 7.03s | Train loss 1.4824 | Train acc 0.3146 | Val loss 1.5529 | Val acc 0.2900
# Epoch 168/200 | Time 6.24s | Train loss 1.4820 | Train acc 0.3093 | Val loss 1.5418 | Val acc 0.2846
# Epoch 169/200 | Time 6.99s | Train loss 1.4815 | Train acc 0.3126 | Val loss 1.5580 | Val acc 0.2654
# Epoch 170/200 | Time 6.21s | Train loss 1.4810 | Train acc 0.3062 | Val loss 1.5329 | Val acc 0.2869
# Epoch 171/200 | Time 6.86s | Train loss 1.4813 | Train acc 0.3126 | Val loss 1.5380 | Val acc 0.2792
# Epoch 172/200 | Time 6.25s | Train loss 1.4775 | Train acc 0.3162 | Val loss 1.5274 | Val acc 0.2877
# Epoch 173/200 | Time 6.92s | Train loss 1.4817 | Train acc 0.3052 | Val loss 1.5388 | Val acc 0.2923
# Epoch 174/200 | Time 6.35s | Train loss 1.4773 | Train acc 0.3136 | Val loss 1.5351 | Val acc 0.2892
# Epoch 175/200 | Time 6.94s | Train loss 1.4810 | Train acc 0.3103 | Val loss 1.5255 | Val acc 0.2962
# Epoch 176/200 | Time 6.22s | Train loss 1.4759 | Train acc 0.3120 | Val loss 1.5420 | Val acc 0.2908
# Epoch 177/200 | Time 6.96s | Train loss 1.4731 | Train acc 0.3185 | Val loss 1.5469 | Val acc 0.2692
# Epoch 178/200 | Time 6.21s | Train loss 1.4769 | Train acc 0.3102 | Val loss 1.5393 | Val acc 0.2862
# Epoch 179/200 | Time 6.85s | Train loss 1.4791 | Train acc 0.3061 | Val loss 1.5299 | Val acc 0.2846
# Epoch 180/200 | Time 6.23s | Train loss 1.4774 | Train acc 0.3100 | Val loss 1.5452 | Val acc 0.2877
# Epoch 181/200 | Time 6.97s | Train loss 1.4747 | Train acc 0.3180 | Val loss 1.5384 | Val acc 0.2931
# Epoch 182/200 | Time 6.19s | Train loss 1.4783 | Train acc 0.3093 | Val loss 1.5283 | Val acc 0.2808
# Epoch 183/200 | Time 7.06s | Train loss 1.4719 | Train acc 0.3154 | Val loss 1.5377 | Val acc 0.2738
# Epoch 184/200 | Time 6.11s | Train loss 1.4731 | Train acc 0.3144 | Val loss 1.5380 | Val acc 0.2715
# Epoch 185/200 | Time 6.89s | Train loss 1.4693 | Train acc 0.3239 | Val loss 1.5503 | Val acc 0.2762
# Epoch 186/200 | Time 6.32s | Train loss 1.4744 | Train acc 0.3144 | Val loss 1.5376 | Val acc 0.2877
# Epoch 187/200 | Time 6.89s | Train loss 1.4742 | Train acc 0.3092 | Val loss 1.5604 | Val acc 0.2769
# Epoch 188/200 | Time 6.26s | Train loss 1.4698 | Train acc 0.3189 | Val loss 1.5303 | Val acc 0.2923
# Epoch 189/200 | Time 6.90s | Train loss 1.4772 | Train acc 0.3157 | Val loss 1.5617 | Val acc 0.2554
# Epoch 190/200 | Time 6.19s | Train loss 1.4669 | Train acc 0.3182 | Val loss 1.5254 | Val acc 0.2877
# Epoch 191/200 | Time 6.94s | Train loss 1.4740 | Train acc 0.3108 | Val loss 1.5670 | Val acc 0.2746
# Epoch 192/200 | Time 6.24s | Train loss 1.4703 | Train acc 0.3116 | Val loss 1.5332 | Val acc 0.2869
# Epoch 193/200 | Time 6.91s | Train loss 1.4703 | Train acc 0.3130 | Val loss 1.5619 | Val acc 0.2785
# Epoch 194/200 | Time 6.21s | Train loss 1.4705 | Train acc 0.3143 | Val loss 1.5540 | Val acc 0.2785
# Epoch 195/200 | Time 6.90s | Train loss 1.4677 | Train acc 0.3151 | Val loss 1.5451 | Val acc 0.2954
# Epoch 196/200 | Time 6.20s | Train loss 1.4678 | Train acc 0.3177 | Val loss 1.5604 | Val acc 0.2862
# Epoch 197/200 | Time 6.87s | Train loss 1.4722 | Train acc 0.3136 | Val loss 1.5510 | Val acc 0.2800
# Epoch 198/200 | Time 6.14s | Train loss 1.4679 | Train acc 0.3203 | Val loss 1.5346 | Val acc 0.2931
# Epoch 199/200 | Time 6.88s | Train loss 1.4671 | Train acc 0.3225 | Val loss 1.5463 | Val acc 0.2877
# Epoch 200/200 | Time 6.18s | Train loss 1.4648 | Train acc 0.3200 | Val loss 1.5409 | Val acc 0.2946
# Training finished. Best epoch: 100. Best monitored metric: 0.3092
# Final model saved to: /content/drive/MyDrive/PainRecognitionProject/models/testing_new_code_sta_lstm_5_classes_1434_coord.pt
# Best model saved to: /content/drive/MyDrive/PainRecognitionProject/models/best_testing_new_code_sta_lstm_5_classes_1434_coord.pt

# %%
trainer.plot_history()

# %% [markdown]
# #### Evaluate

# %%
model.load_state_dict(torch.load(best_model_path, map_location=DEVICE), strict=False)
# Out:
# <All keys matched successfully>

# %%
evaluator = Evaluator(model, test_loader, device=DEVICE, model_name=model_name, num_classes=NUM_CLASSES)

# %%
loss, acc, labels, preds = evaluator.evaluate_epoch()
# Out:
# ==================================================
# WYNIKI OCENY DLA MODELU: testing_new_code_sta_lstm_5_classes_1434_coord.pt
# ==================================================
# Test Loss: 1.6300
# Test Accuracy: 0.2885
#
# --- Szczegółowy Raport Klasyfikacji ---
#               precision    recall  f1-score   support
#
#      Klasa 0       0.27      0.52      0.35       260
#      Klasa 1       0.32      0.03      0.06       260
#      Klasa 2       0.25      0.17      0.20       260
#      Klasa 3       0.18      0.12      0.15       260
#      Klasa 4       0.38      0.59      0.46       260
#
#     accuracy                           0.29      1300
#    macro avg       0.28      0.29      0.25      1300
# weighted avg       0.28      0.29      0.25      1300
#
# ==================================================
# Confusion matrix:
#  [[136   5  45  35  39]
#  [129   9  40  33  49]
#  [102   4  45  45  64]
#  [ 91   5  29  32 103]
#  [ 50   5  21  31 153]]
