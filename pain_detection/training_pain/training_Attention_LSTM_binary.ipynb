# %% [markdown]
# ### Attention-LSTM model - binary training

# %% [markdown]
# #### Environment preparation

# %%
# Montowanie Google Drive
from google.colab import drive
drive.mount('/content/drive')

COLAB_ROOT = '/content/drive/MyDrive/PainRecognitionProject/'
print(f"Dane będą wczytywane z: {COLAB_ROOT}")
# Out:
# Mounted at /content/drive
# Dane będą wczytywane z: /content/drive/MyDrive/PainRecognitionProject/

# %%
import os

# Przejście do katalogu głównego
# %cd /content

# Klonowanie repo
# !rm -rf automatic-pain-recognition

print(f"Obecne położenie: {os.getcwd()}")
# Out:
# /content
# Obecne położenie: /content

# %%
# Upewnij się, że nazwa użytkownika i repozytorium są poprawne
USERNAME = 'alicka33'
REPO_NAME = 'automatic-pain-recognition'

# Tworzenie poprawnego adresu URL (format: https://<TOKEN>@github.com/...)
REPO_URL = f"https://github.com/{USERNAME}/{REPO_NAME}.git"

print("Rozpoczynam klonowanie...")

# Klonowanie
# !git clone {REPO_URL}

# Wejście do katalogu
# %cd $REPO_NAME
# Out:
# Rozpoczynam klonowanie...
# Cloning into 'automatic-pain-recognition'...
# remote: Enumerating objects: 266, done.
# remote: Counting objects: 100% (266/266), done.
# remote: Compressing objects: 100% (210/210), done.
# remote: Total 266 (delta 119), reused 197 (delta 52), pack-reused 0 (from 0)
# Receiving objects: 100% (266/266), 11.27 MiB | 15.05 MiB/s, done.
# Resolving deltas: 100% (119/119), done.
# /content/automatic-pain-recognition

# %%
# Instalacja wymaganych bibliotek
# !pip install -r requirements.txt
# Out:
# Requirement already satisfied: torch>=1.10.0 in /usr/local/lib/python3.12/dist-packages (from -r requirements.txt (line 2)) (2.9.0+cu126)
# Requirement already satisfied: torchvision>=0.11.0 in /usr/local/lib/python3.12/dist-packages (from -r requirements.txt (line 3)) (0.24.0+cu126)
# Requirement already satisfied: torchaudio>=0.10.0 in /usr/local/lib/python3.12/dist-packages (from -r requirements.txt (line 4)) (2.9.0+cu126)
# Requirement already satisfied: pandas>=1.3.0 in /usr/local/lib/python3.12/dist-packages (from -r requirements.txt (line 7)) (2.2.2)
# Requirement already satisfied: numpy>=1.21.0 in /usr/local/lib/python3.12/dist-packages (from -r requirements.txt (line 8)) (2.0.2)
# Requirement already satisfied: opencv-python>=4.5.5 in /usr/local/lib/python3.12/dist-packages (from -r requirements.txt (line 11)) (4.12.0.88)
# Requirement already satisfied: dlib>=19.24.2 in /usr/local/lib/python3.12/dist-packages (from -r requirements.txt (line 12)) (19.24.6)
# Requirement already satisfied: imutils>=0.5.4 in /usr/local/lib/python3.12/dist-packages (from -r requirements.txt (line 13)) (0.5.4)
# Collecting mediapipe>=0.10.15 (from -r requirements.txt (line 14))
#   Downloading mediapipe-0.10.31-py3-none-manylinux_2_28_x86_64.whl.metadata (9.7 kB)
# Requirement already satisfied: scikit-learn>=1.0.0 in /usr/local/lib/python3.12/dist-packages (from -r requirements.txt (line 17)) (1.6.1)
# Requirement already satisfied: tqdm>=4.62.3 in /usr/local/lib/python3.12/dist-packages (from -r requirements.txt (line 20)) (4.67.1)
# Requirement already satisfied: matplotlib>=3.5.0 in /usr/local/lib/python3.12/dist-packages (from -r requirements.txt (line 23)) (3.10.0)
# Requirement already satisfied: shap>=0.44.0 in /usr/local/lib/python3.12/dist-packages (from -r requirements.txt (line 26)) (0.50.0)
# Requirement already satisfied: filelock in /usr/local/lib/python3.12/dist-packages (from torch>=1.10.0->-r requirements.txt (line 2)) (3.20.0)
# Requirement already satisfied: typing-extensions>=4.10.0 in /usr/local/lib/python3.12/dist-packages (from torch>=1.10.0->-r requirements.txt (line 2)) (4.15.0)
# Requirement already satisfied: setuptools in /usr/local/lib/python3.12/dist-packages (from torch>=1.10.0->-r requirements.txt (line 2)) (75.2.0)
# Requirement already satisfied: sympy>=1.13.3 in /usr/local/lib/python3.12/dist-packages (from torch>=1.10.0->-r requirements.txt (line 2)) (1.14.0)
# Requirement already satisfied: networkx>=2.5.1 in /usr/local/lib/python3.12/dist-packages (from torch>=1.10.0->-r requirements.txt (line 2)) (3.6.1)
# Requirement already satisfied: jinja2 in /usr/local/lib/python3.12/dist-packages (from torch>=1.10.0->-r requirements.txt (line 2)) (3.1.6)
# Requirement already satisfied: fsspec>=0.8.5 in /usr/local/lib/python3.12/dist-packages (from torch>=1.10.0->-r requirements.txt (line 2)) (2025.3.0)
# Requirement already satisfied: nvidia-cuda-nvrtc-cu12==12.6.77 in /usr/local/lib/python3.12/dist-packages (from torch>=1.10.0->-r requirements.txt (line 2)) (12.6.77)
# Requirement already satisfied: nvidia-cuda-runtime-cu12==12.6.77 in /usr/local/lib/python3.12/dist-packages (from torch>=1.10.0->-r requirements.txt (line 2)) (12.6.77)
# Requirement already satisfied: nvidia-cuda-cupti-cu12==12.6.80 in /usr/local/lib/python3.12/dist-packages (from torch>=1.10.0->-r requirements.txt (line 2)) (12.6.80)
# Requirement already satisfied: nvidia-cudnn-cu12==9.10.2.21 in /usr/local/lib/python3.12/dist-packages (from torch>=1.10.0->-r requirements.txt (line 2)) (9.10.2.21)
# Requirement already satisfied: nvidia-cublas-cu12==12.6.4.1 in /usr/local/lib/python3.12/dist-packages (from torch>=1.10.0->-r requirements.txt (line 2)) (12.6.4.1)
# Requirement already satisfied: nvidia-cufft-cu12==11.3.0.4 in /usr/local/lib/python3.12/dist-packages (from torch>=1.10.0->-r requirements.txt (line 2)) (11.3.0.4)
# Requirement already satisfied: nvidia-curand-cu12==10.3.7.77 in /usr/local/lib/python3.12/dist-packages (from torch>=1.10.0->-r requirements.txt (line 2)) (10.3.7.77)
# Requirement already satisfied: nvidia-cusolver-cu12==11.7.1.2 in /usr/local/lib/python3.12/dist-packages (from torch>=1.10.0->-r requirements.txt (line 2)) (11.7.1.2)
# Requirement already satisfied: nvidia-cusparse-cu12==12.5.4.2 in /usr/local/lib/python3.12/dist-packages (from torch>=1.10.0->-r requirements.txt (line 2)) (12.5.4.2)
# Requirement already satisfied: nvidia-cusparselt-cu12==0.7.1 in /usr/local/lib/python3.12/dist-packages (from torch>=1.10.0->-r requirements.txt (line 2)) (0.7.1)
# Requirement already satisfied: nvidia-nccl-cu12==2.27.5 in /usr/local/lib/python3.12/dist-packages (from torch>=1.10.0->-r requirements.txt (line 2)) (2.27.5)
# Requirement already satisfied: nvidia-nvshmem-cu12==3.3.20 in /usr/local/lib/python3.12/dist-packages (from torch>=1.10.0->-r requirements.txt (line 2)) (3.3.20)
# Requirement already satisfied: nvidia-nvtx-cu12==12.6.77 in /usr/local/lib/python3.12/dist-packages (from torch>=1.10.0->-r requirements.txt (line 2)) (12.6.77)
# Requirement already satisfied: nvidia-nvjitlink-cu12==12.6.85 in /usr/local/lib/python3.12/dist-packages (from torch>=1.10.0->-r requirements.txt (line 2)) (12.6.85)
# Requirement already satisfied: nvidia-cufile-cu12==1.11.1.6 in /usr/local/lib/python3.12/dist-packages (from torch>=1.10.0->-r requirements.txt (line 2)) (1.11.1.6)
# Requirement already satisfied: triton==3.5.0 in /usr/local/lib/python3.12/dist-packages (from torch>=1.10.0->-r requirements.txt (line 2)) (3.5.0)
# Requirement already satisfied: pillow!=8.3.*,>=5.3.0 in /usr/local/lib/python3.12/dist-packages (from torchvision>=0.11.0->-r requirements.txt (line 3)) (11.3.0)
# Requirement already satisfied: python-dateutil>=2.8.2 in /usr/local/lib/python3.12/dist-packages (from pandas>=1.3.0->-r requirements.txt (line 7)) (2.9.0.post0)
# Requirement already satisfied: pytz>=2020.1 in /usr/local/lib/python3.12/dist-packages (from pandas>=1.3.0->-r requirements.txt (line 7)) (2025.2)
# Requirement already satisfied: tzdata>=2022.7 in /usr/local/lib/python3.12/dist-packages (from pandas>=1.3.0->-r requirements.txt (line 7)) (2025.3)
# Collecting absl-py~=2.3 (from mediapipe>=0.10.15->-r requirements.txt (line 14))
#   Downloading absl_py-2.3.1-py3-none-any.whl.metadata (3.3 kB)
# Collecting sounddevice~=0.5 (from mediapipe>=0.10.15->-r requirements.txt (line 14))
#   Downloading sounddevice-0.5.3-py3-none-any.whl.metadata (1.6 kB)
# Requirement already satisfied: flatbuffers~=25.9 in /usr/local/lib/python3.12/dist-packages (from mediapipe>=0.10.15->-r requirements.txt (line 14)) (25.9.23)
# Requirement already satisfied: scipy>=1.6.0 in /usr/local/lib/python3.12/dist-packages (from scikit-learn>=1.0.0->-r requirements.txt (line 17)) (1.16.3)
# Requirement already satisfied: joblib>=1.2.0 in /usr/local/lib/python3.12/dist-packages (from scikit-learn>=1.0.0->-r requirements.txt (line 17)) (1.5.3)
# Requirement already satisfied: threadpoolctl>=3.1.0 in /usr/local/lib/python3.12/dist-packages (from scikit-learn>=1.0.0->-r requirements.txt (line 17)) (3.6.0)
# Requirement already satisfied: contourpy>=1.0.1 in /usr/local/lib/python3.12/dist-packages (from matplotlib>=3.5.0->-r requirements.txt (line 23)) (1.3.3)
# Requirement already satisfied: cycler>=0.10 in /usr/local/lib/python3.12/dist-packages (from matplotlib>=3.5.0->-r requirements.txt (line 23)) (0.12.1)
# Requirement already satisfied: fonttools>=4.22.0 in /usr/local/lib/python3.12/dist-packages (from matplotlib>=3.5.0->-r requirements.txt (line 23)) (4.61.1)
# Requirement already satisfied: kiwisolver>=1.3.1 in /usr/local/lib/python3.12/dist-packages (from matplotlib>=3.5.0->-r requirements.txt (line 23)) (1.4.9)
# Requirement already satisfied: packaging>=20.0 in /usr/local/lib/python3.12/dist-packages (from matplotlib>=3.5.0->-r requirements.txt (line 23)) (25.0)
# Requirement already satisfied: pyparsing>=2.3.1 in /usr/local/lib/python3.12/dist-packages (from matplotlib>=3.5.0->-r requirements.txt (line 23)) (3.2.5)
# Requirement already satisfied: slicer==0.0.8 in /usr/local/lib/python3.12/dist-packages (from shap>=0.44.0->-r requirements.txt (line 26)) (0.0.8)
# Requirement already satisfied: numba>=0.54 in /usr/local/lib/python3.12/dist-packages (from shap>=0.44.0->-r requirements.txt (line 26)) (0.60.0)
# Requirement already satisfied: cloudpickle in /usr/local/lib/python3.12/dist-packages (from shap>=0.44.0->-r requirements.txt (line 26)) (3.1.2)
# Requirement already satisfied: llvmlite<0.44,>=0.43.0dev0 in /usr/local/lib/python3.12/dist-packages (from numba>=0.54->shap>=0.44.0->-r requirements.txt (line 26)) (0.43.0)
# Requirement already satisfied: six>=1.5 in /usr/local/lib/python3.12/dist-packages (from python-dateutil>=2.8.2->pandas>=1.3.0->-r requirements.txt (line 7)) (1.17.0)
# Requirement already satisfied: CFFI>=1.0 in /usr/local/lib/python3.12/dist-packages (from sounddevice~=0.5->mediapipe>=0.10.15->-r requirements.txt (line 14)) (2.0.0)
# Requirement already satisfied: mpmath<1.4,>=1.1.0 in /usr/local/lib/python3.12/dist-packages (from sympy>=1.13.3->torch>=1.10.0->-r requirements.txt (line 2)) (1.3.0)
# Requirement already satisfied: MarkupSafe>=2.0 in /usr/local/lib/python3.12/dist-packages (from jinja2->torch>=1.10.0->-r requirements.txt (line 2)) (3.0.3)
# Requirement already satisfied: pycparser in /usr/local/lib/python3.12/dist-packages (from CFFI>=1.0->sounddevice~=0.5->mediapipe>=0.10.15->-r requirements.txt (line 14)) (2.23)
# Downloading mediapipe-0.10.31-py3-none-manylinux_2_28_x86_64.whl (10.3 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 10.3/10.3 MB 136.9 MB/s eta 0:00:00
# Downloading absl_py-2.3.1-py3-none-any.whl (135 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 135.8/135.8 kB 16.8 MB/s eta 0:00:00
# Downloading sounddevice-0.5.3-py3-none-any.whl (32 kB)
# Installing collected packages: absl-py, sounddevice, mediapipe
#   Attempting uninstall: absl-py
#     Found existing installation: absl-py 1.4.0
#     Uninstalling absl-py-1.4.0:
#       Successfully uninstalled absl-py-1.4.0
# Successfully installed absl-py-2.3.1 mediapipe-0.10.31 sounddevice-0.5.3

# %%
import sys
import os

# Dodaj katalog główny projektu do ścieżki systemowej
sys.path.append(os.getcwd())
print(f"Dodano do ścieżki Pythona: {os.getcwd()}")
# Out:
# Dodano do ścieżki Pythona: /content/automatic-pain-recognition

# %% [markdown]
# #### Attention-LSTM model - binary training

# %%
import os
import numpy as np
import pandas as pd
import shutil

import torch
import torch.nn as nn
from torch.utils.data import DataLoader
from torch.optim.lr_scheduler import ReduceLROnPlateau

from training_utils.preprocessed_dataset import PreprocessedDataset
from training_utils.train import Trainer
from training_utils.evaluate import Evaluator
from models.Attention_LSTM import AttentionSequenceModel

# %% [markdown]
# #### Hiperparameters

# %%
MAX_SEQUENCE_LENGTH = 46
NUM_FEATURES = 100
NUM_CLASSES = 2
HIDDEN_SIZE = 128
NUM_LAYERS = 2
NUM_EPOCHS = 200
BATCH_SIZE = 16
LEARNING_RATE = 0.00005
DROPOUT_PROB = 0.3
WEIGHT_DECAY = 0.005
SCHEDULER_FACTOR = 0.9

# %% [markdown]
# #### Data preparation

# %%
COLAB_ROOT = '/content/drive/MyDrive/PainRecognitionProject/'
PROCESSED_DATA_DIR = os.path.join(COLAB_ROOT, 'data/BioVid_HeatPain_processed_478_xyz_frontalized/')
MODEL_SAVE_DIR = os.path.join(COLAB_ROOT, 'models/')
LOCAL_PROCESSED_DATA_ROOT = '/content/temp_data/'

DEVICE = torch.device("cuda" if torch.cuda.is_available() else "cpu")

# %%
print("Kopiowanie danych z Google Drive do lokalnej pamięci Colab (RAM)...")
if os.path.exists(LOCAL_PROCESSED_DATA_ROOT):
    shutil.rmtree(LOCAL_PROCESSED_DATA_ROOT)
try:
    shutil.copytree(PROCESSED_DATA_DIR, LOCAL_PROCESSED_DATA_ROOT)
    print("✅ Kopiowanie zakończone pomyślnie. Czas trwania: (sprawdź zegar)")
    CURRENT_DATA_DIR = LOCAL_PROCESSED_DATA_ROOT

except Exception as e:
    print(f"❌ Błąd kopiowania danych (sprawdź, czy dane są zamontowane): {e}")
    print("Używam danych bezpośrednio z Drive (może się zawiesić).")
    CURRENT_DATA_DIR = PROCESSED_DATA_DIR
# Out:
# Kopiowanie danych z Google Drive do lokalnej pamięci Colab (RAM)...
# ✅ Kopiowanie zakończone pomyślnie. Czas trwania: (sprawdź zegar)

# %%
best100 = np.load('/content/drive/MyDrive/PainRecognitionProject/data/top_100_important_landmarks_emotions.npy')

# %%
train_dataset = PreprocessedDataset(
    'train',
    processed_data_dir=CURRENT_DATA_DIR,
    indices=best100,
    compute_euclidean=True,
    center_point_index=2,
    max_sequence_length=MAX_SEQUENCE_LENGTH,
    selected_labels=[0, 4],
    label_map={0: 0, 4: 1},
)

val_dataset = PreprocessedDataset(
    'val',
    processed_data_dir=CURRENT_DATA_DIR,
    indices=best100,
    compute_euclidean=True,
    center_point_index=2,
    max_sequence_length=MAX_SEQUENCE_LENGTH,
    selected_labels=[0, 4],
    label_map={0: 0, 4: 1},
)

test_dataset = PreprocessedDataset(
    'test',
    processed_data_dir=CURRENT_DATA_DIR,
    indices=best100,
    compute_euclidean=True,
    center_point_index=2,
    max_sequence_length=MAX_SEQUENCE_LENGTH,
    selected_labels=[0, 4],
    label_map={0: 0, 4: 1},
)

# %%
def preview_single(dataset, idx=0, timesteps_to_show=3, features_to_show=8):
    x, y = dataset[idx]
    print(f"\nSingle sample idx={idx} from split={dataset.dataset_name}")
    print(f"x shape: {tuple(x.shape)}, y: {y}")
    print(np.round(x[:timesteps_to_show, :features_to_show], 4))

preview_single(train_dataset, 0)
preview_single(val_dataset, 0)
preview_single(test_dataset, 0)
# Out:
# Single sample idx=0 from split=train
# x shape: (46, 100), y: 0
# tensor([[0.2288, 0.2495, 0.1901, 0.2053, 0.2000, 0.2080, 0.1858, 0.2578],
#         [0.2298, 0.2612, 0.1892, 0.2024, 0.1994, 0.2136, 0.1805, 0.2564],
#         [0.2291, 0.2585, 0.1896, 0.2033, 0.2022, 0.2154, 0.1835, 0.2563]])
#
# Single sample idx=0 from split=val
# x shape: (46, 100), y: 0
# tensor([[0.2204, 0.2330, 0.1836, 0.1980, 0.1886, 0.1926, 0.1736, 0.2485],
#         [0.2228, 0.2308, 0.1868, 0.2008, 0.1887, 0.1917, 0.1735, 0.2504],
#         [0.2228, 0.2309, 0.1869, 0.2009, 0.1889, 0.1920, 0.1739, 0.2504]])
#
# Single sample idx=0 from split=test
# x shape: (46, 100), y: 0
# tensor([[0.2235, 0.2448, 0.1836, 0.1956, 0.1864, 0.1941, 0.1716, 0.2511],
#         [0.2218, 0.2424, 0.1822, 0.1946, 0.1854, 0.1941, 0.1707, 0.2496],
#         [0.2226, 0.2452, 0.1828, 0.1951, 0.1891, 0.1974, 0.1740, 0.2504]])

# %%
train_loader = DataLoader(train_dataset, batch_size=BATCH_SIZE, shuffle=True, num_workers=0, pin_memory=True)
for X, y in train_loader:
    print(X.shape, y.shape)  # (B, T_max, num_features)
    break

val_loader = DataLoader(val_dataset, batch_size=BATCH_SIZE, shuffle=True, num_workers=0, pin_memory=True)
for X, y in val_loader:
    print(X.shape, y.shape)  # (B, T_max, num_features)
    break

test_loader = DataLoader(test_dataset, batch_size=BATCH_SIZE, shuffle=True, num_workers=0, pin_memory=True)
for X, y in test_loader:
    print(X.shape, y.shape)  # (B, T_max, num_features)
    break
# Out:
# torch.Size([16, 46, 100]) torch.Size([16])
# torch.Size([16, 46, 100]) torch.Size([16])
# torch.Size([16, 46, 100]) torch.Size([16])

# %% [markdown]
# #### Model preparation

# %%
model = AttentionSequenceModel(NUM_FEATURES, HIDDEN_SIZE, NUM_LAYERS, NUM_CLASSES, DROPOUT_PROB).to(DEVICE)

# %% [markdown]
# #### Training

# %%
criterion = nn.CrossEntropyLoss()
optimizer = torch.optim.AdamW(model.parameters(), lr=LEARNING_RATE, weight_decay=WEIGHT_DECAY)

scheduler = ReduceLROnPlateau(
    optimizer,
    mode='max',
    factor=SCHEDULER_FACTOR,
    patience=10,
    min_lr=1e-7
)

model_name = 'testing_new_code_attention_lstm_2_classes.pt'
model_filepath = os.path.join(MODEL_SAVE_DIR, model_name)

# %%
trainer = Trainer(
    model=model,
    train_loader=train_loader,
    val_loader=val_loader,
    optimizer=optimizer,
    scheduler=scheduler,
    criterion=criterion,
    device=DEVICE,
    model_save_path=model_filepath,
    num_epochs=NUM_EPOCHS,
    monitor='val_acc',  # or 'val_loss'
    minimize_monitor=False,
    save_best_only=True
)

# %%
trainer.print_training_config()
# Out:
# ==================================================
# 🚀 TRAINING CONFIGURATION
# ==================================================
#
# --- Model Architecture ---
#   Model Type            : AttentionSequenceModel
#   Input Features        : 100
#   Hidden Size           : 128
#   Num Layers            : 2
#   Bidirectional         : True
#   Dropout (LSTM)        : 0.3
#   Num Parameters        : 664835
#
# --- Optimizer & Regularization ---
#   Optimizer             : AdamW
#   Learning Rate (LR)    : 5e-05
#   Weight Decay (L2)     : 0.005
#
# --- Training Flow ---
#   Batch Size            : 16
#   Num Epochs            : 200
#   Device                : cuda
# ==================================================

# %%
final_model_path, best_model_path, history = trainer.fit()
print(f"Final model saved to: {final_model_path}")
if best_model_path:
    print(f"Best model saved to: {best_model_path}")
# Out:
# Starting training for 200 epochs on cuda
# Saved best model to /content/drive/MyDrive/PainRecognitionProject/models/best_testing_new_code_attention_lstm_2_classes.pt (metric=0.5000)
# Epoch 1/200 | Time 7.31s | Train loss 0.7291 | Train acc 0.5016 | Val loss 0.7026 | Val acc 0.5000
# Epoch 2/200 | Time 4.79s | Train loss 0.7143 | Train acc 0.5066 | Val loss 0.6945 | Val acc 0.5000
# Epoch 3/200 | Time 4.24s | Train loss 0.7042 | Train acc 0.5180 | Val loss 0.6960 | Val acc 0.5000
# Epoch 4/200 | Time 4.10s | Train loss 0.7080 | Train acc 0.4824 | Val loss 0.6952 | Val acc 0.5000
# Epoch 5/200 | Time 4.66s | Train loss 0.7059 | Train acc 0.4902 | Val loss 0.6941 | Val acc 0.5000
# Epoch 6/200 | Time 4.23s | Train loss 0.7050 | Train acc 0.4922 | Val loss 0.6941 | Val acc 0.5000
# Saved best model to /content/drive/MyDrive/PainRecognitionProject/models/best_testing_new_code_attention_lstm_2_classes.pt (metric=0.5173)
# Epoch 7/200 | Time 4.13s | Train loss 0.6971 | Train acc 0.5111 | Val loss 0.6913 | Val acc 0.5173
# Epoch 8/200 | Time 4.67s | Train loss 0.6953 | Train acc 0.5238 | Val loss 0.6912 | Val acc 0.5135
# Saved best model to /content/drive/MyDrive/PainRecognitionProject/models/best_testing_new_code_attention_lstm_2_classes.pt (metric=0.5288)
# Epoch 9/200 | Time 4.21s | Train loss 0.7004 | Train acc 0.5176 | Val loss 0.6913 | Val acc 0.5288
# Saved best model to /content/drive/MyDrive/PainRecognitionProject/models/best_testing_new_code_attention_lstm_2_classes.pt (metric=0.5615)
# Epoch 10/200 | Time 4.10s | Train loss 0.6960 | Train acc 0.5115 | Val loss 0.6905 | Val acc 0.5615
# Epoch 11/200 | Time 4.69s | Train loss 0.6962 | Train acc 0.5107 | Val loss 0.6904 | Val acc 0.5538
# Epoch 12/200 | Time 4.27s | Train loss 0.6949 | Train acc 0.5246 | Val loss 0.6959 | Val acc 0.5000
# Epoch 13/200 | Time 4.10s | Train loss 0.6962 | Train acc 0.5086 | Val loss 0.6917 | Val acc 0.5154
# Epoch 14/200 | Time 4.70s | Train loss 0.6945 | Train acc 0.5184 | Val loss 0.6922 | Val acc 0.5154
# Epoch 15/200 | Time 4.20s | Train loss 0.6936 | Train acc 0.5283 | Val loss 0.6890 | Val acc 0.5577
# Epoch 16/200 | Time 4.09s | Train loss 0.6915 | Train acc 0.5266 | Val loss 0.6880 | Val acc 0.5596
# Epoch 17/200 | Time 4.71s | Train loss 0.6950 | Train acc 0.5225 | Val loss 0.6877 | Val acc 0.5577
# Epoch 18/200 | Time 4.20s | Train loss 0.6936 | Train acc 0.5160 | Val loss 0.6915 | Val acc 0.5154
# Epoch 19/200 | Time 4.10s | Train loss 0.6919 | Train acc 0.5373 | Val loss 0.6914 | Val acc 0.5288
# Epoch 20/200 | Time 4.70s | Train loss 0.6884 | Train acc 0.5467 | Val loss 0.6843 | Val acc 0.5596
# Epoch 21/200 | Time 4.22s | Train loss 0.6916 | Train acc 0.5455 | Val loss 0.6864 | Val acc 0.5481
# Epoch 22/200 | Time 4.09s | Train loss 0.6861 | Train acc 0.5455 | Val loss 0.6793 | Val acc 0.5615
# Saved best model to /content/drive/MyDrive/PainRecognitionProject/models/best_testing_new_code_attention_lstm_2_classes.pt (metric=0.5731)
# Epoch 23/200 | Time 4.67s | Train loss 0.6855 | Train acc 0.5557 | Val loss 0.6767 | Val acc 0.5731
# Epoch 24/200 | Time 4.19s | Train loss 0.6768 | Train acc 0.5799 | Val loss 0.6914 | Val acc 0.5423
# Epoch 25/200 | Time 4.13s | Train loss 0.6773 | Train acc 0.5750 | Val loss 1.0435 | Val acc 0.5212
# Saved best model to /content/drive/MyDrive/PainRecognitionProject/models/best_testing_new_code_attention_lstm_2_classes.pt (metric=0.5750)
# Epoch 26/200 | Time 4.73s | Train loss 0.6816 | Train acc 0.5861 | Val loss 0.6678 | Val acc 0.5750
# Epoch 27/200 | Time 4.20s | Train loss 0.6758 | Train acc 0.5799 | Val loss 0.6793 | Val acc 0.5519
# Epoch 28/200 | Time 4.14s | Train loss 0.6639 | Train acc 0.5902 | Val loss 0.6590 | Val acc 0.5615
# Epoch 29/200 | Time 4.77s | Train loss 0.6577 | Train acc 0.5926 | Val loss 0.6737 | Val acc 0.5538
# Epoch 30/200 | Time 4.12s | Train loss 0.6606 | Train acc 0.5996 | Val loss 0.6893 | Val acc 0.5346
# Saved best model to /content/drive/MyDrive/PainRecognitionProject/models/best_testing_new_code_attention_lstm_2_classes.pt (metric=0.5885)
# Epoch 31/200 | Time 4.12s | Train loss 0.6595 | Train acc 0.5906 | Val loss 0.6593 | Val acc 0.5885
# Epoch 32/200 | Time 4.75s | Train loss 0.6773 | Train acc 0.5873 | Val loss 0.6805 | Val acc 0.5404
# Epoch 33/200 | Time 4.13s | Train loss 0.6597 | Train acc 0.5918 | Val loss 0.6811 | Val acc 0.5712
# Epoch 34/200 | Time 4.21s | Train loss 0.6740 | Train acc 0.5967 | Val loss 0.6615 | Val acc 0.5808
# Epoch 35/200 | Time 4.83s | Train loss 0.6566 | Train acc 0.5893 | Val loss 0.6698 | Val acc 0.5519
# Epoch 36/200 | Time 4.17s | Train loss 0.6605 | Train acc 0.5971 | Val loss 0.6583 | Val acc 0.5769
# Epoch 37/200 | Time 4.13s | Train loss 0.6511 | Train acc 0.6061 | Val loss 0.7166 | Val acc 0.5615
# Epoch 38/200 | Time 4.83s | Train loss 0.6637 | Train acc 0.6008 | Val loss 0.6772 | Val acc 0.5712
# Epoch 39/200 | Time 4.15s | Train loss 0.6594 | Train acc 0.5910 | Val loss 0.6697 | Val acc 0.5635
# Epoch 40/200 | Time 4.12s | Train loss 0.6746 | Train acc 0.5959 | Val loss 0.7103 | Val acc 0.5808
# Epoch 41/200 | Time 4.79s | Train loss 0.6522 | Train acc 0.6160 | Val loss 0.6637 | Val acc 0.5731
# Epoch 42/200 | Time 4.13s | Train loss 0.6518 | Train acc 0.6225 | Val loss 0.7190 | Val acc 0.5635
# Epoch 43/200 | Time 4.13s | Train loss 0.6510 | Train acc 0.6164 | Val loss 0.6737 | Val acc 0.5846
# Epoch 44/200 | Time 4.76s | Train loss 0.6560 | Train acc 0.6012 | Val loss 0.6714 | Val acc 0.5769
# Epoch 45/200 | Time 4.14s | Train loss 0.6525 | Train acc 0.5996 | Val loss 0.6536 | Val acc 0.5846
# Saved best model to /content/drive/MyDrive/PainRecognitionProject/models/best_testing_new_code_attention_lstm_2_classes.pt (metric=0.5923)
# Epoch 46/200 | Time 4.13s | Train loss 0.6537 | Train acc 0.6074 | Val loss 0.6535 | Val acc 0.5923
# Epoch 47/200 | Time 4.77s | Train loss 0.6619 | Train acc 0.5918 | Val loss 0.6603 | Val acc 0.5885
# Epoch 48/200 | Time 4.14s | Train loss 0.6566 | Train acc 0.5971 | Val loss 0.6650 | Val acc 0.5904
# Epoch 49/200 | Time 4.17s | Train loss 0.6631 | Train acc 0.5971 | Val loss 0.9146 | Val acc 0.5423
# Epoch 50/200 | Time 4.80s | Train loss 0.6525 | Train acc 0.6156 | Val loss 0.6628 | Val acc 0.5827
# Epoch 51/200 | Time 4.12s | Train loss 0.6468 | Train acc 0.6004 | Val loss 0.6677 | Val acc 0.5865
# Saved best model to /content/drive/MyDrive/PainRecognitionProject/models/best_testing_new_code_attention_lstm_2_classes.pt (metric=0.6000)
# Epoch 52/200 | Time 4.20s | Train loss 0.6435 | Train acc 0.5971 | Val loss 0.6621 | Val acc 0.6000
# Epoch 53/200 | Time 4.81s | Train loss 0.6624 | Train acc 0.5996 | Val loss 0.6653 | Val acc 0.5558
# Epoch 54/200 | Time 4.11s | Train loss 0.6465 | Train acc 0.5922 | Val loss 0.7387 | Val acc 0.5635
# Epoch 55/200 | Time 4.11s | Train loss 0.6544 | Train acc 0.6111 | Val loss 0.6549 | Val acc 0.6000
# Epoch 56/200 | Time 4.81s | Train loss 0.6477 | Train acc 0.6168 | Val loss 0.6758 | Val acc 0.5808
# Epoch 57/200 | Time 4.11s | Train loss 0.6606 | Train acc 0.5984 | Val loss 0.6616 | Val acc 0.5942
# Epoch 58/200 | Time 4.11s | Train loss 0.6637 | Train acc 0.5848 | Val loss 0.6642 | Val acc 0.5885
# Epoch 59/200 | Time 4.80s | Train loss 0.6554 | Train acc 0.6123 | Val loss 0.6687 | Val acc 0.5904
# Epoch 60/200 | Time 4.29s | Train loss 0.6440 | Train acc 0.6152 | Val loss 0.6936 | Val acc 0.5731
# Epoch 61/200 | Time 4.14s | Train loss 0.6573 | Train acc 0.6066 | Val loss 0.7234 | Val acc 0.5673
# Epoch 62/200 | Time 4.79s | Train loss 0.6507 | Train acc 0.6094 | Val loss 0.6790 | Val acc 0.5788
# Epoch 63/200 | Time 4.30s | Train loss 0.6560 | Train acc 0.6041 | Val loss 0.6561 | Val acc 0.5904
# Epoch 64/200 | Time 4.16s | Train loss 0.6737 | Train acc 0.6033 | Val loss 0.6643 | Val acc 0.5846
# Epoch 65/200 | Time 4.84s | Train loss 0.6441 | Train acc 0.6184 | Val loss 0.6616 | Val acc 0.5865
# Epoch 66/200 | Time 4.18s | Train loss 0.6529 | Train acc 0.6029 | Val loss 0.6523 | Val acc 0.5712
# Epoch 67/200 | Time 4.14s | Train loss 0.6508 | Train acc 0.6000 | Val loss 0.6576 | Val acc 0.5942
# Epoch 68/200 | Time 4.77s | Train loss 0.6501 | Train acc 0.6078 | Val loss 0.7198 | Val acc 0.5577
# Epoch 69/200 | Time 4.12s | Train loss 0.6451 | Train acc 0.6164 | Val loss 0.6658 | Val acc 0.5750
# Epoch 70/200 | Time 4.18s | Train loss 0.6516 | Train acc 0.6131 | Val loss 0.6876 | Val acc 0.5635
# Epoch 71/200 | Time 4.87s | Train loss 0.6455 | Train acc 0.6143 | Val loss 0.6545 | Val acc 0.5865
# Epoch 72/200 | Time 4.15s | Train loss 0.6507 | Train acc 0.6168 | Val loss 0.6557 | Val acc 0.5788
# Epoch 73/200 | Time 4.16s | Train loss 0.6448 | Train acc 0.6225 | Val loss 0.6771 | Val acc 0.5673
# Epoch 74/200 | Time 4.80s | Train loss 0.6380 | Train acc 0.6143 | Val loss 0.6916 | Val acc 0.5654
# Epoch 75/200 | Time 4.14s | Train loss 0.6445 | Train acc 0.6168 | Val loss 0.7174 | Val acc 0.5654
# Epoch 76/200 | Time 4.14s | Train loss 0.6502 | Train acc 0.6135 | Val loss 0.6759 | Val acc 0.5615
# Epoch 77/200 | Time 4.83s | Train loss 0.6460 | Train acc 0.6168 | Val loss 0.6738 | Val acc 0.5596
# Epoch 78/200 | Time 4.10s | Train loss 0.6477 | Train acc 0.6111 | Val loss 0.6555 | Val acc 0.5942
# Epoch 79/200 | Time 4.12s | Train loss 0.6398 | Train acc 0.6225 | Val loss 0.6767 | Val acc 0.5692
# Epoch 80/200 | Time 4.81s | Train loss 0.6372 | Train acc 0.6168 | Val loss 0.7149 | Val acc 0.5731
# Epoch 81/200 | Time 4.11s | Train loss 0.6462 | Train acc 0.6189 | Val loss 0.7154 | Val acc 0.5731
# Epoch 82/200 | Time 4.16s | Train loss 0.6455 | Train acc 0.6070 | Val loss 0.6653 | Val acc 0.5635
# Epoch 83/200 | Time 4.80s | Train loss 0.6410 | Train acc 0.6078 | Val loss 0.6529 | Val acc 0.5923
# Epoch 84/200 | Time 4.10s | Train loss 0.6420 | Train acc 0.6189 | Val loss 0.7067 | Val acc 0.5558
# Epoch 85/200 | Time 4.13s | Train loss 0.6465 | Train acc 0.6189 | Val loss 0.6597 | Val acc 0.5942
# Epoch 86/200 | Time 4.78s | Train loss 0.6377 | Train acc 0.6230 | Val loss 0.6577 | Val acc 0.5904
# Epoch 87/200 | Time 4.15s | Train loss 0.6398 | Train acc 0.6275 | Val loss 0.6773 | Val acc 0.5692
# Epoch 88/200 | Time 4.13s | Train loss 0.6448 | Train acc 0.6131 | Val loss 0.7129 | Val acc 0.5654
# Epoch 89/200 | Time 4.85s | Train loss 0.6401 | Train acc 0.6193 | Val loss 0.6632 | Val acc 0.5942
# Epoch 90/200 | Time 4.16s | Train loss 0.6349 | Train acc 0.6352 | Val loss 0.6668 | Val acc 0.5904
# Epoch 91/200 | Time 4.19s | Train loss 0.6427 | Train acc 0.6094 | Val loss 0.6854 | Val acc 0.5673
# Epoch 92/200 | Time 4.73s | Train loss 0.6315 | Train acc 0.6201 | Val loss 0.7416 | Val acc 0.5750
# Epoch 93/200 | Time 4.12s | Train loss 0.6549 | Train acc 0.6078 | Val loss 0.6636 | Val acc 0.5904
# Epoch 94/200 | Time 4.24s | Train loss 0.6444 | Train acc 0.6168 | Val loss 0.6930 | Val acc 0.5654
# Epoch 95/200 | Time 4.70s | Train loss 0.6504 | Train acc 0.6217 | Val loss 0.6581 | Val acc 0.6000
# Epoch 96/200 | Time 4.13s | Train loss 0.6264 | Train acc 0.6361 | Val loss 0.7066 | Val acc 0.5750
# Epoch 97/200 | Time 4.23s | Train loss 0.6326 | Train acc 0.6336 | Val loss 0.6730 | Val acc 0.5788
# Epoch 98/200 | Time 4.71s | Train loss 0.6315 | Train acc 0.6205 | Val loss 0.8144 | Val acc 0.5769
# Epoch 99/200 | Time 4.09s | Train loss 0.6346 | Train acc 0.6234 | Val loss 0.6628 | Val acc 0.5885
# Epoch 100/200 | Time 4.20s | Train loss 0.6312 | Train acc 0.6250 | Val loss 0.6526 | Val acc 0.5885
# Epoch 101/200 | Time 4.74s | Train loss 0.6745 | Train acc 0.5984 | Val loss 0.6654 | Val acc 0.5635
# Epoch 102/200 | Time 4.11s | Train loss 0.6439 | Train acc 0.6123 | Val loss 0.6880 | Val acc 0.5635
# Epoch 103/200 | Time 4.20s | Train loss 0.6338 | Train acc 0.6205 | Val loss 0.7470 | Val acc 0.5596
# Saved best model to /content/drive/MyDrive/PainRecognitionProject/models/best_testing_new_code_attention_lstm_2_classes.pt (metric=0.6019)
# Epoch 104/200 | Time 4.74s | Train loss 0.6372 | Train acc 0.6320 | Val loss 0.6678 | Val acc 0.6019
# Epoch 105/200 | Time 4.14s | Train loss 0.6271 | Train acc 0.6311 | Val loss 0.6744 | Val acc 0.5865
# Epoch 106/200 | Time 4.26s | Train loss 0.6460 | Train acc 0.6189 | Val loss 0.6906 | Val acc 0.5558
# Epoch 107/200 | Time 4.77s | Train loss 0.6344 | Train acc 0.6332 | Val loss 0.7723 | Val acc 0.5788
# Epoch 108/200 | Time 4.16s | Train loss 0.6353 | Train acc 0.6176 | Val loss 0.6781 | Val acc 0.5865
# Epoch 109/200 | Time 4.30s | Train loss 0.6361 | Train acc 0.6193 | Val loss 0.6601 | Val acc 0.6019
# Epoch 110/200 | Time 4.70s | Train loss 0.6395 | Train acc 0.6156 | Val loss 0.7422 | Val acc 0.5500
# Epoch 111/200 | Time 4.17s | Train loss 0.6326 | Train acc 0.6307 | Val loss 0.7031 | Val acc 0.6019
# Epoch 112/200 | Time 4.36s | Train loss 0.6345 | Train acc 0.6316 | Val loss 0.6950 | Val acc 0.5788
# Epoch 113/200 | Time 4.61s | Train loss 0.6353 | Train acc 0.6279 | Val loss 0.6568 | Val acc 0.5769
# Epoch 114/200 | Time 4.15s | Train loss 0.6343 | Train acc 0.6246 | Val loss 0.7002 | Val acc 0.5558
# Epoch 115/200 | Time 4.37s | Train loss 0.6388 | Train acc 0.6160 | Val loss 0.6699 | Val acc 0.5808
# Epoch 116/200 | Time 4.59s | Train loss 0.6294 | Train acc 0.6303 | Val loss 0.7586 | Val acc 0.5846
# Saved best model to /content/drive/MyDrive/PainRecognitionProject/models/best_testing_new_code_attention_lstm_2_classes.pt (metric=0.6058)
# Epoch 117/200 | Time 4.11s | Train loss 0.6552 | Train acc 0.6090 | Val loss 0.6563 | Val acc 0.6058
# Epoch 118/200 | Time 4.42s | Train loss 0.6254 | Train acc 0.6336 | Val loss 0.6694 | Val acc 0.5981
# Epoch 119/200 | Time 4.56s | Train loss 0.6288 | Train acc 0.6352 | Val loss 0.7266 | Val acc 0.5904
# Epoch 120/200 | Time 4.15s | Train loss 0.6392 | Train acc 0.6221 | Val loss 0.6767 | Val acc 0.6000
# Epoch 121/200 | Time 4.44s | Train loss 0.6283 | Train acc 0.6398 | Val loss 0.6796 | Val acc 0.5519
# Epoch 122/200 | Time 4.49s | Train loss 0.6475 | Train acc 0.6139 | Val loss 0.6583 | Val acc 0.5962
# Epoch 123/200 | Time 4.12s | Train loss 0.6319 | Train acc 0.6365 | Val loss 0.6655 | Val acc 0.5962
# Epoch 124/200 | Time 4.42s | Train loss 0.6322 | Train acc 0.6299 | Val loss 0.7029 | Val acc 0.5692
# Epoch 125/200 | Time 4.51s | Train loss 0.6201 | Train acc 0.6332 | Val loss 0.6657 | Val acc 0.5808
# Epoch 126/200 | Time 4.19s | Train loss 0.6280 | Train acc 0.6398 | Val loss 0.6942 | Val acc 0.5712
# Epoch 127/200 | Time 4.47s | Train loss 0.6360 | Train acc 0.6201 | Val loss 0.7111 | Val acc 0.5558
# Epoch 128/200 | Time 4.48s | Train loss 0.6574 | Train acc 0.6082 | Val loss 0.6877 | Val acc 0.5538
# Epoch 129/200 | Time 4.12s | Train loss 0.6282 | Train acc 0.6369 | Val loss 0.7051 | Val acc 0.5808
# Epoch 130/200 | Time 4.48s | Train loss 0.6296 | Train acc 0.6328 | Val loss 0.7305 | Val acc 0.5788
# Epoch 131/200 | Time 4.47s | Train loss 0.6426 | Train acc 0.6164 | Val loss 0.7395 | Val acc 0.5538
# Epoch 132/200 | Time 4.18s | Train loss 0.6335 | Train acc 0.6295 | Val loss 0.6641 | Val acc 0.6058
# Epoch 133/200 | Time 4.53s | Train loss 0.6326 | Train acc 0.6221 | Val loss 0.7067 | Val acc 0.5558
# Epoch 134/200 | Time 4.43s | Train loss 0.6278 | Train acc 0.6307 | Val loss 0.6555 | Val acc 0.6038
# Epoch 135/200 | Time 4.14s | Train loss 0.6311 | Train acc 0.6254 | Val loss 0.6954 | Val acc 0.5673
# Epoch 136/200 | Time 4.52s | Train loss 0.6275 | Train acc 0.6225 | Val loss 0.7018 | Val acc 0.5654
# Saved best model to /content/drive/MyDrive/PainRecognitionProject/models/best_testing_new_code_attention_lstm_2_classes.pt (metric=0.6077)
# Epoch 137/200 | Time 4.41s | Train loss 0.6351 | Train acc 0.6213 | Val loss 0.6806 | Val acc 0.6077
# Saved best model to /content/drive/MyDrive/PainRecognitionProject/models/best_testing_new_code_attention_lstm_2_classes.pt (metric=0.6096)
# Epoch 138/200 | Time 4.14s | Train loss 0.6287 | Train acc 0.6266 | Val loss 0.6556 | Val acc 0.6096
# Epoch 139/200 | Time 4.58s | Train loss 0.6217 | Train acc 0.6336 | Val loss 0.6819 | Val acc 0.5712
# Epoch 140/200 | Time 4.43s | Train loss 0.6380 | Train acc 0.6160 | Val loss 0.6570 | Val acc 0.5962
# Epoch 141/200 | Time 4.13s | Train loss 0.6292 | Train acc 0.6332 | Val loss 0.7311 | Val acc 0.5750
# Epoch 142/200 | Time 4.66s | Train loss 0.6257 | Train acc 0.6418 | Val loss 0.6654 | Val acc 0.5827
# Epoch 143/200 | Time 4.35s | Train loss 0.6238 | Train acc 0.6307 | Val loss 0.6634 | Val acc 0.5942
# Epoch 144/200 | Time 4.12s | Train loss 0.6315 | Train acc 0.6242 | Val loss 0.6854 | Val acc 0.5635
# Epoch 145/200 | Time 4.67s | Train loss 0.6342 | Train acc 0.6283 | Val loss 0.8393 | Val acc 0.5808
# Epoch 146/200 | Time 4.35s | Train loss 0.6340 | Train acc 0.6275 | Val loss 0.6735 | Val acc 0.5962
# Epoch 147/200 | Time 4.16s | Train loss 0.6287 | Train acc 0.6410 | Val loss 0.6874 | Val acc 0.5538
# Epoch 148/200 | Time 4.67s | Train loss 0.6318 | Train acc 0.6221 | Val loss 0.6791 | Val acc 0.6000
# Epoch 149/200 | Time 4.35s | Train loss 0.6310 | Train acc 0.6246 | Val loss 0.6640 | Val acc 0.5923
# Epoch 150/200 | Time 4.14s | Train loss 0.6276 | Train acc 0.6230 | Val loss 0.6878 | Val acc 0.5750
# Epoch 151/200 | Time 4.69s | Train loss 0.6276 | Train acc 0.6344 | Val loss 0.6723 | Val acc 0.5904
# Saved best model to /content/drive/MyDrive/PainRecognitionProject/models/best_testing_new_code_attention_lstm_2_classes.pt (metric=0.6135)
# Epoch 152/200 | Time 4.24s | Train loss 0.6270 | Train acc 0.6230 | Val loss 0.6676 | Val acc 0.6135
# Epoch 153/200 | Time 4.15s | Train loss 0.6293 | Train acc 0.6307 | Val loss 0.6632 | Val acc 0.5981
# Epoch 154/200 | Time 4.72s | Train loss 0.6209 | Train acc 0.6381 | Val loss 0.7157 | Val acc 0.5635
# Epoch 155/200 | Time 4.24s | Train loss 0.6270 | Train acc 0.6410 | Val loss 0.6793 | Val acc 0.5500
# Epoch 156/200 | Time 4.15s | Train loss 0.6284 | Train acc 0.6328 | Val loss 0.6549 | Val acc 0.5885
# Epoch 157/200 | Time 4.78s | Train loss 0.6237 | Train acc 0.6332 | Val loss 0.6661 | Val acc 0.5865
# Epoch 158/200 | Time 4.19s | Train loss 0.6227 | Train acc 0.6303 | Val loss 0.6689 | Val acc 0.5885
# Epoch 159/200 | Time 4.12s | Train loss 0.6214 | Train acc 0.6365 | Val loss 0.6751 | Val acc 0.5865
# Epoch 160/200 | Time 4.81s | Train loss 0.6240 | Train acc 0.6303 | Val loss 0.6840 | Val acc 0.6135
# Epoch 161/200 | Time 4.16s | Train loss 0.6341 | Train acc 0.6230 | Val loss 0.6659 | Val acc 0.5827
# Epoch 162/200 | Time 4.31s | Train loss 0.6291 | Train acc 0.6299 | Val loss 0.6608 | Val acc 0.5942
# Epoch 163/200 | Time 4.85s | Train loss 0.6226 | Train acc 0.6275 | Val loss 0.7204 | Val acc 0.5615
# Epoch 164/200 | Time 4.14s | Train loss 0.6186 | Train acc 0.6324 | Val loss 0.6604 | Val acc 0.5981
# Epoch 165/200 | Time 4.16s | Train loss 0.6187 | Train acc 0.6303 | Val loss 0.6543 | Val acc 0.5923
# Epoch 166/200 | Time 4.76s | Train loss 0.6378 | Train acc 0.6197 | Val loss 0.7184 | Val acc 0.6000
# Epoch 167/200 | Time 4.17s | Train loss 0.6218 | Train acc 0.6422 | Val loss 0.6684 | Val acc 0.5865
# Epoch 168/200 | Time 4.15s | Train loss 0.6219 | Train acc 0.6369 | Val loss 0.6515 | Val acc 0.5942
# Epoch 169/200 | Time 4.79s | Train loss 0.6255 | Train acc 0.6389 | Val loss 0.8421 | Val acc 0.5885
# Epoch 170/200 | Time 4.14s | Train loss 0.6244 | Train acc 0.6443 | Val loss 0.6861 | Val acc 0.5827
# Epoch 171/200 | Time 4.14s | Train loss 0.6283 | Train acc 0.6209 | Val loss 0.6691 | Val acc 0.5615
# Epoch 172/200 | Time 4.78s | Train loss 0.6172 | Train acc 0.6455 | Val loss 0.6689 | Val acc 0.5904
# Epoch 173/200 | Time 4.12s | Train loss 0.6229 | Train acc 0.6373 | Val loss 0.6650 | Val acc 0.5827
# Epoch 174/200 | Time 4.14s | Train loss 0.6176 | Train acc 0.6418 | Val loss 0.6759 | Val acc 0.5654
# Epoch 175/200 | Time 4.79s | Train loss 0.6169 | Train acc 0.6316 | Val loss 0.6535 | Val acc 0.6058
# Saved best model to /content/drive/MyDrive/PainRecognitionProject/models/best_testing_new_code_attention_lstm_2_classes.pt (metric=0.6154)
# Epoch 176/200 | Time 4.18s | Train loss 0.6143 | Train acc 0.6340 | Val loss 0.6542 | Val acc 0.6154
# Epoch 177/200 | Time 4.14s | Train loss 0.6152 | Train acc 0.6398 | Val loss 0.6738 | Val acc 0.5904
# Epoch 178/200 | Time 4.82s | Train loss 0.6112 | Train acc 0.6406 | Val loss 0.7625 | Val acc 0.5827
# Epoch 179/200 | Time 4.14s | Train loss 0.6122 | Train acc 0.6377 | Val loss 0.6702 | Val acc 0.6077
# Epoch 180/200 | Time 4.15s | Train loss 0.6204 | Train acc 0.6357 | Val loss 0.6600 | Val acc 0.6077
# Saved best model to /content/drive/MyDrive/PainRecognitionProject/models/best_testing_new_code_attention_lstm_2_classes.pt (metric=0.6308)
# Epoch 181/200 | Time 4.78s | Train loss 0.6153 | Train acc 0.6373 | Val loss 0.6569 | Val acc 0.6308
# Epoch 182/200 | Time 4.19s | Train loss 0.6204 | Train acc 0.6389 | Val loss 0.6609 | Val acc 0.5923
# Epoch 183/200 | Time 4.15s | Train loss 0.6224 | Train acc 0.6311 | Val loss 0.6760 | Val acc 0.6135
# Epoch 184/200 | Time 4.78s | Train loss 0.6100 | Train acc 0.6447 | Val loss 0.6474 | Val acc 0.6154
# Epoch 185/200 | Time 4.14s | Train loss 0.6122 | Train acc 0.6352 | Val loss 0.6932 | Val acc 0.5942
# Epoch 186/200 | Time 4.16s | Train loss 0.6144 | Train acc 0.6377 | Val loss 0.6649 | Val acc 0.6019
# Epoch 187/200 | Time 4.75s | Train loss 0.6085 | Train acc 0.6455 | Val loss 0.6548 | Val acc 0.5942
# Epoch 188/200 | Time 4.18s | Train loss 0.6064 | Train acc 0.6500 | Val loss 0.6511 | Val acc 0.5962
# Epoch 189/200 | Time 4.14s | Train loss 0.6056 | Train acc 0.6459 | Val loss 0.6467 | Val acc 0.6019
# Epoch 190/200 | Time 4.78s | Train loss 0.6110 | Train acc 0.6324 | Val loss 0.7291 | Val acc 0.5808
# Epoch 191/200 | Time 4.16s | Train loss 0.6277 | Train acc 0.6336 | Val loss 0.6426 | Val acc 0.6288
# Saved best model to /content/drive/MyDrive/PainRecognitionProject/models/best_testing_new_code_attention_lstm_2_classes.pt (metric=0.6500)
# Epoch 192/200 | Time 4.13s | Train loss 0.6046 | Train acc 0.6463 | Val loss 0.6378 | Val acc 0.6500
# Epoch 193/200 | Time 4.76s | Train loss 0.6093 | Train acc 0.6369 | Val loss 0.6480 | Val acc 0.6212
# Epoch 194/200 | Time 4.14s | Train loss 0.6018 | Train acc 0.6426 | Val loss 0.6427 | Val acc 0.5962
# Epoch 195/200 | Time 4.17s | Train loss 0.6164 | Train acc 0.6377 | Val loss 0.6470 | Val acc 0.6077
# Epoch 196/200 | Time 4.78s | Train loss 0.5995 | Train acc 0.6484 | Val loss 0.6986 | Val acc 0.6096
# Epoch 197/200 | Time 4.15s | Train loss 0.6151 | Train acc 0.6455 | Val loss 0.6574 | Val acc 0.5885
# Epoch 198/200 | Time 4.19s | Train loss 0.6094 | Train acc 0.6467 | Val loss 0.6431 | Val acc 0.5750
# Epoch 199/200 | Time 4.73s | Train loss 0.6061 | Train acc 0.6475 | Val loss 0.6607 | Val acc 0.5904
# Epoch 200/200 | Time 4.17s | Train loss 0.5976 | Train acc 0.6451 | Val loss 0.6454 | Val acc 0.5923
# Training finished. Best epoch: 191. Best monitored metric: 0.6500
# Final model saved to: /content/drive/MyDrive/PainRecognitionProject/models/testing_new_code_attention_lstm_2_classes.pt
# Best model saved to: /content/drive/MyDrive/PainRecognitionProject/models/best_testing_new_code_attention_lstm_2_classes.pt

# %%
trainer.plot_history()

# %% [markdown]
# #### Evaluate

# %%
model.load_state_dict(torch.load(best_model_path, map_location=DEVICE), strict=False)
# Out:
# <All keys matched successfully>

# %%
evaluator = Evaluator(model, test_loader, device=DEVICE, model_name=model_name, num_classes=NUM_CLASSES)

# %%
loss, acc, labels, preds = evaluator.evaluate_epoch()
# Out:
# ==================================================
# WYNIKI OCENY DLA MODELU: testing_new_code_attention_lstm_2_classes.pt
# ==================================================
# Test Loss: 0.5529
# Test Accuracy: 0.7135
#
# --- Szczegółowy Raport Klasyfikacji ---
#               precision    recall  f1-score   support
#
#      Klasa 0       0.68      0.82      0.74       260
#      Klasa 1       0.77      0.61      0.68       260
#
#     accuracy                           0.71       520
#    macro avg       0.72      0.71      0.71       520
# weighted avg       0.72      0.71      0.71       520
#
# ==================================================
# Confusion matrix:
#  [[213  47]
#  [102 158]]
