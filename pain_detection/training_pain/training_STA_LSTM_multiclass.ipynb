# %% [markdown]
# ### STA-LSTM model - multiclass training - 100 distances

# %% [markdown]
# #### Environment preparation

# %%
# Montowanie Google Drive
from google.colab import drive
drive.mount('/content/drive')

COLAB_ROOT = '/content/drive/MyDrive/PainRecognitionProject/'
print(f"Dane będą wczytywane z: {COLAB_ROOT}")
# Out:
# Mounted at /content/drive
# Dane będą wczytywane z: /content/drive/MyDrive/PainRecognitionProject/

# %%
import os

# Przejście do katalogu głównego
# %cd /content

# Klonowanie repo
# !rm -rf automatic-pain-recognition

print(f"Obecne położenie: {os.getcwd()}")
# Out:
# /content
# Obecne położenie: /content

# %%
# Upewnij się, że nazwa użytkownika i repozytorium są poprawne
USERNAME = 'alicka33'
REPO_NAME = 'automatic-pain-recognition'

# Tworzenie poprawnego adresu URL (format: https://<TOKEN>@github.com/...)
REPO_URL = f"https://github.com/{USERNAME}/{REPO_NAME}.git"

print("Rozpoczynam klonowanie...")

# Klonowanie
# !git clone {REPO_URL}

# Wejście do katalogu
# %cd $REPO_NAME
# Out:
# Rozpoczynam klonowanie...
# Cloning into 'automatic-pain-recognition'...
# remote: Enumerating objects: 344, done.
# remote: Counting objects: 100% (67/67), done.
# remote: Compressing objects: 100% (46/46), done.
# remote: Total 344 (delta 34), reused 53 (delta 20), pack-reused 277 (from 1)
# Receiving objects: 100% (344/344), 12.43 MiB | 17.77 MiB/s, done.
# Resolving deltas: 100% (158/158), done.
# /content/automatic-pain-recognition

# %%
# Instalacja wymaganych bibliotek
# !pip install -r requirements.txt

# %%
import sys
import os

# Dodaj katalog główny projektu do ścieżki systemowej
sys.path.append(os.getcwd())
print(f"Dodano do ścieżki Pythona: {os.getcwd()}")
# Out:
# Dodano do ścieżki Pythona: /content/automatic-pain-recognition

# %% [markdown]
# #### STA-LSTM model - multiclass training

# %%
import os
import numpy as np
import pandas as pd
import shutil

import torch
import torch.nn as nn
from torch.utils.data import DataLoader
from torch.optim.lr_scheduler import ReduceLROnPlateau

from training_utils.preprocessed_dataset import PreprocessedDataset
from training_utils.train import Trainer
from training_utils.evaluate import Evaluator
from models.STA_LSTM import STA_LSTM

# %%
MAX_SEQUENCE_LENGTH = 46
NUM_FEATURES = 100
NUM_CLASSES = 5
HIDDEN_SIZE = 128
NUM_LAYERS = 2
NUM_EPOCHS = 200
BATCH_SIZE = 16
LEARNING_RATE = 0.00005
DROPOUT_PROB = 0.3
WEIGHT_DECAY = 0.005
SCHEDULER_FACTOR = 0.9

# %% [markdown]
# #### Data preparation

# %%
COLAB_ROOT = '/content/drive/MyDrive/PainRecognitionProject/'
PROCESSED_DATA_DIR = os.path.join(COLAB_ROOT, 'data/BioVid_HeatPain_processed_478_xyz_frontalized/')
MODEL_SAVE_DIR = os.path.join(COLAB_ROOT, 'models/')
LOCAL_PROCESSED_DATA_ROOT = '/content/temp_data/'

DEVICE = torch.device("cuda" if torch.cuda.is_available() else "cpu")

# %%
print("Kopiowanie danych z Google Drive do lokalnej pamięci Colab (RAM)...")
if os.path.exists(LOCAL_PROCESSED_DATA_ROOT):
    shutil.rmtree(LOCAL_PROCESSED_DATA_ROOT)
try:
    shutil.copytree(PROCESSED_DATA_DIR, LOCAL_PROCESSED_DATA_ROOT)
    print("✅ Kopiowanie zakończone pomyślnie. Czas trwania: (sprawdź zegar)")
    CURRENT_DATA_DIR = LOCAL_PROCESSED_DATA_ROOT

except Exception as e:
    print(f"❌ Błąd kopiowania danych (sprawdź, czy dane są zamontowane): {e}")
    print("Używam danych bezpośrednio z Drive (może się zawiesić).")
    CURRENT_DATA_DIR = PROCESSED_DATA_DIR
# Out:
# Kopiowanie danych z Google Drive do lokalnej pamięci Colab (RAM)...
# ✅ Kopiowanie zakończone pomyślnie. Czas trwania: (sprawdź zegar)

# %%
best100 = np.load('/content/drive/MyDrive/PainRecognitionProject/data/top_100_important_landmarks_emotions.npy')

# %%
train_dataset = PreprocessedDataset(
    'train',
    processed_data_dir=CURRENT_DATA_DIR,
    indices=best100,
    compute_euclidean=True,
    center_point_index=2,
    max_sequence_length=MAX_SEQUENCE_LENGTH,
    selected_labels=None,
    label_map=None,
)

val_dataset = PreprocessedDataset(
    'val',
    processed_data_dir=CURRENT_DATA_DIR,
    indices=best100,
    compute_euclidean=True,
    center_point_index=2,
    max_sequence_length=MAX_SEQUENCE_LENGTH,
    selected_labels=None,
    label_map=None,
)

test_dataset = PreprocessedDataset(
    'test',
    processed_data_dir=CURRENT_DATA_DIR,
    indices=best100,
    compute_euclidean=True,
    center_point_index=2,
    max_sequence_length=MAX_SEQUENCE_LENGTH,
    selected_labels=None,
    label_map=None,
)

# %%
def preview_single(dataset, idx=0, timesteps_to_show=3, features_to_show=8):
    x, y = dataset[idx]
    print(f"\nSingle sample idx={idx} from split={dataset.dataset_name}")
    print(f"x shape: {tuple(x.shape)}, y: {y}")
    print(np.round(x[:timesteps_to_show, :features_to_show], 4))

preview_single(train_dataset, 0)
preview_single(val_dataset, 0)
preview_single(test_dataset, 0)
# Out:
# Single sample idx=0 from split=train
# x shape: (46, 100), y: 0
# tensor([[0.2288, 0.2495, 0.1901, 0.2053, 0.2000, 0.2080, 0.1858, 0.2578],
#         [0.2298, 0.2612, 0.1892, 0.2024, 0.1994, 0.2136, 0.1805, 0.2564],
#         [0.2291, 0.2585, 0.1896, 0.2033, 0.2022, 0.2154, 0.1835, 0.2563]])
#
# Single sample idx=0 from split=val
# x shape: (46, 100), y: 0
# tensor([[0.2204, 0.2330, 0.1836, 0.1980, 0.1886, 0.1926, 0.1736, 0.2485],
#         [0.2228, 0.2308, 0.1868, 0.2008, 0.1887, 0.1917, 0.1735, 0.2504],
#         [0.2228, 0.2309, 0.1869, 0.2009, 0.1889, 0.1920, 0.1739, 0.2504]])
#
# Single sample idx=0 from split=test
# x shape: (46, 100), y: 0
# tensor([[0.2235, 0.2448, 0.1836, 0.1956, 0.1864, 0.1941, 0.1716, 0.2511],
#         [0.2218, 0.2424, 0.1822, 0.1946, 0.1854, 0.1941, 0.1707, 0.2496],
#         [0.2226, 0.2452, 0.1828, 0.1951, 0.1891, 0.1974, 0.1740, 0.2504]])

# %%
train_loader = DataLoader(train_dataset, batch_size=BATCH_SIZE, shuffle=True, num_workers=0, pin_memory=True)
for X, y in train_loader:
    print(X.shape, y.shape)  # (B, T_max, num_features)
    break

val_loader = DataLoader(val_dataset, batch_size=BATCH_SIZE, shuffle=True, num_workers=0, pin_memory=True)
for X, y in val_loader:
    print(X.shape, y.shape)  # (B, T_max, num_features)
    break

test_loader = DataLoader(test_dataset, batch_size=BATCH_SIZE, shuffle=True, num_workers=0, pin_memory=True)
for X, y in test_loader:
    print(X.shape, y.shape)  # (B, T_max, num_features)
    break
# Out:
# torch.Size([16, 46, 100]) torch.Size([16])
# torch.Size([16, 46, 100]) torch.Size([16])
# torch.Size([16, 46, 100]) torch.Size([16])

# %% [markdown]
# #### Model preparation

# %%
model = STA_LSTM(NUM_FEATURES, HIDDEN_SIZE, NUM_LAYERS, NUM_CLASSES, DROPOUT_PROB).to(DEVICE)

# %% [markdown]
# #### Training

# %%
criterion = nn.CrossEntropyLoss()
optimizer = torch.optim.AdamW(model.parameters(), lr=LEARNING_RATE, weight_decay=WEIGHT_DECAY)

scheduler = ReduceLROnPlateau(
    optimizer,
    mode='max',
    factor=SCHEDULER_FACTOR,
    patience=10,
    min_lr=1e-7
)

model_name = 'testing_new_code_sta_lstm_5_classes_100_dist.pt'
model_filepath = os.path.join(MODEL_SAVE_DIR, model_name)

# %%
trainer = Trainer(
    model=model,
    train_loader=train_loader,
    val_loader=val_loader,
    optimizer=optimizer,
    scheduler=scheduler,
    criterion=criterion,
    device=DEVICE,
    model_save_path=model_filepath,
    num_epochs=NUM_EPOCHS,
    monitor='val_acc',  # or 'val_loss'
    minimize_monitor=False,
    save_best_only=True
)

# %%
trainer.print_training_config()
# Out:
# ==================================================
# 🚀 TRAINING CONFIGURATION
# ==================================================
#
# --- Model Architecture ---
#   Model Type            : STA_LSTM
#   Input Features        : 100
#   Hidden Size           : 128
#   Num Layers            : 2
#   Bidirectional         : True
#   Dropout (LSTM)        : 0.3
#   Num Parameters        : 691434
#
# --- Optimizer & Regularization ---
#   Optimizer             : AdamW
#   Learning Rate (LR)    : 5e-05
#   Weight Decay (L2)     : 0.005
#
# --- Training Flow ---
#   Batch Size            : 16
#   Num Epochs            : 200
#   Device                : cuda
# ==================================================

# %%
final_model_path, best_model_path, history = trainer.fit()
print(f"Final model saved to: {final_model_path}")
if best_model_path:
    print(f"Best model saved to: {best_model_path}")
# Out:
# Starting training for 200 epochs on cuda
# Saved best model to /content/drive/MyDrive/PainRecognitionProject/models/best_testing_new_code_sta_lstm_5_classes_100_dist.pt (metric=0.2046)
# Epoch 1/200 | Time 11.37s | Train loss 1.6589 | Train acc 0.1997 | Val loss 1.6186 | Val acc 0.2046
# Epoch 2/200 | Time 11.55s | Train loss 1.6491 | Train acc 0.1964 | Val loss 1.6175 | Val acc 0.2000
# Saved best model to /content/drive/MyDrive/PainRecognitionProject/models/best_testing_new_code_sta_lstm_5_classes_100_dist.pt (metric=0.2238)
# Epoch 3/200 | Time 11.87s | Train loss 1.6401 | Train acc 0.1977 | Val loss 1.6109 | Val acc 0.2238
# Epoch 4/200 | Time 10.93s | Train loss 1.6296 | Train acc 0.2023 | Val loss 1.6135 | Val acc 0.1977
# Epoch 5/200 | Time 11.36s | Train loss 1.6280 | Train acc 0.2043 | Val loss 1.6138 | Val acc 0.2000
# Epoch 6/200 | Time 11.48s | Train loss 1.6286 | Train acc 0.1977 | Val loss 1.6096 | Val acc 0.2008
# Epoch 7/200 | Time 11.48s | Train loss 1.6259 | Train acc 0.1975 | Val loss 1.6100 | Val acc 0.1992
# Epoch 8/200 | Time 11.41s | Train loss 1.6251 | Train acc 0.2020 | Val loss 1.6114 | Val acc 0.2000
# Epoch 9/200 | Time 11.41s | Train loss 1.6210 | Train acc 0.2043 | Val loss 1.6132 | Val acc 0.2000
# Epoch 10/200 | Time 11.41s | Train loss 1.6214 | Train acc 0.2007 | Val loss 1.6099 | Val acc 0.2046
# Epoch 11/200 | Time 10.99s | Train loss 1.6191 | Train acc 0.1984 | Val loss 1.6121 | Val acc 0.2000
# Epoch 12/200 | Time 11.20s | Train loss 1.6145 | Train acc 0.2126 | Val loss 1.6092 | Val acc 0.1977
# Epoch 13/200 | Time 11.52s | Train loss 1.6179 | Train acc 0.1989 | Val loss 1.6106 | Val acc 0.2085
# Epoch 14/200 | Time 11.37s | Train loss 1.6200 | Train acc 0.1951 | Val loss 1.6098 | Val acc 0.1938
# Epoch 15/200 | Time 11.38s | Train loss 1.6158 | Train acc 0.2002 | Val loss 1.6128 | Val acc 0.2062
# Epoch 187/200 | Time 10.84s | Train loss 1.5022 | Train acc 0.2956 | Val loss 1.5479 | Val acc 0.2692
# Epoch 188/200 | Time 11.20s | Train loss 1.5026 | Train acc 0.2959 | Val loss 1.5368 | Val acc 0.2777
# Epoch 189/200 | Time 11.30s | Train loss 1.5024 | Train acc 0.2926 | Val loss 1.5447 | Val acc 0.2800
# Epoch 190/200 | Time 11.48s | Train loss 1.5000 | Train acc 0.2992 | Val loss 1.5471 | Val acc 0.2731
# Epoch 191/200 | Time 11.29s | Train loss 1.5002 | Train acc 0.2938 | Val loss 1.5404 | Val acc 0.2885
# Epoch 192/200 | Time 11.50s | Train loss 1.4984 | Train acc 0.3052 | Val loss 1.5506 | Val acc 0.2762
# Epoch 193/200 | Time 11.16s | Train loss 1.5004 | Train acc 0.2920 | Val loss 1.5503 | Val acc 0.2769
# Epoch 194/200 | Time 10.80s | Train loss 1.5023 | Train acc 0.2938 | Val loss 1.5373 | Val acc 0.2838
# Epoch 195/200 | Time 11.46s | Train loss 1.4992 | Train acc 0.2984 | Val loss 1.5492 | Val acc 0.2677
# Epoch 196/200 | Time 11.35s | Train loss 1.5001 | Train acc 0.3028 | Val loss 1.5616 | Val acc 0.2685
# Epoch 197/200 | Time 11.26s | Train loss 1.5032 | Train acc 0.2918 | Val loss 1.5469 | Val acc 0.2800
# Epoch 198/200 | Time 11.35s | Train loss 1.5019 | Train acc 0.3034 | Val loss 1.5408 | Val acc 0.2746
# Epoch 199/200 | Time 11.42s | Train loss 1.5008 | Train acc 0.3030 | Val loss 1.5307 | Val acc 0.2869
# Epoch 200/200 | Time 11.26s | Train loss 1.5000 | Train acc 0.2931 | Val loss 1.5427 | Val acc 0.2946
# Training finished. Best epoch: 109. Best monitored metric: 0.2962
# Final model saved to: /content/drive/MyDrive/PainRecognitionProject/models/testing_new_code_sta_lstm_5_classes_100_dist.pt
# Best model saved to: /content/drive/MyDrive/PainRecognitionProject/models/best_testing_new_code_sta_lstm_5_classes_100_dist.pt

# %%
trainer.plot_history()

# %% [markdown]
# #### Evaluate

# %%
model.load_state_dict(torch.load(best_model_path, map_location=DEVICE), strict=False)
# Out:
# <All keys matched successfully>

# %%
evaluator = Evaluator(model, test_loader, device=DEVICE, model_name=model_name, num_classes=NUM_CLASSES)

# %%
loss, acc, labels, preds = evaluator.evaluate_epoch()
# Out:
# ==================================================
# WYNIKI OCENY DLA MODELU: testing_new_code_sta_lstm_5_classes_100_dist.pt
# ==================================================
# Test Loss: 1.5867
# Test Accuracy: 0.2900
#
# --- Szczegółowy Raport Klasyfikacji ---
#               precision    recall  f1-score   support
#
#      Klasa 0       0.25      0.53      0.34       260
#      Klasa 1       0.31      0.10      0.15       260
#      Klasa 2       0.23      0.20      0.21       260
#      Klasa 3       0.21      0.07      0.11       260
#      Klasa 4       0.41      0.55      0.47       260
#
#     accuracy                           0.29      1300
#    macro avg       0.28      0.29      0.26      1300
# weighted avg       0.28      0.29      0.26      1300
#
# ==================================================
# Confusion matrix:
#  [[137  27  53  24  19]
#  [129  26  49  18  38]
#  [125  11  52  19  53]
#  [ 93  13  42  19  93]
#  [ 65   7  33  12 143]]
