# %% [markdown]
# ### Distances 100 shapley points - 6 class training

# %% [markdown]
# #### Environment preparation

# %%
# Montowanie Google Drive
from google.colab import drive
drive.mount('/content/drive')

COLAB_ROOT = '/content/drive/MyDrive/PainRecognitionProject/'
print(f"Dane będą wczytywane z: {COLAB_ROOT}")
# Out:
# Mounted at /content/drive
# Dane będą wczytywane z: /content/drive/MyDrive/PainRecognitionProject/

# %%
import os

# Przejście do katalogu głównego
# %cd /content

# Klonowanie repo
# !rm -rf automatic-pain-recognition

print(f"Obecne położenie: {os.getcwd()}")
# Out:
# /content
# Obecne położenie: /content

# %%
# Upewnij się, że nazwa użytkownika i repozytorium są poprawne
USERNAME = 'alicka33'
REPO_NAME = 'automatic-pain-recognition'

# Tworzenie poprawnego adresu URL (format: https://<TOKEN>@github.com/...)
REPO_URL = f"https://github.com/{USERNAME}/{REPO_NAME}.git"

print("Rozpoczynam klonowanie...")

# Klonowanie
# !git clone {REPO_URL}

# Wejście do katalogu
# %cd $REPO_NAME
# Out:
# Rozpoczynam klonowanie...
# Cloning into 'automatic-pain-recognition'...
# remote: Enumerating objects: 232, done.
# remote: Counting objects: 100% (232/232), done.
# remote: Compressing objects: 100% (183/183), done.
# remote: Total 232 (delta 102), reused 173 (delta 45), pack-reused 0 (from 0)
# Receiving objects: 100% (232/232), 10.76 MiB | 16.82 MiB/s, done.
# Resolving deltas: 100% (102/102), done.
# /content/automatic-pain-recognition

# %%
# Instalacja wymaganych bibliotek
# !pip install -r requirements.txt

# %%
import sys
import os

# Dodaj katalog główny projektu do ścieżki systemowej
sys.path.append(os.getcwd())
print(f"Dodano do ścieżki Pythona: {os.getcwd()}")
# Out:
# Dodano do ścieżki Pythona: /content/automatic-pain-recognition

# %% [markdown]
# #### Distances 100 shapley points - 6 class training

# %%
import os
import numpy as np
import pandas as pd
import shutil

import torch
import torch.nn as nn
from torch.utils.data import DataLoader
from torch.optim.lr_scheduler import ReduceLROnPlateau

from training_utils.preprocessed_dataset import PreprocessedDataset
from training_utils.train import Trainer
from training_utils.evaluate import Evaluator
from models.Bi_LSTM import SequenceModel

# %% [markdown]
# #### Hiperparameters

# %%
MAX_SEQUENCE_LENGTH = 37
NUM_FEATURES = 100
NUM_CLASSES = 6
HIDDEN_SIZE = 128
NUM_LAYERS = 2
NUM_EPOCHS = 200
BATCH_SIZE = 16
LEARNING_RATE = 0.00005
DROPOUT_PROB = 0.4
WEIGHT_DECAY = 0.005
SCHEDULER_FACTOR = 0.8

# %% [markdown]
# #### Data preparation

# %%
COLAB_ROOT = '/content/drive/MyDrive/PainRecognitionProject/'
PROCESSED_DATA_DIR = os.path.join(COLAB_ROOT, 'data/RAVDESS_processed_478_xyz_frontalized/')
MODEL_SAVE_DIR = os.path.join(COLAB_ROOT, 'models/')
LOCAL_PROCESSED_DATA_ROOT = '/content/temp_data/'

DEVICE = torch.device("cuda" if torch.cuda.is_available() else "cpu")

# %%
print("Kopiowanie danych z Google Drive do lokalnej pamięci Colab (RAM)...")
if os.path.exists(LOCAL_PROCESSED_DATA_ROOT):
    shutil.rmtree(LOCAL_PROCESSED_DATA_ROOT)
try:
    shutil.copytree(PROCESSED_DATA_DIR, LOCAL_PROCESSED_DATA_ROOT)
    print("✅ Kopiowanie zakończone pomyślnie. Czas trwania: (sprawdź zegar)")
    CURRENT_DATA_DIR = LOCAL_PROCESSED_DATA_ROOT

except Exception as e:
    print(f"❌ Błąd kopiowania danych (sprawdź, czy dane są zamontowane): {e}")
    print("Używam danych bezpośrednio z Drive (może się zawiesić).")
    CURRENT_DATA_DIR = PROCESSED_DATA_DIR
# Out:
# Kopiowanie danych z Google Drive do lokalnej pamięci Colab (RAM)...
# ✅ Kopiowanie zakończone pomyślnie. Czas trwania: (sprawdź zegar)

# %%
best_100 = np.load('/content/drive/MyDrive/PainRecognitionProject/data/top_100_important_landmarks_emotions.npy')

# %%
train_dataset = PreprocessedDataset(
    'train',
    processed_data_dir=CURRENT_DATA_DIR,
    indices=best_100,
    compute_euclidean=True,
    center_point_index=2,
    max_sequence_length=MAX_SEQUENCE_LENGTH,
    selected_labels=[2, 3, 4, 5, 6, 8],
    label_map={2: 0, 3: 1, 4: 2, 5: 3, 6: 4, 8: 5},
)

val_dataset = PreprocessedDataset(
    'val',
    processed_data_dir=CURRENT_DATA_DIR,
    indices=best_100,
    compute_euclidean=True,
    center_point_index=2,
    max_sequence_length=MAX_SEQUENCE_LENGTH,
    selected_labels=[2, 3, 4, 5, 6, 8],
    label_map={2: 0, 3: 1, 4: 2, 5: 3, 6: 4, 8: 5},
)

test_dataset = PreprocessedDataset(
    'test',
    processed_data_dir=CURRENT_DATA_DIR,
    indices=best_100,
    compute_euclidean=True,
    center_point_index=2,
    max_sequence_length=MAX_SEQUENCE_LENGTH,
    selected_labels=[2, 3, 4, 5, 6, 8],
    label_map={2: 0, 3: 1, 4: 2, 5: 3, 6: 4, 8: 5},
)

# %%
def preview_single(dataset, idx=0, timesteps_to_show=3, features_to_show=8):
    x, y = dataset[idx]
    print(f"\nSingle sample idx={idx} from split={dataset.dataset_name}")
    print(f"x shape: {tuple(x.shape)}, y: {y}")
    print(np.round(x[:timesteps_to_show, :features_to_show], 4))

preview_single(train_dataset, 0)
preview_single(val_dataset, 0)
preview_single(test_dataset, 0)
# Out:
# Single sample idx=0 from split=train
# x shape: (37, 100), y: 0
# tensor([[0.2004, 0.2422, 0.1642, 0.1752, 0.1809, 0.1882, 0.1701, 0.2231],
#         [0.1973, 0.2360, 0.1626, 0.1764, 0.1766, 0.1833, 0.1658, 0.2216],
#         [0.1961, 0.2359, 0.1618, 0.1762, 0.1767, 0.1835, 0.1656, 0.2211]])
#
# Single sample idx=0 from split=val
# x shape: (37, 100), y: 0
# tensor([[0.2235, 0.2754, 0.1782, 0.1783, 0.1996, 0.2145, 0.1828, 0.2463],
#         [0.2210, 0.2703, 0.1766, 0.1775, 0.1968, 0.2114, 0.1818, 0.2443],
#         [0.2186, 0.2695, 0.1744, 0.1756, 0.1931, 0.2075, 0.1772, 0.2418]])
#
# Single sample idx=0 from split=test
# x shape: (37, 100), y: 0
# tensor([[0.2100, 0.2658, 0.1665, 0.1652, 0.1967, 0.2125, 0.1877, 0.2303],
#         [0.2117, 0.2679, 0.1670, 0.1654, 0.1955, 0.2127, 0.1855, 0.2315],
#         [0.2128, 0.2720, 0.1677, 0.1661, 0.1971, 0.2137, 0.1880, 0.2326]])

# %%
train_loader = DataLoader(train_dataset, batch_size=BATCH_SIZE, shuffle=True, num_workers=0, pin_memory=True)
for X, y in train_loader:
    print(X.shape, y.shape)  # (B, T_max, num_features)
    break

val_loader = DataLoader(val_dataset, batch_size=BATCH_SIZE, shuffle=True, num_workers=0, pin_memory=True)
for X, y in val_loader:
    print(X.shape, y.shape)  # (B, T_max, num_features)
    break

test_loader = DataLoader(test_dataset, batch_size=BATCH_SIZE, shuffle=True, num_workers=0, pin_memory=True)
for X, y in test_loader:
    print(X.shape, y.shape)  # (B, T_max, num_features)
    break
# Out:
# torch.Size([16, 37, 100]) torch.Size([16])
# torch.Size([16, 37, 100]) torch.Size([16])
# torch.Size([16, 37, 100]) torch.Size([16])

# %% [markdown]
# #### Model preparation

# %%
model = SequenceModel(NUM_FEATURES, HIDDEN_SIZE, NUM_LAYERS, NUM_CLASSES, DROPOUT_PROB).to(DEVICE)

# %% [markdown]
# #### Training

# %%
criterion = nn.CrossEntropyLoss()
optimizer = torch.optim.AdamW(model.parameters(), lr=LEARNING_RATE, weight_decay=WEIGHT_DECAY)

scheduler = ReduceLROnPlateau(
    optimizer,
    mode='max',
    factor=SCHEDULER_FACTOR,
    patience=10,
    min_lr=1e-7
)

model_name = 'testing_new_code_emotions_100_distances_6_classes.pt'
model_filepath = os.path.join(MODEL_SAVE_DIR, model_name)

# %%
trainer = Trainer(
    model=model,
    train_loader=train_loader,
    val_loader=val_loader,
    optimizer=optimizer,
    scheduler=scheduler,
    criterion=criterion,
    device=DEVICE,
    model_save_path=model_filepath,
    num_epochs=NUM_EPOCHS,
    monitor='val_acc',  # or 'val_loss'
    minimize_monitor=False,
    save_best_only=True
)

# %%
trainer.print_training_config()
# Out:
# ==================================================
# 🚀 TRAINING CONFIGURATION
# ==================================================
#
# --- Model Architecture ---
#   Model Type            : SequenceModel
#   Input Features        : 100
#   Hidden Size           : 128
#   Num Layers            : 2
#   Bidirectional         : True
#   Dropout (LSTM)        : 0.4
#   Num Parameters        : 632326
#
# --- Optimizer & Regularization ---
#   Optimizer             : AdamW
#   Learning Rate (LR)    : 5e-05
#   Weight Decay (L2)     : 0.005
#
# --- Training Flow ---
#   Batch Size            : 16
#   Num Epochs            : 200
#   Device                : cuda
# ==================================================

# %%
final_model_path, best_model_path, history = trainer.fit()
print(f"Final model saved to: {final_model_path}")
if best_model_path:
    print(f"Best model saved to: {best_model_path}")
# Out:
# Starting training for 200 epochs on cuda
# Saved best model to /content/drive/MyDrive/PainRecognitionProject/models/best_testing_new_code_emotions_100_distances_6_classes.pt (metric=0.1671)
# Epoch 1/200 | Time 3.54s | Train loss 1.7932 | Train acc 0.1738 | Val loss 1.7916 | Val acc 0.1671
# Saved best model to /content/drive/MyDrive/PainRecognitionProject/models/best_testing_new_code_emotions_100_distances_6_classes.pt (metric=0.1828)
# Epoch 2/200 | Time 2.61s | Train loss 1.7935 | Train acc 0.1569 | Val loss 1.7909 | Val acc 0.1828
# Saved best model to /content/drive/MyDrive/PainRecognitionProject/models/best_testing_new_code_emotions_100_distances_6_classes.pt (metric=0.1984)
# Epoch 3/200 | Time 3.17s | Train loss 1.7912 | Train acc 0.1621 | Val loss 1.7903 | Val acc 0.1984
# Epoch 4/200 | Time 2.95s | Train loss 1.7899 | Train acc 0.1836 | Val loss 1.7894 | Val acc 0.1671
# Epoch 5/200 | Time 2.57s | Train loss 1.7897 | Train acc 0.1784 | Val loss 1.7878 | Val acc 0.1828
# Saved best model to /content/drive/MyDrive/PainRecognitionProject/models/best_testing_new_code_emotions_100_distances_6_classes.pt (metric=0.2768)
# Epoch 6/200 | Time 2.94s | Train loss 1.7857 | Train acc 0.1901 | Val loss 1.7811 | Val acc 0.2768
# Epoch 7/200 | Time 2.76s | Train loss 1.7454 | Train acc 0.2318 | Val loss 1.6988 | Val acc 0.2480
# Epoch 8/200 | Time 3.29s | Train loss 1.6725 | Train acc 0.2715 | Val loss 1.7300 | Val acc 0.2219
# Epoch 9/200 | Time 2.66s | Train loss 1.6627 | Train acc 0.2669 | Val loss 1.7646 | Val acc 0.2141
# Epoch 10/200 | Time 2.60s | Train loss 1.5983 | Train acc 0.2962 | Val loss 1.6182 | Val acc 0.2611
# Epoch 11/200 | Time 2.56s | Train loss 1.5660 | Train acc 0.2995 | Val loss 1.5814 | Val acc 0.2689
# Epoch 12/200 | Time 2.64s | Train loss 1.5256 | Train acc 0.3073 | Val loss 1.5982 | Val acc 0.2663
# Epoch 13/200 | Time 3.27s | Train loss 1.5622 | Train acc 0.3066 | Val loss 1.5763 | Val acc 0.2637
# Saved best model to /content/drive/MyDrive/PainRecognitionProject/models/best_testing_new_code_emotions
# Saved best model to /content/drive/MyDrive/PainRecognitionProject/models/best_testing_new_code_emotions_100_distances_6_classes.pt (metric=0.5666)
# Epoch 187/200 | Time 2.59s | Train loss 0.7833 | Train acc 0.6947 | Val loss 1.4036 | Val acc 0.5666
# Epoch 188/200 | Time 2.61s | Train loss 0.7802 | Train acc 0.6927 | Val loss 1.4849 | Val acc 0.5379
# Epoch 189/200 | Time 2.62s | Train loss 0.7808 | Train acc 0.7077 | Val loss 1.3060 | Val acc 0.5535
# Epoch 190/200 | Time 3.19s | Train loss 0.7622 | Train acc 0.7018 | Val loss 1.2898 | Val acc 0.5274
# Epoch 191/200 | Time 2.84s | Train loss 0.7869 | Train acc 0.6908 | Val loss 1.5059 | Val acc 0.5274
# Epoch 192/200 | Time 2.61s | Train loss 0.7816 | Train acc 0.6999 | Val loss 1.3773 | Val acc 0.5274
# Epoch 193/200 | Time 2.60s | Train loss 0.7638 | Train acc 0.6979 | Val loss 1.2730 | Val acc 0.5144
# Epoch 194/200 | Time 2.56s | Train loss 0.7774 | Train acc 0.7064 | Val loss 1.6767 | Val acc 0.5144
# Epoch 195/200 | Time 3.27s | Train loss 0.7820 | Train acc 0.6927 | Val loss 1.3287 | Val acc 0.5483
# Epoch 196/200 | Time 2.63s | Train loss 0.7739 | Train acc 0.7064 | Val loss 1.6116 | Val acc 0.5274
# Epoch 197/200 | Time 2.61s | Train loss 0.7653 | Train acc 0.7051 | Val loss 1.4608 | Val acc 0.5222
# Epoch 198/200 | Time 2.61s | Train loss 0.7716 | Train acc 0.7090 | Val loss 1.3797 | Val acc 0.5326
# Epoch 199/200 | Time 2.69s | Train loss 0.7675 | Train acc 0.7103 | Val loss 1.2752 | Val acc 0.5274
# Epoch 200/200 | Time 3.18s | Train loss 0.7781 | Train acc 0.6986 | Val loss 1.4176 | Val acc 0.5248
# Training finished. Best epoch: 186. Best monitored metric: 0.5666
# Final model saved to: /content/drive/MyDrive/PainRecognitionProject/models/testing_new_code_emotions_100_distances_6_classes.pt
# Best model saved to: /content/drive/MyDrive/PainRecognitionProject/models/best_testing_new_code_emotions_100_distances_6_classes.pt

# %%
trainer.plot_history()

# %% [markdown]
# #### Evaluate

# %%
model.load_state_dict(torch.load(best_model_path, map_location=DEVICE), strict=False)
# Out:
# <All keys matched successfully>

# %%
evaluator = Evaluator(model, test_loader, device=DEVICE, model_name=model_name, num_classes=NUM_CLASSES)

# %%
loss, acc, labels, preds = evaluator.evaluate_epoch()
# Out:
# ==================================================
# WYNIKI OCENY DLA MODELU: testing_new_code_emotions_100_distances_6_classes.pt
# ==================================================
# Test Loss: 1.4891
# Test Accuracy: 0.4635
#
# --- Szczegółowy Raport Klasyfikacji ---
#               precision    recall  f1-score   support
#
#      Klasa 0       0.43      0.62      0.51        64
#      Klasa 1       0.73      0.50      0.59        64
#      Klasa 2       0.32      0.44      0.37        64
#      Klasa 3       0.66      0.72      0.69        64
#      Klasa 4       0.36      0.38      0.37        64
#      Klasa 5       0.36      0.12      0.19        64
#
#     accuracy                           0.46       384
#    macro avg       0.48      0.46      0.45       384
# weighted avg       0.48      0.46      0.45       384
#
# ==================================================
# Confusion matrix:
#  [[40  4 14  0  2  4]
#  [30 32  2  0  0  0]
#  [ 8  2 28  8 12  6]
#  [ 0  0  8 46 10  0]
#  [12  4 16  4 24  4]
#  [ 4  2 20 12 18  8]]
