# %% [markdown]
# ### Coordinates 77 manually selected points - 6 class training

# %% [markdown]
# #### Environment preparation

# %%
# Montowanie Google Drive
from google.colab import drive
drive.mount('/content/drive')

COLAB_ROOT = '/content/drive/MyDrive/PainRecognitionProject/'
print(f"Dane będą wczytywane z: {COLAB_ROOT}")
# Out:
# Mounted at /content/drive
# Dane będą wczytywane z: /content/drive/MyDrive/PainRecognitionProject/

# %%
import os

# Przejście do katalogu głównego
# %cd /content

# Klonowanie repo
# !rm -rf automatic-pain-recognition

print(f"Obecne położenie: {os.getcwd()}")
# Out:
# /content
# Obecne położenie: /content

# %%
# Upewnij się, że nazwa użytkownika i repozytorium są poprawne
USERNAME = 'alicka33'
REPO_NAME = 'automatic-pain-recognition'

# Tworzenie poprawnego adresu URL (format: https://<TOKEN>@github.com/...)
REPO_URL = f"https://github.com/{USERNAME}/{REPO_NAME}.git"

print("Rozpoczynam klonowanie...")

# Klonowanie
# !git clone {REPO_URL}

# Wejście do katalogu
# %cd $REPO_NAME
# Out:
# Rozpoczynam klonowanie...
# Cloning into 'automatic-pain-recognition'...
# remote: Enumerating objects: 217, done.
# remote: Counting objects: 100% (217/217), done.
# remote: Compressing objects: 100% (172/172), done.
# remote: Total 217 (delta 93), reused 163 (delta 41), pack-reused 0 (from 0)
# Receiving objects: 100% (217/217), 10.59 MiB | 16.82 MiB/s, done.
# Resolving deltas: 100% (93/93), done.
# /content/automatic-pain-recognition

# %%
# Instalacja wymaganych bibliotek
# !pip install -r requirements.txt

# %%
import sys
import os

# Dodaj katalog główny projektu do ścieżki systemowej
sys.path.append(os.getcwd())
print(f"Dodano do ścieżki Pythona: {os.getcwd()}")
# Out:
# Dodano do ścieżki Pythona: /content/automatic-pain-recognition

# %% [markdown]
# #### Coordinates 77 manually selected points - 6 class training

# %%
import os
import numpy as np
import pandas as pd
import shutil

import torch
import torch.nn as nn
from torch.utils.data import DataLoader
from torch.optim.lr_scheduler import ReduceLROnPlateau

from training_utils.preprocessed_dataset import PreprocessedDataset
from training_utils.train import Trainer
from training_utils.evaluate import Evaluator
from models.Bi_LSTM import SequenceModel

# %% [markdown]
# #### Hiperparameters

# %%
MAX_SEQUENCE_LENGTH = 37
NUM_FEATURES = 231
NUM_CLASSES = 6
HIDDEN_SIZE = 128
NUM_LAYERS = 2
NUM_EPOCHS = 200
BATCH_SIZE = 16
LEARNING_RATE = 0.00005
DROPOUT_PROB = 0.4
WEIGHT_DECAY = 0.005
SCHEDULER_FACTOR = 0.8

# %% [markdown]
# #### Data preparation

# %%
COLAB_ROOT = '/content/drive/MyDrive/PainRecognitionProject/'
PROCESSED_DATA_DIR = os.path.join(COLAB_ROOT, 'data/RAVDESS_processed_478_xyz_frontalized/')
MODEL_SAVE_DIR = os.path.join(COLAB_ROOT, 'models/')
LOCAL_PROCESSED_DATA_ROOT = '/content/temp_data/'

DEVICE = torch.device("cuda" if torch.cuda.is_available() else "cpu")

# %%
print("Kopiowanie danych z Google Drive do lokalnej pamięci Colab (RAM)...")
if os.path.exists(LOCAL_PROCESSED_DATA_ROOT):
    shutil.rmtree(LOCAL_PROCESSED_DATA_ROOT)
try:
    shutil.copytree(PROCESSED_DATA_DIR, LOCAL_PROCESSED_DATA_ROOT)
    print("✅ Kopiowanie zakończone pomyślnie. Czas trwania: (sprawdź zegar)")
    CURRENT_DATA_DIR = LOCAL_PROCESSED_DATA_ROOT

except Exception as e:
    print(f"❌ Błąd kopiowania danych (sprawdź, czy dane są zamontowane): {e}")
    print("Używam danych bezpośrednio z Drive (może się zawiesić).")
    CURRENT_DATA_DIR = PROCESSED_DATA_DIR
# Out:
# Kopiowanie danych z Google Drive do lokalnej pamięci Colab (RAM)...
# ✅ Kopiowanie zakończone pomyślnie. Czas trwania: (sprawdź zegar)

# %%
best_77_landmarks = np.load('/content/drive/MyDrive/PainRecognitionProject/data/manualy_selected_points.npy')

feature_indices_x = best_77_landmarks * 3
feature_indices_y = best_77_landmarks * 3 + 1
feature_indices_z = best_77_landmarks * 3 + 2
# Interleave to get [X1, Y1, Z1, X2, Y2, Z2, ...]
best_231_features = np.stack([feature_indices_x, feature_indices_y, feature_indices_z], axis=1).flatten()

# %%
train_dataset = PreprocessedDataset(
    'train',
    processed_data_dir=CURRENT_DATA_DIR,
    indices=best_231_features,
    compute_euclidean=False,
    center_point_index=2,
    max_sequence_length=MAX_SEQUENCE_LENGTH,
    selected_labels=[2, 3, 4, 5, 6, 8],
    label_map={2: 0, 3: 1, 4: 2, 5: 3, 6: 4, 8: 5},
)

val_dataset = PreprocessedDataset(
    'val',
    processed_data_dir=CURRENT_DATA_DIR,
    indices=best_231_features,
    compute_euclidean=False,
    center_point_index=2,
    max_sequence_length=MAX_SEQUENCE_LENGTH,
    selected_labels=[2, 3, 4, 5, 6, 8],
    label_map={2: 0, 3: 1, 4: 2, 5: 3, 6: 4, 8: 5},
)

test_dataset = PreprocessedDataset(
    'test',
    processed_data_dir=CURRENT_DATA_DIR,
    indices=best_231_features,
    compute_euclidean=False,
    center_point_index=2,
    max_sequence_length=MAX_SEQUENCE_LENGTH,
    selected_labels=[2, 3, 4, 5, 6, 8],
    label_map={2: 0, 3: 1, 4: 2, 5: 3, 6: 4, 8: 5},
)

# %%
def preview_single(dataset, idx=0, timesteps_to_show=3, features_to_show=8):
    x, y = dataset[idx]
    print(f"\nSingle sample idx={idx} from split={dataset.dataset_name}")
    print(f"x shape: {tuple(x.shape)}, y: {y}")
    print(np.round(x[:timesteps_to_show, :features_to_show], 4))

preview_single(train_dataset, 0)
preview_single(val_dataset, 0)
preview_single(test_dataset, 0)
# Out:
# Single sample idx=0 from split=train
# x shape: (37, 231), y: 0
# tensor([[-0.0710, -0.0296,  0.0087, -0.0671, -0.0066,  0.0275, -0.0307,  0.0018],
#         [-0.0735, -0.0284,  0.0082, -0.0694, -0.0050,  0.0270, -0.0313,  0.0030],
#         [-0.0727, -0.0288,  0.0081, -0.0688, -0.0053,  0.0270, -0.0307,  0.0030]])
#
# Single sample idx=0 from split=val
# x shape: (37, 231), y: 0
# tensor([[-7.3400e-02, -3.3600e-02,  8.6000e-03, -6.6400e-02, -7.2000e-03,
#           2.8300e-02, -2.9300e-02,  1.0000e-04],
#         [-7.2900e-02, -3.3300e-02,  8.3000e-03, -6.5800e-02, -6.9000e-03,
#           2.7700e-02, -2.9100e-02,  6.0000e-04],
#         [-7.3800e-02, -3.3600e-02,  8.3000e-03, -6.6600e-02, -7.5000e-03,
#           2.7800e-02, -2.9500e-02,  5.0000e-04]])
#
# Single sample idx=0 from split=test
# x shape: (37, 231), y: 0
# tensor([[-0.0692, -0.0375,  0.0081, -0.0624, -0.0120,  0.0269, -0.0278, -0.0015],
#         [-0.0704, -0.0370,  0.0079, -0.0634, -0.0103,  0.0267, -0.0282, -0.0006],
#         [-0.0700, -0.0372,  0.0078, -0.0631, -0.0106,  0.0268, -0.0281, -0.0007]])

# %%
train_loader = DataLoader(train_dataset, batch_size=BATCH_SIZE, shuffle=True, num_workers=0, pin_memory=True)
for X, y in train_loader:
    print(X.shape, y.shape)  # (B, T_max, num_features)
    break

val_loader = DataLoader(val_dataset, batch_size=BATCH_SIZE, shuffle=True, num_workers=0, pin_memory=True)
for X, y in val_loader:
    print(X.shape, y.shape)  # (B, T_max, num_features)
    break

test_loader = DataLoader(test_dataset, batch_size=BATCH_SIZE, shuffle=True, num_workers=0, pin_memory=True)
for X, y in test_loader:
    print(X.shape, y.shape)  # (B, T_max, num_features)
    break
# Out:
# torch.Size([16, 37, 231]) torch.Size([16])
# torch.Size([16, 37, 231]) torch.Size([16])
# torch.Size([16, 37, 231]) torch.Size([16])

# %% [markdown]
# #### Model preparation

# %%
model = SequenceModel(NUM_FEATURES, HIDDEN_SIZE, NUM_LAYERS, NUM_CLASSES, DROPOUT_PROB).to(DEVICE)

# %% [markdown]
# #### Training

# %%
criterion = nn.CrossEntropyLoss()
optimizer = torch.optim.AdamW(model.parameters(), lr=LEARNING_RATE, weight_decay=WEIGHT_DECAY)

scheduler = ReduceLROnPlateau(
    optimizer,
    mode='max',
    factor=SCHEDULER_FACTOR,
    patience=10,
    min_lr=1e-7
)

model_name = 'testing_new_code_emotions_77_coordinates_6_classes.pt'
model_filepath = os.path.join(MODEL_SAVE_DIR, model_name)

# %%
trainer = Trainer(
    model=model,
    train_loader=train_loader,
    val_loader=val_loader,
    optimizer=optimizer,
    scheduler=scheduler,
    criterion=criterion,
    device=DEVICE,
    model_save_path=model_filepath,
    num_epochs=NUM_EPOCHS,
    monitor='val_acc',  # or 'val_loss'
    minimize_monitor=False,
    save_best_only=True
)

# %%
trainer.print_training_config()
# Out:
# ==================================================
# 🚀 TRAINING CONFIGURATION
# ==================================================
#
# --- Model Architecture ---
#   Model Type            : SequenceModel
#   Input Features        : 231
#   Hidden Size           : 128
#   Num Layers            : 2
#   Bidirectional         : True
#   Dropout (LSTM)        : 0.4
#   Num Parameters        : 766470
#
# --- Optimizer & Regularization ---
#   Optimizer             : AdamW
#   Learning Rate (LR)    : 5e-05
#   Weight Decay (L2)     : 0.005
#
# --- Training Flow ---
#   Batch Size            : 16
#   Num Epochs            : 200
#   Device                : cuda
# ==================================================

# %%
final_model_path, best_model_path, history = trainer.fit()
print(f"Final model saved to: {final_model_path}")
if best_model_path:
    print(f"Best model saved to: {best_model_path}")
# Out:
# Starting training for 200 epochs on cuda
# Saved best model to /content/drive/MyDrive/PainRecognitionProject/models/best_testing_new_code_emotions_77_coordinates_6_classes.pt (metric=0.1488)
# Epoch 1/200 | Time 2.93s | Train loss 1.7921 | Train acc 0.1628 | Val loss 1.7913 | Val acc 0.1488
# Saved best model to /content/drive/MyDrive/PainRecognitionProject/models/best_testing_new_code_emotions_77_coordinates_6_classes.pt (metric=0.1645)
# Epoch 2/200 | Time 1.58s | Train loss 1.7914 | Train acc 0.1706 | Val loss 1.7904 | Val acc 0.1645
# Saved best model to /content/drive/MyDrive/PainRecognitionProject/models/best_testing_new_code_emotions_77_coordinates_6_classes.pt (metric=0.3055)
# Epoch 3/200 | Time 1.45s | Train loss 1.7900 | Train acc 0.1862 | Val loss 1.7891 | Val acc 0.3055
# Epoch 4/200 | Time 1.45s | Train loss 1.7873 | Train acc 0.2096 | Val loss 1.7856 | Val acc 0.2742
# Epoch 5/200 | Time 1.44s | Train loss 1.7743 | Train acc 0.2331 | Val loss 1.7506 | Val acc 0.2742
# Saved best model to /content/drive/MyDrive/PainRecognitionProject/models/best_testing_new_code_emotions_77_coordinates_6_classes.pt (metric=0.3159)
# Epoch 6/200 | Time 1.43s | Train loss 1.5993 | Train acc 0.3053 | Val loss 1.5954 | Val acc 0.3159
# Epoch 7/200 | Time 1.45s | Train loss 1.4950 | Train acc 0.3236 | Val loss 1.5826 | Val acc 0.3055
# Epoch 8/200 | Time 1.46s | Train loss 1.4781 | Train acc 0.3249 | Val loss 1.6003 | Val acc 0.3003
# Epoch 9/200 | Time 1.79s | Train loss 1.4490 | Train acc 0.3424 | Val loss 1.6179 | Val acc 0.3003
# Epoch 10/200 | Time 1.82s | Train loss 1.4080 | Train acc 0.3607 | Val loss 1.7891 | Val acc 0.2872
# Epoch 11/200 | Time 1.49s | Train loss 1.3941 | Train acc 0.3835 | Val loss 1.6342 | Val acc 0.2977
# Epoch 12/200 | Time 1.47s | Train loss 1.3835 | Train acc 0.3854 | Val loss 1.5421 | Val acc 0.3107
# Saved best model to /content/drive/MyDrive/PainRecognitionProject/models/best_testing_new_code_emotions_77_coordinates_6_classes.pt (metric=0.3420)
# Epoch 13/200 | Time 1.45s | Train loss 1.3522 | Train acc 0.4180 | Val loss 1.5251 | Val acc 0.3420
# Epoch 14/200 | Time 1.44s | Train loss 1.3427 | Train acc 0.4173 | Val loss 1.4877 | Val acc 0.3290
# Epoch 15/200 | Time 1.45s | Train loss 1.3592 | Train acc 0.4082 | Val loss 1.6499 | Val acc 0.2820
# Saved best model to /content/drive/MyDrive/PainRecognitionProject/models/best_testing_new_code_emotions_77_coordinates_6_classes.pt (metric=0.3577)
# Epoch 16/200 | Time 1.45s | Train loss 1.3107 | Train acc 0.4427 | Val loss 1.5541 | Val acc 0.3577
# Epoch 17/200 | Time 1.53s | Train loss 1.3149 | Train acc 0.4134 | Val loss 1.5311 | Val acc 0.3551
# Saved best model to /content/drive/MyDrive/PainRecognitionProject/models/best_testing_new_code_emotions_77_coordinates_6_classes.pt (metric=0.3603)
# Epoch 18/200 | Time 1.79s | Train loss 1.3047 | Train acc 0.4355 | Val loss 1.5034 | Val acc 0.3603
# Epoch 19/200 | Time 1.78s | Train loss 1.2919 | Train acc 0.4473 | Val loss 1.5094 | Val acc 0.3603
# Saved best model to /content/drive/MyDrive/PainRecognitionProject/models/best_testing_new_code_emotions_77_coordinates_6_classes.pt (metric=0.3629)
# Epoch 20/200 | Time 1.48s | Train loss 1.2899 | Train acc 0.4473 | Val loss 1.6380 | Val acc 0.3629
# Epoch 21/200 | Time 1.47s | Train loss 1.2556 | Train acc 0.4531 | Val loss 1.6051 | Val acc 0.3499
# Epoch 22/200 | Time 1.48s | Train loss 1.2656 | Train acc 0.4460 | Val loss 1.4406 | Val acc 0.3577
# Epoch 23/200 | Time 1.46s | Train loss 1.2545 | Train acc 0.4577 | Val loss 1.4978 | Val acc 0.3473
# Epoch 24/200 | Time 1.43s | Train loss 1.2784 | Train acc 0.4427 | Val loss 1.5714 | Val acc 0.3420
# Saved best model to /content/drive/MyDrive/PainRecognitionProject/models/best_testing_new_code_emotions_77_coordinates_6_classes.pt (metric=0.3734)
# Epoch 25/200 | Time 1.45s | Train loss 1.2396 | Train acc 0.4564 | Val loss 1.5711 | Val acc 0.3734
# Saved best model to /content/drive/MyDrive/PainRecognitionProject/models/best_testing_new_code_emotions_77_coordinates_6_classes.pt (metric=0.4021)
# Epoch 26/200 | Time 1.62s | Train loss 1.2045 | Train acc 0.4753 | Val loss 1.6225 | Val acc 0.4021
# Epoch 27/200 | Time 1.83s | Train loss 1.2386 | Train acc 0.4531 | Val loss 1.4870 | Val acc 0.3681
# Epoch 28/200 | Time 1.68s | Train loss 1.1943 | Train acc 0.4766 | Val loss 1.6032 | Val acc 0.3786
# Epoch 29/200 | Time 1.45s | Train loss 1.2057 | Train acc 0.4746 | Val loss 1.6715 | Val acc 0.3629
# Epoch 30/200 | Time 1.47s | Train loss 1.2306 | Train acc 0.4596 | Val loss 1.4612 | Val acc 0.3786
# Saved best model to /content/drive/MyDrive/PainRecognitionProject/models/best_testing_new_code_emotions_77_coordinates_6_classes.pt (metric=0.4099)
# Epoch 31/200 | Time 1.52s | Train loss 1.1963 | Train acc 0.4759 | Val loss 1.4579 | Val acc 0.4099
# Epoch 32/200 | Time 1.48s | Train loss 1.1740 | Train acc 0.4883 | Val loss 1.4930 | Val acc 0.4073
# Epoch 33/200 | Time 1.48s | Train loss 1.1603 | Train acc 0.5052 | Val loss 1.4049 | Val acc 0.3943
# Epoch 34/200 | Time 1.48s | Train loss 1.1347 | Train acc 0.5150 | Val loss 1.3794 | Val acc 0.3969
# Epoch 35/200 | Time 1.76s | Train loss 1.1323 | Train acc 0.5378 | Val loss 1.4986 | Val acc 0.3995
# Saved best model to /content/drive/MyDrive/PainRecognitionProject/models/best_testing_new_code_emotions_77_coordinates_6_classes.pt (metric=0.4282)
# Epoch 36/200 | Time 1.85s | Train loss 1.1514 | Train acc 0.5247 | Val loss 1.5415 | Val acc 0.4282
# Saved best model to /content/drive/MyDrive/PainRecognitionProject/models/best_testing_new_code_emotions_77_coordinates_6_classes.pt (metric=0.4465)
# Epoch 37/200 | Time 1.49s | Train loss 1.0704 | Train acc 0.5573 | Val loss 1.4237 | Val acc 0.4465
# Saved best model to /content/drive/MyDrive/PainRecognitionProject/models/best_testing_new_code_emotions_77_coordinates_6_classes.pt (metric=0.4726)
# Epoch 38/200 | Time 1.48s | Train loss 1.0787 | Train acc 0.5495 | Val loss 1.4639 | Val acc 0.4726
# Epoch 39/200 | Time 1.54s | Train loss 1.0778 | Train acc 0.5404 | Val loss 1.3888 | Val acc 0.4726
# Epoch 40/200 | Time 1.50s | Train loss 1.0632 | Train acc 0.5645 | Val loss 1.4673 | Val acc 0.4360
# Epoch 41/200 | Time 1.61s | Train loss 1.0855 | Train acc 0.5430 | Val loss 1.5127 | Val acc 0.4360
# Epoch 42/200 | Time 1.47s | Train loss 1.0515 | Train acc 0.5579 | Val loss 1.6188 | Val acc 0.4439
# Epoch 43/200 | Time 1.66s | Train loss 1.0128 | Train acc 0.5781 | Val loss 1.4269 | Val acc 0.4308
# Epoch 44/200 | Time 1.88s | Train loss 1.0336 | Train acc 0.5632 | Val loss 1.5812 | Val acc 0.4360
# Epoch 45/200 | Time 1.72s | Train loss 1.0238 | Train acc 0.5938 | Val loss 1.5202 | Val acc 0.4700
# Saved best model to /content/drive/MyDrive/PainRecognitionProject/models/best_testing_new_code_emotions_77_coordinates_6_classes.pt (metric=0.4830)
# Epoch 46/200 | Time 1.50s | Train loss 1.0013 | Train acc 0.5781 | Val loss 1.4622 | Val acc 0.4830
# Epoch 47/200 | Time 1.48s | Train loss 1.0052 | Train acc 0.5846 | Val loss 1.3948 | Val acc 0.4621
# Epoch 48/200 | Time 1.48s | Train loss 0.9790 | Train acc 0.6009 | Val loss 1.3901 | Val acc 0.4491
# Saved best model to /content/drive/MyDrive/PainRecognitionProject/models/best_testing_new_code_emotions_77_coordinates_6_classes.pt (metric=0.5065)
# Epoch 49/200 | Time 1.46s | Train loss 0.9584 | Train acc 0.6003 | Val loss 1.4123 | Val acc 0.5065
# Epoch 50/200 | Time 1.48s | Train loss 0.9549 | Train acc 0.6146 | Val loss 1.4069 | Val acc 0.4804
# Epoch 51/200 | Time 1.46s | Train loss 0.9416 | Train acc 0.6087 | Val loss 1.4371 | Val acc 0.4909
# Epoch 52/200 | Time 1.71s | Train loss 0.9155 | Train acc 0.6309 | Val loss 1.4264 | Val acc 0.4804
# Epoch 53/200 | Time 1.79s | Train loss 0.9532 | Train acc 0.6016 | Val loss 1.5876 | Val acc 0.4360
# Epoch 54/200 | Time 1.58s | Train loss 0.9225 | Train acc 0.6198 | Val loss 1.5746 | Val acc 0.4491
# Epoch 55/200 | Time 1.45s | Train loss 0.8967 | Train acc 0.6270 | Val loss 1.3266 | Val acc 0.4935
# Epoch 56/200 | Time 1.45s | Train loss 0.8981 | Train acc 0.6413 | Val loss 1.2841 | Val acc 0.4830
# Saved best model to /content/drive/MyDrive/PainRecognitionProject/models/best_testing_new_code_emotions_77_coordinates_6_classes.pt (metric=0.5196)
# Epoch 57/200 | Time 1.44s | Train loss 0.9045 | Train acc 0.6243 | Val loss 1.2033 | Val acc 0.5196
# Epoch 58/200 | Time 1.47s | Train loss 0.8932 | Train acc 0.6504 | Val loss 1.4484 | Val acc 0.4856
# Epoch 59/200 | Time 1.46s | Train loss 0.8905 | Train acc 0.6465 | Val loss 1.3838 | Val acc 0.5013
# Epoch 60/200 | Time 1.45s | Train loss 0.8989 | Train acc 0.6302 | Val loss 1.4570 | Val acc 0.4726
# Epoch 61/200 | Time 1.78s | Train loss 0.8824 | Train acc 0.6484 | Val loss 1.4578 | Val acc 0.4778
# Epoch 62/200 | Time 1.88s | Train loss 0.8682 | Train acc 0.6484 | Val loss 1.4860 | Val acc 0.4726
# Epoch 63/200 | Time 1.47s | Train loss 0.8539 | Train acc 0.6497 | Val loss 1.3890 | Val acc 0.4778
# Epoch 64/200 | Time 1.45s | Train loss 0.8533 | Train acc 0.6569 | Val loss 1.4550 | Val acc 0.4804
# Epoch 65/200 | Time 1.45s | Train loss 0.8702 | Train acc 0.6562 | Val loss 1.2946 | Val acc 0.5170
# Epoch 66/200 | Time 1.45s | Train loss 0.8450 | Train acc 0.6562 | Val loss 1.4254 | Val acc 0.4621
# Saved best model to /content/drive/MyDrive/PainRecognitionProject/models/best_testing_new_code_emotions_77_coordinates_6_classes.pt (metric=0.5300)
# Epoch 67/200 | Time 1.46s | Train loss 0.8371 | Train acc 0.6771 | Val loss 1.2380 | Val acc 0.5300
# Epoch 68/200 | Time 1.46s | Train loss 0.8450 | Train acc 0.6504 | Val loss 1.5066 | Val acc 0.4125
# Epoch 69/200 | Time 1.45s | Train loss 0.8121 | Train acc 0.6745 | Val loss 1.3353 | Val acc 0.4804
# Epoch 70/200 | Time 1.77s | Train loss 0.8289 | Train acc 0.6667 | Val loss 1.3885 | Val acc 0.4700
# Epoch 71/200 | Time 1.82s | Train loss 0.7996 | Train acc 0.6829 | Val loss 1.3115 | Val acc 0.4778
# Epoch 72/200 | Time 1.46s | Train loss 0.8273 | Train acc 0.6647 | Val loss 1.3975 | Val acc 0.4778
# Epoch 73/200 | Time 1.45s | Train loss 0.7982 | Train acc 0.6732 | Val loss 1.3564 | Val acc 0.4700
# Epoch 74/200 | Time 1.46s | Train loss 0.8387 | Train acc 0.6647 | Val loss 1.5138 | Val acc 0.4648
# Epoch 75/200 | Time 1.46s | Train loss 0.7928 | Train acc 0.6732 | Val loss 1.4070 | Val acc 0.4804
# Epoch 76/200 | Time 1.45s | Train loss 0.7948 | Train acc 0.6868 | Val loss 1.4359 | Val acc 0.5091
# Epoch 77/200 | Time 1.45s | Train loss 0.7954 | Train acc 0.6810 | Val loss 1.4159 | Val acc 0.4883
# Epoch 78/200 | Time 1.54s | Train loss 0.7701 | Train acc 0.6940 | Val loss 1.3755 | Val acc 0.4700
# Epoch 79/200 | Time 1.81s | Train loss 0.7459 | Train acc 0.7044 | Val loss 1.3903 | Val acc 0.4726
# Epoch 80/200 | Time 1.78s | Train loss 0.7489 | Train acc 0.7096 | Val loss 1.4653 | Val acc 0.4804
# Epoch 81/200 | Time 1.45s | Train loss 0.7409 | Train acc 0.7129 | Val loss 1.2754 | Val acc 0.4935
# Epoch 82/200 | Time 1.45s | Train loss 0.7697 | Train acc 0.6953 | Val loss 1.3222 | Val acc 0.4961
# Epoch 83/200 | Time 1.44s | Train loss 0.7355 | Train acc 0.7142 | Val loss 1.2971 | Val acc 0.4961
# Epoch 84/200 | Time 1.46s | Train loss 0.7188 | Train acc 0.7129 | Val loss 1.4087 | Val acc 0.5039
# Epoch 85/200 | Time 1.44s | Train loss 0.7329 | Train acc 0.7214 | Val loss 1.4997 | Val acc 0.5039
# Epoch 86/200 | Time 1.44s | Train loss 0.7291 | Train acc 0.7103 | Val loss 1.3112 | Val acc 0.5196
# Epoch 87/200 | Time 1.59s | Train loss 0.7266 | Train acc 0.7103 | Val loss 1.4500 | Val acc 0.4856
# Epoch 88/200 | Time 1.82s | Train loss 0.7689 | Train acc 0.6992 | Val loss 1.3339 | Val acc 0.5039
# Epoch 89/200 | Time 1.79s | Train loss 0.7212 | Train acc 0.7051 | Val loss 1.5939 | Val acc 0.4308
# Epoch 90/200 | Time 1.48s | Train loss 0.6772 | Train acc 0.7305 | Val loss 1.5167 | Val acc 0.4752
# Epoch 91/200 | Time 1.44s | Train loss 0.7326 | Train acc 0.7083 | Val loss 1.5198 | Val acc 0.5039
# Epoch 92/200 | Time 1.42s | Train loss 0.7193 | Train acc 0.7096 | Val loss 1.3703 | Val acc 0.5013
# Epoch 93/200 | Time 1.43s | Train loss 0.6838 | Train acc 0.7279 | Val loss 1.5035 | Val acc 0.5013
# Epoch 94/200 | Time 1.42s | Train loss 0.6910 | Train acc 0.7305 | Val loss 1.5224 | Val acc 0.4517
# Epoch 95/200 | Time 1.42s | Train loss 0.6923 | Train acc 0.7227 | Val loss 1.5772 | Val acc 0.4413
# Epoch 96/200 | Time 1.62s | Train loss 0.6773 | Train acc 0.7259 | Val loss 1.5459 | Val acc 0.4674
# Epoch 97/200 | Time 1.84s | Train loss 0.6756 | Train acc 0.7376 | Val loss 1.5991 | Val acc 0.4700
# Epoch 98/200 | Time 1.69s | Train loss 0.6872 | Train acc 0.7253 | Val loss 1.5189 | Val acc 0.5091
# Epoch 99/200 | Time 1.46s | Train loss 0.7148 | Train acc 0.7122 | Val loss 1.4519 | Val acc 0.4883
# Epoch 100/200 | Time 1.43s | Train loss 0.6488 | Train acc 0.7441 | Val loss 1.6669 | Val acc 0.4491
# Epoch 101/200 | Time 1.45s | Train loss 0.6621 | Train acc 0.7350 | Val loss 1.6510 | Val acc 0.4282
# Epoch 102/200 | Time 1.46s | Train loss 0.6684 | Train acc 0.7435 | Val loss 1.5380 | Val acc 0.4883
# Epoch 103/200 | Time 1.43s | Train loss 0.6609 | Train acc 0.7415 | Val loss 1.5168 | Val acc 0.5013
# Epoch 104/200 | Time 1.44s | Train loss 0.6597 | Train acc 0.7448 | Val loss 1.5315 | Val acc 0.5065
# Epoch 105/200 | Time 1.64s | Train loss 0.6659 | Train acc 0.7376 | Val loss 1.5845 | Val acc 0.4804
# Epoch 106/200 | Time 1.84s | Train loss 0.6719 | Train acc 0.7305 | Val loss 1.4231 | Val acc 0.5248
# Epoch 107/200 | Time 1.66s | Train loss 0.6367 | Train acc 0.7533 | Val loss 1.4929 | Val acc 0.4961
# Epoch 108/200 | Time 1.44s | Train loss 0.6517 | Train acc 0.7311 | Val loss 1.5076 | Val acc 0.4987
# Epoch 109/200 | Time 1.43s | Train loss 0.6257 | Train acc 0.7676 | Val loss 1.4691 | Val acc 0.4987
# Epoch 110/200 | Time 1.47s | Train loss 0.6331 | Train acc 0.7526 | Val loss 1.4448 | Val acc 0.5013
# Epoch 111/200 | Time 1.46s | Train loss 0.6586 | Train acc 0.7493 | Val loss 1.4958 | Val acc 0.4778
# Epoch 112/200 | Time 1.47s | Train loss 0.6469 | Train acc 0.7591 | Val loss 1.6381 | Val acc 0.4726
# Epoch 113/200 | Time 1.46s | Train loss 0.6102 | Train acc 0.7617 | Val loss 1.5681 | Val acc 0.4883
# Epoch 114/200 | Time 1.76s | Train loss 0.6297 | Train acc 0.7539 | Val loss 1.5290 | Val acc 0.4935
# Epoch 115/200 | Time 1.94s | Train loss 0.6106 | Train acc 0.7669 | Val loss 1.5654 | Val acc 0.4804
# Epoch 116/200 | Time 1.57s | Train loss 0.6039 | Train acc 0.7624 | Val loss 1.5642 | Val acc 0.4883
# Epoch 117/200 | Time 1.49s | Train loss 0.6260 | Train acc 0.7533 | Val loss 1.6264 | Val acc 0.4700
# Epoch 118/200 | Time 1.45s | Train loss 0.5937 | Train acc 0.7702 | Val loss 1.5481 | Val acc 0.4883
# Epoch 119/200 | Time 1.46s | Train loss 0.6033 | Train acc 0.7598 | Val loss 1.5464 | Val acc 0.5013
# Epoch 120/200 | Time 1.46s | Train loss 0.6390 | Train acc 0.7578 | Val loss 1.5170 | Val acc 0.4778
# Epoch 121/200 | Time 1.46s | Train loss 0.6030 | Train acc 0.7650 | Val loss 1.5322 | Val acc 0.5039
# Epoch 122/200 | Time 1.49s | Train loss 0.5916 | Train acc 0.7760 | Val loss 1.5929 | Val acc 0.5065
# Epoch 123/200 | Time 1.83s | Train loss 0.5817 | Train acc 0.7728 | Val loss 1.5627 | Val acc 0.4935
# Epoch 124/200 | Time 1.84s | Train loss 0.5722 | Train acc 0.7747 | Val loss 1.6014 | Val acc 0.4935
# Epoch 125/200 | Time 1.47s | Train loss 0.5768 | Train acc 0.7747 | Val loss 1.5761 | Val acc 0.4909
# Epoch 126/200 | Time 1.47s | Train loss 0.5848 | Train acc 0.7741 | Val loss 1.5899 | Val acc 0.4674
# Epoch 127/200 | Time 1.49s | Train loss 0.5816 | Train acc 0.7747 | Val loss 1.5687 | Val acc 0.4830
# Epoch 128/200 | Time 1.47s | Train loss 0.5768 | Train acc 0.7754 | Val loss 1.6908 | Val acc 0.4674
# Epoch 129/200 | Time 1.46s | Train loss 0.5779 | Train acc 0.7852 | Val loss 1.5437 | Val acc 0.5065
# Epoch 130/200 | Time 1.44s | Train loss 0.5786 | Train acc 0.7819 | Val loss 1.6156 | Val acc 0.4987
# Epoch 131/200 | Time 1.62s | Train loss 0.5694 | Train acc 0.7819 | Val loss 1.7783 | Val acc 0.4752
# Epoch 132/200 | Time 1.81s | Train loss 0.5482 | Train acc 0.7917 | Val loss 1.6953 | Val acc 0.4621
# Epoch 133/200 | Time 1.74s | Train loss 0.5632 | Train acc 0.7865 | Val loss 1.5909 | Val acc 0.4856
# Epoch 134/200 | Time 1.48s | Train loss 0.5473 | Train acc 0.7806 | Val loss 1.6670 | Val acc 0.4700
# Epoch 135/200 | Time 1.46s | Train loss 0.5440 | Train acc 0.7884 | Val loss 1.6229 | Val acc 0.5013
# Epoch 136/200 | Time 1.50s | Train loss 0.5606 | Train acc 0.7845 | Val loss 1.6522 | Val acc 0.4804
# Epoch 137/200 | Time 1.47s | Train loss 0.5533 | Train acc 0.7819 | Val loss 1.5910 | Val acc 0.5091
# Epoch 138/200 | Time 1.50s | Train loss 0.5498 | Train acc 0.7897 | Val loss 1.6656 | Val acc 0.4778
# Epoch 139/200 | Time 1.48s | Train loss 0.5638 | Train acc 0.7799 | Val loss 1.6371 | Val acc 0.5091
# Epoch 140/200 | Time 1.70s | Train loss 0.5368 | Train acc 0.7865 | Val loss 1.6884 | Val acc 0.4856
# Epoch 141/200 | Time 1.82s | Train loss 0.5375 | Train acc 0.7956 | Val loss 1.5552 | Val acc 0.5117
# Epoch 142/200 | Time 1.54s | Train loss 0.5515 | Train acc 0.7891 | Val loss 1.6564 | Val acc 0.5274
# Epoch 143/200 | Time 1.46s | Train loss 0.5386 | Train acc 0.8053 | Val loss 1.6715 | Val acc 0.4935
# Epoch 144/200 | Time 1.44s | Train loss 0.5453 | Train acc 0.7949 | Val loss 1.7366 | Val acc 0.4883
# Epoch 145/200 | Time 1.45s | Train loss 0.5594 | Train acc 0.7793 | Val loss 1.6689 | Val acc 0.4909
# Epoch 146/200 | Time 1.44s | Train loss 0.5343 | Train acc 0.7936 | Val loss 1.7507 | Val acc 0.4830
# Epoch 147/200 | Time 1.45s | Train loss 0.5498 | Train acc 0.7891 | Val loss 1.6369 | Val acc 0.5091
# Epoch 148/200 | Time 1.43s | Train loss 0.5279 | Train acc 0.7949 | Val loss 1.7529 | Val acc 0.4935
# Epoch 149/200 | Time 1.75s | Train loss 0.5312 | Train acc 0.7995 | Val loss 1.7482 | Val acc 0.4726
# Epoch 150/200 | Time 1.89s | Train loss 0.5282 | Train acc 0.8008 | Val loss 1.7012 | Val acc 0.4961
# Epoch 151/200 | Time 1.45s | Train loss 0.5380 | Train acc 0.7936 | Val loss 1.7575 | Val acc 0.4726
# Epoch 152/200 | Time 1.44s | Train loss 0.5218 | Train acc 0.8034 | Val loss 1.6715 | Val acc 0.5039
# Epoch 153/200 | Time 1.46s | Train loss 0.5101 | Train acc 0.8047 | Val loss 1.6547 | Val acc 0.4830
# Epoch 154/200 | Time 1.42s | Train loss 0.5265 | Train acc 0.7878 | Val loss 1.8005 | Val acc 0.4726
# Epoch 155/200 | Time 1.45s | Train loss 0.5383 | Train acc 0.7975 | Val loss 1.7255 | Val acc 0.4569
# Epoch 156/200 | Time 1.49s | Train loss 0.5225 | Train acc 0.8066 | Val loss 1.7121 | Val acc 0.4883
# Epoch 157/200 | Time 1.57s | Train loss 0.5088 | Train acc 0.8008 | Val loss 1.7570 | Val acc 0.4674
# Epoch 158/200 | Time 1.87s | Train loss 0.5190 | Train acc 0.8001 | Val loss 1.6307 | Val acc 0.5013
# Epoch 159/200 | Time 1.86s | Train loss 0.5022 | Train acc 0.8099 | Val loss 1.7494 | Val acc 0.4752
# Epoch 160/200 | Time 1.50s | Train loss 0.5214 | Train acc 0.8053 | Val loss 1.7250 | Val acc 0.4700
# Epoch 161/200 | Time 1.48s | Train loss 0.5128 | Train acc 0.8060 | Val loss 1.5943 | Val acc 0.5013
# Epoch 162/200 | Time 1.45s | Train loss 0.5304 | Train acc 0.7917 | Val loss 1.8293 | Val acc 0.4491
# Epoch 163/200 | Time 1.42s | Train loss 0.5053 | Train acc 0.8184 | Val loss 1.8338 | Val acc 0.4595
# Epoch 164/200 | Time 1.44s | Train loss 0.5310 | Train acc 0.7884 | Val loss 1.7378 | Val acc 0.4726
# Epoch 165/200 | Time 1.44s | Train loss 0.5056 | Train acc 0.8073 | Val loss 1.6896 | Val acc 0.4752
# Epoch 166/200 | Time 1.60s | Train loss 0.5161 | Train acc 0.8014 | Val loss 1.7636 | Val acc 0.4778
# Epoch 167/200 | Time 1.77s | Train loss 0.5046 | Train acc 0.8132 | Val loss 1.7039 | Val acc 0.4830
# Epoch 168/200 | Time 1.75s | Train loss 0.5084 | Train acc 0.8184 | Val loss 1.7388 | Val acc 0.4830
# Epoch 169/200 | Time 1.45s | Train loss 0.5062 | Train acc 0.8047 | Val loss 1.7509 | Val acc 0.5013
# Epoch 170/200 | Time 1.43s | Train loss 0.4997 | Train acc 0.8021 | Val loss 1.7328 | Val acc 0.4935
# Epoch 171/200 | Time 1.46s | Train loss 0.4943 | Train acc 0.8079 | Val loss 1.7274 | Val acc 0.4961
# Epoch 172/200 | Time 1.46s | Train loss 0.5119 | Train acc 0.8105 | Val loss 1.6849 | Val acc 0.4752
# Epoch 173/200 | Time 1.44s | Train loss 0.5070 | Train acc 0.8138 | Val loss 1.7921 | Val acc 0.4700
# Epoch 174/200 | Time 1.45s | Train loss 0.5040 | Train acc 0.8079 | Val loss 1.7518 | Val acc 0.5196
# Epoch 175/200 | Time 1.66s | Train loss 0.4991 | Train acc 0.8164 | Val loss 1.8035 | Val acc 0.4883
# Epoch 176/200 | Time 1.79s | Train loss 0.4978 | Train acc 0.8138 | Val loss 1.7015 | Val acc 0.5091
# Epoch 177/200 | Time 1.58s | Train loss 0.4970 | Train acc 0.8073 | Val loss 1.7516 | Val acc 0.4648
# Epoch 178/200 | Time 1.45s | Train loss 0.5008 | Train acc 0.8008 | Val loss 1.7380 | Val acc 0.5039
# Epoch 179/200 | Time 1.47s | Train loss 0.4871 | Train acc 0.8118 | Val loss 1.7143 | Val acc 0.5039
# Epoch 180/200 | Time 1.43s | Train loss 0.4830 | Train acc 0.8190 | Val loss 1.7883 | Val acc 0.5039
# Epoch 181/200 | Time 1.45s | Train loss 0.4992 | Train acc 0.8125 | Val loss 1.7793 | Val acc 0.5013
# Epoch 182/200 | Time 1.46s | Train loss 0.5059 | Train acc 0.8008 | Val loss 1.8144 | Val acc 0.4909
# Epoch 183/200 | Time 1.48s | Train loss 0.4756 | Train acc 0.8210 | Val loss 1.7347 | Val acc 0.4778
# Epoch 184/200 | Time 1.71s | Train loss 0.4838 | Train acc 0.8132 | Val loss 1.7936 | Val acc 0.4569
# Epoch 185/200 | Time 1.77s | Train loss 0.5003 | Train acc 0.8099 | Val loss 1.8326 | Val acc 0.4621
# Epoch 186/200 | Time 1.55s | Train loss 0.4848 | Train acc 0.8301 | Val loss 1.8116 | Val acc 0.4621
# Epoch 187/200 | Time 1.46s | Train loss 0.4946 | Train acc 0.8099 | Val loss 1.7600 | Val acc 0.4909
# Epoch 188/200 | Time 1.44s | Train loss 0.4827 | Train acc 0.8203 | Val loss 1.7614 | Val acc 0.4700
# Epoch 189/200 | Time 1.45s | Train loss 0.4773 | Train acc 0.8223 | Val loss 1.7853 | Val acc 0.5013
# Epoch 190/200 | Time 1.46s | Train loss 0.4802 | Train acc 0.8255 | Val loss 1.7799 | Val acc 0.4804
# Epoch 191/200 | Time 1.43s | Train loss 0.4803 | Train acc 0.8236 | Val loss 1.7664 | Val acc 0.4621
# Epoch 192/200 | Time 1.47s | Train loss 0.4795 | Train acc 0.8177 | Val loss 1.7929 | Val acc 0.4804
# Epoch 193/200 | Time 1.86s | Train loss 0.4745 | Train acc 0.8203 | Val loss 1.7751 | Val acc 0.4674
# Epoch 194/200 | Time 1.82s | Train loss 0.4807 | Train acc 0.8210 | Val loss 1.7378 | Val acc 0.4909
# Epoch 195/200 | Time 1.48s | Train loss 0.4645 | Train acc 0.8099 | Val loss 1.7862 | Val acc 0.4856
# Epoch 196/200 | Time 1.44s | Train loss 0.4772 | Train acc 0.8079 | Val loss 1.7916 | Val acc 0.4830
# Epoch 197/200 | Time 1.45s | Train loss 0.4732 | Train acc 0.8099 | Val loss 1.7547 | Val acc 0.4987
# Epoch 198/200 | Time 1.44s | Train loss 0.4744 | Train acc 0.8242 | Val loss 1.7944 | Val acc 0.4778
# Epoch 199/200 | Time 1.45s | Train loss 0.4767 | Train acc 0.8249 | Val loss 1.8439 | Val acc 0.4726
# Epoch 200/200 | Time 1.47s | Train loss 0.4676 | Train acc 0.8229 | Val loss 1.7729 | Val acc 0.4778
# Training finished. Best epoch: 66. Best monitored metric: 0.5300
# Final model saved to: /content/drive/MyDrive/PainRecognitionProject/models/testing_new_code_emotions_77_coordinates_6_classes.pt
# Best model saved to: /content/drive/MyDrive/PainRecognitionProject/models/best_testing_new_code_emotions_77_coordinates_6_classes.pt

# %%
trainer.plot_history()

# %% [markdown]
# #### Evaluate

# %%
model.load_state_dict(torch.load(best_model_path, map_location=DEVICE), strict=False)
# Out:
# <All keys matched successfully>

# %%
evaluator = Evaluator(model, test_loader, device=DEVICE, model_name=model_name, num_classes=NUM_CLASSES)

# %%
loss, acc, labels, preds = evaluator.evaluate_epoch()
# Out:
# ==================================================
# WYNIKI OCENY DLA MODELU: testing_new_code_emotions_77_coordinates_6_classes.pt
# ==================================================
# Test Loss: 1.6538
# Test Accuracy: 0.4323
#
# --- Szczegółowy Raport Klasyfikacji ---
#               precision    recall  f1-score   support
#
#      Klasa 0       0.93      0.44      0.60        64
#      Klasa 1       0.94      0.53      0.68        64
#      Klasa 2       0.78      0.44      0.56        64
#      Klasa 3       0.36      0.72      0.48        64
#      Klasa 4       0.22      0.31      0.26        64
#      Klasa 5       0.16      0.16      0.16        64
#
#     accuracy                           0.43       384
#    macro avg       0.57      0.43      0.46       384
# weighted avg       0.57      0.43      0.46       384
#
# ==================================================
# Confusion matrix:
#  [[28  2  4 12  2 16]
#  [ 2 34  0  0 10 18]
#  [ 0  0 28 28  8  0]
#  [ 0  0  0 46 18  0]
#  [ 0  0  0 24 20 20]
#  [ 0  0  4 18 32 10]]
