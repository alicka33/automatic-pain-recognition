# %% [markdown]
# ### Attention-LSTM model - multiclass training - 100 distances

# %% [markdown]
# #### Environment preparation

# %%
from google.colab import drive
drive.mount('/content/drive')

COLAB_ROOT = '/content/drive/MyDrive/PainRecognitionProject/'
print(f"Dane będą wczytywane z: {COLAB_ROOT}")
# Out:
# Mounted at /content/drive
# Dane będą wczytywane z: /content/drive/MyDrive/PainRecognitionProject/

# %%
import os

# %cd /content

# !rm -rf automatic-pain-recognition

print(f"Obecne położenie: {os.getcwd()}")
# Out:
# /content
# Obecne położenie: /content

# %%
USERNAME = 'alicka33'
REPO_NAME = 'automatic-pain-recognition'

REPO_URL = f"https://github.com/{USERNAME}/{REPO_NAME}.git"

print("Rozpoczynam klonowanie...")

# !git clone {REPO_URL}

# %cd $REPO_NAME
# Out:
# Rozpoczynam klonowanie...
# Cloning into 'automatic-pain-recognition'...
# remote: Enumerating objects: 266, done.
# remote: Counting objects: 100% (266/266), done.
# remote: Compressing objects: 100% (210/210), done.
# remote: Total 266 (delta 119), reused 197 (delta 52), pack-reused 0 (from 0)
# Receiving objects: 100% (266/266), 11.27 MiB | 18.06 MiB/s, done.
# Resolving deltas: 100% (119/119), done.
# /content/automatic-pain-recognition

# %%
# !pip install -r requirements.txt

# %%
import sys
import os

sys.path.append(os.getcwd())
print(f"Dodano do ścieżki Pythona: {os.getcwd()}")
# Out:
# Dodano do ścieżki Pythona: /content/automatic-pain-recognition

# %% [markdown]
# #### Attention-LSTM model - multiclass training

# %%
import os
import numpy as np
import pandas as pd
import shutil

import torch
import torch.nn as nn
from torch.utils.data import DataLoader
from torch.optim.lr_scheduler import ReduceLROnPlateau

from training_utils.preprocessed_dataset import PreprocessedDataset
from training_utils.train import Trainer
from training_utils.evaluate import Evaluator
from models.Attention_LSTM import AttentionSequenceModel

# %%
MAX_SEQUENCE_LENGTH = 46
NUM_FEATURES = 100
NUM_CLASSES = 5
HIDDEN_SIZE = 128
NUM_LAYERS = 2
NUM_EPOCHS = 200
BATCH_SIZE = 16
LEARNING_RATE = 0.00005
DROPOUT_PROB = 0.3
WEIGHT_DECAY = 0.005
SCHEDULER_FACTOR = 0.9

# %%
COLAB_ROOT = '/content/drive/MyDrive/PainRecognitionProject/'
PROCESSED_DATA_DIR = os.path.join(COLAB_ROOT, 'data/BioVid_HeatPain_processed_478_xyz_frontalized/')
MODEL_SAVE_DIR = os.path.join(COLAB_ROOT, 'models/')
LOCAL_PROCESSED_DATA_ROOT = '/content/temp_data/'

DEVICE = torch.device("cuda" if torch.cuda.is_available() else "cpu")

# %%
print("Kopiowanie danych z Google Drive do lokalnej pamięci Colab (RAM)...")
if os.path.exists(LOCAL_PROCESSED_DATA_ROOT):
    shutil.rmtree(LOCAL_PROCESSED_DATA_ROOT)
try:
    shutil.copytree(PROCESSED_DATA_DIR, LOCAL_PROCESSED_DATA_ROOT)
    print("✅ Kopiowanie zakończone pomyślnie. Czas trwania: (sprawdź zegar)")
    CURRENT_DATA_DIR = LOCAL_PROCESSED_DATA_ROOT

except Exception as e:
    print(f"❌ Błąd kopiowania danych (sprawdź, czy dane są zamontowane): {e}")
    print("Używam danych bezpośrednio z Drive (może się zawiesić).")
    CURRENT_DATA_DIR = PROCESSED_DATA_DIR
# Out:
# Kopiowanie danych z Google Drive do lokalnej pamięci Colab (RAM)...
# ✅ Kopiowanie zakończone pomyślnie. Czas trwania: (sprawdź zegar)

# %%
best100 = np.load('/content/drive/MyDrive/PainRecognitionProject/data/top_100_important_landmarks_emotions.npy')

# %%
train_dataset = PreprocessedDataset(
    'train',
    processed_data_dir=CURRENT_DATA_DIR,
    indices=best100,
    compute_euclidean=True,
    center_point_index=2,
    max_sequence_length=MAX_SEQUENCE_LENGTH,
    selected_labels=None,
    label_map=None,
)

val_dataset = PreprocessedDataset(
    'val',
    processed_data_dir=CURRENT_DATA_DIR,
    indices=best100,
    compute_euclidean=True,
    center_point_index=2,
    max_sequence_length=MAX_SEQUENCE_LENGTH,
    selected_labels=None,
    label_map=None,
)

test_dataset = PreprocessedDataset(
    'test',
    processed_data_dir=CURRENT_DATA_DIR,
    indices=best100,
    compute_euclidean=True,
    center_point_index=2,
    max_sequence_length=MAX_SEQUENCE_LENGTH,
    selected_labels=None,
    label_map=None,
)

# %%
def preview_single(dataset, idx=0, timesteps_to_show=3, features_to_show=8):
    x, y = dataset[idx]
    print(f"\nSingle sample idx={idx} from split={dataset.dataset_name}")
    print(f"x shape: {tuple(x.shape)}, y: {y}")
    print(np.round(x[:timesteps_to_show, :features_to_show], 4))

preview_single(train_dataset, 0)
preview_single(val_dataset, 0)
preview_single(test_dataset, 0)
# Out:
# Single sample idx=0 from split=train
# x shape: (46, 100), y: 0
# tensor([[0.2288, 0.2495, 0.1901, 0.2053, 0.2000, 0.2080, 0.1858, 0.2578],
#         [0.2298, 0.2612, 0.1892, 0.2024, 0.1994, 0.2136, 0.1805, 0.2564],
#         [0.2291, 0.2585, 0.1896, 0.2033, 0.2022, 0.2154, 0.1835, 0.2563]])
#
# Single sample idx=0 from split=val
# x shape: (46, 100), y: 0
# tensor([[0.2204, 0.2330, 0.1836, 0.1980, 0.1886, 0.1926, 0.1736, 0.2485],
#         [0.2228, 0.2308, 0.1868, 0.2008, 0.1887, 0.1917, 0.1735, 0.2504],
#         [0.2228, 0.2309, 0.1869, 0.2009, 0.1889, 0.1920, 0.1739, 0.2504]])
#
# Single sample idx=0 from split=test
# x shape: (46, 100), y: 0
# tensor([[0.2235, 0.2448, 0.1836, 0.1956, 0.1864, 0.1941, 0.1716, 0.2511],
#         [0.2218, 0.2424, 0.1822, 0.1946, 0.1854, 0.1941, 0.1707, 0.2496],
#         [0.2226, 0.2452, 0.1828, 0.1951, 0.1891, 0.1974, 0.1740, 0.2504]])

# %%
train_loader = DataLoader(train_dataset, batch_size=BATCH_SIZE, shuffle=True, num_workers=0, pin_memory=True)
for X, y in train_loader:
    print(X.shape, y.shape)  # (B, T_max, num_features)
    break

val_loader = DataLoader(val_dataset, batch_size=BATCH_SIZE, shuffle=True, num_workers=0, pin_memory=True)
for X, y in val_loader:
    print(X.shape, y.shape)  # (B, T_max, num_features)
    break

test_loader = DataLoader(test_dataset, batch_size=BATCH_SIZE, shuffle=True, num_workers=0, pin_memory=True)
for X, y in test_loader:
    print(X.shape, y.shape)  # (B, T_max, num_features)
    break
# Out:
# torch.Size([16, 46, 100]) torch.Size([16])
# torch.Size([16, 46, 100]) torch.Size([16])
# torch.Size([16, 46, 100]) torch.Size([16])

# %% [markdown]
# #### Model preparation

# %%
model = AttentionSequenceModel(NUM_FEATURES, HIDDEN_SIZE, NUM_LAYERS, NUM_CLASSES, DROPOUT_PROB).to(DEVICE)

# %% [markdown]
# #### Training

# %%
criterion = nn.CrossEntropyLoss()
optimizer = torch.optim.AdamW(model.parameters(), lr=LEARNING_RATE, weight_decay=WEIGHT_DECAY)

scheduler = ReduceLROnPlateau(
    optimizer,
    mode='max',
    factor=SCHEDULER_FACTOR,
    patience=10,
    min_lr=1e-7
)

model_name = 'testing_new_code_attention_lstm_5_classes.pt'
model_filepath = os.path.join(MODEL_SAVE_DIR, model_name)

# %%
trainer = Trainer(
    model=model,
    train_loader=train_loader,
    val_loader=val_loader,
    optimizer=optimizer,
    scheduler=scheduler,
    criterion=criterion,
    device=DEVICE,
    model_save_path=model_filepath,
    num_epochs=NUM_EPOCHS,
    monitor='val_acc',  # or 'val_loss'
    minimize_monitor=False,
    save_best_only=True
)

# %%
trainer.print_training_config()
# Out:
# ==================================================
# 🚀 TRAINING CONFIGURATION
# ==================================================
#
# --- Model Architecture ---
#   Model Type            : AttentionSequenceModel
#   Input Features        : 100
#   Hidden Size           : 128
#   Num Layers            : 2
#   Bidirectional         : True
#   Dropout (LSTM)        : 0.3
#   Num Parameters        : 665606
#
# --- Optimizer & Regularization ---
#   Optimizer             : AdamW
#   Learning Rate (LR)    : 5e-05
#   Weight Decay (L2)     : 0.005
#
# --- Training Flow ---
#   Batch Size            : 16
#   Num Epochs            : 200
#   Device                : cuda
# ==================================================

# %%
final_model_path, best_model_path, history = trainer.fit()
print(f"Final model saved to: {final_model_path}")
if best_model_path:
    print(f"Best model saved to: {best_model_path}")
# Out:
# Starting training for 200 epochs on cuda
# Saved best model to /content/drive/MyDrive/PainRecognitionProject/models/best_testing_new_code_attention_lstm_5_classes.pt (metric=0.1992)
# Epoch 1/200 | Time 21.90s | Train loss 1.6658 | Train acc 0.1936 | Val loss 1.6154 | Val acc 0.1992
# Saved best model to /content/drive/MyDrive/PainRecognitionProject/models/best_testing_new_code_attention_lstm_5_classes.pt (metric=0.2000)
# Epoch 2/200 | Time 14.37s | Train loss 1.6641 | Train acc 0.1939 | Val loss 1.6220 | Val acc 0.2000
# Epoch 3/200 | Time 11.02s | Train loss 1.6510 | Train acc 0.1949 | Val loss 1.6139 | Val acc 0.2000
# Epoch 4/200 | Time 11.03s | Train loss 1.6342 | Train acc 0.1993 | Val loss 1.6118 | Val acc 0.2000
# Epoch 5/200 | Time 11.14s | Train loss 1.6342 | Train acc 0.1967 | Val loss 1.6220 | Val acc 0.2000
# Saved best model to /content/drive/MyDrive/PainRecognitionProject/models/best_testing_new_code_attention_lstm_5_classes.pt (metric=0.2154)
# Epoch 6/200 | Time 11.17s | Train loss 1.6287 | Train acc 0.1936 | Val loss 1.6101 | Val acc 0.2154
# Epoch 7/200 | Time 11.00s | Train loss 1.6270 | Train acc 0.1987 | Val loss 1.6114 | Val acc 0.2000
# Epoch 8/200 | Time 11.43s | Train loss 1.6237 | Train acc 0.2000 | Val loss 1.6164 | Val acc 0.2000
# Epoch 9/200 | Time 11.38s | Train loss 1.6226 | Train acc 0.2000 | Val loss 1.6097 | Val acc 0.1992
# Epoch 10/200 | Time 11.50s | Train loss 1.6193 | Train acc 0.2015 | Val loss 1.6095 | Val acc 0.1962
# Epoch 11/200 | Time 11.25s | Train loss 1.6213 | Train acc 0.2003 | Val loss 1.6140 | Val acc 0.2054
# Epoch 12/200 | Time 11.24s | Train loss 1.6160 | Train acc 0.2064 | Val loss 1.6100 | Val acc 0.1900
# Epoch 13/200 | Time 10.91s | Train loss 1.6175 | Train acc 0.2115 | Val loss 1.6103 | Val acc 0.2000
# Saved best model to /content/drive/MyDrive/PainRecognitionProject/models/best_testing_new_code_attention_lstm_5_classes.pt (metric=0.2208)
# Epoch 14/200 | Time 10.86s | Train loss 1.6181 | Train acc 0.1997 | Val loss 1.6110 | Val acc 0.2208
# Epoch 15/200 | Time 11.16s | Train loss 1.6174 | Train acc 0.1946 | Val loss 1.6094 | Val acc 0.2077
# Epoch 16/200 | Time 11.10s | Train loss 1.6172 | Train acc 0.2046 | Val loss 1.6128 | Val acc 0.1985
# Epoch 17/200 | Time 11.11s | Train loss 1.6157 | Train acc 0.2007 | Val loss 1.6111 | Val acc 0.2000
# Epoch 187/200 | Time 11.03s | Train loss 1.5183 | Train acc 0.2913 | Val loss 1.5318 | Val acc 0.2692
# Epoch 188/200 | Time 11.11s | Train loss 1.5200 | Train acc 0.2864 | Val loss 1.5397 | Val acc 0.2808
# Epoch 189/200 | Time 11.12s | Train loss 1.5185 | Train acc 0.2915 | Val loss 1.5396 | Val acc 0.2738
# Epoch 190/200 | Time 10.53s | Train loss 1.5172 | Train acc 0.2879 | Val loss 1.5384 | Val acc 0.2792
# Epoch 191/200 | Time 10.99s | Train loss 1.5167 | Train acc 0.2857 | Val loss 1.5389 | Val acc 0.2777
# Epoch 192/200 | Time 11.13s | Train loss 1.5171 | Train acc 0.2895 | Val loss 1.5346 | Val acc 0.2808
# Epoch 193/200 | Time 11.08s | Train loss 1.5186 | Train acc 0.2846 | Val loss 1.5385 | Val acc 0.2792
# Epoch 194/200 | Time 11.15s | Train loss 1.5155 | Train acc 0.2936 | Val loss 1.5395 | Val acc 0.2900
# Epoch 195/200 | Time 11.10s | Train loss 1.5177 | Train acc 0.2975 | Val loss 1.5310 | Val acc 0.2869
# Epoch 196/200 | Time 10.56s | Train loss 1.5155 | Train acc 0.2908 | Val loss 1.5292 | Val acc 0.2854
# Epoch 197/200 | Time 10.98s | Train loss 1.5141 | Train acc 0.2920 | Val loss 1.5367 | Val acc 0.2877
# Epoch 198/200 | Time 11.15s | Train loss 1.5149 | Train acc 0.2964 | Val loss 1.5350 | Val acc 0.2869
# Epoch 199/200 | Time 11.20s | Train loss 1.5175 | Train acc 0.2903 | Val loss 1.5345 | Val acc 0.2815
# Epoch 200/200 | Time 11.33s | Train loss 1.5160 | Train acc 0.2893 | Val loss 1.5350 | Val acc 0.2792
# Training finished. Best epoch: 78. Best monitored metric: 0.3000
# Final model saved to: /content/drive/MyDrive/PainRecognitionProject/models/testing_new_code_attention_lstm_5_classes.pt
# Best model saved to: /content/drive/MyDrive/PainRecognitionProject/models/best_testing_new_code_attention_lstm_5_classes.pt

# %%
trainer.plot_history()

# %% [markdown]
# #### Evaluate

# %%
model.load_state_dict(torch.load(best_model_path, map_location=DEVICE), strict=False)
# Out:
# <All keys matched successfully>

# %%
evaluator = Evaluator(model, test_loader, device=DEVICE, model_name=model_name, num_classes=NUM_CLASSES)

# %%
loss, acc, labels, preds = evaluator.evaluate_epoch()
# Out:
# ==================================================
# WYNIKI OCENY DLA MODELU: testing_new_code_attention_lstm_5_classes.pt
# ==================================================
# Test Loss: 1.5594
# Test Accuracy: 0.2785
#
# --- Szczegółowy Raport Klasyfikacji ---
#               precision    recall  f1-score   support
#
#      Klasa 0       0.26      0.51      0.35       260
#      Klasa 1       0.21      0.20      0.21       260
#      Klasa 2       0.24      0.07      0.10       260
#      Klasa 3       0.16      0.08      0.10       260
#      Klasa 4       0.40      0.54      0.46       260
#
#     accuracy                           0.28      1300
#    macro avg       0.25      0.28      0.24      1300
# weighted avg       0.25      0.28      0.24      1300
#
# ==================================================
# Confusion matrix:
#  [[133  51  18  33  25]
#  [127  52  17  28  36]
#  [110  52  17  26  55]
#  [ 81  55  10  20  94]
#  [ 53  36   9  22 140]]
