# %% [markdown]
# ### STA-LSTM model - binary training - 100 distances

# %% [markdown]
# #### Environment preparation

# %%
from google.colab import drive
drive.mount('/content/drive')

COLAB_ROOT = '/content/drive/MyDrive/PainRecognitionProject/'
print(f"Dane będą wczytywane z: {COLAB_ROOT}")
# Out:
# Mounted at /content/drive
# Dane będą wczytywane z: /content/drive/MyDrive/PainRecognitionProject/

# %%
import os

# %cd /content

# !rm -rf automatic-pain-recognition

print(f"Obecne położenie: {os.getcwd()}")
# Out:
# /content
# Obecne położenie: /content

# %%
USERNAME = 'alicka33'
REPO_NAME = 'automatic-pain-recognition'

REPO_URL = f"https://github.com/{USERNAME}/{REPO_NAME}.git"

print("Rozpoczynam klonowanie...")

# !git clone {REPO_URL}

# %cd $REPO_NAME
# Out:
# Rozpoczynam klonowanie...
# Cloning into 'automatic-pain-recognition'...
# remote: Enumerating objects: 344, done.
# remote: Counting objects: 100% (67/67), done.
# remote: Compressing objects: 100% (46/46), done.
# remote: Total 344 (delta 34), reused 53 (delta 20), pack-reused 277 (from 1)
# Receiving objects: 100% (344/344), 12.43 MiB | 17.77 MiB/s, done.
# Resolving deltas: 100% (158/158), done.
# /content/automatic-pain-recognition

# %%
# !pip install -r requirements.txt

# %%
import sys
import os

sys.path.append(os.getcwd())
print(f"Dodano do ścieżki Pythona: {os.getcwd()}")
# Out:
# Dodano do ścieżki Pythona: /content/automatic-pain-recognition

# %% [markdown]
# #### STA-LSTM model - binary training

# %%
import os
import numpy as np
import pandas as pd
import shutil

import torch
import torch.nn as nn
from torch.utils.data import DataLoader
from torch.optim.lr_scheduler import ReduceLROnPlateau

from training_utils.preprocessed_dataset import PreprocessedDataset
from training_utils.train import Trainer
from training_utils.evaluate import Evaluator
from models.STA_LSTM import STA_LSTM

# %%
MAX_SEQUENCE_LENGTH = 46
NUM_FEATURES = 100
NUM_CLASSES = 2
HIDDEN_SIZE = 128
NUM_LAYERS = 2
NUM_EPOCHS = 200
BATCH_SIZE = 16
LEARNING_RATE = 0.00005
DROPOUT_PROB = 0.3
WEIGHT_DECAY = 0.005
SCHEDULER_FACTOR = 0.9

# %% [markdown]
# #### Data preparation

# %%
COLAB_ROOT = '/content/drive/MyDrive/PainRecognitionProject/'
PROCESSED_DATA_DIR = os.path.join(COLAB_ROOT, 'data/BioVid_HeatPain_processed_478_xyz_frontalized/')
MODEL_SAVE_DIR = os.path.join(COLAB_ROOT, 'models/')
LOCAL_PROCESSED_DATA_ROOT = '/content/temp_data/'

DEVICE = torch.device("cuda" if torch.cuda.is_available() else "cpu")

# %%
print("Kopiowanie danych z Google Drive do lokalnej pamięci Colab (RAM)...")
if os.path.exists(LOCAL_PROCESSED_DATA_ROOT):
    shutil.rmtree(LOCAL_PROCESSED_DATA_ROOT)
try:
    shutil.copytree(PROCESSED_DATA_DIR, LOCAL_PROCESSED_DATA_ROOT)
    print("✅ Kopiowanie zakończone pomyślnie. Czas trwania: (sprawdź zegar)")
    CURRENT_DATA_DIR = LOCAL_PROCESSED_DATA_ROOT

except Exception as e:
    print(f"❌ Błąd kopiowania danych (sprawdź, czy dane są zamontowane): {e}")
    print("Używam danych bezpośrednio z Drive (może się zawiesić).")
    CURRENT_DATA_DIR = PROCESSED_DATA_DIR
# Out:
# Kopiowanie danych z Google Drive do lokalnej pamięci Colab (RAM)...
# ✅ Kopiowanie zakończone pomyślnie. Czas trwania: (sprawdź zegar)

# %%
best100 = np.load('/content/drive/MyDrive/PainRecognitionProject/data/top_100_important_landmarks_emotions.npy')

# %%
train_dataset = PreprocessedDataset(
    'train',
    processed_data_dir=CURRENT_DATA_DIR,
    indices=best100,
    compute_euclidean=True,
    center_point_index=2,
    max_sequence_length=MAX_SEQUENCE_LENGTH,
    selected_labels=[0, 4],
    label_map={0: 0, 4: 1},
)

val_dataset = PreprocessedDataset(
    'val',
    processed_data_dir=CURRENT_DATA_DIR,
    indices=best100,
    compute_euclidean=True,
    center_point_index=2,
    max_sequence_length=MAX_SEQUENCE_LENGTH,
    selected_labels=[0, 4],
    label_map={0: 0, 4: 1},
)

test_dataset = PreprocessedDataset(
    'test',
    processed_data_dir=CURRENT_DATA_DIR,
    indices=best100,
    compute_euclidean=True,
    center_point_index=2,
    max_sequence_length=MAX_SEQUENCE_LENGTH,
    selected_labels=[0, 4],
    label_map={0: 0, 4: 1},
)

# %%
def preview_single(dataset, idx=0, timesteps_to_show=3, features_to_show=8):
    x, y = dataset[idx]
    print(f"\nSingle sample idx={idx} from split={dataset.dataset_name}")
    print(f"x shape: {tuple(x.shape)}, y: {y}")
    print(np.round(x[:timesteps_to_show, :features_to_show], 4))

preview_single(train_dataset, 0)
preview_single(val_dataset, 0)
preview_single(test_dataset, 0)
# Out:
# Single sample idx=0 from split=train
# x shape: (46, 100), y: 0
# tensor([[0.2288, 0.2495, 0.1901, 0.2053, 0.2000, 0.2080, 0.1858, 0.2578],
#         [0.2298, 0.2612, 0.1892, 0.2024, 0.1994, 0.2136, 0.1805, 0.2564],
#         [0.2291, 0.2585, 0.1896, 0.2033, 0.2022, 0.2154, 0.1835, 0.2563]])
#
# Single sample idx=0 from split=val
# x shape: (46, 100), y: 0
# tensor([[0.2204, 0.2330, 0.1836, 0.1980, 0.1886, 0.1926, 0.1736, 0.2485],
#         [0.2228, 0.2308, 0.1868, 0.2008, 0.1887, 0.1917, 0.1735, 0.2504],
#         [0.2228, 0.2309, 0.1869, 0.2009, 0.1889, 0.1920, 0.1739, 0.2504]])
#
# Single sample idx=0 from split=test
# x shape: (46, 100), y: 0
# tensor([[0.2235, 0.2448, 0.1836, 0.1956, 0.1864, 0.1941, 0.1716, 0.2511],
#         [0.2218, 0.2424, 0.1822, 0.1946, 0.1854, 0.1941, 0.1707, 0.2496],
#         [0.2226, 0.2452, 0.1828, 0.1951, 0.1891, 0.1974, 0.1740, 0.2504]])

# %%
train_loader = DataLoader(train_dataset, batch_size=BATCH_SIZE, shuffle=True, num_workers=0, pin_memory=True)
for X, y in train_loader:
    print(X.shape, y.shape)  # (B, T_max, num_features)
    break

val_loader = DataLoader(val_dataset, batch_size=BATCH_SIZE, shuffle=True, num_workers=0, pin_memory=True)
for X, y in val_loader:
    print(X.shape, y.shape)  # (B, T_max, num_features)
    break

test_loader = DataLoader(test_dataset, batch_size=BATCH_SIZE, shuffle=True, num_workers=0, pin_memory=True)
for X, y in test_loader:
    print(X.shape, y.shape)  # (B, T_max, num_features)
    break
# Out:
# torch.Size([16, 46, 100]) torch.Size([16])
# torch.Size([16, 46, 100]) torch.Size([16])
# torch.Size([16, 46, 100]) torch.Size([16])

# %% [markdown]
# #### Model preparation

# %%
model = STA_LSTM(NUM_FEATURES, HIDDEN_SIZE, NUM_LAYERS, NUM_CLASSES, DROPOUT_PROB).to(DEVICE)

# %% [markdown]
# #### Training

# %%
criterion = nn.CrossEntropyLoss()
optimizer = torch.optim.AdamW(model.parameters(), lr=LEARNING_RATE, weight_decay=WEIGHT_DECAY)

scheduler = ReduceLROnPlateau(
    optimizer,
    mode='max',
    factor=SCHEDULER_FACTOR,
    patience=10,
    min_lr=1e-7
)

model_name = 'testing_new_code_sta_lstm_2_classes_100_dist.pt'
model_filepath = os.path.join(MODEL_SAVE_DIR, model_name)

# %%
trainer = Trainer(
    model=model,
    train_loader=train_loader,
    val_loader=val_loader,
    optimizer=optimizer,
    scheduler=scheduler,
    criterion=criterion,
    device=DEVICE,
    model_save_path=model_filepath,
    num_epochs=NUM_EPOCHS,
    monitor='val_acc',  # or 'val_loss'
    minimize_monitor=False,
    save_best_only=True
)

# %%
trainer.print_training_config()
# Out:
# ==================================================
# 🚀 TRAINING CONFIGURATION
# ==================================================
#
# --- Model Architecture ---
#   Model Type            : STA_LSTM
#   Input Features        : 100
#   Hidden Size           : 128
#   Num Layers            : 2
#   Bidirectional         : True
#   Dropout (LSTM)        : 0.3
#   Num Parameters        : 690663
#
# --- Optimizer & Regularization ---
#   Optimizer             : AdamW
#   Learning Rate (LR)    : 5e-05
#   Weight Decay (L2)     : 0.005
#
# --- Training Flow ---
#   Batch Size            : 16
#   Num Epochs            : 200
#   Device                : cuda
# ==================================================

# %%
final_model_path, best_model_path, history = trainer.fit()
print(f"Final model saved to: {final_model_path}")
if best_model_path:
    print(f"Best model saved to: {best_model_path}")
# Out:
# Starting training for 200 epochs on cuda
# Saved best model to /content/drive/MyDrive/PainRecognitionProject/models/best_testing_new_code_sta_lstm_2_classes_100_dist.pt (metric=0.5000)
# Epoch 1/200 | Time 4.39s | Train loss 0.7296 | Train acc 0.4816 | Val loss 0.6945 | Val acc 0.5000
# Epoch 2/200 | Time 4.87s | Train loss 0.7164 | Train acc 0.4951 | Val loss 0.6939 | Val acc 0.5000
# Epoch 3/200 | Time 4.27s | Train loss 0.7102 | Train acc 0.5066 | Val loss 0.7022 | Val acc 0.5000
# Saved best model to /content/drive/MyDrive/PainRecognitionProject/models/best_testing_new_code_sta_lstm_2_classes_100_dist.pt (metric=0.5269)
# Epoch 4/200 | Time 4.46s | Train loss 0.7108 | Train acc 0.4889 | Val loss 0.6915 | Val acc 0.5269
# Epoch 5/200 | Time 4.75s | Train loss 0.7054 | Train acc 0.4922 | Val loss 0.7109 | Val acc 0.5000
# Saved best model to /content/drive/MyDrive/PainRecognitionProject/models/best_testing_new_code_sta_lstm_2_classes_100_dist.pt (metric=0.5577)
# Epoch 6/200 | Time 4.20s | Train loss 0.7028 | Train acc 0.4975 | Val loss 0.6912 | Val acc 0.5577
# Epoch 7/200 | Time 4.54s | Train loss 0.7022 | Train acc 0.5045 | Val loss 0.6924 | Val acc 0.4981
# Epoch 8/200 | Time 4.75s | Train loss 0.6980 | Train acc 0.5168 | Val loss 0.6905 | Val acc 0.5231
# Epoch 9/200 | Time 4.26s | Train loss 0.7011 | Train acc 0.4992 | Val loss 0.6920 | Val acc 0.5135
# Epoch 10/200 | Time 4.61s | Train loss 0.6998 | Train acc 0.5020 | Val loss 0.6902 | Val acc 0.5462
# Epoch 11/200 | Time 4.58s | Train loss 0.6971 | Train acc 0.5213 | Val loss 0.6901 | Val acc 0.5500
# Epoch 12/200 | Time 4.30s | Train loss 0.6985 | Train acc 0.5020 | Val loss 0.6962 | Val acc 0.5019
# Epoch 13/200 | Time 4.71s | Train loss 0.6964 | Train acc 0.5135 | Val loss 0.6970 | Val acc 0.5000
# Epoch 14/200 | Time 4.48s | Train loss 0.6980 | Train acc 0.5029 | Val loss 0.6923 | Val acc 0.5096
# Epoch 15/200 | Time 4.23s | Train loss 0.6937 | Train acc 0.5393 | Val loss 0.6896 | Val acc 0.5346
# Epoch 16/200 | Time 4.75s | Train loss 0.6895 | Train acc 0.5406 | Val loss 0.6867 | Val acc 0.5500
# Epoch 185/200 | Time 4.40s | Train loss 0.5378 | Train acc 0.6980 | Val loss 0.5853 | Val acc 0.7058
# Epoch 186/200 | Time 4.52s | Train loss 0.5400 | Train acc 0.7025 | Val loss 0.5828 | Val acc 0.7154
# Epoch 187/200 | Time 5.07s | Train loss 0.5375 | Train acc 0.7102 | Val loss 0.5854 | Val acc 0.7058
# Epoch 188/200 | Time 4.35s | Train loss 0.5429 | Train acc 0.7061 | Val loss 0.5830 | Val acc 0.7077
# Epoch 189/200 | Time 4.67s | Train loss 0.5378 | Train acc 0.7066 | Val loss 0.5828 | Val acc 0.7096
# Epoch 190/200 | Time 4.78s | Train loss 0.5432 | Train acc 0.6939 | Val loss 0.5796 | Val acc 0.7192
# Epoch 191/200 | Time 4.33s | Train loss 0.5367 | Train acc 0.7020 | Val loss 0.5843 | Val acc 0.7212
# Epoch 192/200 | Time 4.76s | Train loss 0.5368 | Train acc 0.7016 | Val loss 0.6011 | Val acc 0.7077
# Epoch 193/200 | Time 4.64s | Train loss 0.5342 | Train acc 0.7004 | Val loss 0.5975 | Val acc 0.7096
# Epoch 194/200 | Time 4.38s | Train loss 0.5392 | Train acc 0.6996 | Val loss 0.5892 | Val acc 0.7096
# Epoch 195/200 | Time 5.20s | Train loss 0.5387 | Train acc 0.7098 | Val loss 0.6033 | Val acc 0.7019
# Epoch 196/200 | Time 4.35s | Train loss 0.5374 | Train acc 0.7033 | Val loss 0.5976 | Val acc 0.7077
# Epoch 197/200 | Time 4.37s | Train loss 0.5327 | Train acc 0.7029 | Val loss 0.5804 | Val acc 0.7212
# Epoch 198/200 | Time 4.96s | Train loss 0.5370 | Train acc 0.7008 | Val loss 0.5933 | Val acc 0.7096
# Epoch 199/200 | Time 4.29s | Train loss 0.5335 | Train acc 0.7074 | Val loss 0.5870 | Val acc 0.6981
# Epoch 200/200 | Time 4.27s | Train loss 0.5345 | Train acc 0.7016 | Val loss 0.5848 | Val acc 0.7173
# Training finished. Best epoch: 65. Best monitored metric: 0.7346
# Final model saved to: /content/drive/MyDrive/PainRecognitionProject/models/testing_new_code_sta_lstm_2_classes_100_dist.pt
# Best model saved to: /content/drive/MyDrive/PainRecognitionProject/models/best_testing_new_code_sta_lstm_2_classes_100_dist.pt

# %%
trainer.plot_history()

# %% [markdown]
# #### Evaluate

# %%
model.load_state_dict(torch.load(best_model_path, map_location=DEVICE), strict=False)
# Out:
# <All keys matched successfully>

# %%
evaluator = Evaluator(model, test_loader, device=DEVICE, model_name=model_name, num_classes=NUM_CLASSES)

# %%
loss, acc, labels, preds = evaluator.evaluate_epoch()
# Out:
# ==================================================
# WYNIKI OCENY DLA MODELU: testing_new_code_sta_lstm_2_classes_100_dist.pt
# ==================================================
# Test Loss: 0.5380
# Test Accuracy: 0.7250
#
# --- Szczegółowy Raport Klasyfikacji ---
#               precision    recall  f1-score   support
#
#      Klasa 0       0.68      0.86      0.76       260
#      Klasa 1       0.81      0.59      0.68       260
#
#     accuracy                           0.72       520
#    macro avg       0.74      0.73      0.72       520
# weighted avg       0.74      0.72      0.72       520
#
# ==================================================
# Confusion matrix:
#  [[224  36]
#  [107 153]]
