# %% [markdown]
# ### STA-LSTM model - binary training - 300 coordinates

# %% [markdown]
# #### Enviroment preparation

# %%
# Montowanie Google Drive
from google.colab import drive
drive.mount('/content/drive')

COLAB_ROOT = '/content/drive/MyDrive/PainRecognitionProject/'
print(f"Dane będą wczytywane z: {COLAB_ROOT}")
# Out:
# Mounted at /content/drive
# Dane będą wczytywane z: /content/drive/MyDrive/PainRecognitionProject/

# %%
import os

# Przejście do katalogu głównego
# %cd /content

# Klonowanie repo
# !rm -rf automatic-pain-recognition

print(f"Obecne położenie: {os.getcwd()}")
# Out:
# /content
# Obecne położenie: /content

# %%
# Upewnij się, że nazwa użytkownika i repozytorium są poprawne
USERNAME = 'alicka33'
REPO_NAME = 'automatic-pain-recognition'

# Tworzenie poprawnego adresu URL (format: https://<TOKEN>@github.com/...)
REPO_URL = f"https://github.com/{USERNAME}/{REPO_NAME}.git"

print("Rozpoczynam klonowanie...")

# Klonowanie
# !git clone {REPO_URL}

# Wejście do katalogu
# %cd $REPO_NAME
# Out:
# Rozpoczynam klonowanie...
# Cloning into 'automatic-pain-recognition'...
# remote: Enumerating objects: 344, done.
# remote: Counting objects: 100% (67/67), done.
# remote: Compressing objects: 100% (46/46), done.
# remote: Total 344 (delta 34), reused 53 (delta 20), pack-reused 277 (from 1)
# Receiving objects: 100% (344/344), 12.43 MiB | 21.79 MiB/s, done.
# Resolving deltas: 100% (158/158), done.
# /content/automatic-pain-recognition

# %%
# Instalacja wymaganych bibliotek
# !pip install -r requirements.txt

# %%
import sys
import os

# Dodaj katalog główny projektu do ścieżki systemowej
sys.path.append(os.getcwd())
print(f"Dodano do ścieżki Pythona: {os.getcwd()}")
# Out:
# Dodano do ścieżki Pythona: /content/automatic-pain-recognition

# %% [markdown]
# #### STA-LSTM model - binary training

# %%
import os
import numpy as np
import pandas as pd
import shutil

import torch
import torch.nn as nn
from torch.utils.data import DataLoader
from torch.optim.lr_scheduler import ReduceLROnPlateau

from training_utils.preprocessed_dataset import PreprocessedDataset
from training_utils.train import Trainer
from training_utils.evaluate import Evaluator
from models.STA_LSTM import STA_LSTM

# %% [markdown]
# #### Hiperparameters

# %%
MAX_SEQUENCE_LENGTH = 46
NUM_FEATURES = 300
NUM_CLASSES = 2
HIDDEN_SIZE = 128
NUM_LAYERS = 2
NUM_EPOCHS = 200
BATCH_SIZE = 16
LEARNING_RATE = 0.00005
DROPOUT_PROB = 0.3
WEIGHT_DECAY = 0.005
SCHEDULER_FACTOR = 0.9

# %% [markdown]
# #### Data preparation

# %%
COLAB_ROOT = '/content/drive/MyDrive/PainRecognitionProject/'
PROCESSED_DATA_DIR = os.path.join(COLAB_ROOT, 'data/BioVid_HeatPain_processed_478_xyz_frontalized/')
MODEL_SAVE_DIR = os.path.join(COLAB_ROOT, 'models/')
LOCAL_PROCESSED_DATA_ROOT = '/content/temp_data/'

DEVICE = torch.device("cuda" if torch.cuda.is_available() else "cpu")

# %%
print("Kopiowanie danych z Google Drive do lokalnej pamięci Colab (RAM)...")
if os.path.exists(LOCAL_PROCESSED_DATA_ROOT):
    shutil.rmtree(LOCAL_PROCESSED_DATA_ROOT)
try:
    shutil.copytree(PROCESSED_DATA_DIR, LOCAL_PROCESSED_DATA_ROOT)
    print("✅ Kopiowanie zakończone pomyślnie. Czas trwania: (sprawdź zegar)")
    CURRENT_DATA_DIR = LOCAL_PROCESSED_DATA_ROOT

except Exception as e:
    print(f"❌ Błąd kopiowania danych (sprawdź, czy dane są zamontowane): {e}")
    print("Używam danych bezpośrednio z Drive (może się zawiesić).")
    CURRENT_DATA_DIR = PROCESSED_DATA_DIR
# Out:
# Kopiowanie danych z Google Drive do lokalnej pamięci Colab (RAM)...
# ✅ Kopiowanie zakończone pomyślnie. Czas trwania: (sprawdź zegar)

# %%
best_100_landmarks = np.load('/content/drive/MyDrive/PainRecognitionProject/data/top_100_important_landmarks_emotions.npy')

feature_indices_x = best_100_landmarks * 3
feature_indices_y = best_100_landmarks * 3 + 1
feature_indices_z = best_100_landmarks * 3 + 2

# Interleave to get [X1, Y1, Z1, X2, Y2, Z2, ...]
best_300_features = np.stack([feature_indices_x, feature_indices_y, feature_indices_z], axis=1).flatten()

# %%
train_dataset = PreprocessedDataset(
    'train',
    processed_data_dir=CURRENT_DATA_DIR,
    indices=best_300_features,
    compute_euclidean=False,
    center_point_index=2,
    max_sequence_length=MAX_SEQUENCE_LENGTH,
    selected_labels=[0, 4],
    label_map={0: 0, 4: 1},
)

val_dataset = PreprocessedDataset(
    'val',
    processed_data_dir=CURRENT_DATA_DIR,
    indices=best_300_features,
    compute_euclidean=False,
    center_point_index=2,
    max_sequence_length=MAX_SEQUENCE_LENGTH,
    selected_labels=[0, 4],
    label_map={0: 0, 4: 1},
)

test_dataset = PreprocessedDataset(
    'test',
    processed_data_dir=CURRENT_DATA_DIR,
    indices=best_300_features,
    compute_euclidean=False,
    center_point_index=2,
    max_sequence_length=MAX_SEQUENCE_LENGTH,
    selected_labels=[0, 4],
    label_map={0: 0, 4: 1},
)

# %%
def preview_single(dataset, idx=0, timesteps_to_show=3, features_to_show=8):
    x, y = dataset[idx]
    print(f"\nSingle sample idx={idx} from split={dataset.dataset_name}")
    print(f"x shape: {tuple(x.shape)}, y: {y}")
    print(np.round(x[:timesteps_to_show, :features_to_show], 4))

preview_single(train_dataset, 0)
preview_single(val_dataset, 0)
preview_single(test_dataset, 0)
# Out:
# Single sample idx=0 from split=train
# x shape: (46, 300), y: 0
# tensor([[0.1507, 0.1288, 0.1142, 0.1074, 0.2043, 0.0947, 0.1404, 0.0928],
#         [0.1488, 0.1293, 0.1180, 0.1079, 0.2146, 0.1028, 0.1382, 0.0917],
#         [0.1507, 0.1252, 0.1187, 0.1093, 0.2105, 0.1028, 0.1401, 0.0886]])
#
# Single sample idx=0 from split=val
# x shape: (46, 300), y: 0
# tensor([[0.1483, 0.1156, 0.1151, 0.1027, 0.1887, 0.0901, 0.1374, 0.0823],
#         [0.1522, 0.1143, 0.1157, 0.1043, 0.1852, 0.0900, 0.1415, 0.0816],
#         [0.1524, 0.1143, 0.1155, 0.1045, 0.1854, 0.0897, 0.1416, 0.0817]])
#
# Single sample idx=0 from split=test
# x shape: (46, 300), y: 0
# tensor([[0.1401, 0.1400, 0.1036, 0.0984, 0.2080, 0.0833, 0.1307, 0.1012],
#         [0.1392, 0.1376, 0.1043, 0.0974, 0.2055, 0.0839, 0.1297, 0.0993],
#         [0.1393, 0.1381, 0.1052, 0.0976, 0.2081, 0.0852, 0.1300, 0.0995]])

# %%
train_loader = DataLoader(train_dataset, batch_size=BATCH_SIZE, shuffle=True, num_workers=0, pin_memory=True)
for X, y in train_loader:
    print(X.shape, y.shape)  # (B, T_max, num_features)
    break

val_loader = DataLoader(val_dataset, batch_size=BATCH_SIZE, shuffle=True, num_workers=0, pin_memory=True)
for X, y in val_loader:
    print(X.shape, y.shape)  # (B, T_max, num_features)
    break

test_loader = DataLoader(test_dataset, batch_size=BATCH_SIZE, shuffle=True, num_workers=0, pin_memory=True)
for X, y in test_loader:
    print(X.shape, y.shape)  # (B, T_max, num_features)
    break
# Out:
# torch.Size([16, 46, 300]) torch.Size([16])
# torch.Size([16, 46, 300]) torch.Size([16])
# torch.Size([16, 46, 300]) torch.Size([16])

# %% [markdown]
# #### Model preparation

# %%
model = STA_LSTM(NUM_FEATURES, HIDDEN_SIZE, NUM_LAYERS, NUM_CLASSES, DROPOUT_PROB).to(DEVICE)

# %% [markdown]
# #### Training

# %%
criterion = nn.CrossEntropyLoss()
optimizer = torch.optim.AdamW(model.parameters(), lr=LEARNING_RATE, weight_decay=WEIGHT_DECAY)

scheduler = ReduceLROnPlateau(
    optimizer,
    mode='max',
    factor=SCHEDULER_FACTOR,
    patience=10,
    min_lr=1e-7
)

model_name = 'testing_new_code_sta_lstm_2_classes_300_coord.pt'
model_filepath = os.path.join(MODEL_SAVE_DIR, model_name)

# %%
trainer = Trainer(
    model=model,
    train_loader=train_loader,
    val_loader=val_loader,
    optimizer=optimizer,
    scheduler=scheduler,
    criterion=criterion,
    device=DEVICE,
    model_save_path=model_filepath,
    num_epochs=NUM_EPOCHS,
    monitor='val_acc',  # or 'val_loss'
    minimize_monitor=False,
    save_best_only=True
)

# %%
trainer.print_training_config()
# Out:
# ==================================================
# 🚀 TRAINING CONFIGURATION
# ==================================================
#
# --- Model Architecture ---
#   Model Type            : STA_LSTM
#   Input Features        : 300
#   Hidden Size           : 128
#   Num Layers            : 2
#   Bidirectional         : True
#   Dropout (LSTM)        : 0.3
#   Num Parameters        : 946863
#
# --- Optimizer & Regularization ---
#   Optimizer             : AdamW
#   Learning Rate (LR)    : 5e-05
#   Weight Decay (L2)     : 0.005
#
# --- Training Flow ---
#   Batch Size            : 16
#   Num Epochs            : 200
#   Device                : cuda
# ==================================================

# %%
final_model_path, best_model_path, history = trainer.fit()
print(f"Final model saved to: {final_model_path}")
if best_model_path:
    print(f"Best model saved to: {best_model_path}")
# Out:
# Starting training for 200 epochs on cuda
# Saved best model to /content/drive/MyDrive/PainRecognitionProject/models/best_testing_new_code_sta_lstm_2_classes_300_coord.pt (metric=0.5000)
# Epoch 1/200 | Time 7.27s | Train loss 0.7224 | Train acc 0.5123 | Val loss 0.7116 | Val acc 0.5000
# Saved best model to /content/drive/MyDrive/PainRecognitionProject/models/best_testing_new_code_sta_lstm_2_classes_300_coord.pt (metric=0.5019)
# Epoch 2/200 | Time 2.92s | Train loss 0.7130 | Train acc 0.5029 | Val loss 0.6939 | Val acc 0.5019
# Epoch 3/200 | Time 2.52s | Train loss 0.7032 | Train acc 0.5078 | Val loss 0.6914 | Val acc 0.5019
# Saved best model to /content/drive/MyDrive/PainRecognitionProject/models/best_testing_new_code_sta_lstm_2_classes_300_coord.pt (metric=0.5596)
# Epoch 4/200 | Time 3.25s | Train loss 0.6987 | Train acc 0.5328 | Val loss 0.6886 | Val acc 0.5596
# Saved best model to /content/drive/MyDrive/PainRecognitionProject/models/best_testing_new_code_sta_lstm_2_classes_300_coord.pt (metric=0.5654)
# Epoch 5/200 | Time 2.60s | Train loss 0.6965 | Train acc 0.5307 | Val loss 0.6838 | Val acc 0.5654
# Epoch 6/200 | Time 2.51s | Train loss 0.6923 | Train acc 0.5373 | Val loss 0.6811 | Val acc 0.5577
# Epoch 7/200 | Time 2.47s | Train loss 0.6828 | Train acc 0.5582 | Val loss 0.7363 | Val acc 0.5038
# Epoch 8/200 | Time 2.52s | Train loss 0.6833 | Train acc 0.5537 | Val loss 0.6750 | Val acc 0.5654
# Epoch 9/200 | Time 3.29s | Train loss 0.6706 | Train acc 0.5820 | Val loss 0.6764 | Val acc 0.5365
# Saved best model to /content/drive/MyDrive/PainRecognitionProject/models/best_testing_new_code_sta_lstm_2_classes_300_coord.pt (metric=0.5885)
# Epoch 10/200 | Time 2.50s | Train loss 0.6635 | Train acc 0.5980 | Val loss 0.6786 | Val acc 0.5885
# Epoch 11/200 | Time 2.48s | Train loss 0.6654 | Train acc 0.5811 | Val loss 0.6750 | Val acc 0.5885
# Saved best model to /content/drive/MyDrive/PainRecognitionProject/models/best_testing_new_code_sta_lstm_2_classes
# Epoch 185/200 | Time 3.00s | Train loss 0.4930 | Train acc 0.7418 | Val loss 0.6517 | Val acc 0.7154
# Epoch 186/200 | Time 2.51s | Train loss 0.4901 | Train acc 0.7344 | Val loss 0.6138 | Val acc 0.7038
# Epoch 187/200 | Time 2.46s | Train loss 0.4872 | Train acc 0.7430 | Val loss 0.6557 | Val acc 0.6827
# Epoch 188/200 | Time 2.46s | Train loss 0.4882 | Train acc 0.7385 | Val loss 0.6011 | Val acc 0.7019
# Epoch 189/200 | Time 3.00s | Train loss 0.4916 | Train acc 0.7320 | Val loss 0.6164 | Val acc 0.7154
# Epoch 190/200 | Time 2.75s | Train loss 0.4914 | Train acc 0.7402 | Val loss 0.6282 | Val acc 0.7115
# Epoch 191/200 | Time 2.45s | Train loss 0.4961 | Train acc 0.7279 | Val loss 0.6143 | Val acc 0.7096
# Epoch 192/200 | Time 2.47s | Train loss 0.4839 | Train acc 0.7496 | Val loss 0.6524 | Val acc 0.6865
# Epoch 193/200 | Time 2.46s | Train loss 0.4889 | Train acc 0.7324 | Val loss 0.6330 | Val acc 0.7115
# Epoch 194/200 | Time 2.96s | Train loss 0.4851 | Train acc 0.7352 | Val loss 0.6114 | Val acc 0.6962
# Epoch 195/200 | Time 2.80s | Train loss 0.4882 | Train acc 0.7398 | Val loss 0.6416 | Val acc 0.7173
# Epoch 196/200 | Time 2.50s | Train loss 0.4877 | Train acc 0.7389 | Val loss 0.6356 | Val acc 0.7019
# Epoch 197/200 | Time 2.52s | Train loss 0.4933 | Train acc 0.7430 | Val loss 0.6694 | Val acc 0.7135
# Epoch 198/200 | Time 2.49s | Train loss 0.4910 | Train acc 0.7340 | Val loss 0.6584 | Val acc 0.7135
# Epoch 199/200 | Time 2.93s | Train loss 0.4843 | Train acc 0.7377 | Val loss 0.6697 | Val acc 0.7077
# Epoch 200/200 | Time 2.80s | Train loss 0.4812 | Train acc 0.7398 | Val loss 0.6830 | Val acc 0.7115
# Training finished. Best epoch: 102. Best monitored metric: 0.7385
# Final model saved to: /content/drive/MyDrive/PainRecognitionProject/models/testing_new_code_sta_lstm_2_classes_300_coord.pt
# Best model saved to: /content/drive/MyDrive/PainRecognitionProject/models/best_testing_new_code_sta_lstm_2_classes_300_coord.pt

# %%
trainer.plot_history()

# %% [markdown]
# #### Evaluate

# %%
model.load_state_dict(torch.load(best_model_path, map_location=DEVICE), strict=False)
# Out:
# <All keys matched successfully>

# %%
evaluator = Evaluator(model, test_loader, device=DEVICE, model_name=model_name, num_classes=NUM_CLASSES)

# %%
loss, acc, labels, preds = evaluator.evaluate_epoch()
# Out:
# ==================================================
# WYNIKI OCENY DLA MODELU: testing_new_code_sta_lstm_2_classes_300_coord.pt
# ==================================================
# Test Loss: 0.4989
# Test Accuracy: 0.7346
#
# --- Szczegółowy Raport Klasyfikacji ---
#               precision    recall  f1-score   support
#
#      Klasa 0       0.69      0.84      0.76       260
#      Klasa 1       0.80      0.63      0.70       260
#
#     accuracy                           0.73       520
#    macro avg       0.75      0.73      0.73       520
# weighted avg       0.75      0.73      0.73       520
#
# ==================================================
# Confusion matrix:
#  [[219  41]
#  [ 97 163]]
