# %% [markdown]
# ### Distances 100 shapley points - 6 class training

# %% [markdown]
# #### Environment preparation

# %%
from google.colab import drive
drive.mount('/content/drive')

COLAB_ROOT = '/content/drive/MyDrive/PainRecognitionProject/'
print(f"Dane będą wczytywane z: {COLAB_ROOT}")
# Out:
# Mounted at /content/drive
# Dane będą wczytywane z: /content/drive/MyDrive/PainRecognitionProject/

# %%
import os

# %cd /content

# !rm -rf automatic-pain-recognition

print(f"Obecne położenie: {os.getcwd()}")
# Out:
# /content
# Obecne położenie: /content

# %%
USERNAME = 'alicka33'
REPO_NAME = 'automatic-pain-recognition'

REPO_URL = f"https://github.com/{USERNAME}/{REPO_NAME}.git"

print("Rozpoczynam klonowanie...")

# !git clone {REPO_URL}

# %cd $REPO_NAME
# Out:
# Rozpoczynam klonowanie...
# Cloning into 'automatic-pain-recognition'...
# remote: Enumerating objects: 266, done.
# remote: Counting objects: 100% (266/266), done.
# remote: Compressing objects: 100% (210/210), done.
# remote: Total 266 (delta 119), reused 197 (delta 52), pack-reused 0 (from 0)
# Receiving objects: 100% (266/266), 11.27 MiB | 16.05 MiB/s, done.
# Resolving deltas: 100% (119/119), done.
# /content/automatic-pain-recognition

# %%
# !pip install -r requirements.txt

# %%
import sys
import os

sys.path.append(os.getcwd())
print(f"Dodano do ścieżki Pythona: {os.getcwd()}")
# Out:
# Dodano do ścieżki Pythona: /content/automatic-pain-recognition

# %% [markdown]
# #### Distances 100 shapley points - 6 class training

# %%
import os
import numpy as np
import pandas as pd
import shutil

import torch
import torch.nn as nn
from torch.utils.data import DataLoader
from torch.optim.lr_scheduler import ReduceLROnPlateau

from training_utils.preprocessed_dataset import PreprocessedDataset
from training_utils.train import Trainer
from training_utils.evaluate import Evaluator
from models.Bi_LSTM import SequenceModel

# %% [markdown]
# #### Hiperparameters

# %%
MAX_SEQUENCE_LENGTH = 37
NUM_FEATURES = 100
NUM_CLASSES = 6
HIDDEN_SIZE = 128
NUM_LAYERS = 2
NUM_EPOCHS = 200
BATCH_SIZE = 16
LEARNING_RATE = 0.00005
DROPOUT_PROB = 0.4
WEIGHT_DECAY = 0.005
SCHEDULER_FACTOR = 0.8

# %% [markdown]
# #### Data preparation

# %%
COLAB_ROOT = '/content/drive/MyDrive/PainRecognitionProject/'
PROCESSED_DATA_DIR = os.path.join(COLAB_ROOT, 'data/RAVDESS_processed_478_xyz_frontalized/')
MODEL_SAVE_DIR = os.path.join(COLAB_ROOT, 'models/')
LOCAL_PROCESSED_DATA_ROOT = '/content/temp_data/'

DEVICE = torch.device("cuda" if torch.cuda.is_available() else "cpu")

# %%
print("Kopiowanie danych z Google Drive do lokalnej pamięci Colab (RAM)...")
if os.path.exists(LOCAL_PROCESSED_DATA_ROOT):
    shutil.rmtree(LOCAL_PROCESSED_DATA_ROOT)
try:
    shutil.copytree(PROCESSED_DATA_DIR, LOCAL_PROCESSED_DATA_ROOT)
    print("✅ Kopiowanie zakończone pomyślnie. Czas trwania: (sprawdź zegar)")
    CURRENT_DATA_DIR = LOCAL_PROCESSED_DATA_ROOT

except Exception as e:
    print(f"❌ Błąd kopiowania danych (sprawdź, czy dane są zamontowane): {e}")
    print("Używam danych bezpośrednio z Drive (może się zawiesić).")
    CURRENT_DATA_DIR = PROCESSED_DATA_DIR
# Out:
# Kopiowanie danych z Google Drive do lokalnej pamięci Colab (RAM)...
# ✅ Kopiowanie zakończone pomyślnie. Czas trwania: (sprawdź zegar)

# %%
best_100 = np.load('/content/drive/MyDrive/PainRecognitionProject/data/top_100_important_landmarks_emotions.npy')

# %%
train_dataset = PreprocessedDataset(
    'train',
    processed_data_dir=CURRENT_DATA_DIR,
    indices=best_100,
    compute_euclidean=True,
    center_point_index=2,
    max_sequence_length=MAX_SEQUENCE_LENGTH,
    selected_labels=[2, 3, 4, 5, 6, 8],
    label_map={2: 0, 3: 1, 4: 2, 5: 3, 6: 4, 8: 5},
)

val_dataset = PreprocessedDataset(
    'val',
    processed_data_dir=CURRENT_DATA_DIR,
    indices=best_100,
    compute_euclidean=True,
    center_point_index=2,
    max_sequence_length=MAX_SEQUENCE_LENGTH,
    selected_labels=[2, 3, 4, 5, 6, 8],
    label_map={2: 0, 3: 1, 4: 2, 5: 3, 6: 4, 8: 5},
)

test_dataset = PreprocessedDataset(
    'test',
    processed_data_dir=CURRENT_DATA_DIR,
    indices=best_100,
    compute_euclidean=True,
    center_point_index=2,
    max_sequence_length=MAX_SEQUENCE_LENGTH,
    selected_labels=[2, 3, 4, 5, 6, 8],
    label_map={2: 0, 3: 1, 4: 2, 5: 3, 6: 4, 8: 5},
)

# %%
def preview_single(dataset, idx=0, timesteps_to_show=3, features_to_show=8):
    x, y = dataset[idx]
    print(f"\nSingle sample idx={idx} from split={dataset.dataset_name}")
    print(f"x shape: {tuple(x.shape)}, y: {y}")
    print(np.round(x[:timesteps_to_show, :features_to_show], 4))

preview_single(train_dataset, 0)
preview_single(val_dataset, 0)
preview_single(test_dataset, 0)
# Out:
# Single sample idx=0 from split=train
# x shape: (37, 100), y: 0
# tensor([[0.2004, 0.2422, 0.1642, 0.1752, 0.1809, 0.1882, 0.1701, 0.2231],
#         [0.1973, 0.2360, 0.1626, 0.1764, 0.1766, 0.1833, 0.1658, 0.2216],
#         [0.1961, 0.2359, 0.1618, 0.1762, 0.1767, 0.1835, 0.1656, 0.2211]])
#
# Single sample idx=0 from split=val
# x shape: (37, 100), y: 0
# tensor([[0.2235, 0.2754, 0.1782, 0.1783, 0.1996, 0.2145, 0.1828, 0.2463],
#         [0.2210, 0.2703, 0.1766, 0.1775, 0.1968, 0.2114, 0.1818, 0.2443],
#         [0.2186, 0.2695, 0.1744, 0.1756, 0.1931, 0.2075, 0.1772, 0.2418]])
#
# Single sample idx=0 from split=test
# x shape: (37, 100), y: 0
# tensor([[0.2100, 0.2658, 0.1665, 0.1652, 0.1967, 0.2125, 0.1877, 0.2303],
#         [0.2117, 0.2679, 0.1670, 0.1654, 0.1955, 0.2127, 0.1855, 0.2315],
#         [0.2128, 0.2720, 0.1677, 0.1661, 0.1971, 0.2137, 0.1880, 0.2326]])

# %%
train_loader = DataLoader(train_dataset, batch_size=BATCH_SIZE, shuffle=True, num_workers=0, pin_memory=True)
for X, y in train_loader:
    print(X.shape, y.shape)  # (B, T_max, num_features)
    break

val_loader = DataLoader(val_dataset, batch_size=BATCH_SIZE, shuffle=True, num_workers=0, pin_memory=True)
for X, y in val_loader:
    print(X.shape, y.shape)  # (B, T_max, num_features)
    break

test_loader = DataLoader(test_dataset, batch_size=BATCH_SIZE, shuffle=True, num_workers=0, pin_memory=True)
for X, y in test_loader:
    print(X.shape, y.shape)  # (B, T_max, num_features)
    break
# Out:
# torch.Size([16, 37, 100]) torch.Size([16])
# torch.Size([16, 37, 100]) torch.Size([16])
# torch.Size([16, 37, 100]) torch.Size([16])

# %% [markdown]
# #### Model preparation

# %%
model = SequenceModel(NUM_FEATURES, HIDDEN_SIZE, NUM_LAYERS, NUM_CLASSES, DROPOUT_PROB).to(DEVICE)

# %% [markdown]
# #### Training

# %%
criterion = nn.CrossEntropyLoss()
optimizer = torch.optim.AdamW(model.parameters(), lr=LEARNING_RATE, weight_decay=WEIGHT_DECAY)

scheduler = ReduceLROnPlateau(
    optimizer,
    mode='min',
    factor=SCHEDULER_FACTOR,
    patience=10,
    min_lr=1e-7
)

model_name = 'testing_new_code_emotions_100_distances_6_classes_val_loss.pt'
model_filepath = os.path.join(MODEL_SAVE_DIR, model_name)

# %%
trainer = Trainer(
    model=model,
    train_loader=train_loader,
    val_loader=val_loader,
    optimizer=optimizer,
    scheduler=scheduler,
    criterion=criterion,
    device=DEVICE,
    model_save_path=model_filepath,
    num_epochs=NUM_EPOCHS,
    monitor='val_loss',  # or 'val_loss'
    minimize_monitor=True,
    save_best_only=True
)

# %%
trainer.print_training_config()
# Out:
# ==================================================
# 🚀 TRAINING CONFIGURATION
# ==================================================
#
# --- Model Architecture ---
#   Model Type            : SequenceModel
#   Input Features        : 100
#   Hidden Size           : 128
#   Num Layers            : 2
#   Bidirectional         : True
#   Dropout (LSTM)        : 0.4
#   Num Parameters        : 632326
#
# --- Optimizer & Regularization ---
#   Optimizer             : AdamW
#   Learning Rate (LR)    : 5e-05
#   Weight Decay (L2)     : 0.005
#
# --- Training Flow ---
#   Batch Size            : 16
#   Num Epochs            : 200
#   Device                : cuda
# ==================================================

# %%
final_model_path, best_model_path, history = trainer.fit()
print(f"Final model saved to: {final_model_path}")
if best_model_path:
    print(f"Best model saved to: {best_model_path}")
# Out:
# Starting training for 200 epochs on cuda
# Saved best model to /content/drive/MyDrive/PainRecognitionProject/models/best_testing_new_code_emotions_100_distances_6_classes_val_loss.pt (metric=1.7914)
# Epoch 1/200 | Time 3.66s | Train loss 1.7929 | Train acc 0.1641 | Val loss 1.7914 | Val acc 0.2298
# Saved best model to /content/drive/MyDrive/PainRecognitionProject/models/best_testing_new_code_emotions_100_distances_6_classes_val_loss.pt (metric=1.7908)
# Epoch 2/200 | Time 2.58s | Train loss 1.7923 | Train acc 0.1602 | Val loss 1.7908 | Val acc 0.2089
# Saved best model to /content/drive/MyDrive/PainRecognitionProject/models/best_testing_new_code_emotions_100_distances_6_classes_val_loss.pt (metric=1.7902)
# Epoch 3/200 | Time 2.56s | Train loss 1.7918 | Train acc 0.1862 | Val loss 1.7902 | Val acc 0.1749
# Saved best model to /content/drive/MyDrive/PainRecognitionProject/models/best_testing_new_code_emotions_100_distances_6_classes_val_loss.pt (metric=1.7895)
# Epoch 4/200 | Time 2.90s | Train loss 1.7915 | Train acc 0.1725 | Val loss 1.7895 | Val acc 0.2533
# Saved best model to /content/drive/MyDrive/PainRecognitionProject/models/best_testing_new_code_emotions_100_distances_6_classes_val_loss.pt (metric=1.7882)
# Epoch 5/200 | Time 2.94s | Train loss 1.7882 | Train acc 0.1921 | Val loss 1.7882 | Val acc 0.2742
# Saved best model to /content/drive/MyDrive/PainRecognitionProject/models/best_testing_new_code_emotions_100_distances_6_classes_val_loss.pt (metric=1.7854)
# Epoch 6/200 | Time 2.57s | Train loss 1.7878 | Train acc 0.2057 | Val loss 1.7854 | Val acc 0.1775
# Saved best model to /content/drive/MyDrive/PainRecognitionProject/models/best_testing_new_code_emotions_100_distances_6_classes_val_loss.pt (metric=1.7717)
# Epoch 7/200 | Time 2.54s | Train loss 1.7807 | Train acc 0.2044 | Val loss 1.7717 | Val acc 0.1775
# Saved best model to /content/drive/MyDrive/PainRecognitionProject/models/best_testing_new_code_emotions_100_distances_6_classes_val_loss.pt (metric=1.6839)
# Epoch 8/200 | Time 2.57s | Train loss 1.7326 | Train acc 0.2396 | Val loss 1.6839 | Val acc 0.2167
# Epoch 9/200 | Time 3.08s | Train loss 1.6650 | Train acc 0.2708 | Val loss 1.7290 | Val acc 0.2350
# Saved best model to /content/drive/MyDrive/PainRecognitionProject/models/best_testing_new_code_emotions_100_distances_6_classes_val_loss.pt (metric=1.6665)
# Epoch 10/200 | Time 2.80s | Train loss 1.6172 | Train acc 0.2839 | Val loss 1.6665 | Val acc 0.2350
# Epoch 11/200 | Time 2.55s | Train loss 1.5797 | Train acc 0.2969 | Val loss 1.6940 | Val acc 0.2219
# Saved best model to /content/drive/MyDrive/PainRecognitionProject/models/best_testing_new_code_emotions_100_distances_6_classes_val_loss.pt (metric=1.5039)
# Epoch 12/200 | Time 2.56s | Train loss 1.5642 | Train acc 0.2995 | Val loss 1.5039 | Val acc 0.3159
# Epoch 13/200 | Time 2.56s | Train loss 1.5155 | Train acc 0.3086 | Val loss 1.5233 | Val acc 0.2742
# Epoch 14/200 | Time 3.16s | Train loss 1.5207 | Train acc 0.3223 | Val loss 2.1367 | Val acc 0.2324
# Epoch 15/200 | Time 2.70s | Train loss 1.4877 | Train acc 0.3223 | Val loss 1.5439 | Val acc 0.2742
# Saved best model to /content/drive/MyDrive/PainRecognitionProject/models/best_testing_new_code_emotions_100_distances_6_classes_val_loss.pt (metric=1.4538)
# Epoch 16/200 | Time 2.53s | Train loss 1.4743 | Train acc 0.3229 | Val loss 1.4538 | Val acc 0.3290
# Epoch 17/200 | Time 2.55s | Train loss 1.4649 | Train acc 0.3314 | Val loss 1.6374 | Val acc 0.3133
# Epoch 18/200 | Time 2.56s | Train loss 1.4602 | Train acc 0.3418 | Val loss 1.5592 | Val acc 0.2924
# Epoch 19/200 | Time 3.19s | Train loss 1.4459 | Train acc 0.3431 | Val loss 2.0423 | Val acc 0.2402
# Epoch 20/200 | Time 2.71s | Train loss 1.4623 | Train acc 0.3659 | Val loss 1.6028 | Val acc 0.4413
# Epoch 21/200 | Time 2.53s | Train loss 1.4412 | Train acc 0.3613 | Val loss 1.6880 | Val acc 0.3290
# Epoch 22/200 | Time 2.56s | Train loss 1.4259 | Train acc 0.3776 | Val loss 1.8263 | Val acc 0.2924
# Saved best model to /content/drive/MyDrive/PainRecognitionProject/models/best_testing_new_code_emotions_100_distances_6_classes_val_loss.pt (metric=1.3862)
# Epoch 23/200 | Time 2.58s | Train loss 1.4224 | Train acc 0.3906 | Val loss 1.3862 | Val acc 0.4099
# Epoch 24/200 | Time 3.25s | Train loss 1.4105 | Train acc 0.3822 | Val loss 1.6292 | Val acc 0.3211
# Epoch 25/200 | Time 2.55s | Train loss 1.3782 | Train acc 0.3770 | Val loss 1.8575 | Val acc 0.3577
# Saved best model to /content/drive/MyDrive/PainRecognitionProject/models/best_testing_new_code_emotions_100_distances_6_classes_val_loss.pt (metric=1.3503)
# Epoch 26/200 | Time 2.56s | Train loss 1.3613 | Train acc 0.3958 | Val loss 1.3503 | Val acc 0.4282
# Epoch 27/200 | Time 2.56s | Train loss 1.3330 | Train acc 0.4414 | Val loss 1.3559 | Val acc 0.4021
# Epoch 28/200 | Time 2.72s | Train loss 1.3244 | Train acc 0.4531 | Val loss 1.5739 | Val acc 0.3290
# Epoch 29/200 | Time 3.14s | Train loss 1.3612 | Train acc 0.4186 | Val loss 1.3535 | Val acc 0.4386
# Epoch 30/200 | Time 2.54s | Train loss 1.3158 | Train acc 0.4577 | Val loss 1.6506 | Val acc 0.4021
# Epoch 31/200 | Time 2.56s | Train loss 1.3080 | Train acc 0.4629 | Val loss 1.4438 | Val acc 0.4256
# Epoch 32/200 | Time 2.55s | Train loss 1.3319 | Train acc 0.4655 | Val loss 1.6850 | Val acc 0.4256
# Epoch 33/200 | Time 2.77s | Train loss 1.3011 | Train acc 0.4766 | Val loss 1.9384 | Val acc 0.3394
# Epoch 34/200 | Time 3.05s | Train loss 1.2928 | Train acc 0.4674 | Val loss 1.5430 | Val acc 0.4125
# Saved best model to /content/drive/MyDrive/PainRecognitionProject/models/best_testing_new_code_emotions_100_distances_6_classes_val_loss.pt (metric=1.3125)
# Epoch 35/200 | Time 2.58s | Train loss 1.2609 | Train acc 0.4779 | Val loss 1.3125 | Val acc 0.4543
# Epoch 36/200 | Time 2.60s | Train loss 1.2735 | Train acc 0.4668 | Val loss 1.6639 | Val acc 0.4178
# Epoch 37/200 | Time 2.56s | Train loss 1.2497 | Train acc 0.5020 | Val loss 1.5032 | Val acc 0.4256
# Epoch 38/200 | Time 2.91s | Train loss 1.2325 | Train acc 0.5039 | Val loss 1.5265 | Val acc 0.4726
# Epoch 39/200 | Time 2.95s | Train loss 1.2042 | Train acc 0.5254 | Val loss 1.4863 | Val acc 0.4308
# Epoch 40/200 | Time 2.57s | Train loss 1.1801 | Train acc 0.5443 | Val loss 1.5281 | Val acc 0.4543
# Epoch 41/200 | Time 2.55s | Train loss 1.1789 | Train acc 0.5475 | Val loss 1.4465 | Val acc 0.4517
# Saved best model to /content/drive/MyDrive/PainRecognitionProject/models/best_testing_new_code_emotions_100_distances_6_classes_val_loss.pt (metric=1.2459)
# Epoch 42/200 | Time 2.55s | Train loss 1.1953 | Train acc 0.5241 | Val loss 1.2459 | Val acc 0.4856
# Epoch 43/200 | Time 2.95s | Train loss 1.1719 | Train acc 0.5241 | Val loss 1.6279 | Val acc 0.4334
# Epoch 44/200 | Time 2.84s | Train loss 1.1806 | Train acc 0.5273 | Val loss 1.7279 | Val acc 0.4621
# Epoch 45/200 | Time 2.54s | Train loss 1.1762 | Train acc 0.5267 | Val loss 1.5561 | Val acc 0.4047
# Epoch 46/200 | Time 2.55s | Train loss 1.1593 | Train acc 0.5469 | Val loss 1.6567 | Val acc 0.4491
# Epoch 47/200 | Time 2.57s | Train loss 1.1490 | Train acc 0.5326 | Val loss 1.2641 | Val acc 0.4856
# Epoch 48/200 | Time 3.09s | Train loss 1.1069 | Train acc 0.5632 | Val loss 1.2624 | Val acc 0.4726
# Epoch 49/200 | Time 2.82s | Train loss 1.1451 | Train acc 0.5319 | Val loss 1.3672 | Val acc 0.4491
# Epoch 50/200 | Time 2.61s | Train loss 1.1228 | Train acc 0.5514 | Val loss 1.6701 | Val acc 0.3943
# Epoch 51/200 | Time 2.55s | Train loss 1.1174 | Train acc 0.5488 | Val loss 1.2700 | Val acc 0.5274
# Epoch 52/200 | Time 2.55s | Train loss 1.1271 | Train acc 0.5560 | Val loss 1.4369 | Val acc 0.4517
# Epoch 53/200 | Time 3.15s | Train loss 1.1334 | Train acc 0.5423 | Val loss 1.5745 | Val acc 0.4648
# Epoch 54/200 | Time 2.68s | Train loss 1.0552 | Train acc 0.5859 | Val loss 1.3600 | Val acc 0.5013
# Epoch 55/200 | Time 2.55s | Train loss 1.0849 | Train acc 0.5599 | Val loss 1.9266 | Val acc 0.3995
# Epoch 56/200 | Time 2.56s | Train loss 1.0679 | Train acc 0.5703 | Val loss 1.5081 | Val acc 0.4595
# Epoch 57/200 | Time 2.55s | Train loss 1.0212 | Train acc 0.5957 | Val loss 1.5764 | Val acc 0.4595
# Saved best model to /content/drive/MyDrive/PainRecognitionProject/models/best_testing_new_code_emotions_100_distances_6_classes_val_loss.pt (metric=1.2076)
# Epoch 58/200 | Time 3.24s | Train loss 1.0374 | Train acc 0.5964 | Val loss 1.2076 | Val acc 0.5013
# Epoch 59/200 | Time 2.58s | Train loss 1.0481 | Train acc 0.5807 | Val loss 1.2264 | Val acc 0.5117
# Epoch 60/200 | Time 2.59s | Train loss 1.0244 | Train acc 0.6094 | Val loss 1.2481 | Val acc 0.5117
# Epoch 61/200 | Time 2.54s | Train loss 1.0619 | Train acc 0.5677 | Val loss 1.2325 | Val acc 0.4935
# Epoch 62/200 | Time 2.62s | Train loss 1.0219 | Train acc 0.5918 | Val loss 1.2640 | Val acc 0.5196
# Epoch 63/200 | Time 3.19s | Train loss 1.0389 | Train acc 0.5924 | Val loss 1.4168 | Val acc 0.4778
# Epoch 64/200 | Time 2.53s | Train loss 1.0453 | Train acc 0.5918 | Val loss 1.3724 | Val acc 0.4961
# Epoch 65/200 | Time 2.56s | Train loss 0.9952 | Train acc 0.6003 | Val loss 1.6168 | Val acc 0.4047
# Epoch 66/200 | Time 2.53s | Train loss 0.9924 | Train acc 0.5951 | Val loss 1.6681 | Val acc 0.4569
# Epoch 67/200 | Time 2.68s | Train loss 1.0173 | Train acc 0.5859 | Val loss 1.6061 | Val acc 0.4386
# Epoch 68/200 | Time 3.13s | Train loss 1.0015 | Train acc 0.6055 | Val loss 1.2577 | Val acc 0.4961
# Epoch 69/200 | Time 2.53s | Train loss 0.9923 | Train acc 0.6074 | Val loss 1.4220 | Val acc 0.4569
# Epoch 70/200 | Time 2.55s | Train loss 0.9466 | Train acc 0.6367 | Val loss 1.2590 | Val acc 0.5196
# Saved best model to /content/drive/MyDrive/PainRecognitionProject/models/best_testing_new_code_emotions_100_distances_6_classes_val_loss.pt (metric=1.1913)
# Epoch 71/200 | Time 2.56s | Train loss 0.9806 | Train acc 0.6100 | Val loss 1.1913 | Val acc 0.5352
# Epoch 72/200 | Time 2.79s | Train loss 0.9686 | Train acc 0.6074 | Val loss 1.4199 | Val acc 0.4856
# Saved best model to /content/drive/MyDrive/PainRecognitionProject/models/best_testing_new_code_emotions_100_distances_6_classes_val_loss.pt (metric=1.1573)
# Epoch 73/200 | Time 3.04s | Train loss 0.9330 | Train acc 0.6276 | Val loss 1.1573 | Val acc 0.5170
# Epoch 74/200 | Time 2.55s | Train loss 0.9601 | Train acc 0.6146 | Val loss 1.2093 | Val acc 0.5196
# Epoch 75/200 | Time 2.55s | Train loss 0.9148 | Train acc 0.6432 | Val loss 1.5407 | Val acc 0.4856
# Epoch 76/200 | Time 2.52s | Train loss 0.9313 | Train acc 0.6335 | Val loss 1.3106 | Val acc 0.5144
# Epoch 77/200 | Time 2.88s | Train loss 0.9345 | Train acc 0.6361 | Val loss 1.3417 | Val acc 0.5222
# Epoch 78/200 | Time 2.97s | Train loss 0.9504 | Train acc 0.6120 | Val loss 1.4934 | Val acc 0.4935
# Epoch 79/200 | Time 2.53s | Train loss 0.9672 | Train acc 0.6133 | Val loss 1.1790 | Val acc 0.5117
# Epoch 80/200 | Time 2.59s | Train loss 0.9354 | Train acc 0.6191 | Val loss 1.1869 | Val acc 0.5509
# Epoch 81/200 | Time 2.53s | Train loss 0.9142 | Train acc 0.6517 | Val loss 1.2192 | Val acc 0.5274
# Epoch 82/200 | Time 2.93s | Train loss 0.9059 | Train acc 0.6419 | Val loss 1.2004 | Val acc 0.5483
# Epoch 83/200 | Time 2.90s | Train loss 0.9028 | Train acc 0.6380 | Val loss 1.2455 | Val acc 0.5379
# Epoch 84/200 | Time 2.53s | Train loss 0.9156 | Train acc 0.6367 | Val loss 1.2144 | Val acc 0.5091
# Epoch 85/200 | Time 2.53s | Train loss 0.9325 | Train acc 0.6276 | Val loss 1.2486 | Val acc 0.5405
# Epoch 86/200 | Time 2.53s | Train loss 0.9019 | Train acc 0.6413 | Val loss 1.2923 | Val acc 0.5170
# Epoch 87/200 | Time 2.98s | Train loss 0.8865 | Train acc 0.6602 | Val loss 1.4573 | Val acc 0.5117
# Epoch 88/200 | Time 2.85s | Train loss 0.8906 | Train acc 0.6556 | Val loss 1.2406 | Val acc 0.5144
# Epoch 89/200 | Time 2.51s | Train loss 0.8506 | Train acc 0.6673 | Val loss 1.3586 | Val acc 0.5039
# Epoch 90/200 | Time 2.53s | Train loss 0.8500 | Train acc 0.6569 | Val loss 1.2659 | Val acc 0.5222
# Epoch 91/200 | Time 2.55s | Train loss 0.8705 | Train acc 0.6634 | Val loss 1.5437 | Val acc 0.4883
# Epoch 92/200 | Time 3.02s | Train loss 0.8630 | Train acc 0.6523 | Val loss 1.4963 | Val acc 0.4883
# Epoch 93/200 | Time 2.77s | Train loss 0.8853 | Train acc 0.6465 | Val loss 1.1850 | Val acc 0.5117
# Epoch 94/200 | Time 2.53s | Train loss 0.8710 | Train acc 0.6543 | Val loss 1.7712 | Val acc 0.4543
# Epoch 95/200 | Time 2.56s | Train loss 0.8818 | Train acc 0.6647 | Val loss 1.4978 | Val acc 0.5013
# Epoch 96/200 | Time 2.56s | Train loss 0.8444 | Train acc 0.6608 | Val loss 1.3141 | Val acc 0.5196
# Epoch 97/200 | Time 3.10s | Train loss 0.8393 | Train acc 0.6693 | Val loss 1.4067 | Val acc 0.4804
# Epoch 98/200 | Time 2.69s | Train loss 0.8628 | Train acc 0.6647 | Val loss 1.3345 | Val acc 0.5248
# Epoch 99/200 | Time 2.56s | Train loss 0.8279 | Train acc 0.6823 | Val loss 1.3419 | Val acc 0.5222
# Epoch 100/200 | Time 2.53s | Train loss 0.8391 | Train acc 0.6725 | Val loss 1.2133 | Val acc 0.5431
# Epoch 101/200 | Time 2.54s | Train loss 0.8292 | Train acc 0.6699 | Val loss 1.2312 | Val acc 0.5170
# Epoch 102/200 | Time 3.18s | Train loss 0.8386 | Train acc 0.6686 | Val loss 1.1852 | Val acc 0.5666
# Epoch 103/200 | Time 2.62s | Train loss 0.8031 | Train acc 0.6888 | Val loss 1.2280 | Val acc 0.5248
# Epoch 104/200 | Time 2.53s | Train loss 0.8152 | Train acc 0.6764 | Val loss 1.3296 | Val acc 0.5248
# Epoch 105/200 | Time 2.57s | Train loss 0.8281 | Train acc 0.6634 | Val loss 1.3319 | Val acc 0.5196
# Epoch 106/200 | Time 2.56s | Train loss 0.8266 | Train acc 0.6712 | Val loss 1.3372 | Val acc 0.5091
# Epoch 107/200 | Time 3.26s | Train loss 0.7947 | Train acc 0.6758 | Val loss 1.2571 | Val acc 0.5170
# Epoch 108/200 | Time 2.55s | Train loss 0.7952 | Train acc 0.6882 | Val loss 1.2333 | Val acc 0.5352
# Epoch 109/200 | Time 2.53s | Train loss 0.7911 | Train acc 0.6784 | Val loss 1.3452 | Val acc 0.5274
# Epoch 110/200 | Time 2.59s | Train loss 0.7994 | Train acc 0.6784 | Val loss 1.2947 | Val acc 0.5431
# Epoch 111/200 | Time 2.61s | Train loss 0.8072 | Train acc 0.6895 | Val loss 1.3219 | Val acc 0.4987
# Epoch 112/200 | Time 3.17s | Train loss 0.8071 | Train acc 0.6784 | Val loss 1.4015 | Val acc 0.4883
# Epoch 113/200 | Time 2.55s | Train loss 0.7969 | Train acc 0.6764 | Val loss 1.2510 | Val acc 0.5196
# Epoch 114/200 | Time 2.53s | Train loss 0.7958 | Train acc 0.6842 | Val loss 1.4249 | Val acc 0.5013
# Epoch 115/200 | Time 2.55s | Train loss 0.7880 | Train acc 0.6882 | Val loss 1.4126 | Val acc 0.4935
# Epoch 116/200 | Time 2.68s | Train loss 0.7868 | Train acc 0.6908 | Val loss 1.4573 | Val acc 0.5196
# Epoch 117/200 | Time 3.14s | Train loss 0.7762 | Train acc 0.6947 | Val loss 1.2064 | Val acc 0.5170
# Epoch 118/200 | Time 2.54s | Train loss 0.7750 | Train acc 0.7012 | Val loss 1.5043 | Val acc 0.5352
# Epoch 119/200 | Time 2.53s | Train loss 0.7739 | Train acc 0.6947 | Val loss 1.3217 | Val acc 0.5013
# Epoch 120/200 | Time 2.54s | Train loss 0.7571 | Train acc 0.7051 | Val loss 1.1855 | Val acc 0.5274
# Epoch 121/200 | Time 2.74s | Train loss 0.7652 | Train acc 0.6973 | Val loss 1.2237 | Val acc 0.5248
# Epoch 122/200 | Time 3.05s | Train loss 0.7898 | Train acc 0.6966 | Val loss 1.4536 | Val acc 0.4856
# Epoch 123/200 | Time 2.53s | Train loss 0.7858 | Train acc 0.6862 | Val loss 1.3105 | Val acc 0.5144
# Epoch 124/200 | Time 2.54s | Train loss 0.7501 | Train acc 0.7142 | Val loss 1.2654 | Val acc 0.5300
# Epoch 125/200 | Time 2.54s | Train loss 0.7639 | Train acc 0.7057 | Val loss 1.2112 | Val acc 0.5692
# Epoch 126/200 | Time 2.81s | Train loss 0.7584 | Train acc 0.7044 | Val loss 1.3741 | Val acc 0.5379
# Epoch 127/200 | Time 3.00s | Train loss 0.7541 | Train acc 0.7031 | Val loss 1.3078 | Val acc 0.5274
# Epoch 128/200 | Time 2.54s | Train loss 0.7522 | Train acc 0.7122 | Val loss 1.3676 | Val acc 0.5039
# Epoch 129/200 | Time 2.56s | Train loss 0.7294 | Train acc 0.7090 | Val loss 1.3218 | Val acc 0.5300
# Epoch 130/200 | Time 2.52s | Train loss 0.7559 | Train acc 0.7109 | Val loss 1.2930 | Val acc 0.5379
# Epoch 131/200 | Time 2.87s | Train loss 0.7471 | Train acc 0.7064 | Val loss 1.2249 | Val acc 0.5300
# Epoch 132/200 | Time 2.92s | Train loss 0.7407 | Train acc 0.7057 | Val loss 1.3910 | Val acc 0.5196
# Epoch 133/200 | Time 2.56s | Train loss 0.7378 | Train acc 0.7129 | Val loss 1.2381 | Val acc 0.5274
# Epoch 134/200 | Time 2.55s | Train loss 0.7553 | Train acc 0.6992 | Val loss 1.3816 | Val acc 0.5091
# Epoch 135/200 | Time 2.53s | Train loss 0.7506 | Train acc 0.7057 | Val loss 1.3192 | Val acc 0.5144
# Epoch 136/200 | Time 2.99s | Train loss 0.7413 | Train acc 0.7135 | Val loss 1.2174 | Val acc 0.5170
# Epoch 137/200 | Time 2.84s | Train loss 0.7429 | Train acc 0.7142 | Val loss 1.3138 | Val acc 0.5379
# Epoch 138/200 | Time 2.54s | Train loss 0.7496 | Train acc 0.7109 | Val loss 1.2705 | Val acc 0.5274
# Epoch 139/200 | Time 2.53s | Train loss 0.7326 | Train acc 0.7201 | Val loss 1.2954 | Val acc 0.5222
# Epoch 140/200 | Time 2.59s | Train loss 0.7226 | Train acc 0.7194 | Val loss 1.2291 | Val acc 0.5222
# Epoch 141/200 | Time 3.03s | Train loss 0.7446 | Train acc 0.7057 | Val loss 1.3649 | Val acc 0.5248
# Epoch 142/200 | Time 2.75s | Train loss 0.7150 | Train acc 0.7220 | Val loss 1.4024 | Val acc 0.4883
# Epoch 143/200 | Time 2.54s | Train loss 0.7177 | Train acc 0.7161 | Val loss 1.3434 | Val acc 0.5170
# Epoch 144/200 | Time 2.55s | Train loss 0.7116 | Train acc 0.7188 | Val loss 1.2510 | Val acc 0.5274
# Epoch 145/200 | Time 2.58s | Train loss 0.7297 | Train acc 0.7155 | Val loss 1.4062 | Val acc 0.5170
# Epoch 146/200 | Time 3.10s | Train loss 0.7112 | Train acc 0.7259 | Val loss 1.3208 | Val acc 0.5379
# Epoch 147/200 | Time 2.69s | Train loss 0.7305 | Train acc 0.7090 | Val loss 1.3378 | Val acc 0.5117
# Epoch 148/200 | Time 2.55s | Train loss 0.7173 | Train acc 0.7279 | Val loss 1.4179 | Val acc 0.4987
# Epoch 149/200 | Time 2.54s | Train loss 0.7057 | Train acc 0.7298 | Val loss 1.3197 | Val acc 0.5248
# Epoch 150/200 | Time 2.54s | Train loss 0.7110 | Train acc 0.7389 | Val loss 1.4466 | Val acc 0.5170
# Epoch 151/200 | Time 3.18s | Train loss 0.7176 | Train acc 0.7220 | Val loss 1.5291 | Val acc 0.5065
# Epoch 152/200 | Time 2.64s | Train loss 0.6978 | Train acc 0.7383 | Val loss 1.2707 | Val acc 0.5352
# Epoch 153/200 | Time 2.53s | Train loss 0.7192 | Train acc 0.7214 | Val loss 1.4521 | Val acc 0.5248
# Epoch 154/200 | Time 2.52s | Train loss 0.6924 | Train acc 0.7266 | Val loss 1.3241 | Val acc 0.5405
# Epoch 155/200 | Time 2.52s | Train loss 0.7099 | Train acc 0.7214 | Val loss 1.3291 | Val acc 0.5326
# Epoch 156/200 | Time 3.26s | Train loss 0.7266 | Train acc 0.7194 | Val loss 1.2482 | Val acc 0.5144
# Epoch 157/200 | Time 2.59s | Train loss 0.7035 | Train acc 0.7207 | Val loss 1.3283 | Val acc 0.5222
# Epoch 158/200 | Time 2.54s | Train loss 0.7162 | Train acc 0.7298 | Val loss 1.5766 | Val acc 0.4935
# Epoch 159/200 | Time 2.53s | Train loss 0.7112 | Train acc 0.7311 | Val loss 1.2766 | Val acc 0.5300
# Epoch 160/200 | Time 2.53s | Train loss 0.7109 | Train acc 0.7207 | Val loss 1.2861 | Val acc 0.5379
# Epoch 161/200 | Time 3.26s | Train loss 0.7136 | Train acc 0.7161 | Val loss 1.4440 | Val acc 0.5039
# Epoch 162/200 | Time 2.54s | Train loss 0.7115 | Train acc 0.7135 | Val loss 1.5256 | Val acc 0.5248
# Epoch 163/200 | Time 2.54s | Train loss 0.6917 | Train acc 0.7311 | Val loss 1.2421 | Val acc 0.5535
# Epoch 164/200 | Time 2.56s | Train loss 0.7058 | Train acc 0.7240 | Val loss 1.2463 | Val acc 0.5431
# Epoch 165/200 | Time 2.62s | Train loss 0.6880 | Train acc 0.7305 | Val loss 1.2718 | Val acc 0.5300
# Epoch 166/200 | Time 3.16s | Train loss 0.6946 | Train acc 0.7376 | Val loss 1.2849 | Val acc 0.5352
# Epoch 167/200 | Time 2.56s | Train loss 0.6943 | Train acc 0.7259 | Val loss 1.3991 | Val acc 0.5144
# Epoch 168/200 | Time 2.54s | Train loss 0.7031 | Train acc 0.7207 | Val loss 1.3309 | Val acc 0.5379
# Epoch 169/200 | Time 2.55s | Train loss 0.6842 | Train acc 0.7396 | Val loss 1.3755 | Val acc 0.5013
# Epoch 170/200 | Time 2.78s | Train loss 0.6921 | Train acc 0.7396 | Val loss 1.3694 | Val acc 0.5274
# Epoch 171/200 | Time 3.10s | Train loss 0.6944 | Train acc 0.7298 | Val loss 1.4440 | Val acc 0.5170
# Epoch 172/200 | Time 2.54s | Train loss 0.6910 | Train acc 0.7357 | Val loss 1.3841 | Val acc 0.5039
# Epoch 173/200 | Time 2.53s | Train loss 0.6844 | Train acc 0.7350 | Val loss 1.5254 | Val acc 0.5144
# Epoch 174/200 | Time 2.56s | Train loss 0.6928 | Train acc 0.7409 | Val loss 1.4361 | Val acc 0.5144
# Epoch 175/200 | Time 2.77s | Train loss 0.6801 | Train acc 0.7318 | Val loss 1.4076 | Val acc 0.5222
# Epoch 176/200 | Time 3.02s | Train loss 0.6845 | Train acc 0.7318 | Val loss 1.3800 | Val acc 0.5352
# Epoch 177/200 | Time 2.55s | Train loss 0.6810 | Train acc 0.7357 | Val loss 1.3899 | Val acc 0.5352
# Epoch 178/200 | Time 2.54s | Train loss 0.6813 | Train acc 0.7409 | Val loss 1.4264 | Val acc 0.4961
# Epoch 179/200 | Time 2.53s | Train loss 0.6975 | Train acc 0.7370 | Val loss 1.2617 | Val acc 0.5535
# Epoch 180/200 | Time 2.83s | Train loss 0.6918 | Train acc 0.7324 | Val loss 1.3983 | Val acc 0.5196
# Epoch 181/200 | Time 2.95s | Train loss 0.6787 | Train acc 0.7441 | Val loss 1.3746 | Val acc 0.5274
# Epoch 182/200 | Time 2.53s | Train loss 0.6784 | Train acc 0.7487 | Val loss 1.3691 | Val acc 0.5222
# Epoch 183/200 | Time 2.55s | Train loss 0.6758 | Train acc 0.7487 | Val loss 1.4152 | Val acc 0.5196
# Epoch 184/200 | Time 2.53s | Train loss 0.6820 | Train acc 0.7376 | Val loss 1.4218 | Val acc 0.5326
# Epoch 185/200 | Time 2.93s | Train loss 0.6717 | Train acc 0.7435 | Val loss 1.2942 | Val acc 0.5170
# Epoch 186/200 | Time 2.88s | Train loss 0.6788 | Train acc 0.7305 | Val loss 1.3172 | Val acc 0.5352
# Epoch 187/200 | Time 2.54s | Train loss 0.6721 | Train acc 0.7409 | Val loss 1.3701 | Val acc 0.5431
# Epoch 188/200 | Time 2.53s | Train loss 0.6712 | Train acc 0.7357 | Val loss 1.3609 | Val acc 0.5222
# Epoch 189/200 | Time 2.53s | Train loss 0.6745 | Train acc 0.7513 | Val loss 1.4028 | Val acc 0.4961
# Epoch 190/200 | Time 2.99s | Train loss 0.6704 | Train acc 0.7500 | Val loss 1.2927 | Val acc 0.5379
# Epoch 191/200 | Time 2.82s | Train loss 0.6613 | Train acc 0.7448 | Val loss 1.3027 | Val acc 0.5274
# Epoch 192/200 | Time 2.52s | Train loss 0.6860 | Train acc 0.7422 | Val loss 1.4077 | Val acc 0.5274
# Epoch 193/200 | Time 2.54s | Train loss 0.6747 | Train acc 0.7383 | Val loss 1.3501 | Val acc 0.5274
# Epoch 194/200 | Time 2.54s | Train loss 0.6636 | Train acc 0.7474 | Val loss 1.3573 | Val acc 0.5352
# Epoch 195/200 | Time 3.04s | Train loss 0.6610 | Train acc 0.7513 | Val loss 1.3560 | Val acc 0.5352
# Epoch 196/200 | Time 2.73s | Train loss 0.6784 | Train acc 0.7376 | Val loss 1.4487 | Val acc 0.5144
# Epoch 197/200 | Time 2.55s | Train loss 0.6618 | Train acc 0.7480 | Val loss 1.3012 | Val acc 0.5326
# Epoch 198/200 | Time 2.53s | Train loss 0.6759 | Train acc 0.7370 | Val loss 1.4011 | Val acc 0.5326
# Epoch 199/200 | Time 2.54s | Train loss 0.6641 | Train acc 0.7435 | Val loss 1.3531 | Val acc 0.5431
# Epoch 200/200 | Time 3.09s | Train loss 0.6693 | Train acc 0.7441 | Val loss 1.4099 | Val acc 0.5248
# Training finished. Best epoch: 72. Best monitored metric: 1.1573
# Final model saved to: /content/drive/MyDrive/PainRecognitionProject/models/testing_new_code_emotions_100_distances_6_classes_val_loss.pt
# Best model saved to: /content/drive/MyDrive/PainRecognitionProject/models/best_testing_new_code_emotions_100_distances_6_classes_val_loss.pt

# %%
trainer.plot_history()

# %% [markdown]
# #### Evaluate

# %%
model.load_state_dict(torch.load(best_model_path, map_location=DEVICE), strict=False)
# Out:
# <All keys matched successfully>

# %%
evaluator = Evaluator(model, test_loader, device=DEVICE, model_name=model_name, num_classes=NUM_CLASSES)

# %%
loss, acc, labels, preds = evaluator.evaluate_epoch()
# Out:
# ==================================================
# WYNIKI OCENY DLA MODELU: testing_new_code_emotions_100_distances_6_classes_val_loss.pt
# ==================================================
# Test Loss: 1.4352
# Test Accuracy: 0.5052
#
# --- Szczegółowy Raport Klasyfikacji ---
#               precision    recall  f1-score   support
#
#      Klasa 0       0.63      0.42      0.50        64
#      Klasa 1       0.95      0.56      0.71        64
#      Klasa 2       0.56      0.69      0.62        64
#      Klasa 3       0.58      0.69      0.63        64
#      Klasa 4       0.33      0.56      0.42        64
#      Klasa 5       0.17      0.11      0.13        64
#
#     accuracy                           0.51       384
#    macro avg       0.54      0.51      0.50       384
# weighted avg       0.54      0.51      0.50       384
#
# ==================================================
# Confusion matrix:
#  [[27  0 19  0 14  4]
#  [ 6 36  0  0  2 20]
#  [ 0  0 44 10  8  2]
#  [ 0  0  0 44 20  0]
#  [10  0  1 10 36  7]
#  [ 0  2 15 12 28  7]]
