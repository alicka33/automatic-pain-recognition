# %% [markdown]
# ### Bi-LSTM model - multiclass - 1434 coordinates

# %% [markdown]
# #### Environment preparation

# %%
from google.colab import drive
drive.mount('/content/drive')

COLAB_ROOT = '/content/drive/MyDrive/PainRecognitionProject/'
print(f"Dane będą wczytywane z: {COLAB_ROOT}")
# Out:
# Mounted at /content/drive
# Dane będą wczytywane z: /content/drive/MyDrive/PainRecognitionProject/

# %%
import os

# %cd /content

# !rm -rf automatic-pain-recognition

print(f"Obecne położenie: {os.getcwd()}")
# Out:
# /content
# Obecne położenie: /content

# %%
USERNAME = 'alicka33'
REPO_NAME = 'automatic-pain-recognition'

REPO_URL = f"https://github.com/{USERNAME}/{REPO_NAME}.git"

print("Rozpoczynam klonowanie...")

# !git clone {REPO_URL}

# %cd $REPO_NAME
# Out:
# Rozpoczynam klonowanie...
# Cloning into 'automatic-pain-recognition'...
# remote: Enumerating objects: 313, done.
# remote: Counting objects: 100% (36/36), done.
# remote: Compressing objects: 100% (22/22), done.
# remote: Total 313 (delta 23), reused 27 (delta 14), pack-reused 277 (from 1)
# Receiving objects: 100% (313/313), 11.57 MiB | 34.34 MiB/s, done.
# Resolving deltas: 100% (147/147), done.
# /content/automatic-pain-recognition

# %%
# !pip install -r requirements.txt

# %%
import sys
import os

sys.path.append(os.getcwd())
print(f"Dodano do ścieżki Pythona: {os.getcwd()}")
# Out:
# Dodano do ścieżki Pythona: /content/automatic-pain-recognition

# %% [markdown]
# #### Bi-LSTM model - multiclas training

# %%
import os
import numpy as np
import pandas as pd
import shutil

import torch
import torch.nn as nn
from torch.utils.data import DataLoader
from torch.optim.lr_scheduler import ReduceLROnPlateau

from training_utils.preprocessed_dataset import PreprocessedDataset
from training_utils.train import Trainer
from training_utils.evaluate import Evaluator
from models.Bi_LSTM import SequenceModel

# %%
MAX_SEQUENCE_LENGTH = 46
NUM_FEATURES = 1434
NUM_CLASSES = 5
HIDDEN_SIZE = 128
NUM_LAYERS = 2
NUM_EPOCHS = 200
BATCH_SIZE = 16
LEARNING_RATE = 0.00005
DROPOUT_PROB = 0.3
WEIGHT_DECAY = 0.005
SCHEDULER_FACTOR = 0.9

# %% [markdown]
# #### Data preparation

# %%
COLAB_ROOT = '/content/drive/MyDrive/PainRecognitionProject/'
PROCESSED_DATA_DIR = os.path.join(COLAB_ROOT, 'data/BioVid_HeatPain_processed_478_xyz_frontalized/')
MODEL_SAVE_DIR = os.path.join(COLAB_ROOT, 'models/')
LOCAL_PROCESSED_DATA_ROOT = '/content/temp_data/'

DEVICE = torch.device("cuda" if torch.cuda.is_available() else "cpu")

# %%
print("Kopiowanie danych z Google Drive do lokalnej pamięci Colab (RAM)...")
if os.path.exists(LOCAL_PROCESSED_DATA_ROOT):
    shutil.rmtree(LOCAL_PROCESSED_DATA_ROOT)
try:
    shutil.copytree(PROCESSED_DATA_DIR, LOCAL_PROCESSED_DATA_ROOT)
    print("✅ Kopiowanie zakończone pomyślnie. Czas trwania: (sprawdź zegar)")
    CURRENT_DATA_DIR = LOCAL_PROCESSED_DATA_ROOT

except Exception as e:
    print(f"❌ Błąd kopiowania danych (sprawdź, czy dane są zamontowane): {e}")
    print("Używam danych bezpośrednio z Drive (może się zawiesić).")
    CURRENT_DATA_DIR = PROCESSED_DATA_DIR
# Out:
# Kopiowanie danych z Google Drive do lokalnej pamięci Colab (RAM)...
# ✅ Kopiowanie zakończone pomyślnie. Czas trwania: (sprawdź zegar)

# %%
best100 = np.load('/content/drive/MyDrive/PainRecognitionProject/data/top_100_important_landmarks_emotions.npy')

# %%
train_dataset = PreprocessedDataset(
    'train',
    processed_data_dir=CURRENT_DATA_DIR,
    indices=None,
    compute_euclidean=False,
    center_point_index=2,
    max_sequence_length=MAX_SEQUENCE_LENGTH,
    selected_labels=None,
    label_map=None,
)

val_dataset = PreprocessedDataset(
    'val',
    processed_data_dir=CURRENT_DATA_DIR,
    indices=None,
    compute_euclidean=False,
    center_point_index=2,
    max_sequence_length=MAX_SEQUENCE_LENGTH,
    selected_labels=None,
    label_map=None,
)

test_dataset = PreprocessedDataset(
    'test',
    processed_data_dir=CURRENT_DATA_DIR,
    indices=None,
    compute_euclidean=False,
    center_point_index=2,
    max_sequence_length=MAX_SEQUENCE_LENGTH,
    selected_labels=None,
    label_map=None,
)

# %%
def preview_single(dataset, idx=0, timesteps_to_show=3, features_to_show=8):
    x, y = dataset[idx]
    print(f"\nSingle sample idx={idx} from split={dataset.dataset_name}")
    print(f"x shape: {tuple(x.shape)}, y: {y}")
    print(np.round(x[:timesteps_to_show, :features_to_show], 4))

preview_single(train_dataset, 0)
preview_single(val_dataset, 0)
preview_single(test_dataset, 0)
# Out:
# Single sample idx=0 from split=train
# x shape: (46, 1434), y: 0
# tensor([[ 0.0166,  0.1003,  0.0049,  0.0033, -0.0350, -0.0782,  0.0000,  0.0000],
#         [ 0.0074,  0.0975,  0.0028,  0.0024, -0.0366, -0.0783,  0.0000,  0.0000],
#         [ 0.0077,  0.0955,  0.0037,  0.0022, -0.0362, -0.0781,  0.0000,  0.0000]])
#
# Single sample idx=0 from split=val
# x shape: (46, 1434), y: 0
# tensor([[ 0.0002,  0.1079,  0.0064,  0.0040, -0.0341, -0.0773,  0.0000,  0.0000],
#         [-0.0022,  0.1043,  0.0072,  0.0032, -0.0341, -0.0777,  0.0000,  0.0000],
#         [-0.0005,  0.1048,  0.0073,  0.0031, -0.0340, -0.0774,  0.0000,  0.0000]])
#
# Single sample idx=0 from split=test
# x shape: (46, 1434), y: 0
# tensor([[ 0.0002,  0.0989,  0.0039,  0.0052, -0.0319, -0.0745,  0.0000,  0.0000],
#         [-0.0045,  0.0965,  0.0040,  0.0047, -0.0339, -0.0747,  0.0000,  0.0000],
#         [-0.0028,  0.0980,  0.0043,  0.0052, -0.0344, -0.0745,  0.0000,  0.0000]])

# %%
train_loader = DataLoader(train_dataset, batch_size=BATCH_SIZE, shuffle=True, num_workers=0, pin_memory=True)
for X, y in train_loader:
    print(X.shape, y.shape)  # (B, T_max, num_features)
    break

val_loader = DataLoader(val_dataset, batch_size=BATCH_SIZE, shuffle=True, num_workers=0, pin_memory=True)
for X, y in val_loader:
    print(X.shape, y.shape)  # (B, T_max, num_features)
    break

test_loader = DataLoader(test_dataset, batch_size=BATCH_SIZE, shuffle=True, num_workers=0, pin_memory=True)
for X, y in test_loader:
    print(X.shape, y.shape)  # (B, T_max, num_features)
    break
# Out:
# torch.Size([16, 46, 1434]) torch.Size([16])
# torch.Size([16, 46, 1434]) torch.Size([16])
# torch.Size([16, 46, 1434]) torch.Size([16])

# %% [markdown]
# #### Model preparation

# %%
model = SequenceModel(NUM_FEATURES, HIDDEN_SIZE, NUM_LAYERS, NUM_CLASSES, DROPOUT_PROB).to(DEVICE)

# %% [markdown]
# #### Training

# %%
criterion = nn.CrossEntropyLoss()
optimizer = torch.optim.AdamW(model.parameters(), lr=LEARNING_RATE, weight_decay=WEIGHT_DECAY)

scheduler = ReduceLROnPlateau(
    optimizer,
    mode='max',
    factor=SCHEDULER_FACTOR,
    patience=10,
    min_lr=1e-7
)

model_name = 'testing_new_code_bi_lstm_5_classes_1434_coord.pt'
model_filepath = os.path.join(MODEL_SAVE_DIR, model_name)

# %%
trainer = Trainer(
    model=model,
    train_loader=train_loader,
    val_loader=val_loader,
    optimizer=optimizer,
    scheduler=scheduler,
    criterion=criterion,
    device=DEVICE,
    model_save_path=model_filepath,
    num_epochs=NUM_EPOCHS,
    monitor='val_acc',  # or 'val_loss'
    minimize_monitor=False,
    save_best_only=True
)

# %%
trainer.print_training_config()
# Out:
# ==================================================
# 🚀 TRAINING CONFIGURATION
# ==================================================
#
# --- Model Architecture ---
#   Model Type            : SequenceModel
#   Input Features        : 1434
#   Hidden Size           : 128
#   Num Layers            : 2
#   Bidirectional         : True
#   Dropout (LSTM)        : 0.3
#   Num Parameters        : 1998085
#
# --- Optimizer & Regularization ---
#   Optimizer             : AdamW
#   Learning Rate (LR)    : 5e-05
#   Weight Decay (L2)     : 0.005
#
# --- Training Flow ---
#   Batch Size            : 16
#   Num Epochs            : 200
#   Device                : cuda
# ==================================================

# %%
final_model_path, best_model_path, history = trainer.fit()
print(f"Final model saved to: {final_model_path}")
if best_model_path:
    print(f"Best model saved to: {best_model_path}")
# Out:
# Starting training for 200 epochs on cuda
# Saved best model to /content/drive/MyDrive/PainRecognitionProject/models/best_testing_new_code_bi_lstm_5_classes_1434_coord.pt (metric=0.1977)
# Epoch 1/200 | Time 16.87s | Train loss 1.6112 | Train acc 0.1949 | Val loss 1.6101 | Val acc 0.1977
# Saved best model to /content/drive/MyDrive/PainRecognitionProject/models/best_testing_new_code_bi_lstm_5_classes_1434_coord.pt (metric=0.2000)
# Epoch 2/200 | Time 11.02s | Train loss 1.6098 | Train acc 0.2043 | Val loss 1.6110 | Val acc 0.2000
# Epoch 3/200 | Time 6.37s | Train loss 1.6113 | Train acc 0.1959 | Val loss 1.6096 | Val acc 0.1969
# Epoch 4/200 | Time 6.02s | Train loss 1.6108 | Train acc 0.1949 | Val loss 1.6099 | Val acc 0.2000
# Epoch 5/200 | Time 5.91s | Train loss 1.6101 | Train acc 0.2020 | Val loss 1.6095 | Val acc 0.2000
# Epoch 6/200 | Time 6.16s | Train loss 1.6103 | Train acc 0.1982 | Val loss 1.6093 | Val acc 0.2000
# Saved best model to /content/drive/MyDrive/PainRecognitionProject/models/best_testing_new_code_bi_lstm_5_classes_1434_coord.pt (metric=0.2062)
# Epoch 7/200 | Time 5.84s | Train loss 1.6096 | Train acc 0.2048 | Val loss 1.6102 | Val acc 0.2062
# Epoch 8/200 | Time 6.45s | Train loss 1.6108 | Train acc 0.1980 | Val loss 1.6094 | Val acc 0.2023
# Saved best model to /content/drive/MyDrive/PainRecognitionProject/models/best_testing_new_code_bi_lstm_5_classes_1434_coord.pt (metric=0.2200)
# Epoch 9/200 | Time 5.72s | Train loss 1.6101 | Train acc 0.1984 | Val loss 1.6093 | Val acc 0.2200
# Epoch 10/200 | Time 6.45s | Train loss 1.6095 | Train acc 0.1939 | Val loss 1.6096 | Val acc 0.2000
# Epoch 11/200 | Time 5.71s | Train loss 1.6098 | Train acc 0.2003 | Val loss 1.6092 | Val acc 0.2000
# Saved best model to /content/drive/MyDrive/PainRecognitionProject/models/best_testing_new_code_bi_lstm_5_classes_1434_coord.pt (metric=0.2262)
# Epoch 12/200 | Time 6.43s | Train loss 1.6090 | Train acc 0.2046 | Val loss 1.6087 | Val acc 0.2262
# Epoch 13/200 | Time 5.78s | Train loss 1.6091 | Train acc 0.2103 | Val loss 1.6088 | Val acc 0.2054
# Epoch 14/200 | Time 6.33s | Train loss 1.6082 | Train acc 0.2080 | Val loss 1.6088 | Val acc 0.2015
# Epoch 15/200 | Time 5.88s | Train loss 1.6083 | Train acc 0.2089 | Val loss 1.6072 | Val acc 0.2108
# Epoch 16/200 | Time 6.04s | Train loss 1.6032 | Train acc 0.2218 | Val loss 1.6011 | Val acc 0.2208
# Epoch 17/200 | Time 6.11s | Train loss 1.6027 | Train acc 0.2257 | Val loss 1.6076 | Val acc 0.2054
# Epoch 18/200 | Time 5.78s | Train loss 1.6036 | Train acc 0.2151 | Val loss 1.5968 | Val acc 0.2254
# Epoch 19/200 | Time 6.31s | Train loss 1.5990 | Train acc 0.2228 | Val loss 1.5982 | Val acc 0.2254
# Saved best model to /content/drive/MyDrive/PainRecognitionProject/models/best_testing_new_code_bi_lstm
# Epoch 187/200 | Time 6.50s | Train loss 1.5170 | Train acc 0.2800 | Val loss 1.6174 | Val acc 0.2492
# Epoch 188/200 | Time 5.75s | Train loss 1.5171 | Train acc 0.2838 | Val loss 1.5825 | Val acc 0.2438
# Epoch 189/200 | Time 6.34s | Train loss 1.5178 | Train acc 0.2921 | Val loss 1.5783 | Val acc 0.2346
# Epoch 190/200 | Time 5.78s | Train loss 1.5196 | Train acc 0.2874 | Val loss 1.5742 | Val acc 0.2438
# Epoch 191/200 | Time 6.32s | Train loss 1.5193 | Train acc 0.2811 | Val loss 1.5933 | Val acc 0.2346
# Epoch 192/200 | Time 5.77s | Train loss 1.5207 | Train acc 0.2884 | Val loss 1.5833 | Val acc 0.2408
# Epoch 193/200 | Time 6.23s | Train loss 1.5125 | Train acc 0.2836 | Val loss 1.5839 | Val acc 0.2431
# Epoch 194/200 | Time 5.90s | Train loss 1.5103 | Train acc 0.2851 | Val loss 1.5852 | Val acc 0.2408
# Epoch 195/200 | Time 6.17s | Train loss 1.5163 | Train acc 0.2902 | Val loss 1.6149 | Val acc 0.2562
# Epoch 196/200 | Time 6.04s | Train loss 1.5134 | Train acc 0.2864 | Val loss 1.6095 | Val acc 0.2423
# Epoch 197/200 | Time 5.82s | Train loss 1.5162 | Train acc 0.2852 | Val loss 1.5993 | Val acc 0.2400
# Epoch 198/200 | Time 6.30s | Train loss 1.5152 | Train acc 0.2774 | Val loss 1.6017 | Val acc 0.2415
# Epoch 199/200 | Time 5.75s | Train loss 1.5157 | Train acc 0.2802 | Val loss 1.5863 | Val acc 0.2392
# Epoch 200/200 | Time 6.34s | Train loss 1.5133 | Train acc 0.2857 | Val loss 1.5868 | Val acc 0.2415
# Training finished. Best epoch: 158. Best monitored metric: 0.2638
# Final model saved to: /content/drive/MyDrive/PainRecognitionProject/models/testing_new_code_bi_lstm_5_classes_1434_coord.pt
# Best model saved to: /content/drive/MyDrive/PainRecognitionProject/models/best_testing_new_code_bi_lstm_5_classes_1434_coord.pt

# %%
trainer.plot_history()

# %% [markdown]
# #### Evaluate

# %%
model.load_state_dict(torch.load(best_model_path, map_location=DEVICE), strict=False)
# Out:
# <All keys matched successfully>

# %%
evaluator = Evaluator(model, test_loader, device=DEVICE, model_name=model_name, num_classes=NUM_CLASSES)

# %%
loss, acc, labels, preds = evaluator.evaluate_epoch()
# Out:
# ==================================================
# WYNIKI OCENY DLA MODELU: testing_new_code_bi_lstm_5_classes_1434_coord.pt
# ==================================================
# Test Loss: 1.6264
# Test Accuracy: 0.2677
#
# --- Szczegółowy Raport Klasyfikacji ---
#               precision    recall  f1-score   support
#
#      Klasa 0       0.24      0.57      0.34       260
#      Klasa 1       0.19      0.04      0.07       260
#      Klasa 2       0.26      0.12      0.16       260
#      Klasa 3       0.13      0.07      0.09       260
#      Klasa 4       0.38      0.53      0.44       260
#
#     accuracy                           0.27      1300
#    macro avg       0.24      0.27      0.22      1300
# weighted avg       0.24      0.27      0.22      1300
#
# ==================================================
# Confusion matrix:
#  [[149  11  32  38  30]
#  [142  11  32  32  43]
#  [127  12  31  28  62]
#  [116  16  16  19  93]
#  [ 81   7   8  26 138]]
