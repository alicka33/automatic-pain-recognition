# %% [markdown]
# ### STA-LSTM model - binary training - 1434 coordinates

# %% [markdown]
# #### Enviroment preparation

# %%
from google.colab import drive
drive.mount('/content/drive')

COLAB_ROOT = '/content/drive/MyDrive/PainRecognitionProject/'
print(f"Dane będą wczytywane z: {COLAB_ROOT}")
# Out:
# Mounted at /content/drive
# Dane będą wczytywane z: /content/drive/MyDrive/PainRecognitionProject/

# %%
import os

# %cd /content

# !rm -rf automatic-pain-recognition

print(f"Obecne położenie: {os.getcwd()}")
# Out:
# /content
# Obecne położenie: /content

# %%
USERNAME = 'alicka33'
REPO_NAME = 'automatic-pain-recognition'

REPO_URL = f"https://github.com/{USERNAME}/{REPO_NAME}.git"

print("Rozpoczynam klonowanie...")

# !git clone {REPO_URL}

# %cd $REPO_NAME
# Out:
# Rozpoczynam klonowanie...
# Cloning into 'automatic-pain-recognition'...
# remote: Enumerating objects: 313, done.
# remote: Counting objects: 100% (36/36), done.
# remote: Compressing objects: 100% (22/22), done.
# remote: Total 313 (delta 23), reused 27 (delta 14), pack-reused 277 (from 1)
# Receiving objects: 100% (313/313), 11.57 MiB | 30.85 MiB/s, done.
# Resolving deltas: 100% (147/147), done.
# /content/automatic-pain-recognition

# %%
# !pip install -r requirements.txt

# %%
import sys
import os

sys.path.append(os.getcwd())
print(f"Dodano do ścieżki Pythona: {os.getcwd()}")
# Out:
# Dodano do ścieżki Pythona: /content/automatic-pain-recognition

# %% [markdown]
# #### STA-LSTM model - binary training

# %%
import os
import numpy as np
import pandas as pd
import shutil

import torch
import torch.nn as nn
from torch.utils.data import DataLoader
from torch.optim.lr_scheduler import ReduceLROnPlateau

from training_utils.preprocessed_dataset import PreprocessedDataset
from training_utils.train import Trainer
from training_utils.evaluate import Evaluator
from models.STA_LSTM import STA_LSTM

# %% [markdown]
# #### Hiperparameters

# %%
MAX_SEQUENCE_LENGTH = 46
NUM_FEATURES = 1434
NUM_CLASSES = 2
HIDDEN_SIZE = 128
NUM_LAYERS = 2
NUM_EPOCHS = 200
BATCH_SIZE = 16
LEARNING_RATE = 0.001
DROPOUT_PROB = 0.2
WEIGHT_DECAY = 0.0001
SCHEDULER_FACTOR = 0.9

# %% [markdown]
# #### Data preparation

# %%
COLAB_ROOT = '/content/drive/MyDrive/PainRecognitionProject/'
PROCESSED_DATA_DIR = os.path.join(COLAB_ROOT, 'data/BioVid_HeatPain_processed_478_xyz_frontalized/')
MODEL_SAVE_DIR = os.path.join(COLAB_ROOT, 'models/')
LOCAL_PROCESSED_DATA_ROOT = '/content/temp_data/'

DEVICE = torch.device("cuda" if torch.cuda.is_available() else "cpu")

# %%
print("Kopiowanie danych z Google Drive do lokalnej pamięci Colab (RAM)...")
if os.path.exists(LOCAL_PROCESSED_DATA_ROOT):
    shutil.rmtree(LOCAL_PROCESSED_DATA_ROOT)
try:
    shutil.copytree(PROCESSED_DATA_DIR, LOCAL_PROCESSED_DATA_ROOT)
    print("Kopiowanie zakończone pomyślnie. Czas trwania: (sprawdź zegar)")
    CURRENT_DATA_DIR = LOCAL_PROCESSED_DATA_ROOT

except Exception as e:
    print(f"Błąd kopiowania danych (sprawdź, czy dane są zamontowane): {e}")
    print("Używam danych bezpośrednio z Drive (może się zawiesić).")
    CURRENT_DATA_DIR = PROCESSED_DATA_DIR

# %%
train_dataset = PreprocessedDataset(
    'train',
    processed_data_dir=CURRENT_DATA_DIR,
    indices=None,
    compute_euclidean=False,
    center_point_index=2,
    max_sequence_length=MAX_SEQUENCE_LENGTH,
    selected_labels=[0, 4],
    label_map={0: 0, 4: 1},
)

val_dataset = PreprocessedDataset(
    'val',
    processed_data_dir=CURRENT_DATA_DIR,
    indices=None,
    compute_euclidean=False,
    center_point_index=2,
    max_sequence_length=MAX_SEQUENCE_LENGTH,
    selected_labels=[0, 4],
    label_map={0: 0, 4: 1},
)

test_dataset = PreprocessedDataset(
    'test',
    processed_data_dir=CURRENT_DATA_DIR,
    indices=None,
    compute_euclidean=False,
    center_point_index=2,
    max_sequence_length=MAX_SEQUENCE_LENGTH,
    selected_labels=[0, 4],
    label_map={0: 0, 4: 1},
)

# %%
def preview_single(dataset, idx=0, timesteps_to_show=3, features_to_show=8):
    x, y = dataset[idx]
    print(f"\nSingle sample idx={idx} from split={dataset.dataset_name}")
    print(f"x shape: {tuple(x.shape)}, y: {y}")
    print(np.round(x[:timesteps_to_show, :features_to_show], 4))

preview_single(train_dataset, 0)
preview_single(val_dataset, 0)
preview_single(test_dataset, 0)
# Out:
# Single sample idx=0 from split=train
# x shape: (46, 1434), y: 0
# tensor([[ 0.0166,  0.1003,  0.0049,  0.0033, -0.0350, -0.0782,  0.0000,  0.0000],
#         [ 0.0074,  0.0975,  0.0028,  0.0024, -0.0366, -0.0783,  0.0000,  0.0000],
#         [ 0.0077,  0.0955,  0.0037,  0.0022, -0.0362, -0.0781,  0.0000,  0.0000]])
#
# Single sample idx=0 from split=val
# x shape: (46, 1434), y: 0
# tensor([[ 0.0002,  0.1079,  0.0064,  0.0040, -0.0341, -0.0773,  0.0000,  0.0000],
#         [-0.0022,  0.1043,  0.0072,  0.0032, -0.0341, -0.0777,  0.0000,  0.0000],
#         [-0.0005,  0.1048,  0.0073,  0.0031, -0.0340, -0.0774,  0.0000,  0.0000]])
#
# Single sample idx=0 from split=test
# x shape: (46, 1434), y: 0
# tensor([[ 0.0002,  0.0989,  0.0039,  0.0052, -0.0319, -0.0745,  0.0000,  0.0000],
#         [-0.0045,  0.0965,  0.0040,  0.0047, -0.0339, -0.0747,  0.0000,  0.0000],
#         [-0.0028,  0.0980,  0.0043,  0.0052, -0.0344, -0.0745,  0.0000,  0.0000]])

# %%
train_loader = DataLoader(train_dataset, batch_size=BATCH_SIZE, shuffle=True, num_workers=0, pin_memory=True)
for X, y in train_loader:
    print(X.shape, y.shape)  # (B, T_max, num_features)
    break

val_loader = DataLoader(val_dataset, batch_size=BATCH_SIZE, shuffle=True, num_workers=0, pin_memory=True)
for X, y in val_loader:
    print(X.shape, y.shape)  # (B, T_max, num_features)
    break

test_loader = DataLoader(test_dataset, batch_size=BATCH_SIZE, shuffle=True, num_workers=0, pin_memory=True)
for X, y in test_loader:
    print(X.shape, y.shape)  # (B, T_max, num_features)
    break
# Out:
# torch.Size([16, 46, 1434]) torch.Size([16])
# torch.Size([16, 46, 1434]) torch.Size([16])
# torch.Size([16, 46, 1434]) torch.Size([16])

# %% [markdown]
# #### Model preparation

# %%
model = STA_LSTM(NUM_FEATURES, HIDDEN_SIZE, NUM_LAYERS, NUM_CLASSES, DROPOUT_PROB).to(DEVICE)

# %% [markdown]
# #### Training

# %%
criterion = nn.CrossEntropyLoss()
optimizer = torch.optim.AdamW(model.parameters(), lr=LEARNING_RATE, weight_decay=WEIGHT_DECAY)

scheduler = ReduceLROnPlateau(
    optimizer,
    mode='max',
    factor=SCHEDULER_FACTOR,
    patience=10,
    min_lr=1e-7
)

model_name = 'testing_new_code_sta_lstm_2_classes_v2.pt'
model_filepath = os.path.join(MODEL_SAVE_DIR, model_name)

# %%
trainer = Trainer(
    model=model,
    train_loader=train_loader,
    val_loader=val_loader,
    optimizer=optimizer,
    scheduler=scheduler,
    criterion=criterion,
    device=DEVICE,
    model_save_path=model_filepath,
    num_epochs=NUM_EPOCHS,
    monitor='val_acc',  # or 'val_loss'
    minimize_monitor=False,
    save_best_only=True
)

# %%
trainer.print_training_config()

# %%
final_model_path, best_model_path, history = trainer.fit()
print(f"Final model saved to: {final_model_path}")
if best_model_path:
    print(f"Best model saved to: {best_model_path}")
# Out:
# Starting training for 200 epochs on cuda
# Saved best model to /content/drive/MyDrive/PainRecognitionProject/models/best_testing_new_code_sta_lstm_2_classes_v2.pt (metric=0.5019)
# Epoch 1/200 | Time 9.22s | Train loss 0.7502 | Train acc 0.5037 | Val loss 0.6944 | Val acc 0.5019
# Epoch 2/200 | Time 3.55s | Train loss 0.7132 | Train acc 0.4881 | Val loss 0.7011 | Val acc 0.5000
# Epoch 3/200 | Time 2.85s | Train loss 0.7035 | Train acc 0.5000 | Val loss 0.7102 | Val acc 0.5000
# Epoch 4/200 | Time 3.19s | Train loss 0.7128 | Train acc 0.4955 | Val loss 0.6979 | Val acc 0.5000
# Epoch 5/200 | Time 2.56s | Train loss 0.7085 | Train acc 0.5123 | Val loss 0.7169 | Val acc 0.5000
# Epoch 6/200 | Time 2.52s | Train loss 0.7064 | Train acc 0.4930 | Val loss 0.7031 | Val acc 0.5000
# Epoch 7/200 | Time 2.56s | Train loss 0.7030 | Train acc 0.4930 | Val loss 0.6978 | Val acc 0.5000
# Epoch 8/200 | Time 2.74s | Train loss 0.7055 | Train acc 0.4963 | Val loss 0.7153 | Val acc 0.5000
# Epoch 9/200 | Time 3.19s | Train loss 0.7088 | Train acc 0.4750 | Val loss 0.6939 | Val acc 0.5000
# Saved best model to /content/drive/MyDrive/PainRecognitionProject/models/best_testing_new_code_sta_lstm_2_classes_v2.pt (metric=0.5885)
# Epoch 10/200 | Time 2.55s | Train loss 0.7033 | Train acc 0.4959 | Val loss 0.6930 | Val acc 0.5885
# Epoch 11/200 | Time 2.56s | Train loss 0.7039 | Train acc 0.4902 | Val loss 0.6952 | Val acc 0.5000
# Epoch 12/200 | Time 2.62s | Train loss 0.6979 | Train acc 0.5082 | Val loss 0.7077 | Val acc 0.5000
# Epoch 13/200 | Time 2.78s | Train loss 0.7013 | Train acc 0.5102 | Val loss 0.7137 | Val acc 0.5000
# Epoch 14/200 | Time 3.07s | Train loss 0.6985 | Train acc 0.5061 | Val loss 0.6924 | Val acc 0.5000
# Epoch 15/200 | Time 2.54s | Train loss 0.7027 | Train acc 0.5057 | Val loss 0.7007 | Val acc 0.5000
# Epoch 16/200 | Time 2.50s | Train loss 0.7056 | Train acc 0.5049 | Val loss 0.6899 | Val acc 0.4981
# Epoch 17/200 | Time 2.53s | Train loss 0.7042 | Train acc 0.4959 | Val loss 0.6914 | Val acc 0.5058
# Epoch 18/200 | Time 2.86s | Train loss 0.7003 | Train acc 0.5242 | Val loss 0.7441 | Val acc 0.5000
# Epoch 19/200 | Time 3.06s | Train loss 0.7015 | Train acc 0.5246 | Val loss 0.7094 | Val acc 0.5173
# Epoch 20/200 | Time 2.57s | Train loss 0.6931 | Train acc 0.5311 | Val loss 0.6860 | Val acc 0.5019
# Epoch 21/200 | Time 2.54s | Train loss 0.6952 | Train acc 0.5344 | Val loss 0.6950 | Val acc 0.5000
# Epoch 186/200 | Time 2.54s | Train loss 0.5336 | Train acc 0.7164 | Val loss 0.5659 | Val acc 0.7115
# Epoch 187/200 | Time 2.78s | Train loss 0.5332 | Train acc 0.7266 | Val loss 0.5642 | Val acc 0.7038
# Epoch 188/200 | Time 3.04s | Train loss 0.5360 | Train acc 0.7221 | Val loss 0.5658 | Val acc 0.7154
# Epoch 189/200 | Time 2.55s | Train loss 0.5272 | Train acc 0.7189 | Val loss 0.5815 | Val acc 0.7250
# Epoch 190/200 | Time 2.52s | Train loss 0.5295 | Train acc 0.7262 | Val loss 0.5814 | Val acc 0.7019
# Epoch 191/200 | Time 2.51s | Train loss 0.5321 | Train acc 0.7131 | Val loss 0.5761 | Val acc 0.6981
# Epoch 192/200 | Time 2.85s | Train loss 0.5323 | Train acc 0.7205 | Val loss 0.5822 | Val acc 0.7231
# Epoch 193/200 | Time 2.99s | Train loss 0.5270 | Train acc 0.7303 | Val loss 0.5713 | Val acc 0.7231
# Epoch 194/200 | Time 2.51s | Train loss 0.5259 | Train acc 0.7250 | Val loss 0.5716 | Val acc 0.7308
# Epoch 195/200 | Time 2.52s | Train loss 0.5228 | Train acc 0.7270 | Val loss 0.5709 | Val acc 0.7154
# Epoch 196/200 | Time 2.50s | Train loss 0.5240 | Train acc 0.7254 | Val loss 0.5702 | Val acc 0.7115
# Epoch 197/200 | Time 2.90s | Train loss 0.5269 | Train acc 0.7201 | Val loss 0.5678 | Val acc 0.7231
# Saved best model to /content/drive/MyDrive/PainRecognitionProject/models/best_testing_new_code_sta_lstm_2_classes_v2.pt (metric=0.7327)
# Epoch 198/200 | Time 2.87s | Train loss 0.5208 | Train acc 0.7295 | Val loss 0.5883 | Val acc 0.7327
# Epoch 199/200 | Time 2.52s | Train loss 0.5271 | Train acc 0.7213 | Val loss 0.5617 | Val acc 0.7115
# Epoch 200/200 | Time 2.55s | Train loss 0.5168 | Train acc 0.7283 | Val loss 0.5867 | Val acc 0.7096
# Training finished. Best epoch: 197. Best monitored metric: 0.7327
# Final model saved to: /content/drive/MyDrive/PainRecognitionProject/models/testing_new_code_sta_lstm_2_classes_v2.pt
# Best model saved to: /content/drive/MyDrive/PainRecognitionProject/models/best_testing_new_code_sta_lstm_2_classes_v2.pt

# %%
trainer.plot_history()

# %% [markdown]
# #### Evaluate

# %%
model.load_state_dict(torch.load(best_model_path, map_location=DEVICE), strict=False)
# Out:
# <All keys matched successfully>

# %%
evaluator = Evaluator(model, test_loader, device=DEVICE, model_name=model_name, num_classes=NUM_CLASSES)

# %%
loss, acc, labels, preds = evaluator.evaluate_epoch()
# Out:
# ==================================================
# WYNIKI OCENY DLA MODELU: testing_new_code_sta_lstm_2_classes_v2.pt
# ==================================================
# Test Loss: 0.5932
# Test Accuracy: 0.7192
#
# --- Szczegółowy Raport Klasyfikacji ---
#               precision    recall  f1-score   support
#
#      Klasa 0       0.70      0.78      0.73       260
#      Klasa 1       0.75      0.66      0.70       260
#
#     accuracy                           0.72       520
#    macro avg       0.72      0.72      0.72       520
# weighted avg       0.72      0.72      0.72       520
#
# ==================================================
# Confusion matrix:
#  [[202  58]
#  [ 88 172]]
