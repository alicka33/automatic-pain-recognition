# %% [markdown]
# ### Bi-LSTM model - binary training

# %% [markdown]
# #### Environment preparation

# %%
# Montowanie Google Drive
from google.colab import drive
drive.mount('/content/drive')

COLAB_ROOT = '/content/drive/MyDrive/PainRecognitionProject/'
print(f"Dane będą wczytywane z: {COLAB_ROOT}")
# Out:
# Mounted at /content/drive
# Dane będą wczytywane z: /content/drive/MyDrive/PainRecognitionProject/

# %%
import os

# Przejście do katalogu głównego
# %cd /content

# Klonowanie repo
# !rm -rf automatic-pain-recognition

print(f"Obecne położenie: {os.getcwd()}")
# Out:
# /content
# Obecne położenie: /content

# %%
# Upewnij się, że nazwa użytkownika i repozytorium są poprawne
USERNAME = 'alicka33'
REPO_NAME = 'automatic-pain-recognition'

# Tworzenie poprawnego adresu URL (format: https://<TOKEN>@github.com/...)
REPO_URL = f"https://github.com/{USERNAME}/{REPO_NAME}.git"

print("Rozpoczynam klonowanie...")

# Klonowanie
# !git clone {REPO_URL}

# Wejście do katalogu
# %cd $REPO_NAME
# Out:
# Rozpoczynam klonowanie...
# Cloning into 'automatic-pain-recognition'...
# remote: Enumerating objects: 313, done.
# remote: Counting objects: 100% (36/36), done.
# remote: Compressing objects: 100% (22/22), done.
# remote: Total 313 (delta 23), reused 27 (delta 14), pack-reused 277 (from 1)
# Receiving objects: 100% (313/313), 11.57 MiB | 27.11 MiB/s, done.
# Resolving deltas: 100% (147/147), done.
# /content/automatic-pain-recognition

# %%
# Instalacja wymaganych bibliotek
# !pip install -r requirements.txt
# Out:
# Requirement already satisfied: torch>=1.10.0 in /usr/local/lib/python3.12/dist-packages (from -r requirements.txt (line 2)) (2.9.0+cu126)
# Requirement already satisfied: torchvision>=0.11.0 in /usr/local/lib/python3.12/dist-packages (from -r requirements.txt (line 3)) (0.24.0+cu126)
# Requirement already satisfied: torchaudio>=0.10.0 in /usr/local/lib/python3.12/dist-packages (from -r requirements.txt (line 4)) (2.9.0+cu126)
# Requirement already satisfied: pandas>=1.3.0 in /usr/local/lib/python3.12/dist-packages (from -r requirements.txt (line 7)) (2.2.2)
# Requirement already satisfied: numpy>=1.21.0 in /usr/local/lib/python3.12/dist-packages (from -r requirements.txt (line 8)) (2.0.2)
# Requirement already satisfied: opencv-python>=4.5.5 in /usr/local/lib/python3.12/dist-packages (from -r requirements.txt (line 11)) (4.12.0.88)
# Requirement already satisfied: dlib>=19.24.2 in /usr/local/lib/python3.12/dist-packages (from -r requirements.txt (line 12)) (19.24.6)
# Requirement already satisfied: imutils>=0.5.4 in /usr/local/lib/python3.12/dist-packages (from -r requirements.txt (line 13)) (0.5.4)
# Collecting mediapipe>=0.10.15 (from -r requirements.txt (line 14))
#   Downloading mediapipe-0.10.31-py3-none-manylinux_2_28_x86_64.whl.metadata (9.7 kB)
# Requirement already satisfied: scikit-learn>=1.0.0 in /usr/local/lib/python3.12/dist-packages (from -r requirements.txt (line 17)) (1.6.1)
# Requirement already satisfied: tqdm>=4.62.3 in /usr/local/lib/python3.12/dist-packages (from -r requirements.txt (line 20)) (4.67.1)
# Requirement already satisfied: matplotlib>=3.5.0 in /usr/local/lib/python3.12/dist-packages (from -r requirements.txt (line 23)) (3.10.0)
# Requirement already satisfied: shap>=0.44.0 in /usr/local/lib/python3.12/dist-packages (from -r requirements.txt (line 26)) (0.50.0)
# Requirement already satisfied: filelock in /usr/local/lib/python3.12/dist-packages (from torch>=1.10.0->-r requirements.txt (line 2)) (3.20.0)
# Requirement already satisfied: typing-extensions>=4.10.0 in /usr/local/lib/python3.12/dist-packages (from torch>=1.10.0->-r requirements.txt (line 2)) (4.15.0)
# Requirement already satisfied: setuptools in /usr/local/lib/python3.12/dist-packages (from torch>=1.10.0->-r requirements.txt (line 2)) (75.2.0)
# Requirement already satisfied: sympy>=1.13.3 in /usr/local/lib/python3.12/dist-packages (from torch>=1.10.0->-r requirements.txt (line 2)) (1.14.0)
# Requirement already satisfied: networkx>=2.5.1 in /usr/local/lib/python3.12/dist-packages (from torch>=1.10.0->-r requirements.txt (line 2)) (3.6.1)
# Requirement already satisfied: jinja2 in /usr/local/lib/python3.12/dist-packages (from torch>=1.10.0->-r requirements.txt (line 2)) (3.1.6)
# Requirement already satisfied: fsspec>=0.8.5 in /usr/local/lib/python3.12/dist-packages (from torch>=1.10.0->-r requirements.txt (line 2)) (2025.3.0)
# Requirement already satisfied: nvidia-cuda-nvrtc-cu12==12.6.77 in /usr/local/lib/python3.12/dist-packages (from torch>=1.10.0->-r requirements.txt (line 2)) (12.6.77)
# Requirement already satisfied: nvidia-cuda-runtime-cu12==12.6.77 in /usr/local/lib/python3.12/dist-packages (from torch>=1.10.0->-r requirements.txt (line 2)) (12.6.77)
# Requirement already satisfied: nvidia-cuda-cupti-cu12==12.6.80 in /usr/local/lib/python3.12/dist-packages (from torch>=1.10.0->-r requirements.txt (line 2)) (12.6.80)
# Requirement already satisfied: nvidia-cudnn-cu12==9.10.2.21 in /usr/local/lib/python3.12/dist-packages (from torch>=1.10.0->-r requirements.txt (line 2)) (9.10.2.21)
# Requirement already satisfied: nvidia-cublas-cu12==12.6.4.1 in /usr/local/lib/python3.12/dist-packages (from torch>=1.10.0->-r requirements.txt (line 2)) (12.6.4.1)
# Requirement already satisfied: nvidia-cufft-cu12==11.3.0.4 in /usr/local/lib/python3.12/dist-packages (from torch>=1.10.0->-r requirements.txt (line 2)) (11.3.0.4)
# Requirement already satisfied: nvidia-curand-cu12==10.3.7.77 in /usr/local/lib/python3.12/dist-packages (from torch>=1.10.0->-r requirements.txt (line 2)) (10.3.7.77)
# Requirement already satisfied: nvidia-cusolver-cu12==11.7.1.2 in /usr/local/lib/python3.12/dist-packages (from torch>=1.10.0->-r requirements.txt (line 2)) (11.7.1.2)
# Requirement already satisfied: nvidia-cusparse-cu12==12.5.4.2 in /usr/local/lib/python3.12/dist-packages (from torch>=1.10.0->-r requirements.txt (line 2)) (12.5.4.2)
# Requirement already satisfied: nvidia-cusparselt-cu12==0.7.1 in /usr/local/lib/python3.12/dist-packages (from torch>=1.10.0->-r requirements.txt (line 2)) (0.7.1)
# Requirement already satisfied: nvidia-nccl-cu12==2.27.5 in /usr/local/lib/python3.12/dist-packages (from torch>=1.10.0->-r requirements.txt (line 2)) (2.27.5)
# Requirement already satisfied: nvidia-nvshmem-cu12==3.3.20 in /usr/local/lib/python3.12/dist-packages (from torch>=1.10.0->-r requirements.txt (line 2)) (3.3.20)
# Requirement already satisfied: nvidia-nvtx-cu12==12.6.77 in /usr/local/lib/python3.12/dist-packages (from torch>=1.10.0->-r requirements.txt (line 2)) (12.6.77)
# Requirement already satisfied: nvidia-nvjitlink-cu12==12.6.85 in /usr/local/lib/python3.12/dist-packages (from torch>=1.10.0->-r requirements.txt (line 2)) (12.6.85)
# Requirement already satisfied: nvidia-cufile-cu12==1.11.1.6 in /usr/local/lib/python3.12/dist-packages (from torch>=1.10.0->-r requirements.txt (line 2)) (1.11.1.6)
# Requirement already satisfied: triton==3.5.0 in /usr/local/lib/python3.12/dist-packages (from torch>=1.10.0->-r requirements.txt (line 2)) (3.5.0)
# Requirement already satisfied: pillow!=8.3.*,>=5.3.0 in /usr/local/lib/python3.12/dist-packages (from torchvision>=0.11.0->-r requirements.txt (line 3)) (11.3.0)
# Requirement already satisfied: python-dateutil>=2.8.2 in /usr/local/lib/python3.12/dist-packages (from pandas>=1.3.0->-r requirements.txt (line 7)) (2.9.0.post0)
# Requirement already satisfied: pytz>=2020.1 in /usr/local/lib/python3.12/dist-packages (from pandas>=1.3.0->-r requirements.txt (line 7)) (2025.2)
# Requirement already satisfied: tzdata>=2022.7 in /usr/local/lib/python3.12/dist-packages (from pandas>=1.3.0->-r requirements.txt (line 7)) (2025.3)
# Collecting absl-py~=2.3 (from mediapipe>=0.10.15->-r requirements.txt (line 14))
#   Downloading absl_py-2.3.1-py3-none-any.whl.metadata (3.3 kB)
# Collecting sounddevice~=0.5 (from mediapipe>=0.10.15->-r requirements.txt (line 14))
#   Downloading sounddevice-0.5.3-py3-none-any.whl.metadata (1.6 kB)
# Requirement already satisfied: flatbuffers~=25.9 in /usr/local/lib/python3.12/dist-packages (from mediapipe>=0.10.15->-r requirements.txt (line 14)) (25.9.23)
# Requirement already satisfied: scipy>=1.6.0 in /usr/local/lib/python3.12/dist-packages (from scikit-learn>=1.0.0->-r requirements.txt (line 17)) (1.16.3)
# Requirement already satisfied: joblib>=1.2.0 in /usr/local/lib/python3.12/dist-packages (from scikit-learn>=1.0.0->-r requirements.txt (line 17)) (1.5.3)
# Requirement already satisfied: threadpoolctl>=3.1.0 in /usr/local/lib/python3.12/dist-packages (from scikit-learn>=1.0.0->-r requirements.txt (line 17)) (3.6.0)
# Requirement already satisfied: contourpy>=1.0.1 in /usr/local/lib/python3.12/dist-packages (from matplotlib>=3.5.0->-r requirements.txt (line 23)) (1.3.3)
# Requirement already satisfied: cycler>=0.10 in /usr/local/lib/python3.12/dist-packages (from matplotlib>=3.5.0->-r requirements.txt (line 23)) (0.12.1)
# Requirement already satisfied: fonttools>=4.22.0 in /usr/local/lib/python3.12/dist-packages (from matplotlib>=3.5.0->-r requirements.txt (line 23)) (4.61.1)
# Requirement already satisfied: kiwisolver>=1.3.1 in /usr/local/lib/python3.12/dist-packages (from matplotlib>=3.5.0->-r requirements.txt (line 23)) (1.4.9)
# Requirement already satisfied: packaging>=20.0 in /usr/local/lib/python3.12/dist-packages (from matplotlib>=3.5.0->-r requirements.txt (line 23)) (25.0)
# Requirement already satisfied: pyparsing>=2.3.1 in /usr/local/lib/python3.12/dist-packages (from matplotlib>=3.5.0->-r requirements.txt (line 23)) (3.2.5)
# Requirement already satisfied: slicer==0.0.8 in /usr/local/lib/python3.12/dist-packages (from shap>=0.44.0->-r requirements.txt (line 26)) (0.0.8)
# Requirement already satisfied: numba>=0.54 in /usr/local/lib/python3.12/dist-packages (from shap>=0.44.0->-r requirements.txt (line 26)) (0.60.0)
# Requirement already satisfied: cloudpickle in /usr/local/lib/python3.12/dist-packages (from shap>=0.44.0->-r requirements.txt (line 26)) (3.1.2)
# Requirement already satisfied: llvmlite<0.44,>=0.43.0dev0 in /usr/local/lib/python3.12/dist-packages (from numba>=0.54->shap>=0.44.0->-r requirements.txt (line 26)) (0.43.0)
# Requirement already satisfied: six>=1.5 in /usr/local/lib/python3.12/dist-packages (from python-dateutil>=2.8.2->pandas>=1.3.0->-r requirements.txt (line 7)) (1.17.0)
# Requirement already satisfied: CFFI>=1.0 in /usr/local/lib/python3.12/dist-packages (from sounddevice~=0.5->mediapipe>=0.10.15->-r requirements.txt (line 14)) (2.0.0)
# Requirement already satisfied: mpmath<1.4,>=1.1.0 in /usr/local/lib/python3.12/dist-packages (from sympy>=1.13.3->torch>=1.10.0->-r requirements.txt (line 2)) (1.3.0)
# Requirement already satisfied: MarkupSafe>=2.0 in /usr/local/lib/python3.12/dist-packages (from jinja2->torch>=1.10.0->-r requirements.txt (line 2)) (3.0.3)
# Requirement already satisfied: pycparser in /usr/local/lib/python3.12/dist-packages (from CFFI>=1.0->sounddevice~=0.5->mediapipe>=0.10.15->-r requirements.txt (line 14)) (2.23)
# Downloading mediapipe-0.10.31-py3-none-manylinux_2_28_x86_64.whl (10.3 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 10.3/10.3 MB 87.5 MB/s eta 0:00:00
# Downloading absl_py-2.3.1-py3-none-any.whl (135 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 135.8/135.8 kB 14.5 MB/s eta 0:00:00
# Downloading sounddevice-0.5.3-py3-none-any.whl (32 kB)
# Installing collected packages: absl-py, sounddevice, mediapipe
#   Attempting uninstall: absl-py
#     Found existing installation: absl-py 1.4.0
#     Uninstalling absl-py-1.4.0:
#       Successfully uninstalled absl-py-1.4.0
# Successfully installed absl-py-2.3.1 mediapipe-0.10.31 sounddevice-0.5.3

# %%
import sys
import os

# Dodaj katalog główny projektu do ścieżki systemowej
sys.path.append(os.getcwd())
print(f"Dodano do ścieżki Pythona: {os.getcwd()}")
# Out:
# Dodano do ścieżki Pythona: /content/automatic-pain-recognition

# %% [markdown]
# #### Bi-LSTM model - binary training

# %%
import os
import numpy as np
import pandas as pd
import shutil

import torch
import torch.nn as nn
from torch.utils.data import DataLoader
from torch.optim.lr_scheduler import ReduceLROnPlateau

from training_utils.preprocessed_dataset import PreprocessedDataset
from training_utils.train import Trainer
from training_utils.evaluate import Evaluator
from models.Bi_LSTM import SequenceModel

# %% [markdown]
# #### Hiperparameters

# %%
MAX_SEQUENCE_LENGTH = 46
NUM_FEATURES = 1434
NUM_CLASSES = 2
HIDDEN_SIZE = 128
NUM_LAYERS = 2
NUM_EPOCHS = 200
BATCH_SIZE = 16
LEARNING_RATE = 0.00005
DROPOUT_PROB = 0.3
WEIGHT_DECAY = 0.005
SCHEDULER_FACTOR = 0.9

# %% [markdown]
# #### Data preparation

# %%
COLAB_ROOT = '/content/drive/MyDrive/PainRecognitionProject/'
PROCESSED_DATA_DIR = os.path.join(COLAB_ROOT, 'data/BioVid_HeatPain_processed_478_xyz_frontalized/')
MODEL_SAVE_DIR = os.path.join(COLAB_ROOT, 'models/')
LOCAL_PROCESSED_DATA_ROOT = '/content/temp_data/'

DEVICE = torch.device("cuda" if torch.cuda.is_available() else "cpu")

# %%
print("Kopiowanie danych z Google Drive do lokalnej pamięci Colab (RAM)...")
if os.path.exists(LOCAL_PROCESSED_DATA_ROOT):
    shutil.rmtree(LOCAL_PROCESSED_DATA_ROOT)
try:
    shutil.copytree(PROCESSED_DATA_DIR, LOCAL_PROCESSED_DATA_ROOT)
    print("✅ Kopiowanie zakończone pomyślnie. Czas trwania: (sprawdź zegar)")
    CURRENT_DATA_DIR = LOCAL_PROCESSED_DATA_ROOT

except Exception as e:
    print(f"❌ Błąd kopiowania danych (sprawdź, czy dane są zamontowane): {e}")
    print("Używam danych bezpośrednio z Drive (może się zawiesić).")
    CURRENT_DATA_DIR = PROCESSED_DATA_DIR
# Out:
# Kopiowanie danych z Google Drive do lokalnej pamięci Colab (RAM)...
# ✅ Kopiowanie zakończone pomyślnie. Czas trwania: (sprawdź zegar)

# %%
best100 = np.load('/content/drive/MyDrive/PainRecognitionProject/data/top_100_important_landmarks_emotions.npy')

# %%
train_dataset = PreprocessedDataset(
    'train',
    processed_data_dir=CURRENT_DATA_DIR,
    indices=None,
    compute_euclidean=False,
    center_point_index=2,
    max_sequence_length=MAX_SEQUENCE_LENGTH,
    selected_labels=[0, 4],
    label_map={0: 0, 4: 1},
)

val_dataset = PreprocessedDataset(
    'val',
    processed_data_dir=CURRENT_DATA_DIR,
    indices=None,
    compute_euclidean=False,
    center_point_index=2,
    max_sequence_length=MAX_SEQUENCE_LENGTH,
    selected_labels=[0, 4],
    label_map={0: 0, 4: 1},
)

test_dataset = PreprocessedDataset(
    'test',
    processed_data_dir=CURRENT_DATA_DIR,
    indices=None,
    compute_euclidean=False,
    center_point_index=2,
    max_sequence_length=MAX_SEQUENCE_LENGTH,
    selected_labels=[0, 4],
    label_map={0: 0, 4: 1},
)

# %%
def preview_single(dataset, idx=0, timesteps_to_show=3, features_to_show=8):
    x, y = dataset[idx]
    print(f"\nSingle sample idx={idx} from split={dataset.dataset_name}")
    print(f"x shape: {tuple(x.shape)}, y: {y}")
    print(np.round(x[:timesteps_to_show, :features_to_show], 4))

preview_single(train_dataset, 0)
preview_single(val_dataset, 0)
preview_single(test_dataset, 0)
# Out:
# Single sample idx=0 from split=train
# x shape: (46, 1434), y: 0
# tensor([[ 0.0166,  0.1003,  0.0049,  0.0033, -0.0350, -0.0782,  0.0000,  0.0000],
#         [ 0.0074,  0.0975,  0.0028,  0.0024, -0.0366, -0.0783,  0.0000,  0.0000],
#         [ 0.0077,  0.0955,  0.0037,  0.0022, -0.0362, -0.0781,  0.0000,  0.0000]])
#
# Single sample idx=0 from split=val
# x shape: (46, 1434), y: 0
# tensor([[ 0.0002,  0.1079,  0.0064,  0.0040, -0.0341, -0.0773,  0.0000,  0.0000],
#         [-0.0022,  0.1043,  0.0072,  0.0032, -0.0341, -0.0777,  0.0000,  0.0000],
#         [-0.0005,  0.1048,  0.0073,  0.0031, -0.0340, -0.0774,  0.0000,  0.0000]])
#
# Single sample idx=0 from split=test
# x shape: (46, 1434), y: 0
# tensor([[ 0.0002,  0.0989,  0.0039,  0.0052, -0.0319, -0.0745,  0.0000,  0.0000],
#         [-0.0045,  0.0965,  0.0040,  0.0047, -0.0339, -0.0747,  0.0000,  0.0000],
#         [-0.0028,  0.0980,  0.0043,  0.0052, -0.0344, -0.0745,  0.0000,  0.0000]])

# %%
train_loader = DataLoader(train_dataset, batch_size=BATCH_SIZE, shuffle=True, num_workers=0, pin_memory=True)
for X, y in train_loader:
    print(X.shape, y.shape)  # (B, T_max, num_features)
    break

val_loader = DataLoader(val_dataset, batch_size=BATCH_SIZE, shuffle=True, num_workers=0, pin_memory=True)
for X, y in val_loader:
    print(X.shape, y.shape)  # (B, T_max, num_features)
    break

test_loader = DataLoader(test_dataset, batch_size=BATCH_SIZE, shuffle=True, num_workers=0, pin_memory=True)
for X, y in test_loader:
    print(X.shape, y.shape)  # (B, T_max, num_features)
    break
# Out:
# torch.Size([16, 46, 1434]) torch.Size([16])
# torch.Size([16, 46, 1434]) torch.Size([16])
# torch.Size([16, 46, 1434]) torch.Size([16])

# %% [markdown]
# #### Model preparation

# %%
model = SequenceModel(NUM_FEATURES, HIDDEN_SIZE, NUM_LAYERS, NUM_CLASSES, DROPOUT_PROB).to(DEVICE)

# %% [markdown]
# #### Training

# %%
criterion = nn.CrossEntropyLoss()
optimizer = torch.optim.AdamW(model.parameters(), lr=LEARNING_RATE, weight_decay=WEIGHT_DECAY)

scheduler = ReduceLROnPlateau(
    optimizer,
    mode='max',
    factor=SCHEDULER_FACTOR,
    patience=10,
    min_lr=1e-7
)

model_name = 'testing_new_code_bi_lstm_2_classes_1434_coord.pt'
model_filepath = os.path.join(MODEL_SAVE_DIR, model_name)

# %% [markdown]
# saprawdzic jak teraz działa ten scheduler !!!!

# %%
trainer = Trainer(
    model=model,
    train_loader=train_loader,
    val_loader=val_loader,
    optimizer=optimizer,
    scheduler=scheduler,
    criterion=criterion,
    device=DEVICE,
    model_save_path=model_filepath,
    num_epochs=NUM_EPOCHS,
    monitor='val_acc',  # or 'val_loss'
    minimize_monitor=False,
    save_best_only=True
)

# %%
trainer.print_training_config()
# Out:
# ==================================================
# 🚀 TRAINING CONFIGURATION
# ==================================================
#
# --- Model Architecture ---
#   Model Type            : SequenceModel
#   Input Features        : 1434
#   Hidden Size           : 128
#   Num Layers            : 2
#   Bidirectional         : True
#   Dropout (LSTM)        : 0.3
#   Num Parameters        : 1997314
#
# --- Optimizer & Regularization ---
#   Optimizer             : AdamW
#   Learning Rate (LR)    : 5e-05
#   Weight Decay (L2)     : 0.005
#
# --- Training Flow ---
#   Batch Size            : 16
#   Num Epochs            : 200
#   Device                : cuda
# ==================================================

# %%
final_model_path, best_model_path, history = trainer.fit()
print(f"Final model saved to: {final_model_path}")
if best_model_path:
    print(f"Best model saved to: {best_model_path}")
# Out:
# Starting training for 200 epochs on cuda
# Saved best model to /content/drive/MyDrive/PainRecognitionProject/models/best_testing_new_code_bi_lstm_2_classes_1434_coord.pt (metric=0.5000)
# Epoch 1/200 | Time 7.40s | Train loss 0.6955 | Train acc 0.4943 | Val loss 0.6932 | Val acc 0.5000
# Saved best model to /content/drive/MyDrive/PainRecognitionProject/models/best_testing_new_code_bi_lstm_2_classes_1434_coord.pt (metric=0.5500)
# Epoch 2/200 | Time 2.88s | Train loss 0.6941 | Train acc 0.4906 | Val loss 0.6929 | Val acc 0.5500
# Epoch 3/200 | Time 2.44s | Train loss 0.6947 | Train acc 0.4857 | Val loss 0.6928 | Val acc 0.5058
# Epoch 4/200 | Time 2.44s | Train loss 0.6932 | Train acc 0.5008 | Val loss 0.6928 | Val acc 0.5000
# Epoch 5/200 | Time 2.92s | Train loss 0.6930 | Train acc 0.4914 | Val loss 0.6924 | Val acc 0.5365
# Epoch 6/200 | Time 2.63s | Train loss 0.6931 | Train acc 0.5172 | Val loss 0.6918 | Val acc 0.5192
# Epoch 7/200 | Time 2.43s | Train loss 0.6919 | Train acc 0.5152 | Val loss 0.6918 | Val acc 0.5019
# Epoch 8/200 | Time 2.39s | Train loss 0.6920 | Train acc 0.5139 | Val loss 0.6938 | Val acc 0.5000
# Epoch 9/200 | Time 2.39s | Train loss 0.6934 | Train acc 0.5049 | Val loss 0.6912 | Val acc 0.5481
# Epoch 10/200 | Time 2.66s | Train loss 0.6902 | Train acc 0.5291 | Val loss 0.6955 | Val acc 0.5000
# Epoch 11/200 | Time 2.64s | Train loss 0.6914 | Train acc 0.5197 | Val loss 0.6890 | Val acc 0.5154
# Epoch 12/200 | Time 2.35s | Train loss 0.6886 | Train acc 0.5439 | Val loss 0.6891 | Val acc 0.5481
# Saved best model to /content/drive/MyDrive/PainRecognitionProject/models/best_testing_new_code_bi_lstm_2_classes_1434_coord.pt (metric=0.5731)
# Epoch 13/200 | Time 2.42s | Train loss 0.6870 | Train acc 0.5459 | Val loss 0.6847 | Val acc 0.5731
# Epoch 14/200 | Time 2.43s | Train loss 0.6803 | Train acc 0.5660 | Val loss 0.6815 | Val acc 0.5731
# Epoch 15/200 | Time 2.64s | Train loss 0.6757 | Train acc 0.5795 | Val loss 0.6911 | Val acc 0.5250
# Saved best model to /content/drive/MyDrive/PainRecognitionProject/models/best_testing_new_code_bi_lstm_2_classes_1434_coord.pt (metric=0.5808)
# Epoch 16/200 | Time 2.77s | Train loss 0.6731 | Train acc 0.5865 | Val loss 0.6839 | Val acc 0.5808
# Epoch 17/200 | Time 2.42s | Train loss 0.6685 | Train acc 0.5963 | Val loss 0.6869 | Val acc 0.5577
# Epoch 18/200 | Time 2.36s | Train loss 0.6699 | Train acc 0.5943 | Val loss 0.7239 | Val acc 0.5000
# Epoch 19/200 | Time 2.37s | Train loss 0.6704 | Train acc 0.5930 | Val loss 0.6727 | Val acc 0.5769
# Epoch 20/200 | Time 2.50s | Train loss 0.6667 | Train acc 0.5918 | Val loss 0.6690 | Val acc 0.5750
# Saved best model to /content/drive/MyDrive/PainRecognitionProject/models/best_testing_new_code_bi_lstm_2_classes_1434_coord.pt (metric=0.5942)
# Epoch 21/200 | Time 2.82s | Train loss 0.6656 | Train acc 0.5852 | Val loss 0.6575 | Val acc 0.5942
# Epoch 22/200 | Time 2.46s | Train loss 0.6674 | Train acc 0.5959 | Val loss 0.6811 | Val acc 0.5442
# Epoch 23/200 | Time 2.39s | Train loss 0.6636 | Train acc 0.5898 | Val loss 0.6749 | Val acc 0.5577
# Epoch 24/200 | Time 2.39s | Train loss 0.6593 | Train acc 0.6115 | Val loss 0.6629 | Val acc 0.5846
# Epoch 25/200 | Time 2.44s | Train loss 0.6652 | Train acc 0.6057 | Val loss 0.6898 | Val acc 0.5269
# Saved best model to /content/drive/MyDrive/PainRecognitionProject/models/best_testing_new_code_bi_lstm_2_classes_1434_coord.pt (metric=0.6173)
# Epoch 26/200 | Time 2.87s | Train loss 0.6640 | Train acc 0.5918 | Val loss 0.6476 | Val acc 0.6173
# Epoch 27/200 | Time 2.56s | Train loss 0.6621 | Train acc 0.6020 | Val loss 0.6574 | Val acc 0.6000
# Saved best model to /content/drive/MyDrive/PainRecognitionProject/models/best_testing_new_code_bi_lstm_2_classes_1434_coord.pt (metric=0.6231)
# Epoch 28/200 | Time 2.40s | Train loss 0.6580 | Train acc 0.5971 | Val loss 0.6517 | Val acc 0.6231
# Epoch 29/200 | Time 2.41s | Train loss 0.6512 | Train acc 0.6193 | Val loss 0.6476 | Val acc 0.6154
# Saved best model to /content/drive/MyDrive/PainRecognitionProject/models/best_testing_new_code_bi_lstm_2_classes_1434_coord.pt (metric=0.6442)
# Epoch 30/200 | Time 2.33s | Train loss 0.6599 | Train acc 0.6082 | Val loss 0.6461 | Val acc 0.6442
# Epoch 31/200 | Time 2.69s | Train loss 0.6495 | Train acc 0.6180 | Val loss 0.6470 | Val acc 0.6250
# Epoch 32/200 | Time 2.71s | Train loss 0.6600 | Train acc 0.5975 | Val loss 0.6537 | Val acc 0.6019
# Epoch 33/200 | Time 2.34s | Train loss 0.6553 | Train acc 0.6115 | Val loss 0.6594 | Val acc 0.6077
# Epoch 34/200 | Time 2.35s | Train loss 0.6578 | Train acc 0.6078 | Val loss 0.6469 | Val acc 0.6385
# Epoch 35/200 | Time 2.32s | Train loss 0.6509 | Train acc 0.6246 | Val loss 0.6485 | Val acc 0.6077
# Epoch 36/200 | Time 2.55s | Train loss 0.6588 | Train acc 0.6045 | Val loss 0.6947 | Val acc 0.5481
# Epoch 37/200 | Time 2.83s | Train loss 0.6553 | Train acc 0.6131 | Val loss 0.6819 | Val acc 0.5577
# Epoch 38/200 | Time 2.40s | Train loss 0.6548 | Train acc 0.6053 | Val loss 0.6562 | Val acc 0.5981
# Epoch 39/200 | Time 2.37s | Train loss 0.6500 | Train acc 0.6275 | Val loss 0.6585 | Val acc 0.6231
# Epoch 40/200 | Time 2.35s | Train loss 0.6531 | Train acc 0.6078 | Val loss 0.6564 | Val acc 0.5846
# Epoch 41/200 | Time 2.55s | Train loss 0.6557 | Train acc 0.6016 | Val loss 0.6863 | Val acc 0.5346
# Epoch 42/200 | Time 2.85s | Train loss 0.6504 | Train acc 0.6152 | Val loss 0.6502 | Val acc 0.6077
# Epoch 43/200 | Time 2.43s | Train loss 0.6419 | Train acc 0.6225 | Val loss 0.8536 | Val acc 0.5250
# Epoch 44/200 | Time 2.33s | Train loss 0.6654 | Train acc 0.6016 | Val loss 0.6717 | Val acc 0.5596
# Epoch 45/200 | Time 2.39s | Train loss 0.6443 | Train acc 0.6184 | Val loss 0.6651 | Val acc 0.5808
# Epoch 46/200 | Time 2.40s | Train loss 0.6550 | Train acc 0.6049 | Val loss 0.6484 | Val acc 0.6231
# Epoch 47/200 | Time 2.82s | Train loss 0.6533 | Train acc 0.6172 | Val loss 0.6473 | Val acc 0.6135
# Epoch 48/200 | Time 2.58s | Train loss 0.6481 | Train acc 0.6123 | Val loss 0.6547 | Val acc 0.5846
# Epoch 49/200 | Time 2.38s | Train loss 0.6455 | Train acc 0.6131 | Val loss 0.6430 | Val acc 0.6250
# Epoch 50/200 | Time 2.35s | Train loss 0.6502 | Train acc 0.6119 | Val loss 0.6385 | Val acc 0.6365
# Epoch 51/200 | Time 2.48s | Train loss 0.6430 | Train acc 0.6197 | Val loss 0.6562 | Val acc 0.5885
# Epoch 52/200 | Time 2.68s | Train loss 0.6343 | Train acc 0.6242 | Val loss 0.6479 | Val acc 0.6077
# Epoch 53/200 | Time 2.67s | Train loss 0.6405 | Train acc 0.6164 | Val loss 0.6722 | Val acc 0.6231
# Epoch 54/200 | Time 2.38s | Train loss 0.6412 | Train acc 0.6295 | Val loss 0.6598 | Val acc 0.5654
# Epoch 55/200 | Time 2.39s | Train loss 0.6344 | Train acc 0.6221 | Val loss 0.6406 | Val acc 0.6058
# Epoch 56/200 | Time 2.36s | Train loss 0.6370 | Train acc 0.6295 | Val loss 0.6419 | Val acc 0.6115
# Epoch 57/200 | Time 2.53s | Train loss 0.6337 | Train acc 0.6254 | Val loss 0.6709 | Val acc 0.5615
# Epoch 58/200 | Time 2.76s | Train loss 0.6469 | Train acc 0.6053 | Val loss 0.6560 | Val acc 0.5865
# Epoch 59/200 | Time 2.41s | Train loss 0.6377 | Train acc 0.6242 | Val loss 0.6579 | Val acc 0.6404
# Epoch 60/200 | Time 2.41s | Train loss 0.6292 | Train acc 0.6316 | Val loss 0.6657 | Val acc 0.5923
# Epoch 61/200 | Time 2.42s | Train loss 0.6413 | Train acc 0.6184 | Val loss 0.6325 | Val acc 0.6288
# Epoch 62/200 | Time 2.38s | Train loss 0.6275 | Train acc 0.6279 | Val loss 0.6955 | Val acc 0.5481
# Epoch 63/200 | Time 2.85s | Train loss 0.6496 | Train acc 0.6111 | Val loss 0.7052 | Val acc 0.5462
# Epoch 64/200 | Time 2.44s | Train loss 0.6337 | Train acc 0.6279 | Val loss 0.6806 | Val acc 0.5731
# Epoch 65/200 | Time 2.36s | Train loss 0.6314 | Train acc 0.6250 | Val loss 0.6443 | Val acc 0.6019
# Epoch 66/200 | Time 2.34s | Train loss 0.6383 | Train acc 0.6352 | Val loss 0.6377 | Val acc 0.6135
# Epoch 67/200 | Time 2.34s | Train loss 0.6241 | Train acc 0.6373 | Val loss 0.6425 | Val acc 0.6231
# Epoch 68/200 | Time 2.73s | Train loss 0.6387 | Train acc 0.6156 | Val loss 0.6831 | Val acc 0.6077
# Epoch 69/200 | Time 2.63s | Train loss 0.6331 | Train acc 0.6324 | Val loss 0.6644 | Val acc 0.6404
# Epoch 70/200 | Time 2.36s | Train loss 0.6247 | Train acc 0.6336 | Val loss 0.6388 | Val acc 0.6077
# Epoch 71/200 | Time 2.35s | Train loss 0.6191 | Train acc 0.6377 | Val loss 0.6490 | Val acc 0.6327
# Epoch 72/200 | Time 2.38s | Train loss 0.6272 | Train acc 0.6373 | Val loss 0.6319 | Val acc 0.6038
# Epoch 73/200 | Time 2.67s | Train loss 0.6239 | Train acc 0.6320 | Val loss 0.6519 | Val acc 0.6423
# Epoch 74/200 | Time 2.77s | Train loss 0.6252 | Train acc 0.6365 | Val loss 0.6551 | Val acc 0.6096
# Epoch 75/200 | Time 2.39s | Train loss 0.6136 | Train acc 0.6414 | Val loss 0.6574 | Val acc 0.5750
# Epoch 76/200 | Time 2.30s | Train loss 0.6253 | Train acc 0.6213 | Val loss 0.6378 | Val acc 0.5923
# Epoch 77/200 | Time 2.34s | Train loss 0.6204 | Train acc 0.6287 | Val loss 0.6627 | Val acc 0.5865
# Epoch 78/200 | Time 2.46s | Train loss 0.6326 | Train acc 0.6443 | Val loss 0.6987 | Val acc 0.6154
# Epoch 79/200 | Time 2.80s | Train loss 0.6240 | Train acc 0.6299 | Val loss 0.6777 | Val acc 0.6269
# Saved best model to /content/drive/MyDrive/PainRecognitionProject/models/best_testing_new_code_bi_lstm_2_classes_1434_coord.pt (metric=0.6500)
# Epoch 80/200 | Time 2.45s | Train loss 0.6326 | Train acc 0.6324 | Val loss 0.6612 | Val acc 0.6500
# Epoch 81/200 | Time 2.44s | Train loss 0.6236 | Train acc 0.6270 | Val loss 0.6755 | Val acc 0.5750
# Epoch 82/200 | Time 2.43s | Train loss 0.6116 | Train acc 0.6480 | Val loss 0.6408 | Val acc 0.6077
# Epoch 83/200 | Time 2.38s | Train loss 0.6272 | Train acc 0.6193 | Val loss 0.6507 | Val acc 0.5827
# Epoch 84/200 | Time 2.78s | Train loss 0.6169 | Train acc 0.6348 | Val loss 0.6471 | Val acc 0.6212
# Epoch 85/200 | Time 2.60s | Train loss 0.6290 | Train acc 0.6287 | Val loss 0.6854 | Val acc 0.6308
# Epoch 86/200 | Time 2.41s | Train loss 0.6136 | Train acc 0.6377 | Val loss 0.6678 | Val acc 0.6077
# Epoch 87/200 | Time 2.42s | Train loss 0.6134 | Train acc 0.6393 | Val loss 0.6963 | Val acc 0.6192
# Epoch 88/200 | Time 2.35s | Train loss 0.6151 | Train acc 0.6389 | Val loss 0.6678 | Val acc 0.6231
# Epoch 89/200 | Time 2.67s | Train loss 0.6211 | Train acc 0.6344 | Val loss 0.7496 | Val acc 0.5404
# Epoch 90/200 | Time 2.63s | Train loss 0.6229 | Train acc 0.6365 | Val loss 0.6513 | Val acc 0.5769
# Epoch 91/200 | Time 2.37s | Train loss 0.6193 | Train acc 0.6299 | Val loss 0.6319 | Val acc 0.6327
# Epoch 92/200 | Time 2.39s | Train loss 0.6095 | Train acc 0.6385 | Val loss 0.6574 | Val acc 0.6500
# Epoch 93/200 | Time 2.36s | Train loss 0.6256 | Train acc 0.6369 | Val loss 0.6482 | Val acc 0.6346
# Epoch 94/200 | Time 2.52s | Train loss 0.6157 | Train acc 0.6443 | Val loss 0.6541 | Val acc 0.6404
# Epoch 95/200 | Time 2.78s | Train loss 0.6118 | Train acc 0.6516 | Val loss 0.6304 | Val acc 0.6115
# Epoch 96/200 | Time 2.45s | Train loss 0.6189 | Train acc 0.6406 | Val loss 0.6587 | Val acc 0.5962
# Epoch 97/200 | Time 2.41s | Train loss 0.6163 | Train acc 0.6426 | Val loss 0.6636 | Val acc 0.6096
# Epoch 98/200 | Time 2.40s | Train loss 0.6228 | Train acc 0.6393 | Val loss 0.6519 | Val acc 0.6019
# Epoch 99/200 | Time 2.44s | Train loss 0.6178 | Train acc 0.6385 | Val loss 0.6424 | Val acc 0.6135
# Epoch 100/200 | Time 2.87s | Train loss 0.6116 | Train acc 0.6414 | Val loss 0.6481 | Val acc 0.6250
# Epoch 101/200 | Time 2.45s | Train loss 0.6190 | Train acc 0.6512 | Val loss 0.6870 | Val acc 0.5788
# Epoch 102/200 | Time 2.39s | Train loss 0.6145 | Train acc 0.6410 | Val loss 0.6622 | Val acc 0.5923
# Epoch 103/200 | Time 2.37s | Train loss 0.6010 | Train acc 0.6492 | Val loss 0.6417 | Val acc 0.6346
# Epoch 104/200 | Time 2.36s | Train loss 0.6001 | Train acc 0.6500 | Val loss 0.6297 | Val acc 0.6346
# Epoch 105/200 | Time 2.76s | Train loss 0.6183 | Train acc 0.6324 | Val loss 0.6421 | Val acc 0.6154
# Epoch 106/200 | Time 2.55s | Train loss 0.6107 | Train acc 0.6340 | Val loss 0.6713 | Val acc 0.5827
# Epoch 107/200 | Time 2.39s | Train loss 0.6120 | Train acc 0.6414 | Val loss 0.6714 | Val acc 0.6250
# Epoch 108/200 | Time 2.39s | Train loss 0.6077 | Train acc 0.6504 | Val loss 0.6441 | Val acc 0.6154
# Epoch 109/200 | Time 2.41s | Train loss 0.5995 | Train acc 0.6541 | Val loss 0.6589 | Val acc 0.6115
# Epoch 110/200 | Time 2.67s | Train loss 0.6052 | Train acc 0.6512 | Val loss 0.6751 | Val acc 0.5712
# Epoch 111/200 | Time 2.80s | Train loss 0.6105 | Train acc 0.6500 | Val loss 0.6616 | Val acc 0.6404
# Epoch 112/200 | Time 2.41s | Train loss 0.5991 | Train acc 0.6541 | Val loss 0.6446 | Val acc 0.6115
# Epoch 113/200 | Time 2.42s | Train loss 0.6209 | Train acc 0.6348 | Val loss 0.6701 | Val acc 0.5846
# Epoch 114/200 | Time 2.36s | Train loss 0.6013 | Train acc 0.6484 | Val loss 0.6757 | Val acc 0.6365
# Epoch 115/200 | Time 2.57s | Train loss 0.6052 | Train acc 0.6414 | Val loss 0.6859 | Val acc 0.6327
# Epoch 116/200 | Time 2.78s | Train loss 0.6078 | Train acc 0.6484 | Val loss 0.6909 | Val acc 0.6346
# Epoch 117/200 | Time 2.41s | Train loss 0.6114 | Train acc 0.6283 | Val loss 0.6403 | Val acc 0.5904
# Epoch 118/200 | Time 2.41s | Train loss 0.6040 | Train acc 0.6549 | Val loss 0.6442 | Val acc 0.6346
# Epoch 119/200 | Time 2.42s | Train loss 0.5978 | Train acc 0.6512 | Val loss 0.7158 | Val acc 0.6423
# Epoch 120/200 | Time 2.43s | Train loss 0.6028 | Train acc 0.6434 | Val loss 0.6647 | Val acc 0.6135
# Epoch 121/200 | Time 2.86s | Train loss 0.6037 | Train acc 0.6525 | Val loss 0.7262 | Val acc 0.6346
# Epoch 122/200 | Time 2.45s | Train loss 0.6070 | Train acc 0.6467 | Val loss 0.6337 | Val acc 0.6327
# Epoch 123/200 | Time 2.36s | Train loss 0.6001 | Train acc 0.6627 | Val loss 0.7040 | Val acc 0.6404
# Saved best model to /content/drive/MyDrive/PainRecognitionProject/models/best_testing_new_code_bi_lstm_2_classes_1434_coord.pt (metric=0.6538)
# Epoch 124/200 | Time 2.35s | Train loss 0.6161 | Train acc 0.6287 | Val loss 0.6910 | Val acc 0.6538
# Epoch 125/200 | Time 2.39s | Train loss 0.6026 | Train acc 0.6566 | Val loss 0.6609 | Val acc 0.5904
# Epoch 126/200 | Time 2.75s | Train loss 0.5947 | Train acc 0.6623 | Val loss 0.6386 | Val acc 0.6308
# Epoch 127/200 | Time 2.59s | Train loss 0.6035 | Train acc 0.6484 | Val loss 0.6694 | Val acc 0.6481
# Epoch 128/200 | Time 2.39s | Train loss 0.6044 | Train acc 0.6439 | Val loss 0.6747 | Val acc 0.5788
# Epoch 129/200 | Time 2.37s | Train loss 0.5967 | Train acc 0.6619 | Val loss 0.6620 | Val acc 0.6192
# Epoch 130/200 | Time 2.38s | Train loss 0.5896 | Train acc 0.6574 | Val loss 0.7525 | Val acc 0.6404
# Epoch 131/200 | Time 2.65s | Train loss 0.6179 | Train acc 0.6336 | Val loss 0.6638 | Val acc 0.6385
# Epoch 132/200 | Time 2.71s | Train loss 0.5899 | Train acc 0.6582 | Val loss 0.6633 | Val acc 0.6077
# Epoch 133/200 | Time 2.38s | Train loss 0.5937 | Train acc 0.6537 | Val loss 0.6412 | Val acc 0.6115
# Epoch 134/200 | Time 2.33s | Train loss 0.6057 | Train acc 0.6533 | Val loss 0.6299 | Val acc 0.6231
# Epoch 135/200 | Time 2.41s | Train loss 0.5970 | Train acc 0.6557 | Val loss 0.6442 | Val acc 0.6077
# Epoch 136/200 | Time 2.50s | Train loss 0.5955 | Train acc 0.6434 | Val loss 0.6424 | Val acc 0.6212
# Epoch 137/200 | Time 2.83s | Train loss 0.6040 | Train acc 0.6504 | Val loss 0.7183 | Val acc 0.6423
# Epoch 138/200 | Time 2.44s | Train loss 0.5946 | Train acc 0.6557 | Val loss 0.6674 | Val acc 0.6500
# Epoch 139/200 | Time 2.39s | Train loss 0.5926 | Train acc 0.6586 | Val loss 0.6394 | Val acc 0.6212
# Epoch 140/200 | Time 2.37s | Train loss 0.5892 | Train acc 0.6602 | Val loss 0.6597 | Val acc 0.6404
# Epoch 141/200 | Time 2.37s | Train loss 0.5847 | Train acc 0.6566 | Val loss 0.6661 | Val acc 0.6135
# Epoch 142/200 | Time 2.85s | Train loss 0.5830 | Train acc 0.6553 | Val loss 0.6484 | Val acc 0.6192
# Epoch 143/200 | Time 2.49s | Train loss 0.5857 | Train acc 0.6631 | Val loss 0.6319 | Val acc 0.6442
# Epoch 144/200 | Time 2.40s | Train loss 0.5919 | Train acc 0.6652 | Val loss 0.6468 | Val acc 0.6481
# Epoch 145/200 | Time 2.43s | Train loss 0.5885 | Train acc 0.6693 | Val loss 0.6427 | Val acc 0.6250
# Epoch 146/200 | Time 2.37s | Train loss 0.5856 | Train acc 0.6631 | Val loss 0.7288 | Val acc 0.6308
# Epoch 147/200 | Time 2.72s | Train loss 0.6054 | Train acc 0.6512 | Val loss 0.6792 | Val acc 0.5865
# Epoch 148/200 | Time 2.64s | Train loss 0.5927 | Train acc 0.6590 | Val loss 0.6415 | Val acc 0.5942
# Saved best model to /content/drive/MyDrive/PainRecognitionProject/models/best_testing_new_code_bi_lstm_2_classes_1434_coord.pt (metric=0.6596)
# Epoch 149/200 | Time 2.38s | Train loss 0.5989 | Train acc 0.6496 | Val loss 0.7175 | Val acc 0.6596
# Epoch 150/200 | Time 2.36s | Train loss 0.5874 | Train acc 0.6561 | Val loss 0.6637 | Val acc 0.6462
# Epoch 151/200 | Time 2.41s | Train loss 0.6004 | Train acc 0.6594 | Val loss 0.6391 | Val acc 0.6385
# Epoch 152/200 | Time 2.66s | Train loss 0.5877 | Train acc 0.6598 | Val loss 0.7018 | Val acc 0.6500
# Epoch 153/200 | Time 2.79s | Train loss 0.5908 | Train acc 0.6643 | Val loss 0.7203 | Val acc 0.6500
# Epoch 154/200 | Time 2.39s | Train loss 0.6048 | Train acc 0.6516 | Val loss 0.6427 | Val acc 0.6077
# Epoch 155/200 | Time 2.39s | Train loss 0.5852 | Train acc 0.6582 | Val loss 0.6418 | Val acc 0.6288
# Epoch 156/200 | Time 2.40s | Train loss 0.5822 | Train acc 0.6574 | Val loss 0.6463 | Val acc 0.6115
# Epoch 157/200 | Time 2.55s | Train loss 0.5835 | Train acc 0.6582 | Val loss 0.6319 | Val acc 0.6404
# Epoch 158/200 | Time 2.78s | Train loss 0.5791 | Train acc 0.6623 | Val loss 0.6641 | Val acc 0.6423
# Epoch 159/200 | Time 2.46s | Train loss 0.5838 | Train acc 0.6594 | Val loss 0.6860 | Val acc 0.6462
# Epoch 160/200 | Time 2.37s | Train loss 0.5821 | Train acc 0.6615 | Val loss 0.6895 | Val acc 0.6442
# Epoch 161/200 | Time 2.35s | Train loss 0.5815 | Train acc 0.6582 | Val loss 0.6421 | Val acc 0.6327
# Epoch 162/200 | Time 2.31s | Train loss 0.5803 | Train acc 0.6680 | Val loss 0.6656 | Val acc 0.6192
# Epoch 163/200 | Time 2.83s | Train loss 0.5909 | Train acc 0.6672 | Val loss 0.6597 | Val acc 0.6019
# Epoch 164/200 | Time 2.56s | Train loss 0.5831 | Train acc 0.6623 | Val loss 0.7166 | Val acc 0.6519
# Epoch 165/200 | Time 2.37s | Train loss 0.5773 | Train acc 0.6693 | Val loss 0.7009 | Val acc 0.6519
# Epoch 166/200 | Time 2.34s | Train loss 0.5802 | Train acc 0.6635 | Val loss 0.6439 | Val acc 0.6135
# Epoch 167/200 | Time 2.35s | Train loss 0.5774 | Train acc 0.6697 | Val loss 0.6647 | Val acc 0.6365
# Epoch 168/200 | Time 2.68s | Train loss 0.5746 | Train acc 0.6734 | Val loss 0.7022 | Val acc 0.6462
# Epoch 169/200 | Time 2.69s | Train loss 0.5762 | Train acc 0.6676 | Val loss 0.6651 | Val acc 0.6462
# Epoch 170/200 | Time 2.35s | Train loss 0.5829 | Train acc 0.6730 | Val loss 0.6920 | Val acc 0.6481
# Epoch 171/200 | Time 2.39s | Train loss 0.5767 | Train acc 0.6586 | Val loss 0.6575 | Val acc 0.6288
# Epoch 172/200 | Time 2.42s | Train loss 0.5848 | Train acc 0.6533 | Val loss 0.6957 | Val acc 0.5846
# Epoch 173/200 | Time 2.59s | Train loss 0.5745 | Train acc 0.6648 | Val loss 0.6587 | Val acc 0.6288
# Epoch 174/200 | Time 2.75s | Train loss 0.5721 | Train acc 0.6713 | Val loss 0.6838 | Val acc 0.6577
# Epoch 175/200 | Time 2.42s | Train loss 0.5741 | Train acc 0.6734 | Val loss 0.6695 | Val acc 0.6173
# Epoch 176/200 | Time 2.39s | Train loss 0.5800 | Train acc 0.6656 | Val loss 0.7043 | Val acc 0.6327
# Epoch 177/200 | Time 2.52s | Train loss 0.5809 | Train acc 0.6578 | Val loss 0.6866 | Val acc 0.6365
# Epoch 178/200 | Time 2.54s | Train loss 0.5770 | Train acc 0.6676 | Val loss 0.6907 | Val acc 0.6135
# Epoch 179/200 | Time 2.81s | Train loss 0.5710 | Train acc 0.6754 | Val loss 0.6592 | Val acc 0.6154
# Epoch 180/200 | Time 2.43s | Train loss 0.5816 | Train acc 0.6623 | Val loss 0.6621 | Val acc 0.6308
# Epoch 181/200 | Time 2.39s | Train loss 0.5721 | Train acc 0.6717 | Val loss 0.6934 | Val acc 0.6423
# Epoch 182/200 | Time 2.38s | Train loss 0.5744 | Train acc 0.6766 | Val loss 0.6949 | Val acc 0.6500
# Epoch 183/200 | Time 2.41s | Train loss 0.5654 | Train acc 0.6766 | Val loss 0.7032 | Val acc 0.6212
# Epoch 184/200 | Time 2.78s | Train loss 0.5682 | Train acc 0.6660 | Val loss 0.7527 | Val acc 0.6173
# Epoch 185/200 | Time 2.55s | Train loss 0.5810 | Train acc 0.6795 | Val loss 0.6916 | Val acc 0.6385
# Epoch 186/200 | Time 2.36s | Train loss 0.5807 | Train acc 0.6631 | Val loss 0.6866 | Val acc 0.6385
# Epoch 187/200 | Time 2.37s | Train loss 0.5736 | Train acc 0.6787 | Val loss 0.6807 | Val acc 0.6077
# Epoch 188/200 | Time 2.33s | Train loss 0.5772 | Train acc 0.6680 | Val loss 0.7015 | Val acc 0.6462
# Epoch 189/200 | Time 2.65s | Train loss 0.5652 | Train acc 0.6820 | Val loss 0.6663 | Val acc 0.6231
# Epoch 190/200 | Time 2.62s | Train loss 0.5664 | Train acc 0.6680 | Val loss 0.6618 | Val acc 0.6385
# Epoch 191/200 | Time 2.38s | Train loss 0.5677 | Train acc 0.6734 | Val loss 0.6688 | Val acc 0.6154
# Epoch 192/200 | Time 2.38s | Train loss 0.5854 | Train acc 0.6611 | Val loss 0.7279 | Val acc 0.6500
# Epoch 193/200 | Time 2.40s | Train loss 0.5758 | Train acc 0.6672 | Val loss 0.6803 | Val acc 0.6058
# Epoch 194/200 | Time 2.57s | Train loss 0.5706 | Train acc 0.6578 | Val loss 0.6973 | Val acc 0.6250
# Epoch 195/200 | Time 2.77s | Train loss 0.5716 | Train acc 0.6660 | Val loss 0.7208 | Val acc 0.6308
# Epoch 196/200 | Time 2.40s | Train loss 0.5682 | Train acc 0.6660 | Val loss 0.6982 | Val acc 0.6442
# Epoch 197/200 | Time 2.40s | Train loss 0.5734 | Train acc 0.6684 | Val loss 0.7124 | Val acc 0.6346
# Epoch 198/200 | Time 2.34s | Train loss 0.5667 | Train acc 0.6717 | Val loss 0.6948 | Val acc 0.6173
# Epoch 199/200 | Time 2.43s | Train loss 0.5697 | Train acc 0.6709 | Val loss 0.6606 | Val acc 0.6192
# Epoch 200/200 | Time 2.84s | Train loss 0.5681 | Train acc 0.6680 | Val loss 0.7081 | Val acc 0.6462
# Training finished. Best epoch: 148. Best monitored metric: 0.6596
# Final model saved to: /content/drive/MyDrive/PainRecognitionProject/models/testing_new_code_bi_lstm_2_classes_1434_coord.pt
# Best model saved to: /content/drive/MyDrive/PainRecognitionProject/models/best_testing_new_code_bi_lstm_2_classes_1434_coord.pt

# %%
trainer.plot_history()

# %% [markdown]
# #### Evaluate

# %%
model.load_state_dict(torch.load(best_model_path, map_location=DEVICE), strict=False)
# Out:
# <All keys matched successfully>

# %%
evaluator = Evaluator(model, test_loader, device=DEVICE, model_name=model_name, num_classes=NUM_CLASSES)

# %%
loss, acc, labels, preds = evaluator.evaluate_epoch()
# Out:
# ==================================================
# WYNIKI OCENY DLA MODELU: testing_new_code_bi_lstm_2_classes_1434_coord.pt
# ==================================================
# Test Loss: 0.5841
# Test Accuracy: 0.7096
#
# --- Szczegółowy Raport Klasyfikacji ---
#               precision    recall  f1-score   support
#
#      Klasa 0       0.68      0.81      0.74       260
#      Klasa 1       0.76      0.61      0.68       260
#
#     accuracy                           0.71       520
#    macro avg       0.72      0.71      0.71       520
# weighted avg       0.72      0.71      0.71       520
#
# ==================================================
# Confusion matrix:
#  [[210  50]
#  [101 159]]
