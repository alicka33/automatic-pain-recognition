# %% [markdown]
# ### Bi-LSTM model - multiclass training - 300 coordinates

# %% [markdown]
# #### Environment preparation

# %%
# Montowanie Google Drive
from google.colab import drive
drive.mount('/content/drive')

COLAB_ROOT = '/content/drive/MyDrive/PainRecognitionProject/'
print(f"Dane będą wczytywane z: {COLAB_ROOT}")
# Out:
# Mounted at /content/drive
# Dane będą wczytywane z: /content/drive/MyDrive/PainRecognitionProject/

# %%
import os

# Przejście do katalogu głównego
# %cd /content

# Klonowanie repo
# !rm -rf automatic-pain-recognition

print(f"Obecne położenie: {os.getcwd()}")
# Out:
# /content
# Obecne położenie: /content

# %%
# Upewnij się, że nazwa użytkownika i repozytorium są poprawne
USERNAME = 'alicka33'
REPO_NAME = 'automatic-pain-recognition'

# Tworzenie poprawnego adresu URL (format: https://<TOKEN>@github.com/...)
REPO_URL = f"https://github.com/{USERNAME}/{REPO_NAME}.git"

print("Rozpoczynam klonowanie...")

# Klonowanie
# !git clone {REPO_URL}

# Wejście do katalogu
# %cd $REPO_NAME
# Out:
# Rozpoczynam klonowanie...
# Cloning into 'automatic-pain-recognition'...
# remote: Enumerating objects: 328, done.
# remote: Counting objects: 100% (51/51), done.
# remote: Compressing objects: 100% (35/35), done.
# remote: Total 328 (delta 26), reused 41 (delta 16), pack-reused 277 (from 1)
# Receiving objects: 100% (328/328), 12.30 MiB | 18.33 MiB/s, done.
# Resolving deltas: 100% (150/150), done.
# /content/automatic-pain-recognition

# %%
# Instalacja wymaganych bibliotek
# !pip install -r requirements.txt

# %%
import sys
import os

# Dodaj katalog główny projektu do ścieżki systemowej
sys.path.append(os.getcwd())
print(f"Dodano do ścieżki Pythona: {os.getcwd()}")
# Out:
# Dodano do ścieżki Pythona: /content/automatic-pain-recognition

# %% [markdown]
# #### Bi-LSTM model - multiclas training

# %%
import os
import numpy as np
import pandas as pd
import shutil

import torch
import torch.nn as nn
from torch.utils.data import DataLoader
from torch.optim.lr_scheduler import ReduceLROnPlateau

from training_utils.preprocessed_dataset import PreprocessedDataset
from training_utils.train import Trainer
from training_utils.evaluate import Evaluator
from models.Bi_LSTM import SequenceModel

# %%
MAX_SEQUENCE_LENGTH = 46
NUM_FEATURES = 300
NUM_CLASSES = 5
HIDDEN_SIZE = 128
NUM_LAYERS = 2
NUM_EPOCHS = 200
BATCH_SIZE = 16
LEARNING_RATE = 0.00005
DROPOUT_PROB = 0.3
WEIGHT_DECAY = 0.005
SCHEDULER_FACTOR = 0.9

# %% [markdown]
# #### Data preparation

# %%
COLAB_ROOT = '/content/drive/MyDrive/PainRecognitionProject/'
PROCESSED_DATA_DIR = os.path.join(COLAB_ROOT, 'data/BioVid_HeatPain_processed_478_xyz_frontalized/')
MODEL_SAVE_DIR = os.path.join(COLAB_ROOT, 'models/')
LOCAL_PROCESSED_DATA_ROOT = '/content/temp_data/'

DEVICE = torch.device("cuda" if torch.cuda.is_available() else "cpu")

# %%
print("Kopiowanie danych z Google Drive do lokalnej pamięci Colab (RAM)...")
if os.path.exists(LOCAL_PROCESSED_DATA_ROOT):
    shutil.rmtree(LOCAL_PROCESSED_DATA_ROOT)
try:
    shutil.copytree(PROCESSED_DATA_DIR, LOCAL_PROCESSED_DATA_ROOT)
    print("✅ Kopiowanie zakończone pomyślnie. Czas trwania: (sprawdź zegar)")
    CURRENT_DATA_DIR = LOCAL_PROCESSED_DATA_ROOT

except Exception as e:
    print(f"❌ Błąd kopiowania danych (sprawdź, czy dane są zamontowane): {e}")
    print("Używam danych bezpośrednio z Drive (może się zawiesić).")
    CURRENT_DATA_DIR = PROCESSED_DATA_DIR
# Out:
# Kopiowanie danych z Google Drive do lokalnej pamięci Colab (RAM)...
# ✅ Kopiowanie zakończone pomyślnie. Czas trwania: (sprawdź zegar)

# %%
best100 = np.load('/content/drive/MyDrive/PainRecognitionProject/data/top_100_important_landmarks_emotions.npy')

# %%
best_100_landmarks = np.load('/content/drive/MyDrive/PainRecognitionProject/data/top_100_important_landmarks_emotions.npy')

feature_indices_x = best_100_landmarks * 3
feature_indices_y = best_100_landmarks * 3 + 1
feature_indices_z = best_100_landmarks * 3 + 2

# Interleave to get [X1, Y1, Z1, X2, Y2, Z2, ...]
best_300_features = np.stack([feature_indices_x, feature_indices_y, feature_indices_z], axis=1).flatten()

# %%
train_dataset = PreprocessedDataset(
    'train',
    processed_data_dir=CURRENT_DATA_DIR,
    indices=best_300_features,
    compute_euclidean=False,
    center_point_index=2,
    max_sequence_length=MAX_SEQUENCE_LENGTH,
    selected_labels=None,
    label_map=None,
)

val_dataset = PreprocessedDataset(
    'val',
    processed_data_dir=CURRENT_DATA_DIR,
    indices=best_300_features,
    compute_euclidean=False,
    center_point_index=2,
    max_sequence_length=MAX_SEQUENCE_LENGTH,
    selected_labels=None,
    label_map=None,
)

test_dataset = PreprocessedDataset(
    'test',
    processed_data_dir=CURRENT_DATA_DIR,
    indices=best_300_features,
    compute_euclidean=False,
    center_point_index=2,
    max_sequence_length=MAX_SEQUENCE_LENGTH,
    selected_labels=None,
    label_map=None,
)

# %%
def preview_single(dataset, idx=0, timesteps_to_show=3, features_to_show=8):
    x, y = dataset[idx]
    print(f"\nSingle sample idx={idx} from split={dataset.dataset_name}")
    print(f"x shape: {tuple(x.shape)}, y: {y}")
    print(np.round(x[:timesteps_to_show, :features_to_show], 4))

preview_single(train_dataset, 0)
preview_single(val_dataset, 0)
preview_single(test_dataset, 0)
# Out:
# Single sample idx=0 from split=train
# x shape: (46, 300), y: 0
# tensor([[0.1507, 0.1288, 0.1142, 0.1074, 0.2043, 0.0947, 0.1404, 0.0928],
#         [0.1488, 0.1293, 0.1180, 0.1079, 0.2146, 0.1028, 0.1382, 0.0917],
#         [0.1507, 0.1252, 0.1187, 0.1093, 0.2105, 0.1028, 0.1401, 0.0886]])
#
# Single sample idx=0 from split=val
# x shape: (46, 300), y: 0
# tensor([[0.1483, 0.1156, 0.1151, 0.1027, 0.1887, 0.0901, 0.1374, 0.0823],
#         [0.1522, 0.1143, 0.1157, 0.1043, 0.1852, 0.0900, 0.1415, 0.0816],
#         [0.1524, 0.1143, 0.1155, 0.1045, 0.1854, 0.0897, 0.1416, 0.0817]])
#
# Single sample idx=0 from split=test
# x shape: (46, 300), y: 0
# tensor([[0.1401, 0.1400, 0.1036, 0.0984, 0.2080, 0.0833, 0.1307, 0.1012],
#         [0.1392, 0.1376, 0.1043, 0.0974, 0.2055, 0.0839, 0.1297, 0.0993],
#         [0.1393, 0.1381, 0.1052, 0.0976, 0.2081, 0.0852, 0.1300, 0.0995]])

# %%
train_loader = DataLoader(train_dataset, batch_size=BATCH_SIZE, shuffle=True, num_workers=0, pin_memory=True)
for X, y in train_loader:
    print(X.shape, y.shape)  # (B, T_max, num_features)
    break

val_loader = DataLoader(val_dataset, batch_size=BATCH_SIZE, shuffle=True, num_workers=0, pin_memory=True)
for X, y in val_loader:
    print(X.shape, y.shape)  # (B, T_max, num_features)
    break

test_loader = DataLoader(test_dataset, batch_size=BATCH_SIZE, shuffle=True, num_workers=0, pin_memory=True)
for X, y in test_loader:
    print(X.shape, y.shape)  # (B, T_max, num_features)
    break
# Out:
# torch.Size([16, 46, 300]) torch.Size([16])
# torch.Size([16, 46, 300]) torch.Size([16])
# torch.Size([16, 46, 300]) torch.Size([16])

# %% [markdown]
# #### Model preparation

# %%
model = SequenceModel(NUM_FEATURES, HIDDEN_SIZE, NUM_LAYERS, NUM_CLASSES, DROPOUT_PROB).to(DEVICE)

# %% [markdown]
# #### Training

# %%
criterion = nn.CrossEntropyLoss()
optimizer = torch.optim.AdamW(model.parameters(), lr=LEARNING_RATE, weight_decay=WEIGHT_DECAY)

scheduler = ReduceLROnPlateau(
    optimizer,
    mode='max',
    factor=SCHEDULER_FACTOR,
    patience=10,
    min_lr=1e-7
)

model_name = 'testing_new_code_bi_lstm_5_classes_300_coord.pt'
model_filepath = os.path.join(MODEL_SAVE_DIR, model_name)

# %%
trainer = Trainer(
    model=model,
    train_loader=train_loader,
    val_loader=val_loader,
    optimizer=optimizer,
    scheduler=scheduler,
    criterion=criterion,
    device=DEVICE,
    model_save_path=model_filepath,
    num_epochs=NUM_EPOCHS,
    monitor='val_acc',  # or 'val_loss'
    minimize_monitor=False,
    save_best_only=True
)

# %%
trainer.print_training_config()
# Out:
# ==================================================
# 🚀 TRAINING CONFIGURATION
# ==================================================
#
# --- Model Architecture ---
#   Model Type            : SequenceModel
#   Input Features        : 300
#   Hidden Size           : 128
#   Num Layers            : 2
#   Bidirectional         : True
#   Dropout (LSTM)        : 0.3
#   Num Parameters        : 836869
#
# --- Optimizer & Regularization ---
#   Optimizer             : AdamW
#   Learning Rate (LR)    : 5e-05
#   Weight Decay (L2)     : 0.005
#
# --- Training Flow ---
#   Batch Size            : 16
#   Num Epochs            : 200
#   Device                : cuda
# ==================================================

# %%
final_model_path, best_model_path, history = trainer.fit()
print(f"Final model saved to: {final_model_path}")
if best_model_path:
    print(f"Best model saved to: {best_model_path}")
# Out:
# Starting training for 200 epochs on cuda
# Saved best model to /content/drive/MyDrive/PainRecognitionProject/models/best_testing_new_code_bi_lstm_5_classes_300_coord.pt (metric=0.2000)
# Epoch 1/200 | Time 15.13s | Train loss 1.6107 | Train acc 0.1959 | Val loss 1.6095 | Val acc 0.2000
# Epoch 2/200 | Time 9.76s | Train loss 1.6101 | Train acc 0.1977 | Val loss 1.6095 | Val acc 0.2000
# Epoch 3/200 | Time 6.04s | Train loss 1.6101 | Train acc 0.2052 | Val loss 1.6094 | Val acc 0.2000
# Epoch 4/200 | Time 6.07s | Train loss 1.6097 | Train acc 0.1961 | Val loss 1.6094 | Val acc 0.2000
# Epoch 5/200 | Time 6.31s | Train loss 1.6099 | Train acc 0.2000 | Val loss 1.6094 | Val acc 0.2000
# Epoch 6/200 | Time 5.85s | Train loss 1.6100 | Train acc 0.2000 | Val loss 1.6093 | Val acc 0.1985
# Epoch 7/200 | Time 6.56s | Train loss 1.6097 | Train acc 0.1916 | Val loss 1.6095 | Val acc 0.1985
# Epoch 8/200 | Time 5.82s | Train loss 1.6097 | Train acc 0.1970 | Val loss 1.6092 | Val acc 0.1938
# Saved best model to /content/drive/MyDrive/PainRecognitionProject/models/best_testing_new_code_bi_lstm_5_classes_300_coord.pt (metric=0.2008)
# Epoch 9/200 | Time 6.48s | Train loss 1.6096 | Train acc 0.2030 | Val loss 1.6090 | Val acc 0.2008
# Saved best model to /content/drive/MyDrive/PainRecognitionProject/models/best_testing_new_code_bi_lstm_5_classes_300_coord.pt (metric=0.2238)
# Epoch 10/200 | Time 5.91s | Train loss 1.6091 | Train acc 0.2069 | Val loss 1.6087 | Val acc 0.2238
# Saved best model to /content/drive/MyDrive/PainRecognitionProject/models/best_testing_new_code_bi_lstm_5_classes_300_coord.pt (metric=0.2254)
# Epoch 11/200 | Time 6.54s | Train loss 1.6089 | Train acc 0.2059 | Val loss 1.6077 | Val acc 0.2254
# Epoch 12/200 | Time 5.84s | Train loss 1.6064 | Train acc 0.2141 | Val loss 1.6023 | Val acc 0.2162
# Saved best model to /content/drive/MyDrive/PainRecognitionProject/models/best_testing_new_code_bi_lstm
# Epoch 187/200 | Time 5.90s | Train loss 1.5243 | Train acc 0.2815 | Val loss 1.6035 | Val acc 0.2392
# Epoch 188/200 | Time 6.54s | Train loss 1.5229 | Train acc 0.2810 | Val loss 1.5849 | Val acc 0.2592
# Epoch 189/200 | Time 5.84s | Train loss 1.5235 | Train acc 0.2743 | Val loss 1.6379 | Val acc 0.2577
# Epoch 190/200 | Time 6.37s | Train loss 1.5240 | Train acc 0.2779 | Val loss 1.6481 | Val acc 0.2462
# Epoch 191/200 | Time 5.90s | Train loss 1.5238 | Train acc 0.2751 | Val loss 1.6015 | Val acc 0.2423
# Saved best model to /content/drive/MyDrive/PainRecognitionProject/models/best_testing_new_code_bi_lstm_5_classes_300_coord.pt (metric=0.2638)
# Epoch 192/200 | Time 6.45s | Train loss 1.5252 | Train acc 0.2818 | Val loss 1.5775 | Val acc 0.2638
# Epoch 193/200 | Time 5.88s | Train loss 1.5177 | Train acc 0.2825 | Val loss 1.5969 | Val acc 0.2477
# Epoch 194/200 | Time 6.39s | Train loss 1.5216 | Train acc 0.2877 | Val loss 1.5794 | Val acc 0.2477
# Epoch 195/200 | Time 5.87s | Train loss 1.5220 | Train acc 0.2861 | Val loss 1.6483 | Val acc 0.2369
# Epoch 196/200 | Time 6.27s | Train loss 1.5242 | Train acc 0.2793 | Val loss 1.5931 | Val acc 0.2446
# Epoch 197/200 | Time 5.95s | Train loss 1.5259 | Train acc 0.2792 | Val loss 1.5786 | Val acc 0.2577
# Epoch 198/200 | Time 6.15s | Train loss 1.5229 | Train acc 0.2843 | Val loss 1.5766 | Val acc 0.2485
# Epoch 199/200 | Time 6.12s | Train loss 1.5213 | Train acc 0.2843 | Val loss 1.5876 | Val acc 0.2538
# Epoch 200/200 | Time 6.15s | Train loss 1.5217 | Train acc 0.2828 | Val loss 1.5924 | Val acc 0.2462
# Training finished. Best epoch: 191. Best monitored metric: 0.2638
# Final model saved to: /content/drive/MyDrive/PainRecognitionProject/models/testing_new_code_bi_lstm_5_classes_300_coord.pt
# Best model saved to: /content/drive/MyDrive/PainRecognitionProject/models/best_testing_new_code_bi_lstm_5_classes_300_coord.pt

# %%
trainer.plot_history()

# %% [markdown]
# #### Evaluate

# %%
model.load_state_dict(torch.load(best_model_path, map_location=DEVICE), strict=False)
# Out:
# <All keys matched successfully>

# %%
evaluator = Evaluator(model, test_loader, device=DEVICE, model_name=model_name, num_classes=NUM_CLASSES)

# %%
loss, acc, labels, preds = evaluator.evaluate_epoch()
# Out:
# ==================================================
# WYNIKI OCENY DLA MODELU: testing_new_code_bi_lstm_5_classes_300_coord.pt
# ==================================================
# Test Loss: 1.6092
# Test Accuracy: 0.2908
#
# --- Szczegółowy Raport Klasyfikacji ---
#               precision    recall  f1-score   support
#
#      Klasa 0       0.26      0.63      0.37       260
#      Klasa 1       0.22      0.04      0.07       260
#      Klasa 2       0.22      0.08      0.11       260
#      Klasa 3       0.23      0.13      0.17       260
#      Klasa 4       0.39      0.57      0.46       260
#
#     accuracy                           0.29      1300
#    macro avg       0.26      0.29      0.24      1300
# weighted avg       0.26      0.29      0.24      1300
#
# ==================================================
# Confusion matrix:
#  [[164   6  25  35  30]
#  [153  11  24  28  44]
#  [131  13  20  31  65]
#  [106  11  15  35  93]
#  [ 71  10   9  22 148]]
