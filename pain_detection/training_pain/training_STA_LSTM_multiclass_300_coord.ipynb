# %% [markdown]
# ### STA-LSTM model - multiclass training - 300 coordinates

# %% [markdown]
# #### Environment preparation

# %%
# Montowanie Google Drive
from google.colab import drive
drive.mount('/content/drive')

COLAB_ROOT = '/content/drive/MyDrive/PainRecognitionProject/'
print(f"Dane będą wczytywane z: {COLAB_ROOT}")
# Out:
# Mounted at /content/drive
# Dane będą wczytywane z: /content/drive/MyDrive/PainRecognitionProject/

# %%
import os

# Przejście do katalogu głównego
# %cd /content

# Klonowanie repo
# !rm -rf automatic-pain-recognition

print(f"Obecne położenie: {os.getcwd()}")
# Out:
# /content
# Obecne położenie: /content

# %%
# Upewnij się, że nazwa użytkownika i repozytorium są poprawne
USERNAME = 'alicka33'
REPO_NAME = 'automatic-pain-recognition'

# Tworzenie poprawnego adresu URL (format: https://<TOKEN>@github.com/...)
REPO_URL = f"https://github.com/{USERNAME}/{REPO_NAME}.git"

print("Rozpoczynam klonowanie...")

# Klonowanie
# !git clone {REPO_URL}

# Wejście do katalogu
# %cd $REPO_NAME
# Out:
# Rozpoczynam klonowanie...
# Cloning into 'automatic-pain-recognition'...
# remote: Enumerating objects: 344, done.
# remote: Counting objects: 100% (67/67), done.
# remote: Compressing objects: 100% (46/46), done.
# remote: Total 344 (delta 34), reused 53 (delta 20), pack-reused 277 (from 1)
# Receiving objects: 100% (344/344), 12.43 MiB | 17.77 MiB/s, done.
# Resolving deltas: 100% (158/158), done.
# /content/automatic-pain-recognition

# %%
# Instalacja wymaganych bibliotek
# !pip install -r requirements.txt

# %%
import sys
import os

# Dodaj katalog główny projektu do ścieżki systemowej
sys.path.append(os.getcwd())
print(f"Dodano do ścieżki Pythona: {os.getcwd()}")
# Out:
# Dodano do ścieżki Pythona: /content/automatic-pain-recognition

# %% [markdown]
# #### STA-LSTM model - multiclass training

# %%
import os
import numpy as np
import pandas as pd
import shutil

import torch
import torch.nn as nn
from torch.utils.data import DataLoader
from torch.optim.lr_scheduler import ReduceLROnPlateau

from training_utils.preprocessed_dataset import PreprocessedDataset
from training_utils.train import Trainer
from training_utils.evaluate import Evaluator
from models.STA_LSTM import STA_LSTM

# %%
MAX_SEQUENCE_LENGTH = 46
NUM_FEATURES = 300
NUM_CLASSES = 5
HIDDEN_SIZE = 128
NUM_LAYERS = 2
NUM_EPOCHS = 200
BATCH_SIZE = 16
LEARNING_RATE = 0.00005
DROPOUT_PROB = 0.3
WEIGHT_DECAY = 0.005
SCHEDULER_FACTOR = 0.9

# %% [markdown]
# #### Data preparation

# %%
COLAB_ROOT = '/content/drive/MyDrive/PainRecognitionProject/'
PROCESSED_DATA_DIR = os.path.join(COLAB_ROOT, 'data/BioVid_HeatPain_processed_478_xyz_frontalized/')
MODEL_SAVE_DIR = os.path.join(COLAB_ROOT, 'models/')
LOCAL_PROCESSED_DATA_ROOT = '/content/temp_data/'

DEVICE = torch.device("cuda" if torch.cuda.is_available() else "cpu")

# %%
print("Kopiowanie danych z Google Drive do lokalnej pamięci Colab (RAM)...")
if os.path.exists(LOCAL_PROCESSED_DATA_ROOT):
    shutil.rmtree(LOCAL_PROCESSED_DATA_ROOT)
try:
    shutil.copytree(PROCESSED_DATA_DIR, LOCAL_PROCESSED_DATA_ROOT)
    print("✅ Kopiowanie zakończone pomyślnie. Czas trwania: (sprawdź zegar)")
    CURRENT_DATA_DIR = LOCAL_PROCESSED_DATA_ROOT

except Exception as e:
    print(f"❌ Błąd kopiowania danych (sprawdź, czy dane są zamontowane): {e}")
    print("Używam danych bezpośrednio z Drive (może się zawiesić).")
    CURRENT_DATA_DIR = PROCESSED_DATA_DIR
# Out:
# Kopiowanie danych z Google Drive do lokalnej pamięci Colab (RAM)...
# ✅ Kopiowanie zakończone pomyślnie. Czas trwania: (sprawdź zegar)

# %%
best_100_landmarks = np.load('/content/drive/MyDrive/PainRecognitionProject/data/top_100_important_landmarks_emotions.npy')

feature_indices_x = best_100_landmarks * 3
feature_indices_y = best_100_landmarks * 3 + 1
feature_indices_z = best_100_landmarks * 3 + 2

# Interleave to get [X1, Y1, Z1, X2, Y2, Z2, ...]
best_300_features = np.stack([feature_indices_x, feature_indices_y, feature_indices_z], axis=1).flatten()

# %%
train_dataset = PreprocessedDataset(
    'train',
    processed_data_dir=CURRENT_DATA_DIR,
    indices=best_300_features,
    compute_euclidean=False,
    center_point_index=2,
    max_sequence_length=MAX_SEQUENCE_LENGTH,
    selected_labels=None,
    label_map=None,
)

val_dataset = PreprocessedDataset(
    'val',
    processed_data_dir=CURRENT_DATA_DIR,
    indices=best_300_features,
    compute_euclidean=False,
    center_point_index=2,
    max_sequence_length=MAX_SEQUENCE_LENGTH,
    selected_labels=None,
    label_map=None,
)

test_dataset = PreprocessedDataset(
    'test',
    processed_data_dir=CURRENT_DATA_DIR,
    indices=best_300_features,
    compute_euclidean=False,
    center_point_index=2,
    max_sequence_length=MAX_SEQUENCE_LENGTH,
    selected_labels=None,
    label_map=None,
)

# %%
def preview_single(dataset, idx=0, timesteps_to_show=3, features_to_show=8):
    x, y = dataset[idx]
    print(f"\nSingle sample idx={idx} from split={dataset.dataset_name}")
    print(f"x shape: {tuple(x.shape)}, y: {y}")
    print(np.round(x[:timesteps_to_show, :features_to_show], 4))

preview_single(train_dataset, 0)
preview_single(val_dataset, 0)
preview_single(test_dataset, 0)
# Out:
# Single sample idx=0 from split=train
# x shape: (46, 300), y: 0
# tensor([[0.1507, 0.1288, 0.1142, 0.1074, 0.2043, 0.0947, 0.1404, 0.0928],
#         [0.1488, 0.1293, 0.1180, 0.1079, 0.2146, 0.1028, 0.1382, 0.0917],
#         [0.1507, 0.1252, 0.1187, 0.1093, 0.2105, 0.1028, 0.1401, 0.0886]])
#
# Single sample idx=0 from split=val
# x shape: (46, 300), y: 0
# tensor([[0.1483, 0.1156, 0.1151, 0.1027, 0.1887, 0.0901, 0.1374, 0.0823],
#         [0.1522, 0.1143, 0.1157, 0.1043, 0.1852, 0.0900, 0.1415, 0.0816],
#         [0.1524, 0.1143, 0.1155, 0.1045, 0.1854, 0.0897, 0.1416, 0.0817]])
#
# Single sample idx=0 from split=test
# x shape: (46, 300), y: 0
# tensor([[0.1401, 0.1400, 0.1036, 0.0984, 0.2080, 0.0833, 0.1307, 0.1012],
#         [0.1392, 0.1376, 0.1043, 0.0974, 0.2055, 0.0839, 0.1297, 0.0993],
#         [0.1393, 0.1381, 0.1052, 0.0976, 0.2081, 0.0852, 0.1300, 0.0995]])

# %%
train_loader = DataLoader(train_dataset, batch_size=BATCH_SIZE, shuffle=True, num_workers=0, pin_memory=True)
for X, y in train_loader:
    print(X.shape, y.shape)  # (B, T_max, num_features)
    break

val_loader = DataLoader(val_dataset, batch_size=BATCH_SIZE, shuffle=True, num_workers=0, pin_memory=True)
for X, y in val_loader:
    print(X.shape, y.shape)  # (B, T_max, num_features)
    break

test_loader = DataLoader(test_dataset, batch_size=BATCH_SIZE, shuffle=True, num_workers=0, pin_memory=True)
for X, y in test_loader:
    print(X.shape, y.shape)  # (B, T_max, num_features)
    break
# Out:
# torch.Size([16, 46, 300]) torch.Size([16])
# torch.Size([16, 46, 300]) torch.Size([16])
# torch.Size([16, 46, 300]) torch.Size([16])

# %% [markdown]
# #### Model preparation

# %%
model = STA_LSTM(NUM_FEATURES, HIDDEN_SIZE, NUM_LAYERS, NUM_CLASSES, DROPOUT_PROB).to(DEVICE)

# %% [markdown]
# #### Training

# %%
criterion = nn.CrossEntropyLoss()
optimizer = torch.optim.AdamW(model.parameters(), lr=LEARNING_RATE, weight_decay=WEIGHT_DECAY)

scheduler = ReduceLROnPlateau(
    optimizer,
    mode='max',
    factor=SCHEDULER_FACTOR,
    patience=10,
    min_lr=1e-7
)

model_name = 'testing_new_code_sta_lstm_5_classes_300_coord.pt'
model_filepath = os.path.join(MODEL_SAVE_DIR, model_name)

# %%
trainer = Trainer(
    model=model,
    train_loader=train_loader,
    val_loader=val_loader,
    optimizer=optimizer,
    scheduler=scheduler,
    criterion=criterion,
    device=DEVICE,
    model_save_path=model_filepath,
    num_epochs=NUM_EPOCHS,
    monitor='val_acc',  # or 'val_loss'
    minimize_monitor=False,
    save_best_only=True
)

# %%
trainer.print_training_config()
# Out:
# ==================================================
# 🚀 TRAINING CONFIGURATION
# ==================================================
#
# --- Model Architecture ---
#   Model Type            : STA_LSTM
#   Input Features        : 300
#   Hidden Size           : 128
#   Num Layers            : 2
#   Bidirectional         : True
#   Dropout (LSTM)        : 0.3
#   Num Parameters        : 947634
#
# --- Optimizer & Regularization ---
#   Optimizer             : AdamW
#   Learning Rate (LR)    : 5e-05
#   Weight Decay (L2)     : 0.005
#
# --- Training Flow ---
#   Batch Size            : 16
#   Num Epochs            : 200
#   Device                : cuda
# ==================================================

# %%
final_model_path, best_model_path, history = trainer.fit()
print(f"Final model saved to: {final_model_path}")
if best_model_path:
    print(f"Best model saved to: {best_model_path}")
# Out:
# Starting training for 200 epochs on cuda
# Saved best model to /content/drive/MyDrive/PainRecognitionProject/models/best_testing_new_code_sta_lstm_5_classes_300_coord.pt (metric=0.2000)
# Epoch 1/200 | Time 19.60s | Train loss 1.6645 | Train acc 0.2028 | Val loss 1.6226 | Val acc 0.2000
# Epoch 2/200 | Time 9.67s | Train loss 1.6450 | Train acc 0.1959 | Val loss 1.6152 | Val acc 0.1992
# Epoch 3/200 | Time 6.34s | Train loss 1.6352 | Train acc 0.1925 | Val loss 1.6116 | Val acc 0.2000
# Epoch 4/200 | Time 6.59s | Train loss 1.6307 | Train acc 0.1992 | Val loss 1.6092 | Val acc 0.2000
# Saved best model to /content/drive/MyDrive/PainRecognitionProject/models/best_testing_new_code_sta_lstm_5_classes_300_coord.pt (metric=0.2185)
# Epoch 5/200 | Time 6.26s | Train loss 1.6272 | Train acc 0.2030 | Val loss 1.6150 | Val acc 0.2185
# Epoch 6/200 | Time 6.69s | Train loss 1.6225 | Train acc 0.2148 | Val loss 1.6088 | Val acc 0.2177
# Epoch 7/200 | Time 6.16s | Train loss 1.6183 | Train acc 0.2179 | Val loss 1.6130 | Val acc 0.2000
# Epoch 8/200 | Time 6.71s | Train loss 1.6161 | Train acc 0.2144 | Val loss 1.6105 | Val acc 0.2138
# Epoch 9/200 | Time 5.99s | Train loss 1.6142 | Train acc 0.2218 | Val loss 1.6101 | Val acc 0.2123
# Epoch 10/200 | Time 6.83s | Train loss 1.6114 | Train acc 0.2179 | Val loss 1.5991 | Val acc 0.2131
# Saved best model to /content/drive/MyDrive/PainRecognitionProject/models/best_testing_new_code_sta_lstm_5_classes_300_coord.pt (metric=0.2308)
# Epoch 11/200 | Time 6.02s | Train loss 1.6024 | Train acc 0.2266 | Val loss 1.5999 | Val acc 0.2308
# Epoch 12/200 | Time 6.74s | Train loss 1.6042 | Train acc 0.2207 | Val loss 1.5967 | Val acc 0.2215
# Saved best model to /content/drive/MyDrive/PainRecognitionProject/models/best_testing_new_code_sta_lstm_5_classes_300_coord.pt (metric=0.2400)
# Epoch 13/200 | Time 5.95s | Train loss 1.6005 | Train acc 0.2259 | Val loss 1.5943 | Val acc 0.2400
# Epoch 14/200 | Time 6.79s | Train loss 1.5961 | Train acc 0.2416 | Val loss 1.5994 | Val acc 0.2277
# Epoch 15/200 | Time 6.06s | Train loss 1.5935 | Train acc 0.2362 | Val loss 1.6015 | Val acc 0.2285
# Saved best model to /content/drive/MyDrive/PainRecognitionProject/models/best_testing_new_code_sta_lstm_5_classes_300_coord.pt (metric=0.2423)
# Epoch 16/200 | Time 6.83s | Train loss 1.5846 | Train acc 0.2415 | Val loss 1.5806 | Val acc 0.2423
# Epoch 17/200 | Time 6.03s | Train loss 1.5782 | Train acc 0.2531 | Val loss 1.5863 | Val acc 0.2315
# Saved best model to /content/drive/MyDrive/PainRecognitionProject/models/best_testing_new_code_sta_lstm_5_classes_300_coord.pt (metric=0.2462)
# Epoch 18/200 | Time 6.74s | Train loss 1.5768 | Train acc 0.2543 | Val loss 1.5758 | Val acc 0.2462
# Saved best model to /content/drive/MyDrive/PainRecognitionProject/models/best_testing_new_code_sta_lstm_5_classes_300_coord.pt (metric=0.2492)
# Epoch 19/200 | Time 6.05s | Train loss 1.5704 | Train acc 0.2654 | Val loss 1.5679 | Val acc 0.2492
# Saved best model to /content/drive/MyDrive/PainRecognitionProject/models/best_testing_new_code_sta_lstm_5_classes_300_coord.pt (metric=0.2623)
# Epoch 20/200 | Time 6.99s | Train loss 1.5720 | Train acc 0.2575 | Val loss 1.5690 | Val acc 0.2623
# Epoch 21/200 | Time 6.08s | Train loss 1.5746 | Train acc 0.2487 | Val loss 1.5841 | Val acc 0.2446
# Epoch 22/200 | Time 6.81s | Train loss 1.5660 | Train acc 0.2611 | Val loss 1.5711 | Val acc 0.2554
# Epoch 23/200 | Time 6.11s | Train loss 1.5704 | Train acc 0.2564 | Val loss 1.5760 | Val acc 0.2362
# Epoch 24/200 | Time 6.80s | Train loss 1.5629 | Train acc 0.2625 | Val loss 1.5626 | Val acc 0.2577
# Saved best model to /content/drive/MyDrive/PainRecognitionProject/models/best_testing_new_code_sta_lstm_5_classes_300_coord.pt (metric=0.2754)
# Epoch 25/200 | Time 6.06s | Train loss 1.5662 | Train acc 0.2615 | Val loss 1.5721 | Val acc 0.2754
# Epoch 26/200 | Time 6.76s | Train loss 1.5607 | Train acc 0.2656 | Val loss 1.5778 | Val acc 0.2485
# Epoch 27/200 | Time 6.04s | Train loss 1.5611 | Train acc 0.2738 | Val loss 1.5693 | Val acc 0.2646
# Epoch 28/200 | Time 6.75s | Train loss 1.5632 | Train acc 0.2651 | Val loss 1.5694 | Val acc 0.2485
# Epoch 29/200 | Time 6.03s | Train loss 1.5637 | Train acc 0.2641 | Val loss 1.5645 | Val acc 0.2554
# Epoch 30/200 | Time 6.75s | Train loss 1.5585 | Train acc 0.2713 | Val loss 1.5670 | Val acc 0.2523
# Epoch 31/200 | Time 5.94s | Train loss 1.5578 | Train acc 0.2595 | Val loss 1.5672 | Val acc 0.2592
# Epoch 32/200 | Time 6.76s | Train loss 1.5589 | Train acc 0.2662 | Val loss 1.5574 | Val acc 0.2723
# Epoch 33/200 | Time 6.04s | Train loss 1.5566 | Train acc 0.2684 | Val loss 1.5593 | Val acc 0.2708
# Epoch 34/200 | Time 6.80s | Train loss 1.5581 | Train acc 0.2608 | Val loss 1.5551 | Val acc 0.2723
# Epoch 35/200 | Time 6.13s | Train loss 1.5545 | Train acc 0.2661 | Val loss 1.5562 | Val acc 0.2585
# Epoch 36/200 | Time 6.86s | Train loss 1.5545 | Train acc 0.2630 | Val loss 1.5633 | Val acc 0.2654
# Epoch 37/200 | Time 6.09s | Train loss 1.5507 | Train acc 0.2710 | Val loss 1.5590 | Val acc 0.2723
# Epoch 38/200 | Time 6.78s | Train loss 1.5472 | Train acc 0.2720 | Val loss 1.5632 | Val acc 0.2646
# Epoch 39/200 | Time 6.06s | Train loss 1.5475 | Train acc 0.2710 | Val loss 1.5680 | Val acc 0.2600
# Saved best model to /content/drive/MyDrive/PainRecognitionProject/models/best_testing_new_code_sta_lstm_5_classes_300_coord.pt (metric=0.2769)
# Epoch 40/200 | Time 6.77s | Train loss 1.5454 | Train acc 0.2805 | Val loss 1.5654 | Val acc 0.2769
# Epoch 41/200 | Time 6.07s | Train loss 1.5443 | Train acc 0.2764 | Val loss 1.5458 | Val acc 0.2692
# Epoch 42/200 | Time 6.84s | Train loss 1.5459 | Train acc 0.2743 | Val loss 1.5590 | Val acc 0.2569
# Epoch 43/200 | Time 6.12s | Train loss 1.5463 | Train acc 0.2695 | Val loss 1.5536 | Val acc 0.2723
# Epoch 44/200 | Time 6.83s | Train loss 1.5441 | Train acc 0.2610 | Val loss 1.5489 | Val acc 0.2762
# Epoch 45/200 | Time 6.07s | Train loss 1.5458 | Train acc 0.2657 | Val loss 1.5563 | Val acc 0.2669
# Saved best model to /content/drive/MyDrive/PainRecognitionProject/models/best_testing_new_code_sta_lstm_5_classes_300_coord.pt (metric=0.2815)
# Epoch 46/200 | Time 6.82s | Train loss 1.5472 | Train acc 0.2687 | Val loss 1.5475 | Val acc 0.2815
# Saved best model to /content/drive/MyDrive/PainRecognitionProject/models/best_testing_new_code_sta_lstm_5_classes_300_coord.pt (metric=0.2846)
# Epoch 47/200 | Time 6.11s | Train loss 1.5444 | Train acc 0.2672 | Val loss 1.5465 | Val acc 0.2846
# Saved best model to /content/drive/MyDrive/PainRecognitionProject/models/best_testing_new_code_sta_lstm_5_classes_300_coord.pt (metric=0.2869)
# Epoch 48/200 | Time 6.73s | Train loss 1.5436 | Train acc 0.2725 | Val loss 1.5418 | Val acc 0.2869
# Epoch 49/200 | Time 6.00s | Train loss 1.5432 | Train acc 0.2746 | Val loss 1.5437 | Val acc 0.2715
# Epoch 50/200 | Time 6.69s | Train loss 1.5424 | Train acc 0.2782 | Val loss 1.5418 | Val acc 0.2838
# Epoch 51/200 | Time 6.10s | Train loss 1.5364 | Train acc 0.2697 | Val loss 1.5489 | Val acc 0.2785
# Epoch 52/200 | Time 6.60s | Train loss 1.5398 | Train acc 0.2775 | Val loss 1.5453 | Val acc 0.2792
# Epoch 53/200 | Time 6.24s | Train loss 1.5403 | Train acc 0.2787 | Val loss 1.5532 | Val acc 0.2654
# Epoch 54/200 | Time 6.61s | Train loss 1.5406 | Train acc 0.2715 | Val loss 1.5456 | Val acc 0.2762
# Epoch 55/200 | Time 6.31s | Train loss 1.5327 | Train acc 0.2797 | Val loss 1.5467 | Val acc 0.2762
# Epoch 56/200 | Time 6.47s | Train loss 1.5348 | Train acc 0.2780 | Val loss 1.5648 | Val acc 0.2754
# Epoch 57/200 | Time 6.38s | Train loss 1.5355 | Train acc 0.2867 | Val loss 1.5754 | Val acc 0.2454
# Epoch 58/200 | Time 6.36s | Train loss 1.5363 | Train acc 0.2675 | Val loss 1.5647 | Val acc 0.2654
# Epoch 59/200 | Time 6.43s | Train loss 1.5342 | Train acc 0.2656 | Val loss 1.5400 | Val acc 0.2808
# Epoch 60/200 | Time 6.39s | Train loss 1.5312 | Train acc 0.2752 | Val loss 1.5501 | Val acc 0.2623
# Epoch 61/200 | Time 6.48s | Train loss 1.5284 | Train acc 0.2793 | Val loss 1.5508 | Val acc 0.2792
# Epoch 62/200 | Time 6.26s | Train loss 1.5314 | Train acc 0.2756 | Val loss 1.5510 | Val acc 0.2731
# Epoch 63/200 | Time 6.54s | Train loss 1.5285 | Train acc 0.2797 | Val loss 1.5447 | Val acc 0.2777
# Epoch 64/200 | Time 6.21s | Train loss 1.5290 | Train acc 0.2756 | Val loss 1.5479 | Val acc 0.2723
# Epoch 65/200 | Time 6.56s | Train loss 1.5296 | Train acc 0.2811 | Val loss 1.5512 | Val acc 0.2846
# Epoch 66/200 | Time 6.18s | Train loss 1.5270 | Train acc 0.2798 | Val loss 1.5390 | Val acc 0.2769
# Epoch 67/200 | Time 6.62s | Train loss 1.5275 | Train acc 0.2839 | Val loss 1.5469 | Val acc 0.2762
# Epoch 68/200 | Time 5.94s | Train loss 1.5249 | Train acc 0.2805 | Val loss 1.5468 | Val acc 0.2792
# Epoch 69/200 | Time 6.75s | Train loss 1.5279 | Train acc 0.2757 | Val loss 1.5433 | Val acc 0.2723
# Epoch 70/200 | Time 6.00s | Train loss 1.5265 | Train acc 0.2766 | Val loss 1.5425 | Val acc 0.2808
# Epoch 71/200 | Time 6.69s | Train loss 1.5230 | Train acc 0.2844 | Val loss 1.5463 | Val acc 0.2815
# Epoch 72/200 | Time 6.06s | Train loss 1.5240 | Train acc 0.2874 | Val loss 1.5402 | Val acc 0.2769
# Epoch 73/200 | Time 6.76s | Train loss 1.5222 | Train acc 0.2918 | Val loss 1.5507 | Val acc 0.2662
# Saved best model to /content/drive/MyDrive/PainRecognitionProject/models/best_testing_new_code_sta_lstm_5_classes_300_coord.pt (metric=0.2908)
# Epoch 74/200 | Time 5.97s | Train loss 1.5176 | Train acc 0.2877 | Val loss 1.5389 | Val acc 0.2908
# Epoch 75/200 | Time 6.74s | Train loss 1.5188 | Train acc 0.2885 | Val loss 1.5584 | Val acc 0.2669
# Epoch 76/200 | Time 6.10s | Train loss 1.5231 | Train acc 0.2798 | Val loss 1.5604 | Val acc 0.2662
# Epoch 77/200 | Time 6.69s | Train loss 1.5197 | Train acc 0.2818 | Val loss 1.5403 | Val acc 0.2808
# Epoch 78/200 | Time 5.99s | Train loss 1.5185 | Train acc 0.2915 | Val loss 1.5428 | Val acc 0.2792
# Epoch 79/200 | Time 6.69s | Train loss 1.5182 | Train acc 0.2880 | Val loss 1.5388 | Val acc 0.2854
# Epoch 80/200 | Time 6.14s | Train loss 1.5168 | Train acc 0.2918 | Val loss 1.5338 | Val acc 0.2823
# Epoch 81/200 | Time 6.72s | Train loss 1.5187 | Train acc 0.2831 | Val loss 1.5376 | Val acc 0.2785
# Epoch 82/200 | Time 5.96s | Train loss 1.5154 | Train acc 0.2882 | Val loss 1.5542 | Val acc 0.2715
# Epoch 83/200 | Time 6.74s | Train loss 1.5150 | Train acc 0.2974 | Val loss 1.5425 | Val acc 0.2800
# Epoch 84/200 | Time 5.97s | Train loss 1.5165 | Train acc 0.2872 | Val loss 1.5297 | Val acc 0.2831
# Epoch 85/200 | Time 6.75s | Train loss 1.5186 | Train acc 0.2890 | Val loss 1.5435 | Val acc 0.2646
# Epoch 86/200 | Time 6.04s | Train loss 1.5162 | Train acc 0.2925 | Val loss 1.5310 | Val acc 0.2831
# Epoch 87/200 | Time 6.78s | Train loss 1.5142 | Train acc 0.2933 | Val loss 1.5530 | Val acc 0.2669
# Epoch 88/200 | Time 5.97s | Train loss 1.5146 | Train acc 0.2952 | Val loss 1.5416 | Val acc 0.2685
# Epoch 89/200 | Time 6.75s | Train loss 1.5126 | Train acc 0.2939 | Val loss 1.5663 | Val acc 0.2738
# Epoch 90/200 | Time 6.04s | Train loss 1.5170 | Train acc 0.2831 | Val loss 1.5456 | Val acc 0.2815
# Epoch 91/200 | Time 6.69s | Train loss 1.5129 | Train acc 0.2848 | Val loss 1.5384 | Val acc 0.2869
# Epoch 92/200 | Time 6.05s | Train loss 1.5116 | Train acc 0.2857 | Val loss 1.5520 | Val acc 0.2708
# Epoch 93/200 | Time 6.73s | Train loss 1.5097 | Train acc 0.2944 | Val loss 1.5327 | Val acc 0.2692
# Epoch 94/200 | Time 6.07s | Train loss 1.5065 | Train acc 0.2987 | Val loss 1.5515 | Val acc 0.2715
# Epoch 95/200 | Time 6.79s | Train loss 1.5084 | Train acc 0.2923 | Val loss 1.5379 | Val acc 0.2785
# Epoch 96/200 | Time 6.01s | Train loss 1.5087 | Train acc 0.2930 | Val loss 1.5340 | Val acc 0.2831
# Epoch 97/200 | Time 6.58s | Train loss 1.5064 | Train acc 0.2964 | Val loss 1.5481 | Val acc 0.2785
# Epoch 98/200 | Time 6.19s | Train loss 1.5060 | Train acc 0.2911 | Val loss 1.5457 | Val acc 0.2746
# Epoch 99/200 | Time 6.48s | Train loss 1.5084 | Train acc 0.3036 | Val loss 1.5417 | Val acc 0.2677
# Epoch 100/200 | Time 6.33s | Train loss 1.5086 | Train acc 0.2885 | Val loss 1.5297 | Val acc 0.2823
# Epoch 101/200 | Time 6.47s | Train loss 1.5038 | Train acc 0.2954 | Val loss 1.5373 | Val acc 0.2792
# Epoch 102/200 | Time 6.30s | Train loss 1.5083 | Train acc 0.2934 | Val loss 1.5328 | Val acc 0.2846
# Epoch 103/200 | Time 6.28s | Train loss 1.5066 | Train acc 0.2923 | Val loss 1.5331 | Val acc 0.2854
# Epoch 104/200 | Time 6.46s | Train loss 1.5066 | Train acc 0.2898 | Val loss 1.5343 | Val acc 0.2869
# Epoch 105/200 | Time 6.26s | Train loss 1.5043 | Train acc 0.2895 | Val loss 1.5534 | Val acc 0.2638
# Epoch 106/200 | Time 6.49s | Train loss 1.5062 | Train acc 0.2887 | Val loss 1.5356 | Val acc 0.2746
# Epoch 107/200 | Time 6.07s | Train loss 1.5039 | Train acc 0.3015 | Val loss 1.5474 | Val acc 0.2708
# Epoch 108/200 | Time 6.61s | Train loss 1.4993 | Train acc 0.2985 | Val loss 1.5466 | Val acc 0.2692
# Epoch 109/200 | Time 6.12s | Train loss 1.4987 | Train acc 0.3093 | Val loss 1.5423 | Val acc 0.2777
# Epoch 110/200 | Time 6.68s | Train loss 1.4999 | Train acc 0.3008 | Val loss 1.5389 | Val acc 0.2723
# Epoch 111/200 | Time 6.07s | Train loss 1.5006 | Train acc 0.3052 | Val loss 1.5307 | Val acc 0.2815
# Epoch 112/200 | Time 6.68s | Train loss 1.4971 | Train acc 0.2939 | Val loss 1.5366 | Val acc 0.2762
# Epoch 113/200 | Time 6.02s | Train loss 1.4992 | Train acc 0.2977 | Val loss 1.5403 | Val acc 0.2792
# Epoch 114/200 | Time 6.75s | Train loss 1.5014 | Train acc 0.2952 | Val loss 1.5514 | Val acc 0.2754
# Epoch 115/200 | Time 5.98s | Train loss 1.5004 | Train acc 0.2975 | Val loss 1.5419 | Val acc 0.2631
# Epoch 116/200 | Time 6.67s | Train loss 1.5017 | Train acc 0.2892 | Val loss 1.5485 | Val acc 0.2615
# Epoch 117/200 | Time 5.95s | Train loss 1.4995 | Train acc 0.2902 | Val loss 1.5384 | Val acc 0.2738
# Epoch 118/200 | Time 6.74s | Train loss 1.5001 | Train acc 0.3013 | Val loss 1.5475 | Val acc 0.2731
# Epoch 119/200 | Time 6.08s | Train loss 1.4948 | Train acc 0.2990 | Val loss 1.5444 | Val acc 0.2715
# Epoch 120/200 | Time 6.73s | Train loss 1.4946 | Train acc 0.3008 | Val loss 1.5460 | Val acc 0.2800
# Epoch 121/200 | Time 5.94s | Train loss 1.4965 | Train acc 0.3010 | Val loss 1.5784 | Val acc 0.2669
# Epoch 122/200 | Time 6.65s | Train loss 1.4954 | Train acc 0.2970 | Val loss 1.5295 | Val acc 0.2700
# Epoch 123/200 | Time 6.03s | Train loss 1.4954 | Train acc 0.2977 | Val loss 1.5711 | Val acc 0.2631
# Epoch 124/200 | Time 6.82s | Train loss 1.4940 | Train acc 0.2952 | Val loss 1.5603 | Val acc 0.2715
# Epoch 125/200 | Time 5.95s | Train loss 1.4953 | Train acc 0.2984 | Val loss 1.5514 | Val acc 0.2785
# Epoch 126/200 | Time 6.68s | Train loss 1.4918 | Train acc 0.2980 | Val loss 1.5576 | Val acc 0.2592
# Epoch 127/200 | Time 5.98s | Train loss 1.4922 | Train acc 0.3105 | Val loss 1.5630 | Val acc 0.2715
# Epoch 128/200 | Time 6.79s | Train loss 1.4920 | Train acc 0.2961 | Val loss 1.5644 | Val acc 0.2654
# Epoch 129/200 | Time 5.94s | Train loss 1.4921 | Train acc 0.3007 | Val loss 1.5609 | Val acc 0.2669
# Epoch 130/200 | Time 6.76s | Train loss 1.4927 | Train acc 0.3039 | Val loss 1.5587 | Val acc 0.2746
# Epoch 131/200 | Time 6.00s | Train loss 1.4928 | Train acc 0.3028 | Val loss 1.5658 | Val acc 0.2646
# Epoch 132/200 | Time 6.75s | Train loss 1.4932 | Train acc 0.2977 | Val loss 1.5566 | Val acc 0.2746
# Epoch 133/200 | Time 6.04s | Train loss 1.4905 | Train acc 0.3051 | Val loss 1.5521 | Val acc 0.2615
# Epoch 134/200 | Time 6.71s | Train loss 1.4906 | Train acc 0.2982 | Val loss 1.5818 | Val acc 0.2592
# Epoch 135/200 | Time 5.99s | Train loss 1.4884 | Train acc 0.3064 | Val loss 1.5557 | Val acc 0.2738
# Epoch 136/200 | Time 6.69s | Train loss 1.4896 | Train acc 0.3080 | Val loss 1.5776 | Val acc 0.2638
# Epoch 137/200 | Time 6.02s | Train loss 1.4875 | Train acc 0.3051 | Val loss 1.5555 | Val acc 0.2831
# Epoch 138/200 | Time 6.73s | Train loss 1.4886 | Train acc 0.3052 | Val loss 1.5498 | Val acc 0.2715
# Epoch 139/200 | Time 5.97s | Train loss 1.4835 | Train acc 0.3057 | Val loss 1.5688 | Val acc 0.2638
# Epoch 140/200 | Time 6.52s | Train loss 1.4897 | Train acc 0.3028 | Val loss 1.5547 | Val acc 0.2692
# Epoch 141/200 | Time 6.17s | Train loss 1.4843 | Train acc 0.3046 | Val loss 1.5690 | Val acc 0.2608
# Epoch 142/200 | Time 6.44s | Train loss 1.4861 | Train acc 0.3070 | Val loss 1.5554 | Val acc 0.2692
# Epoch 143/200 | Time 6.29s | Train loss 1.4859 | Train acc 0.2954 | Val loss 1.5629 | Val acc 0.2792
# Epoch 144/200 | Time 6.38s | Train loss 1.4848 | Train acc 0.3049 | Val loss 1.5487 | Val acc 0.2808
# Epoch 145/200 | Time 6.37s | Train loss 1.4854 | Train acc 0.3054 | Val loss 1.5657 | Val acc 0.2638
# Epoch 146/200 | Time 6.35s | Train loss 1.4830 | Train acc 0.3075 | Val loss 1.5440 | Val acc 0.2623
# Epoch 147/200 | Time 6.51s | Train loss 1.4833 | Train acc 0.3049 | Val loss 1.5804 | Val acc 0.2662
# Epoch 148/200 | Time 6.36s | Train loss 1.4832 | Train acc 0.3070 | Val loss 1.5615 | Val acc 0.2669
# Epoch 149/200 | Time 6.64s | Train loss 1.4841 | Train acc 0.3016 | Val loss 1.5825 | Val acc 0.2700
# Epoch 150/200 | Time 6.18s | Train loss 1.4862 | Train acc 0.3030 | Val loss 1.5515 | Val acc 0.2800
# Epoch 151/200 | Time 6.60s | Train loss 1.4810 | Train acc 0.3089 | Val loss 1.5629 | Val acc 0.2723
# Epoch 152/200 | Time 6.20s | Train loss 1.4786 | Train acc 0.3110 | Val loss 1.5488 | Val acc 0.2838
# Epoch 153/200 | Time 6.54s | Train loss 1.4799 | Train acc 0.3010 | Val loss 1.5666 | Val acc 0.2769
# Epoch 154/200 | Time 6.13s | Train loss 1.4792 | Train acc 0.3098 | Val loss 1.5920 | Val acc 0.2731
# Epoch 155/200 | Time 6.66s | Train loss 1.4816 | Train acc 0.2984 | Val loss 1.6128 | Val acc 0.2708
# Epoch 156/200 | Time 6.23s | Train loss 1.4812 | Train acc 0.3036 | Val loss 1.5725 | Val acc 0.2623
# Epoch 157/200 | Time 6.90s | Train loss 1.4802 | Train acc 0.3100 | Val loss 1.5856 | Val acc 0.2685
# Epoch 158/200 | Time 6.00s | Train loss 1.4800 | Train acc 0.3005 | Val loss 1.5885 | Val acc 0.2692
# Epoch 159/200 | Time 6.69s | Train loss 1.4774 | Train acc 0.3133 | Val loss 1.5879 | Val acc 0.2692
# Epoch 160/200 | Time 5.98s | Train loss 1.4773 | Train acc 0.3130 | Val loss 1.5713 | Val acc 0.2554
# Epoch 161/200 | Time 6.76s | Train loss 1.4748 | Train acc 0.3115 | Val loss 1.5594 | Val acc 0.2700
# Epoch 162/200 | Time 5.89s | Train loss 1.4799 | Train acc 0.3008 | Val loss 1.5667 | Val acc 0.2638
# Epoch 163/200 | Time 6.69s | Train loss 1.4782 | Train acc 0.3090 | Val loss 1.5898 | Val acc 0.2585
# Epoch 164/200 | Time 5.98s | Train loss 1.4776 | Train acc 0.3020 | Val loss 1.5560 | Val acc 0.2769
# Epoch 165/200 | Time 6.74s | Train loss 1.4747 | Train acc 0.3020 | Val loss 1.5916 | Val acc 0.2738
# Epoch 166/200 | Time 6.03s | Train loss 1.4771 | Train acc 0.3072 | Val loss 1.5576 | Val acc 0.2677
# Epoch 167/200 | Time 6.78s | Train loss 1.4724 | Train acc 0.3146 | Val loss 1.5740 | Val acc 0.2685
# Epoch 168/200 | Time 6.03s | Train loss 1.4724 | Train acc 0.3066 | Val loss 1.5793 | Val acc 0.2669
# Epoch 169/200 | Time 6.81s | Train loss 1.4743 | Train acc 0.3125 | Val loss 1.5889 | Val acc 0.2746
# Epoch 170/200 | Time 5.93s | Train loss 1.4730 | Train acc 0.3089 | Val loss 1.5724 | Val acc 0.2569
# Epoch 171/200 | Time 6.75s | Train loss 1.4743 | Train acc 0.3115 | Val loss 1.5693 | Val acc 0.2677
# Epoch 172/200 | Time 5.99s | Train loss 1.4703 | Train acc 0.3174 | Val loss 1.5782 | Val acc 0.2592
# Epoch 173/200 | Time 6.76s | Train loss 1.4713 | Train acc 0.3159 | Val loss 1.5545 | Val acc 0.2815
# Epoch 174/200 | Time 5.92s | Train loss 1.4755 | Train acc 0.3066 | Val loss 1.5923 | Val acc 0.2715
# Epoch 175/200 | Time 6.75s | Train loss 1.4714 | Train acc 0.3180 | Val loss 1.5839 | Val acc 0.2723
# Epoch 176/200 | Time 5.97s | Train loss 1.4727 | Train acc 0.2979 | Val loss 1.5867 | Val acc 0.2708
# Epoch 177/200 | Time 6.65s | Train loss 1.4703 | Train acc 0.3110 | Val loss 1.5916 | Val acc 0.2662
# Epoch 178/200 | Time 5.98s | Train loss 1.4706 | Train acc 0.3141 | Val loss 1.5883 | Val acc 0.2792
# Epoch 179/200 | Time 6.71s | Train loss 1.4716 | Train acc 0.3085 | Val loss 1.5805 | Val acc 0.2831
# Epoch 180/200 | Time 6.06s | Train loss 1.4717 | Train acc 0.3051 | Val loss 1.5789 | Val acc 0.2746
# Epoch 181/200 | Time 6.67s | Train loss 1.4722 | Train acc 0.3084 | Val loss 1.5875 | Val acc 0.2608
# Epoch 182/200 | Time 5.98s | Train loss 1.4711 | Train acc 0.3033 | Val loss 1.5792 | Val acc 0.2654
# Epoch 183/200 | Time 6.66s | Train loss 1.4673 | Train acc 0.3093 | Val loss 1.5802 | Val acc 0.2700
# Epoch 184/200 | Time 6.09s | Train loss 1.4705 | Train acc 0.3121 | Val loss 1.5987 | Val acc 0.2769
# Epoch 185/200 | Time 6.84s | Train loss 1.4702 | Train acc 0.3151 | Val loss 1.5775 | Val acc 0.2585
# Epoch 186/200 | Time 6.20s | Train loss 1.4692 | Train acc 0.3152 | Val loss 1.5727 | Val acc 0.2708
# Epoch 187/200 | Time 6.55s | Train loss 1.4666 | Train acc 0.3146 | Val loss 1.5717 | Val acc 0.2869
# Epoch 188/200 | Time 6.16s | Train loss 1.4672 | Train acc 0.3156 | Val loss 1.5873 | Val acc 0.2746
# Epoch 189/200 | Time 6.36s | Train loss 1.4690 | Train acc 0.3089 | Val loss 1.5977 | Val acc 0.2746
# Epoch 190/200 | Time 6.41s | Train loss 1.4636 | Train acc 0.3116 | Val loss 1.5768 | Val acc 0.2638
# Epoch 191/200 | Time 6.38s | Train loss 1.4660 | Train acc 0.3200 | Val loss 1.5676 | Val acc 0.2746
# Epoch 192/200 | Time 6.52s | Train loss 1.4669 | Train acc 0.3146 | Val loss 1.5990 | Val acc 0.2723
# Epoch 193/200 | Time 6.17s | Train loss 1.4655 | Train acc 0.3185 | Val loss 1.6125 | Val acc 0.2569
# Epoch 194/200 | Time 6.61s | Train loss 1.4664 | Train acc 0.3108 | Val loss 1.5855 | Val acc 0.2723
# Epoch 195/200 | Time 6.25s | Train loss 1.4658 | Train acc 0.3070 | Val loss 1.5927 | Val acc 0.2754
# Epoch 196/200 | Time 6.57s | Train loss 1.4664 | Train acc 0.3074 | Val loss 1.5879 | Val acc 0.2669
# Epoch 197/200 | Time 6.13s | Train loss 1.4648 | Train acc 0.3075 | Val loss 1.5981 | Val acc 0.2746
# Epoch 198/200 | Time 6.63s | Train loss 1.4664 | Train acc 0.3166 | Val loss 1.5907 | Val acc 0.2738
# Epoch 199/200 | Time 6.05s | Train loss 1.4631 | Train acc 0.3197 | Val loss 1.5769 | Val acc 0.2738
# Epoch 200/200 | Time 6.76s | Train loss 1.4617 | Train acc 0.3197 | Val loss 1.5973 | Val acc 0.2746
# Training finished. Best epoch: 73. Best monitored metric: 0.2908
# Final model saved to: /content/drive/MyDrive/PainRecognitionProject/models/testing_new_code_sta_lstm_5_classes_300_coord.pt
# Best model saved to: /content/drive/MyDrive/PainRecognitionProject/models/best_testing_new_code_sta_lstm_5_classes_300_coord.pt

# %%
trainer.plot_history()

# %% [markdown]
# #### Evaluate

# %%
model.load_state_dict(torch.load(best_model_path, map_location=DEVICE), strict=False)
# Out:
# <All keys matched successfully>

# %%
evaluator = Evaluator(model, test_loader, device=DEVICE, model_name=model_name, num_classes=NUM_CLASSES)

# %%
loss, acc, labels, preds = evaluator.evaluate_epoch()
# Out:
# ==================================================
# WYNIKI OCENY DLA MODELU: testing_new_code_sta_lstm_5_classes_300_coord.pt
# ==================================================
# Test Loss: 1.5484
# Test Accuracy: 0.3062
#
# --- Szczegółowy Raport Klasyfikacji ---
#               precision    recall  f1-score   support
#
#      Klasa 0       0.26      0.71      0.38       260
#      Klasa 1       0.31      0.08      0.13       260
#      Klasa 2       0.20      0.10      0.13       260
#      Klasa 3       0.26      0.12      0.16       260
#      Klasa 4       0.48      0.53      0.50       260
#
#     accuracy                           0.31      1300
#    macro avg       0.30      0.31      0.26      1300
# weighted avg       0.30      0.31      0.26      1300
#
# ==================================================
# Confusion matrix:
#  [[184  20  25  20  11]
#  [163  22  25  30  20]
#  [162   7  25  24  42]
#  [114   7  32  30  77]
#  [ 78  15  19  11 137]]
